# %% [markdown]
# # Notebook for generating predictions from a model

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Config

# %%
model_path = "./good_models/pegasus-large-submission-30/"
model_class = 'google/pegasus-large'

# %% [markdown]
# ## Load resources

# %%
from transformers import BartForConditionalGeneration, PegasusForConditionalGeneration

#model = BartForConditionalGeneration.from_pretrained(model_path)
model = PegasusForConditionalGeneration.from_pretrained(model_path)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# PegasusForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(96103, 1024, padding_idx=0)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): BartSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): Identity()
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): BartSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): Identity()
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=96103, bias=False)
# )

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_class)

# %%
from model import SpainAICollator

collator = SpainAICollator(tokenizer, model)

# %%
from data import load_data

train, val, test = load_data()

# %% [markdown]
# ## Generate predictions for test data

# %%
from model import generate_names
from postprocessing import save_submission

# %%
names = generate_names(model, tokenizer, collator, test["description"], batchsize=4)

# %%
names
# Out:
# [['knit dress with lace',
#   'lace dress',
#   'knit dress',
#   'lace dress trf',
#   'knit dress trf',
#   'printed dress trf',
#   'lace knit dress',
#   'limited edition knit dress',
#   'contrast knit dress',
#   'ribbed dress trf'],
#  ['printed dress',
#   'printed dress trf',
#   'pleated dress trf',
#   'pleated dress',
#   'floral print dress',
#   'loose-fitting dress',
#   'polka dot print dress',
#   'poplin dress',
#   'flowing dress trf',
#   'satin dress trf'],
#  ['nautical cap',
#   'nautical cap with peak',
#   'peak nautical cap',
#   'nautical cap trf',
#   'limited edition nautical cap',
#   'cap with peak',
#   'nautical cap with bow',
#   'marine cap with peak',
#   'printed nautical cap',
#   'striped nautical cap'],
#  ['nautical cap',
#   'nautical cap trf',
#   'nautical cap with peak',
#   'limited edition nautical cap',
#   'nautical cap with bow',
#   'printed nautical cap',
#   'nautical cap with strap',
#   'embroidered nautical cap',
#   'striped nautical cap',
#   'sporty nautical cap'],
#  ['nautical cap',
#   'nautical cap with buttons',
#   'nautical cap with button',
#   'nautical cap trf',
#   'limited edition nautical cap',
#   'printed nautical cap',
#   'striped nautical cap',
#   'embroidered nautical cap',
#   'button nautical cap',
#   'buttoned nautical cap'],
#  ['t-shirt with front print',
#   'printed t-shirt',
#   't-shirt with print',
#   'animal print t-shirt',
#   't-shirt with text',
#   'zara t-shirt',
#   'colour block t-shirt',
#   'mickey mouse t-shirt',
#   'striped t-shirt',
#   'faded print t-shirt'],
#  ['coat with faux suede',
#   'faux suede coat',
#   'textured coat',
#   'houndstooth coat',
#   'double-faced coat',
#   'coat with faux shearling',
#   'check coat',
#   'coat with contrast collar',
#   'textured coat trf',
#   'textured faux suede coat'],
#  ['ripped t-shirt',
#   'ripped t-shirt trf',
#   't-shirt with rips',
#   'ribbed t-shirt',
#   'ribbed t-shirt trf',
#   't-shirt with ripped sleeves',
#   'striped t-shirt trf',
#   't-shirt with ripped detail',
#   't-shirt trf',
#   'striped t-shirt'],
#  ['printed top trf',
#   'fitted top trf',
#   'fitted top',
#   'knit top trf',
#   'ribbed top trf',
#   'polyamide top trf',
#   'textured top trf',
#   'knit top',
#   'cropped top trf',
#   'wide-leg top'],
#  ['printed top trf',
#   'fitted top trf',
#   'fitted top',
#   'knit top trf',
#   'ribbed top trf',
#   'polyamide top trf',
#   'textured top trf',
#   'knit top',
#   'cropped top trf',
#   'wide-leg top'],
#  ['printed top trf',
#   'fitted top trf',
#   'fitted top',
#   'knit top trf',
#   'ribbed top trf',
#   'polyamide top trf',
#   'textured top trf',
#   'knit top',
#   'cropped top trf',
#   'wide-leg top'],
#  ['printed top trf',
#   'knit top',
#   'fitted top trf',
#   'knit top trf',
#   'printed top',
#   'fitted top',
#   'ribbed top trf',
#   'cropped top trf',
#   'textured top trf',
#   'top trf'],
#  ['knit top trf',
#   'printed top trf',
#   'textured top trf',
#   'fitted top trf',
#   'knit top',
#   'fitted vest top',
#   'cropped top trf',
#   'ribbed top trf',
#   'textured top',
#   'printed vest top'],
#  ['printed top trf',
#   'knit top',
#   'fitted top trf',
#   'knit top trf',
#   'printed top',
#   'fitted top',
#   'ribbed top trf',
#   'cropped top trf',
#   'textured top trf',
#   'top trf'],
#  ['fitted top trf',
#   'printed top trf',
#   'fitted top',
#   'ribbed top trf',
#   'knit top trf',
#   'cropped top trf',
#   'textured top trf',
#   'top with wide straps',
#   'stretch top trf',
#   'knit top'],
#  ['printed dress',
#   'printed dress trf',
#   'poplin dress',
#   'asymmetric dress trf',
#   'asymmetric poplin dress',
#   'asymmetric dress',
#   'floral print dress',
#   'ruffled dress trf',
#   'ruffled dress',
#   'asymmetric printed dress'],
#  ['striped knit sweater',
#   'striped sweater',
#   'striped sweater trf',
#   'contrast knit sweater',
#   'contrast sweater trf',
#   'contrast sweater',
#   'contrast striped sweater',
#   'knit sweater',
#   'sweater with side stripes',
#   'sweater with contrast stripes'],
#  ['bucket hat',
#   'bucket hat with band',
#   'bucket hat trf',
#   'bucket hat with bands',
#   'limited edition bucket hat',
#   'hat with band',
#   'knit bucket hat',
#   'hat with band detail',
#   'striped bucket hat',
#   'band bucket hat'],
#  ['fine knit sweater',
#   'textured sweater',
#   'textured knit sweater',
#   'loose-fitting sweater',
#   'cable-knit sweater',
#   'textured sweater trf',
#   'knit sweater',
#   'contrast knit sweater',
#   'striped knit sweater',
#   'knit sweater trf'],
#  ['knit sweater',
#   'textured sweater',
#   'loose-fitting sweater',
#   'textured knit sweater',
#   'knit sweater trf',
#   'cable-knit sweater',
#   'textured sweater trf',
#   'basic knit sweater',
#   'striped knit sweater',
#   'long knit sweater'],
#  ['knit turtleneck sweater',
#   'textured knit sweater',
#   'cable-knit sweater',
#   'knit sweater',
#   'textured knit turtleneck sweater',
#   'loose-fitting sweater',
#   'basic knit sweater',
#   'long knit sweater',
#   'knit sweater trf',
#   'textured turtleneck sweater'],
#  ['high neck sweater',
#   'high neck knit sweater',
#   'knit sweater',
#   'textured sweater',
#   'cable-knit sweater',
#   'loose-fitting sweater',
#   'knit sweater trf',
#   'textured knit sweater',
#   'textured sweater trf',
#   'oversized sweater trf'],
#  ['faux fur bomber jacket',
#   'contrast faux fur jacket',
#   'contrast faux shearling jacket',
#   'faux shearling jacket',
#   'quilted jacket',
#   'faux shearling bomber jacket',
#   'faux fur jacket',
#   'faux fur puffer jacket',
#   'quilted jacket trf',
#   'contrast bomber jacket'],
#  ['straight cut coat',
#   'straight coat',
#   'houndstooth coat',
#   'textured coat',
#   'coat with pockets',
#   'faux fur coat',
#   'faux shearling coat',
#   'check coat',
#   'high collar coat',
#   'combined coat'],
#  ['faux shearling coat',
#   'faux fur coat',
#   'double-faced coat',
#   'coat with matching collar',
#   'coat with contrast collar',
#   'houndstooth coat',
#   'textured coat',
#   'high collar coat',
#   'coat with high collar',
#   'coat with removable collar'],
#  ['straight cut coat',
#   'straight coat',
#   'houndstooth coat',
#   'textured coat',
#   'coat with pockets',
#   'faux shearling coat',
#   'faux fur coat',
#   'check coat',
#   'high collar coat',
#   'combined coat'],
#  ['straight fit coat',
#   'textured coat',
#   'double-faced coat',
#   'coat with raised collar',
#   'houndstooth coat',
#   'faux shearling coat',
#   'check coat',
#   'raised lapel collar coat',
#   'textured coat trf',
#   'faux fur coat'],
#  ['ribbed t-shirt',
#   't-shirt with piping',
#   'ribbed t-shirt with piping',
#   'ribbed t-shirt trf',
#   'textured t-shirt',
#   'plain t-shirt',
#   'plain t-shirt with piping',
#   'straight fit t-shirt',
#   'plain t-shirt trf',
#   'textured t-shirt with piping'],
#  ['straight fit t-shirt',
#   'ribbed t-shirt',
#   'ribbed t-shirt trf',
#   'textured t-shirt',
#   'plain t-shirt',
#   'short sleeve t-shirt',
#   'v-neck t-shirt',
#   'striped t-shirt',
#   'basic t-shirt',
#   'basic t-shirt trf'],
#  ['t-shirt with text',
#   't-shirt with print',
#   'animal print t-shirt',
#   'printed t-shirt',
#   'colour block t-shirt',
#   'striped t-shirt',
#   't-shirt with contrast print',
#   't-shirt with slogan',
#   'colour block print t-shirt',
#   'printed t-shirt trf'],
#  ['ribbed t-shirt',
#   'textured t-shirt',
#   'plain t-shirt',
#   'long sleeve t-shirt',
#   'striped t-shirt',
#   't-shirt with slogan',
#   'basic t-shirt',
#   't-shirt',
#   't-shirt trf',
#   'printed t-shirt'],
#  ['ribbed beanie',
#   'ribbed beanie with slogan',
#   'ribbed hat with slogan',
#   'ribbed beanie trf',
#   'ribbed beanie with label',
#   'slogan ribbed beanie',
#   'ribbed slogan beanie',
#   'ribbed hat',
#   'beanie with slogan',
#   'limited edition ribbed beanie'],
#  ['knit sweater',
#   'cable-knit sweater',
#   'knit sweater trf',
#   'textured sweater',
#   'textured knit sweater',
#   'knit sweater with vents',
#   'contrast knit sweater',
#   'textured sweater trf',
#   'striped knit sweater',
#   'ribbed sweater trf'],
#  ['knit sweater',
#   'cable-knit sweater',
#   'knit sweater trf',
#   'textured sweater',
#   'textured knit sweater',
#   'knit sweater with vents',
#   'contrast knit sweater',
#   'textured sweater trf',
#   'striped knit sweater',
#   'ribbed sweater trf'],
#  ['belt with golden buckle',
#   'golden buckle belt',
#   'stretch belt',
#   'stretch belt with buckle',
#   'golden buckle stretch belt',
#   'gold buckle belt',
#   'buckle belt',
#   'belt with buckle',
#   'limited edition stretch belt',
#   'metallic buckle belt'],
#  ['wide belt',
#   'wide belt with chain',
#   'double buckle belt',
#   'wide belt trf',
#   'chain belt',
#   'belt with chain',
#   'wide belt with chains',
#   'belt with double buckle',
#   'limited edition wide belt',
#   'double buckle wide belt'],
#  ['jogging trousers',
#   'trousers with slogan print',
#   'trousers with slogan',
#   'jogging trousers with slogan',
#   'sporty trousers',
#   'slogan trousers',
#   'slogan jogger trousers',
#   'slogan jogger waist trousers',
#   'ribbed trousers with slogan',
#   'slogan print trousers'],
#  ['slogan trousers',
#   'jogging trousers',
#   'sporty trousers',
#   'trousers with slogan',
#   'slogan jogger trousers',
#   'jogger waist trousers',
#   'printed trousers',
#   'slogan jogging trousers',
#   'plush trousers',
#   'slogan print trousers'],
#  ['ribbed t-shirt',
#   'textured t-shirt',
#   'plain t-shirt',
#   'plain t-shirt trf',
#   'printed t-shirt',
#   'striped t-shirt',
#   'basic t-shirt',
#   'ribbed t-shirt trf',
#   'short sleeve t-shirt',
#   't-shirt with slogan'],
#  ['faux leather trousers',
#   'wide-leg trousers',
#   'cargo trousers trf',
#   'cropped trousers trf',
#   'trousers with side pockets',
#   'loose-fitting trousers',
#   'textured trousers trf',
#   'flared trousers trf',
#   'slouchy trousers trf',
#   'textured trousers'],
#  ['printed dress trf',
#   'pleated dress trf',
#   'printed dress',
#   'flowing dress trf',
#   'voluminous dress trf',
#   'midi dress trf',
#   'satin dress trf',
#   'mini dress trf',
#   'cropped dress trf',
#   'knit dress trf'],
#  ['loose-fitting jumpsuit',
#   'jumpsuit with gathered detail',
#   'jumpsuit with contrast belt',
#   'jumpsuit with belt',
#   'gathered jumpsuit',
#   'printed jumpsuit trf',
#   'gathered jumpsuit trf',
#   'printed jumpsuit',
#   'belted jumpsuit trf',
#   'belted jumpsuit'],
#  ['pack of fujifilm instax mini 9 camera',
#   'fujifilm instax mini 9 camera',
#   'fujifilm mini 9 camera (pack of 3)',
#   '3-pack of fujifilm instax mini 9 camera',
#   'instax mini 9 camera (pack of 3)',
#   'fujifilm instax mini 9 camera pack',
#   'fujifilm instax mini camera (pack of 3)',
#   '3-pack of fujifilm instax mini 9 cameras',
#   'fujifilm instax mini 9 camera (3x10)',
#   'pack with fujifilm instax mini 9 camera'],
#  ['asymmetric dress with belt',
#   'asymmetric dress trf',
#   'asymmetric dress',
#   'dress with belt',
#   'belted dress trf',
#   'printed dress trf',
#   'belted dress',
#   'pleated dress with belt',
#   'printed dress',
#   'pleated dress trf'],
#  ['faux fur jacket trf',
#   'faux shearling jacket trf',
#   'faux fur bomber jacket',
#   'faux leather jacket trf',
#   'faux fur jacket',
#   'faux shearling jacket',
#   'faux fur biker jacket',
#   'jacket with faux fur lining',
#   'belted jacket trf',
#   'faux fur puffer jacket'],
#  ['faux shearling jacket',
#   'flared jacket trf',
#   'cropped jacket trf',
#   'jacket with shoulder pads',
#   'flared jacket',
#   'cropped jacket',
#   'faux leather jacket',
#   'padded jacket trf',
#   'shoulder pads jacket',
#   'padded jacket'],
#  ['henley sweater',
#   'knit henley sweater',
#   'textured henley sweater',
#   'ribbed henley sweater',
#   'striped henley sweater',
#   'long knit henley sweater',
#   'henley sweater trf',
#   'basic henley sweater',
#   'knitted henley sweater',
#   'limited edition henley sweater'],
#  ['bejewelled jacket',
#   'bejewelled fringe jacket',
#   'bejewelled denim jacket',
#   'bejewelled cropped jacket',
#   'bejewelled biker jacket',
#   'bejewelled puffer jacket',
#   'bejewelled fringed jacket',
#   'cropped jacket trf',
#   'bejewelled bomber jacket',
#   'fringed jacket trf'],
#  ['printed dress trf',
#   'belted dress',
#   'belted dress trf',
#   'printed dress',
#   'faux leather dress',
#   'satin dress with belt',
#   'dress with belt',
#   'denim dress trf',
#   'pleated dress trf',
#   'midi dress trf'],
#  ['join lifecare leggings',
#   'ecologically grown cotton leggings',
#   'join lifecare cotton leggings',
#   'join lifecare fibre leggings',
#   'join lifecare fiber leggings',
#   'join lifecare fibers leggings',
#   'ecologically grown leggings',
#   'join lifecare® leggings',
#   'cotton leggings',
#   'join lifecare technical leggings'],
#  ['knit sweater',
#   'cable-knit sweater',
#   'textured sweater',
#   'textured knit sweater',
#   'basic knit sweater',
#   'knit sweater trf',
#   'long knit sweater',
#   'textured sweater trf',
#   'striped knit sweater',
#   'plain knit sweater'],
#  ['textured knit sweater',
#   'knit sweater',
#   'wool blend sweater',
#   'knit sweater trf',
#   'cable-knit sweater',
#   'wool blend knit sweater',
#   'textured wool blend sweater',
#   'merino wool blend sweater',
#   'basic knit sweater',
#   'striped knit sweater'],
#  ['textured suit blazer',
#   'textured blazer',
#   'check blazer',
#   'textured check blazer',
#   'blazer with buttons',
#   'buttoned blazer',
#   'check suit blazer',
#   'houndstooth blazer',
#   'faux leather blazer',
#   'faux suede blazer'],
#  ['zw premium ‘80s skinny jeans',
#   'the ‘80s skinny bering blue jeans',
#   '‘80s skinny bering blue jeans',
#   'bering blue ‘80s skinny jeans',
#   'zw premium ‘80s bering blue jeans',
#   'zw premium ‘80s skinny bering blue',
#   'zw premium ‘80s skinny jeans trf',
#   'the ‘80s skinny jeans',
#   'the ‘80s skinny jeans bering blue',
#   'bering blue jeans'],
#  ['t-shirt with asymmetric hem',
#   'asymmetric t-shirt',
#   'textured t-shirt',
#   'ribbed t-shirt',
#   'asymmetric t-shirt trf',
#   'striped t-shirt',
#   'contrast t-shirt',
#   'short sleeve t-shirt',
#   'plain t-shirt',
#   't-shirt with contrast hem'],
#  ['t-shirt with asymmetric hem',
#   'asymmetric t-shirt',
#   'asymmetric t-shirt trf',
#   'textured t-shirt',
#   'ribbed t-shirt',
#   't-shirt with contrast hem',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'striped t-shirt',
#   'striped t-shirt trf'],
#  ['t-shirt with asymmetrical hem',
#   't-shirt with asymmetric hem',
#   'asymmetric t-shirt',
#   'asymmetric t-shirt trf',
#   'textured t-shirt',
#   'striped t-shirt trf',
#   't-shirt with contrast hem',
#   'ribbed t-shirt',
#   'striped t-shirt',
#   'textured t-shirt trf'],
#  ['ecologically grown cotton t-shirt',
#   'cotton t-shirt',
#   'ecological cotton t-shirt',
#   'ecologically grown t-shirt',
#   't-shirt with asymmetrical hem',
#   'eco cotton t-shirt',
#   't-shirt with contrast hem',
#   'ecological t-shirt',
#   'ecological grown cotton t-shirt',
#   't-shirt with asymmetric hem'],
#  ['plain t-shirt',
#   'textured t-shirt',
#   'ribbed t-shirt',
#   'plain t-shirt trf',
#   'basic t-shirt trf',
#   'basic t-shirt',
#   'short sleeve t-shirt',
#   't-shirt with slogan',
#   't-shirt',
#   'textured t-shirt trf'],
#  ['large hoop earrings',
#   'hoop earrings',
#   'limited edition hoop earrings',
#   'small hoop earrings',
#   'large earrings',
#   'medium hoop earrings',
#   'long hoop earrings',
#   'large hoop earring',
#   'wide hoop earrings',
#   'oversized hoop earrings'],
#  ['2-pack of hoop earrings',
#   'pack of hoop earrings',
#   'pack of contrasting hoop earrings',
#   '2-pack of contrasting hoop earrings',
#   '2-pack of mini hoop earrings',
#   'two-pack of hoop earrings',
#   '2-pack of small hoop earrings',
#   '2-pack of plain hoop earrings',
#   '2-pack of earrings',
#   'pack of double hoop earrings'],
#  ['textured scarf',
#   'fringed scarf',
#   'textured scarf with fringing',
#   'textured scarf trf',
#   'fringed scarf trf',
#   'scarf with fringed edges',
#   'textured scarf with fringe',
#   'limited edition fringed scarf',
#   'limited edition textured scarf',
#   'textured knit scarf'],
#  ['pleated skirt',
#   'pleated skirt trf',
#   'pleated midi skirt',
#   'printed skirt trf',
#   'limited edition pleated skirt',
#   'printed skirt',
#   'faux leather skirt',
#   'floral print skirt',
#   'midi skirt trf',
#   'ribbed skirt trf'],
#  ['ribbed t-shirt',
#   'textured t-shirt',
#   'v-neck t-shirt',
#   'short sleeve t-shirt',
#   'ribbed t-shirt trf',
#   't-shirt with slogan',
#   'striped t-shirt',
#   'basic t-shirt trf',
#   'plain t-shirt',
#   'plain t-shirt trf'],
#  ['ribbed t-shirt',
#   'textured t-shirt',
#   'v-neck t-shirt',
#   'short sleeve t-shirt',
#   'ribbed t-shirt trf',
#   't-shirt with slogan',
#   'striped t-shirt',
#   'basic t-shirt trf',
#   'plain t-shirt',
#   'plain t-shirt trf'],
#  ['ribbed t-shirt',
#   'textured t-shirt',
#   'v-neck t-shirt',
#   'striped t-shirt',
#   't-shirt',
#   'short sleeve t-shirt',
#   't-shirt with short sleeves',
#   't-shirt trf',
#   'ribbed t-shirt trf',
#   'plain t-shirt'],
#  ['ruffled top',
#   'ruffled top trf',
#   'printed top trf',
#   'contrast top trf',
#   'contrast top',
#   'poplin top',
#   'top with contrasting ruffle',
#   'top with contrast ruffle',
#   'contrasting top trf',
#   'printed top'],
#  ['round earrings',
#   'fabric earrings',
#   'earrings with fabric',
#   'round fabric earrings',
#   'limited edition earrings',
#   'textured earrings',
#   'metal earrings',
#   'floral earrings',
#   'round hoop earrings',
#   'plain earrings'],
#  ['jumpsuit with belt',
#   'belted jumpsuit trf',
#   'belted jumpsuit',
#   'printed jumpsuit trf',
#   'faux leather jumpsuit',
#   'denim jumpsuit with belt',
#   'printed jumpsuit',
#   'denim jumpsuit trf',
#   'striped jumpsuit with belt',
#   'denim jumpsuit'],
#  ['knit sweater',
#   'knit sweater trf',
#   'basic knit sweater',
#   'long knit sweater',
#   'striped knit sweater',
#   'textured knit sweater',
#   'cable-knit sweater',
#   'plain knit sweater',
#   'textured sweater',
#   'straight knit sweater'],
#  ['plain t-shirt',
#   'textured t-shirt',
#   'ribbed t-shirt',
#   'plain t-shirt trf',
#   'basic t-shirt trf',
#   'basic t-shirt',
#   'short sleeve t-shirt',
#   't-shirt with slogan',
#   't-shirt',
#   'textured t-shirt trf'],
#  ['halter bodysuit',
#   'halter bodysuit trf',
#   'ribbed bodysuit trf',
#   'bodysuit trf',
#   'camisole bodysuit',
#   'halter neck bodysuit',
#   'printed bodysuit trf',
#   'ribbed bodysuit',
#   'bodysuit with snap buttons',
#   'snap-button bodysuit'],
#  ['t-shirt with front print',
#   'contrast print t-shirt',
#   't-shirt with contrast print',
#   'mickey mouse t-shirt',
#   'printed t-shirt',
#   'animal print t-shirt',
#   't-shirt with print',
#   'animal t-shirt',
#   'slogan t-shirt',
#   'tiger t-shirt'],
#  ['faux shearling jacket',
#   'faux leather jacket',
#   'faux shearling bomber jacket',
#   'basic puffer jacket',
#   'faux fur bomber jacket',
#   'faux suede jacket',
#   'faux shearling puffer jacket',
#   'quilted jacket',
#   'faux suede bomber jacket',
#   'plush jacket'],
#  ['double-breasted trench coat',
#   'trench coat with belt',
#   'belted trench coat',
#   'faux leather trench coat',
#   'double-faced trench coat',
#   'faux shearling trench coat',
#   'check trench coat',
#   'limited edition trench coat',
#   'houndstooth trench coat',
#   'belted trench coat trf'],
#  ['faux shearling jacket',
#   'tailored jacket',
#   'tailored jacket trf',
#   'hooded jacket trf',
#   'tailored jacket with hood',
#   'faux shearling puffer jacket',
#   'cropped jacket trf',
#   'faux shearling bomber jacket',
#   'quilted jacket trf',
#   'limited edition tailored jacket'],
#  ['knit sweater',
#   'knit sweater trf',
#   'long knit sweater',
#   'ribbed sweater trf',
#   'v-neck sweater',
#   'cable-knit sweater',
#   'textured sweater trf',
#   'ribbed sweater',
#   'jacquard sweater trf',
#   'textured knit sweater'],
#  ['knit sweater',
#   'knit sweater trf',
#   'long knit sweater',
#   'ribbed sweater trf',
#   'v-neck sweater',
#   'cable-knit sweater',
#   'textured sweater trf',
#   'ribbed sweater',
#   'jacquard sweater trf',
#   'textured knit sweater'],
#  ['snoopy ® peanuts plush jogging trousers',
#   'snoopy ® peanuts jogging trousers',
#   'snoopy ® peanuts jogger trousers',
#   'plush snoopy ® peanuts jogging trousers',
#   'snoopy ® peanuts plush jersey joggers',
#   'snoopy ® peanuts joggers',
#   'snoopy ® peanuts jersey jogging trousers',
#   'snoopy ®peanuts jogging trousers',
#   'snoopy ® peanuts plush trousers',
#   'snoopy ® peanuts plush jogger trousers'],
#  ['z1975 slim fit jeans',
#   'slim fit jeans',
#   'slim fit jeans trf',
#   'zw premium slim fit jeans',
#   'z1975 slim fit skinny jeans',
#   'z1975 skinny jeans',
#   'slim fit z1975 jeans',
#   'slim fit jeans with zips',
#   'faded slim fit jeans',
#   'z1975 loose-fitting jeans'],
#  ['contrast top',
#   'pleated top',
#   'contrast top trf',
#   'pleated top trf',
#   'top with contrast sleeves',
#   'printed top trf',
#   'printed top',
#   'cropped top trf',
#   'poplin top',
#   'floral print top'],
#  ['poplin shirt',
#   'super slim poplin shirt',
#   'poplin shirt trf',
#   'limited edition poplin shirt',
#   'stretch poplin shirt',
#   'striped poplin shirt',
#   'oversized poplin shirt',
#   'textured poplin shirt',
#   'basic poplin shirt',
#   'printed poplin shirt'],
#  ['super slim fit shirt',
#   'striped super slim fit shirt',
#   'slim fit shirt trf',
#   'super slim fit printed shirt',
#   'super slim fit striped shirt',
#   'super slim fit knit shirt',
#   'super slim fit textured shirt',
#   'super slim fit check shirt',
#   'super slim fit denim shirt',
#   'super slim-fit shirt'],
#  ['embroidered dress',
#   'embroidered dress trf',
#   'embroidered dress with tassels',
#   'embroidered mini dress',
#   'embroidered poplin dress',
#   'printed dress trf',
#   'limited edition embroidered dress',
#   'embroidered tulle dress',
#   'embroidery dress trf',
#   'contrast embroidered dress'],
#  ['down puffer jacket',
#   'down puffer jacket with slogan',
#   'slogan down puffer jacket',
#   'rubberised down puffer jacket',
#   'sporty down puffer jacket',
#   'puffer jacket with slogan',
#   'down puffer jacket trf',
#   'hooded down puffer jacket',
#   'contrast down puffer jacket',
#   'faux shearling down puffer jacket'],
#  ['high neck sweater',
#   'knit sweater',
#   'knit sweater with buttons',
#   'cable-knit sweater',
#   'sweater with buttons',
#   'high neck knit sweater',
#   'textured knit sweater',
#   'textured sweater',
#   'sweater with metal buttons',
#   'knit sweater trf'],
#  ['linen blend blazer',
#   'linen blend suit blazer',
#   'linen blend check blazer',
#   'textured linen blend blazer',
#   'linen blazer',
#   'check blazer',
#   'linen blend textured blazer',
#   'textured linen blazer',
#   'basic linen blend blazer',
#   'buttoned blazer'],
#  ['slim fit linen trousers',
#   'slim fit trousers',
#   'linen blend trousers',
#   'linen blend jogging trousers',
#   'linen blend suit trousers',
#   'slim fit cargo trousers',
#   'linen blend cargo trousers',
#   'slim fit suit trousers',
#   'slim fit corduroy trousers',
#   'basic linen blend trousers'],
#  ['wool blend sweater',
#   'high neck sweater',
#   'knit sweater',
#   'knit sweater trf',
#   'cable-knit sweater',
#   'wool blend knit sweater',
#   'high neck knit sweater',
#   'ribbed sweater trf',
#   'textured wool blend sweater',
#   'knit sweater with vents'],
#  ['star carrycot baby wrap',
#   'star print carrycot baby wrap',
#   'star print carrycot',
#   'carrycot baby wrap',
#   'star baby wrap',
#   'star carrycot',
#   'carrycot with star print',
#   'carrycot baby wrap with stars',
#   'baby wrap with star print',
#   'stars carrycot baby wrap'],
#  ['faux shearling coat',
#   'coat with contrast collar',
#   'faux fur coat',
#   'double-faced coat',
#   'coat with matching collar',
#   'coat with removable collar',
#   'houndstooth coat',
#   'contrast coat',
#   'textured coat',
#   'coat with faux shearling'],
#  ['cropped trousers',
#   'cropped trousers trf',
#   'slim fit trousers',
#   'cropped jogger waist trousers',
#   'slim fit cropped trousers',
#   'cropped trousers with pockets',
#   'cropped slim fit trousers',
#   'limited edition cropped trousers',
#   'textured cropped trousers',
#   'cropped chino trousers'],
#  ['zw premium high waist revolve black jeans',
#   'z1975 high waist revolve black jeans',
#   'the high waist revolve black jeans',
#   'zw premium high rise revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium slim revolve black jeans',
#   'zw premium revolve black high waist jeans',
#   'zw premium revolve black skinny jeans',
#   'z1975 high-rise revolve black jeans',
#   'z1975 high rise revolve black jeans'],
#  ['zw premium revolve black skinny jeans',
#   'zw premium revolve black jeans',
#   'zw premium skinny revolve black jeans',
#   'zw premium high waist revolve black jeans',
#   'zw premium slim revolve black jeans',
#   'the high waist revolve black skinny jeans',
#   'the high waist revolve black jeans',
#   'zw premium super soft revolve black jeans',
#   'z1975 high waist revolve black jeans',
#   'z1975 high rise revolve black skinny jeans'],
#  ['zw premium high waist revolve black jeans',
#   'z1975 high waist revolve black jeans',
#   'the high waist revolve black jeans',
#   'zw premium high rise revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium slim revolve black jeans',
#   'zw premium revolve black high waist jeans',
#   'zw premium revolve black skinny jeans',
#   'z1975 high-rise revolve black jeans',
#   'z1975 high rise revolve black jeans'],
#  ['slogan t-shirt',
#   't-shirt with slogan',
#   't-shirt with front slogan',
#   't-shirt with front print',
#   'mickey mouse t-shirt',
#   'printed t-shirt',
#   'animal t-shirt with slogan',
#   't-shirt with slogan print',
#   'colour block t-shirt',
#   'plain t-shirt with slogan'],
#  ['sequinned dress',
#   'sequinned dress trf',
#   'sequinned mini dress',
#   'sequinned midi dress',
#   'sequinned poplin dress',
#   'contrast sequinned dress',
#   'sequinned tulle dress',
#   'limited edition sequinned dress',
#   'sequinned surplice dress',
#   'sequin dress trf'],
#  ['nautical cap',
#   'nautical cap with peak',
#   'peak nautical cap',
#   'nautical cap trf',
#   'limited edition nautical cap',
#   'cap with peak',
#   'nautical cap with bow',
#   'marine cap with peak',
#   'printed nautical cap',
#   'striped nautical cap'],
#  ['asymmetric skirt trf',
#   'asymmetric skirt',
#   'printed skirt trf',
#   'midi skirt trf',
#   'pleated skirt trf',
#   'faux leather skirt',
#   'printed skirt',
#   'denim skirt trf',
#   'belted skirt trf',
#   'textured skirt trf'],
#  ['coat with contrast collar',
#   'contrast coat',
#   'faux shearling coat',
#   'double-faced coat',
#   'coat with contrasting collar',
#   'faux fur coat',
#   'contrast coat trf',
#   'combined coat',
#   'high collar coat',
#   'houndstooth coat'],
#  ['knit sweater',
#   'knit sweater trf',
#   'cable-knit sweater',
#   'long knit sweater',
#   'textured sweater',
#   'textured sweater trf',
#   'ribbed sweater trf',
#   'textured knit sweater',
#   'basic knit sweater',
#   'striped knit sweater'],
#  ['textured bermuda shorts',
#   'textured bermuda shorts trf',
#   'textured bermuda shorts with pockets',
#   'textured denim bermuda shorts',
#   'textured fabric bermuda shorts',
#   'textured cargo bermuda shorts',
#   'textured print bermuda shorts',
#   'textured bermudas',
#   'textured bermuda shorts with zip',
#   'textured cotton bermuda shorts'],
#  ['printed dress trf',
#   'printed dress',
#   'floral print dress',
#   'flowing dress trf',
#   'midi dress trf',
#   'satin dress trf',
#   'polka dot print dress',
#   'flowing dress',
#   'pleated dress trf',
#   'poplin dress'],
#  ['faux shearling parka',
#   'contrast faux shearling parka',
#   'contrast parka',
#   'parka with faux shearling lining',
#   'parka with contrast faux shearling',
#   'parka with contrast lining',
#   'faux shearling parka trf',
#   'contrasting faux shearling parka',
#   'limited edition faux shearling parka',
#   'contrast parka with faux shearling'],
#  ['textured shirt',
#   'striped shirt',
#   'regular fit shirt',
#   'textured check shirt',
#   'basic shirt',
#   'poplin shirt',
#   'animal print shirt',
#   'floral print shirt',
#   'check shirt',
#   'printed shirt'],
#  ['textured trousers',
#   'jogging trousers',
#   'cargo trousers',
#   'jogger waist trousers',
#   'satin trousers',
#   'trousers with pockets',
#   'floral print trousers',
#   'plush trousers',
#   'faux leather trousers',
#   'loose fit trousers'],
#  ['plush leggings trf',
#   'leggings with pockets',
#   'faux leather leggings',
#   'textured leggings',
#   'plush leggings',
#   'textured leggings trf',
#   'ribbed leggings trf',
#   'printed leggings trf',
#   'faux shearling leggings',
#   'leggings trf'],
#  ['printed blouse',
#   'contrast blouse',
#   'printed blouse trf',
#   'flowing blouse',
#   'floral print blouse',
#   'blouse with contrast lining',
#   'flowing blouse trf',
#   'polka dot print blouse',
#   'blouse with contrast fabric',
#   'contrast blouse trf'],
#  ['diagonal tie',
#   'jacquard skinny tie',
#   'silk skinny tie',
#   'diagonal silk tie',
#   'diagonal jacquard skinny tie',
#   'diagonal jacquard tie',
#   'silk jacquard skinny tie',
#   'diagonal knotted tie',
#   'silk tie',
#   'diagonal textured tie'],
#  ['zw premium skinny sunrise blue jeans',
#   'zw premium sunrise blue skinny jeans',
#   'zw premium high waist skinny sunrise blue jeans',
#   'the high waist skinny in sunrise blue jeans',
#   'zw premium high rise skinny sunrise blue jeans',
#   'zw premium high waist sunrise blue skinny jeans',
#   'zw premium sunrise blue jeans',
#   'the high waist skinny sunrise blue jeans',
#   'zw premium high-rise skinny jeans',
#   'zw premium high waist skinny jeans'],
#  ['the high waist revolve black trousers',
#   'the high waist in revolve black trousers',
#   'zw premium skinny revolve black trousers',
#   'zw premium revolve high waist trousers',
#   'zw premium skinny high waist trousers',
#   'zw premium high waist revolve trousers',
#   'shirred high waist trousers',
#   'zw premium high waist trousers',
#   'the high waist in revolve black',
#   'zw premium revolve black trousers'],
#  ['double-breasted coat',
#   'wool blend coat',
#   'double-faced coat',
#   'textured wool blend coat',
#   'textured coat',
#   'combined wool blend coat',
#   'coat with pockets',
#   'check coat',
#   'long wool blend coat',
#   'faux shearling coat'],
#  ['linen blend shirt',
#   'linen/cotton shirt',
#   'linen shirt',
#   'basic linen shirt',
#   'striped linen shirt',
#   'regular fit linen shirt',
#   'regular fit shirt',
#   'textured shirt',
#   'limited edition linen shirt',
#   'plain linen shirt'],
#  ['shirt with contrast trims',
#   'striped shirt trf',
#   'contrast shirt',
#   'contrast shirt trf',
#   'printed shirt trf',
#   'striped shirt',
#   'textured shirt trf',
#   'shirt with contrasting trims',
#   'cropped shirt trf',
#   'printed shirt'],
#  ['trousers with shiny thread',
#   'shiny thread trousers',
#   'pleated trousers',
#   'satin trousers',
#   'loose-fitting trousers',
#   'shiny thread bow trousers',
#   'trousers with shiny bow',
#   'satin trousers with bow',
#   'metallic thread trousers',
#   'trousers with bow'],
#  ['metallic thread trousers',
#   'pleated trousers',
#   'trousers with bow',
#   'textured trousers',
#   'satin trousers',
#   'houndstooth trousers',
#   'printed trousers',
#   'trousers with bows',
#   'faux leather trousers',
#   'cargo trousers'],
#  ['double-breasted jacket',
#   'jacket with contrast buttons',
#   'faux shearling jacket',
#   'double breasted jacket',
#   'shawl collar jacket',
#   'jacket with shawl collar',
#   'textured jacket trf',
#   'cropped jacket trf',
#   'textured jacket',
#   'jacket with contrasting buttons'],
#  ['sequinned trousers',
#   'sequinned flared trousers',
#   'flared trousers',
#   'sequin trousers',
#   'flared trousers with sequins',
#   'flared trousers trf',
#   'sequinned trousers trf',
#   'sequin trousers trf',
#   'flared trousers with sequin detail',
#   'flared trousers with sequin'],
#  ['high-rise trousers',
#   'cropped trousers trf',
#   'slouchy trousers trf',
#   'pleated trousers trf',
#   'knit trousers trf',
#   'textured trousers trf',
#   'trousers trf',
#   'cargo trousers trf',
#   'high rise trousers',
#   'printed trousers trf'],
#  ['jumpsuit with belt',
#   'belted jumpsuit',
#   'faux leather jumpsuit',
#   'belted jumpsuit trf',
#   'contrast jumpsuit',
#   'printed jumpsuit',
#   'striped jumpsuit with belt',
#   'satin jumpsuit with belt',
#   'printed jumpsuit trf',
#   'denim jumpsuit with belt'],
#  ['contrast knit dress',
#   'knit dress',
#   'knit dress trf',
#   'printed dress trf',
#   'contrast dress',
#   'printed dress',
#   'contrasting knit dress',
#   'ruffled knit dress',
#   'contrast dress trf',
#   'knit dress with ruffles'],
#  ['thermo-sealed puffer jacket',
#   'water-repellent puffer jacket',
#   'hooded puffer jacket',
#   'puffer jacket',
#   'puffer jacket trf',
#   'double-faced puffer jacket',
#   'hooded puffer jacket trf',
#   'faux shearling puffer jacket',
#   'colour block puffer jacket',
#   'faux suede puffer jacket'],
#  ['faux leather jacket',
#   'faux leather bomber jacket',
#   'faux leather biker jacket',
#   'basic faux leather jacket',
#   'faux leather puffer jacket',
#   'textured faux leather jacket',
#   'contrast faux leather jacket',
#   'ribbed faux leather jacket',
#   'faux suede jacket',
#   'reversible faux leather jacket'],
#  ['overshirt with pockets',
#   'rolled-up overshirt',
#   'corduroy overshirt',
#   'textured overshirt',
#   'check overshirt',
#   'oversized overshirt',
#   'oversized overshirt trf',
#   'corduroy overshirt trf',
#   'textured overshirt trf',
#   'oversized check overshirt'],
#  ['belted trousers',
#   'trousers with belt',
#   'faux leather trousers',
#   'belted trousers trf',
#   'wide-leg trousers',
#   'cargo trousers with belt',
#   'check trousers',
#   'check trousers with belt',
#   'loose-fitting trousers',
#   'limited edition belted trousers'],
#  ['belted trousers',
#   'belted trousers trf',
#   'trousers with belt',
#   'faux leather trousers',
#   'wide-leg trousers',
#   'pleated trousers with belt',
#   'loose-fitting trousers',
#   'limited edition belted trousers',
#   'trousers with buckled belt',
#   'pleated trousers'],
#  ['water-repellent parka',
#   'water-repellent padded parka',
#   'water-repellent parka trf',
#   'thermore® parka',
#   'water-repellent parka with pockets',
#   'parka with thermore® insulation',
#   'water-repellent parka with hood',
#   'lightweight water-repellent parka',
#   'water repellent parka',
#   'limited edition water-repellent parka'],
#  ['3-pack of panda briefs',
#   'three-pack of panda briefs',
#   'panda briefs (pack of 3)',
#   'pack of panda briefs',
#   '3-pack of panda print briefs',
#   '3-pack of plush panda briefs',
#   '3-pack of printed panda briefs',
#   '2-pack of panda briefs',
#   '3-pack of pandas briefs',
#   '3-pack of panda plush briefs'],
#  ['loose-fitting coat',
#   'textured coat',
#   'faux shearling coat',
#   'houndstooth coat',
#   'oversized coat',
#   'oversized coat trf',
#   'faux fur coat',
#   'textured coat trf',
#   'limited edition coat',
#   'coat with pockets'],
#  ['lace dress',
#   'printed dress trf',
#   'lace dress trf',
#   'printed dress',
#   'pleated dress trf',
#   'velvet dress trf',
#   'polka dot print dress',
#   'dress with velvet tape',
#   'combined dress trf',
#   'velvet dress'],
#  ['oversized shirt trf',
#   'oversized shirt',
#   'textured shirt trf',
#   'textured shirt',
#   'oversize shirt trf',
#   'cropped shirt trf',
#   'printed shirt trf',
#   'oversized poplin shirt',
#   'striped shirt trf',
#   'poplin shirt'],
#  ['feather t-shirt',
#   'feather print t-shirt',
#   't-shirt with feather appliqués',
#   'feather t-shirt with appliqués',
#   'feather t-shirt trf',
#   't-shirt with feather print',
#   't-shirt with feather appliqué',
#   'feather print t-shirt trf',
#   't-shirt with feather appliques',
#   't-shirt with feather embroidery'],
#  ['feather t-shirt',
#   'feather print t-shirt',
#   't-shirt with feather appliqués',
#   'feather t-shirt with appliqués',
#   'feather t-shirt trf',
#   't-shirt with feather print',
#   't-shirt with feather appliqué',
#   'feather print t-shirt trf',
#   't-shirt with feather appliques',
#   't-shirt with feather embroidery'],
#  ['t-shirt with front print',
#   'contrast print t-shirt',
#   't-shirt with contrast print',
#   'animal print t-shirt',
#   'mickey mouse t-shirt',
#   'printed t-shirt',
#   't-shirt with print',
#   'animal t-shirt',
#   'slogan t-shirt',
#   'front print t-shirt'],
#  ['zw premium ‘80s high waist skinny jeans',
#   'zw premium ‘80s high waist jeans',
#   'zw premium ‘80s skinny old blue jeans',
#   'zw premium ‘80s old blue skinny jeans',
#   'zw premium ‘80s skinny jeans',
#   'zw premium ‘80s old blue jeans',
#   "zw premium '80s high waist skinny jeans",
#   '‘80s high waist skinny jeans',
#   '‘80s high waist old blue skinny jeans',
#   "zw premium '80s high waist jeans"],
#  ['knit dress with ruffles',
#   'knit dress',
#   'floral print dress',
#   'printed dress trf',
#   'ruffled knit dress',
#   'knit dress trf',
#   'printed dress',
#   'poplin dress',
#   'polka dot knit dress',
#   'polka dot print dress'],
#  ['chino trousers with cord',
#   'textured chino trousers',
#   'basic chino trousers',
#   'corduroy chino trousers',
#   'limited edition chino trousers',
#   'trousers with lobster clasp',
#   'chino trousers',
#   'trousers with multicoloured cord',
#   'rustic chino trousers',
#   'faux leather chino trousers'],
#  ['animal print leather boots trf',
#   'animal print leather high heel boots',
#   'animal print slouchy boots trf',
#   'animal print high heel boots trf',
#   'animal print leather boots',
#   'animal print high heel boots',
#   'animal print leather high-heel boots',
#   'leather high heel boots with animal print',
#   'slouchy animal print leather boots trf',
#   'animal print slouchy leather boots trf'],
#  ['giraffe crossbody bag',
#   'mini giraffe crossbody bag',
#   'giraffe-shaped crossbody bag',
#   'giraffe crossbody bag trf',
#   'crossbody bag with mini giraffe',
#   'limited edition giraffe crossbody bag',
#   'crossbody bag with giraffe',
#   'giraffe crossbody bag with accessory',
#   'crossbody bag with giraffes',
#   'giraffe crossbody bag with tassel'],
#  ['animal print ankle boots trf',
#   'animal print high heel ankle boots trf',
#   'animal print ankle boots',
#   'animal print mid-heel ankle boots',
#   'animal print stiletto ankle boots trf',
#   'animal print high-heel ankle boots',
#   'animal print heeled ankle boots trf',
#   'animal print high heel ankle boots',
#   'animal print mid heel ankle boots trf',
#   'animal print animal print ankle boots trf'],
#  ['mesh high-heel ankle boots trf',
#   'high-heel mesh ankle boots trf',
#   'high-heel ankle boots with mesh',
#   'high heel mesh ankle boots trf',
#   'mesh high heel ankle boots trf',
#   'mesh high-heel ankle boots',
#   'shiny mesh high-heel ankle boots',
#   'shiny high-heel ankle boots trf',
#   'shiny mesh ankle boots trf',
#   'high-heel ankle boots with shiny mesh'],
#  ['animal print high-heel shoes trf',
#   'animal print high-heel shoes',
#   'animal print high heel shoes trf',
#   'asymmetric snakeskin high-heel shoes trf',
#   'animal print high-heels trf',
#   'animal print stilettos trf',
#   'animal print heeled shoes trf',
#   'animal print high-heel sneakers trf',
#   'animal print high heeled shoes trf',
#   'snakeskin high-heel shoes trf'],
#  ['high-heel shoes with vinyl detail',
#   'vinyl high-heel shoes trf',
#   'high-heel shoes with transparent vinyl',
#   'vinyl high-heel shoes',
#   'high-heel shoes with vinyl',
#   'metallic high-heel shoes trf',
#   'combined high-heel shoes trf',
#   'metallic high-heel shoes',
#   'contrast high-heel shoes trf',
#   'high-heel shoes with vinyl details'],
#  ['metallic leather heeled shoes',
#   'metallic suede heeled shoes',
#   'metallic heeled leather shoes',
#   'metallic heeled shoes',
#   'suede heeled shoes',
#   'studded leather heeled shoes',
#   'metallic heeled shoes trf',
#   'suede heeled shoes trf',
#   'leather heeled shoes',
#   'metallic stiletto heeled shoes'],
#  ['vinyl mid-heel mules',
#   'vinyl mid-heel mules trf',
#   'mid-heel vinyl mules trf',
#   'vinyl high-heel mules trf',
#   'mid-heel vinyl mules',
#   'vinyl mules with faux patent finish',
#   'vinyl high-heel mules',
#   'vinyl high heel mules trf',
#   'contrast vinyl mid-heel mules',
#   'contrast mid-heel mules trf'],
#  ['suede high-heel mules trf',
#   'high-heel mules trf',
#   'suede high-heel mules',
#   'high heel mules trf',
#   'leather high-heel mules trf',
#   'high-heel mules',
#   'high-heel suede mules trf',
#   'high-heel mules with leather',
#   'suede high heel mules trf',
#   'high-heel mules with leather detail'],
#  ['asymmetric high-heel sandals trf',
#   'rhinestone high-heel sandals trf',
#   'asymmetric high-heel sandals',
#   'asymmetric high heel sandals trf',
#   'studded high-heel sandals trf',
#   'asymmetric strappy sandals trf',
#   'high-heel sandals with rhinestone strap',
#   'rhinestone heeled sandals trf',
#   'strappy sandals with rhinestone strap trf',
#   'rhinestone high-heel sandals'],
#  ['velvet platform sandals trf',
#   'velvet high heel sandals trf',
#   'high heel velvet sandals trf',
#   'velvet high heel sandals',
#   'velvet platform sandals',
#   'high heel velvet sandals',
#   'high heel sandals trf',
#   'velvet platform high heel sandals',
#   'knotted high heel sandals trf',
#   'platform sandals with knot trf'],
#  ['leather mini wedges trf',
#   'leather mini wedges',
#   'leather mini wedge sandals trf',
#   'buckled leather mini wedges trf',
#   'mini leather wedges trf',
#   'leather mini wedges with track soles',
#   'leather wedges trf',
#   'buckled leather mini wedges',
#   'leather wedges with track soles',
#   'leather mini wedge trf'],
#  ['diamanté leather high-heel sandals',
#   'black leather high-heel sandals',
#   'leather high-heel sandals',
#   'leather high-heel sandals trf',
#   'black leather high-heel sandals trf',
#   'blue leather high-heel sandals trf',
#   'high-heel leather sandals trf',
#   'premium leather high-heel sandals',
#   'limited edition leather high-heel sandals',
#   'blue leather high-heel sandals'],
#  ['jute high heel mules trf',
#   'jute high heel mules',
#   'high heel mules with frayed knot',
#   'frayed knot mules trf',
#   'knotted high heel mules trf',
#   'jute mules trf',
#   'jute high heel mules with knot',
#   'natural high heel mules trf',
#   'knotted mules trf',
#   'jute high-heel mules'],
#  ['mid-heel mules trf',
#   'mid heel mules trf',
#   'asymmetric mules trf',
#   'asymmetric mid heel mules trf',
#   'asymmetric high heel mules trf',
#   'asymmetric heeled mules trf',
#   'asymmetric heel mules trf',
#   'high heel mules trf',
#   'strappy mules trf',
#   'mid block heel mules trf'],
#  ['plaited heeled sandals trf',
#   'plaited sandals trf',
#   'plaited heeled sandals',
#   'combined heeled sandals trf',
#   'combined plaited sandals trf',
#   'heeled sandals with plaited strap',
#   'braided heeled sandals trf',
#   'plaited strappy sandals trf',
#   'combined high-heel sandals trf',
#   'plaited sandals'],
#  ['piggy-shaped bad',
#   'sheep piggy-shaped bad',
#   'piggy-shaped bad.',
#   'piggy-shaped bad bag',
#   'piggy and sheep bad christmas decoration',
#   'sheep print piggy-shaped bad',
#   'piggy-shaped bad book',
#   'sheep-shaped piggy-shaped bad',
#   'piggy-shaped bad christmas decoration',
#   'sheep piggy-shaped bad.'],
#  ['contrast sneakers trf',
#   'chunky sneakers trf',
#   'white sneakers trf',
#   'combined sneakers trf',
#   'contrasting sneakers trf',
#   'sneakers with chunky soles',
#   'white sneakers',
#   'sneakers trf',
#   'textured sneakers trf',
#   'contrast sneakers'],
#  ['cotton lunch bag',
#   'lunch bag',
#   'lunch bag with zip',
#   'lunch bag trf',
#   '100% cotton lunch bag',
#   'lunch bag with handles',
#   'plain cotton lunch bag',
#   'soft cotton lunch bag',
#   'printed lunch bag',
#   'premium cotton lunch bag'],
#  ['leather loafers',
#   'leather loafers trf',
#   'gathered seam leather loafers',
#   'limited edition leather loafers',
#   'black leather loafers',
#   'heeled leather loafers',
#   'studded loafers trf',
#   'faux leather loafers',
#   'loafers with gathered seam',
#   'loafers with gathered seams'],
#  ['cotton backpack',
#   'cotton backpack with ears',
#   'faux shearling backpack',
#   'quilted backpack',
#   'faux shearling cotton backpack',
#   'backpack with ears',
#   'cotton backpack trf',
#   'backpack with faux shearling',
#   'limited edition cotton backpack',
#   'plush backpack'],
#  ['die-cut flat shoes',
#   'flat shoes',
#   'die-cut shoes trf',
#   'die-cut shoes',
#   'flat shoes trf',
#   'die cut flat shoes trf',
#   'flat shoes with die cut detail',
#   'flat shoes die-cut',
#   'die cut flat shoes',
#   'flat shoes with die cut sole'],
#  ['flat slingback shoes',
#   'flat slingback shoes trf',
#   'flat slingback shoes with cage',
#   'slingback shoes with cage',
#   'flat slingback shoes with cage straps',
#   'flat slingback shoes with straps',
#   'slingback shoes with pointed toes',
#   'slingback shoes with cage straps',
#   'slingback shoes with pointed toe',
#   'slingback shoes'],
#  ['dog crossbody bag',
#   'faux fur dog crossbody bag',
#   'dog crossbody bag trf',
#   'dog faux fur crossbody bag',
#   'faux fur crossbody bag',
#   'dog crossbody bag with zip',
#   'dog-shaped crossbody bag',
#   'faux dog crossbody bag',
#   'animal crossbody bag trf',
#   'animal crossbody bag'],
#  ['animal print leather heeled sandals',
#   'animal print heeled sandals',
#   'animal print leather sandals',
#   'animal print leather high-heel sandals',
#   'animal print leather kitten heel sandals',
#   'animal print leather kitten-heel sandals',
#   'heeled animal print leather sandals',
#   'animal print heeled sandals trf',
#   'animal print leather kitten heeled sandals',
#   'animal print high-heel sandals'],
#  ['leather cowboy flat sandals trf',
#   'cowboy flat leather sandals trf',
#   'cowboy leather flat sandals trf',
#   'flat cowboy leather sandals trf',
#   'flat cowboy sandals trf',
#   'flat leather cowboy sandals trf',
#   'flat leather sandals with buckles',
#   'flat leather sandals trf',
#   'flat leather sandals',
#   'cowboy flat leather sandals'],
#  ['leather high-heel ankle boots trf',
#   'high-heel leather ankle boots trf',
#   'leather cowboy heel ankle boots trf',
#   'leather cowboy ankle boots',
#   'leather cowboy heel ankle boots',
#   'leather cowboy high-heel ankle boots trf',
#   'leather high-heel ankle boots',
#   'leather cowboy ankle boots trf',
#   'high-heel leather ankle boots',
#   'contrast leather high-heel ankle boots trf'],
#  ['animal print leather heeled boots',
#   'animal print heeled boots',
#   'leather heeled boots with animal print',
#   'animal print leather boots',
#   'animal print leather high-heel boots',
#   'animal print heeled boots trf',
#   'heeled leather boots with animal print',
#   'animal print leather boots trf',
#   'animal print leather high heel boots',
#   'heeled boots with animal print'],
#  ['leather high-heel boots trf',
#   'high heel leather boots trf',
#   'high-heel leather boots trf',
#   'high heel boots trf',
#   'leather high heel boots trf',
#   'high-heel boots trf',
#   'leather high-heel boots',
#   'high-heel boots with platform soles',
#   'leather high heel boots',
#   'block high heel boots trf'],
#  ['split suede leather ankle boots',
#   'brown leather ankle boots',
#   'leather ankle boots',
#   'split suede ankle boots',
#   'brown split suede ankle boots',
#   'low-cut leather ankle boots',
#   'brown split suede leather ankle boots',
#   'split suede ankle boots trf',
#   'leather ankle boots with seams',
#   'brown leather ankle boots trf'],
#  ['leather desert boots',
#   'lace-up desert boots',
#   'soft leather desert boots',
#   'soft leather boots',
#   'desert boots',
#   'desert boots with eyelets',
#   'leather desert boots with eyelets',
#   'leather boots',
#   'leather boots with eyelets',
#   'leather desert boots trf'],
#  ['block heel ankle boots trf',
#   'mid-heel ankle boots trf',
#   'ankle boots with block heel trf',
#   'high heel ankle boots trf',
#   'round heel ankle boots trf',
#   'high-heel ankle boots trf',
#   'mid heel ankle boots trf',
#   'round-heel ankle boots trf',
#   'ankle boots trf',
#   'round block heel ankle boots trf'],
#  ['technical high-top sneakers',
#   'laceless high-top sneakers',
#   'sock-style sneakers trf',
#   'high-top sneakers trf',
#   'black high-top sneakers',
#   'high-top sneakers',
#   'sock-style sneakers',
#   'laceless sneakers',
#   'black laceless sneakers',
#   'technical laceless sneakers'],
#  ['camouflage high-top sneakers',
#   'high-top sneakers',
#   'contrast high-top sneakers',
#   'animal print sneakers trf',
#   'animal print sneakers',
#   'black high-top sneakers',
#   'chunky high-top sneakers',
#   'zara high top sneakers',
#   'high top sneakers trf',
#   'animal print high top sneakers'],
#  ['split suede ankle boots trf',
#   'split suede high heel ankle boots trf',
#   'split suede high-heel ankle boots',
#   'leather high-heel ankle boots trf',
#   'split suede heeled ankle boots trf',
#   'split suede leather ankle boots trf',
#   'split suede ankle boots',
#   'split suede high-heel boots trf',
#   'split suede block heel ankle boots trf',
#   'split suede high heel ankle boots'],
#  ['high-heel ankle boots trf',
#   'high heel ankle boots trf',
#   'contrast high heel ankle boots trf',
#   'contrast ankle boots trf',
#   'high-heel ankle boots',
#   'contrast high-heel ankle boots',
#   'block heel ankle boots trf',
#   'contrast heeled ankle boots trf',
#   'contrasting high heel ankle boots trf',
#   'lined ankle boots trf'],
#  ['stretch ankle boots trf',
#   'heeled ankle boots trf',
#   'ankle boots trf',
#   'heeled ankle boots',
#   'high heel ankle boots trf',
#   'stretch heeled ankle boots',
# ...
#   'patterned wool cushion cover',
#   'cushion cover',
#   'striped wool cushion cover',
#   'cushion cover with zip',
#   'textured wool cushion cover',
#   'contrast wool cushion cover',
#   'textured cushion cover',
#   'knit cushion cover'],
#  ['double-sided blanket',
#   'check blanket',
#   'double blanket',
#   'double check blanket',
#   'double blanket with check',
#   'check blanket trf',
#   'checked blanket',
#   'two-sided blanket',
#   'blanket with check design',
#   'check blanket with fleece'],
#  ['tartan cushion',
#   'decorative cushion',
#   'decorative tartan cushion',
#   'tartan print cushion',
#   'printed cushion',
#   'tartan decorative cushion',
#   'faux tartan cushion',
#   'textured cushion',
#   'cushion with tartan',
#   'cushion'],
#  ['tartan cushion cover',
#   'dark tartan cushion cover',
#   'dark print cushion cover',
#   'cushion cover with tartan',
#   'tartan print cushion cover',
#   'dark textured cushion cover',
#   'black tartan cushion cover',
#   'tartan cushion',
#   'printed cushion cover',
#   'contrast tartan cushion cover'],
#  ['dear santa cushion',
#   'dear santa christmas cushion',
#   'dear santa slogan christmas cushion',
#   'dear santa slogan cushion',
#   'dear santa rectangular christmas cushion',
#   'dear christmas cushion',
#   'dear santa cushion trf',
#   'dear santa santa cushion',
#   'dear santa rectangular cushion',
#   'dear santa round cushion'],
#  ['towel with metallic thread',
#   'towel with jacquard border',
#   'towel with geometric border',
#   'oyster towel',
#   'jacquard towel',
#   'towel with geometric jacquard',
#   'metallic thread towel',
#   'towel with geometric print',
#   'cotton towel',
#   'oyster white towel'],
#  ['towel with metallic thread',
#   'towel with jacquard border',
#   'towel with geometric border',
#   'oyster towel',
#   'jacquard towel',
#   'towel with geometric jacquard',
#   'metallic thread towel',
#   'towel with geometric print',
#   'cotton towel',
#   'oyster white towel'],
#  ['lacquered hanger',
#   'lacquered wood hanger',
#   'lacquered trousers hanger',
#   'lacquered wooden hanger',
#   'lacquered hanger with bar',
#   'wooden hanger',
#   'wood hanger',
#   'wooden hanger with bar',
#   'lacquered wood trousers hanger',
#   'wood hanger with bar'],
#  ['lacquered hanger',
#   'lacquered skirt hanger',
#   'lacquered hanger with clips',
#   'lacquered wood hanger',
#   'wooden hanger',
#   'lacquered wooden hanger',
#   'wooden skirt hanger',
#   'wood hanger',
#   'wooden hanger with clips',
#   'skirt hanger'],
#  ['hanger (pack of 2)',
#   'hanger (set of 2)',
#   'wooden hanger (pack of 2)',
#   'metal hanger (pack of 2)',
#   'aluminium hanger (pack of 2)',
#   'metal hanger (set of 2)',
#   'wooden hanger (set of 2)',
#   'aluminum hanger (pack of 2)',
#   'bar hanger (pack of 2)',
#   'hanger with wooden bar and clips'],
#  ['hanger (pack of 2)',
#   'hanger (set of 2)',
#   'wooden hanger (pack of 2)',
#   'metal hanger (pack of 2)',
#   'hanger with wooden bar',
#   'wooden hanger (set of 2)',
#   'aluminium hanger (pack of 2)',
#   'hangers (pack of 2)',
#   'clothes hanger (pack of 2)',
#   'bar hanger (pack of 2)'],
#  ['faux fur blanket',
#   'super soft blanket',
#   'soft faux fur blanket',
#   'blanket with faux fur',
#   'textured faux fur blanket',
#   'plush blanket',
#   'fluffy blanket',
#   'soft-touch blanket',
#   'super plush blanket',
#   'soft blanket'],
#  ['metal skirt hangers',
#   'set of metal skirt hangers',
#   'set of skirt hangers',
#   'skirt hangers',
#   'set of hanger skirt hangers',
#   'metal skirt hanger set',
#   'metal skirt hanger',
#   'set of mini skirt hangers',
#   'skirt hanger set',
#   'limited edition skirt hangers'],
#  ['padded hanger (pack of 4)',
#   'iron hanger (pack of 4)',
#   'padded iron hanger (pack of 4)',
#   'linen hanger (pack of 4)',
#   'embroidered hanger (pack of 4)',
#   'hanger (pack of 4)',
#   'lined iron hanger (pack of 4)',
#   'rustic iron hanger (pack of 4)',
#   'linen padded hanger (pack of 4)',
#   'iron hanger with tassel'],
#  ['metal hanger',
#   'hanger with notches',
#   'hanger',
#   'garment hanger',
#   'ribbed hanger',
#   'tie hanger',
#   'metal shirt hanger',
#   'metal garment hanger',
#   'limited edition hanger',
#   'hangers with notches'],
#  ['oversized t-shirt',
#   'oversized cotton jersey t-shirt',
#   'cotton jersey t-shirt',
#   'oversized t-shirt trf',
#   'oversized jersey t-shirt',
#   'oversize cotton jersey t-shirt',
#   'oversized cotton t-shirt',
#   'plain cotton jersey t-shirt',
#   'striped cotton jersey t-shirt',
#   'textured t-shirt'],
#  ['cotton jersey trousers',
#   'straight-leg trousers',
#   'straight leg trousers',
#   'cotton jersey jogging trousers',
#   'basic cotton jersey trousers',
#   'plain cotton jersey trousers',
#   'straight cotton jersey trousers',
#   'loose-fitting trousers',
#   'striped cotton jersey trousers',
#   'cotton jersey jogger trousers'],
#  ['cotton jersey dressing gown',
#   'long cotton dressing gown',
#   'long jersey dressing gown',
#   'long dressing gown',
#   'cotton dressing gown',
#   'long linen dressing gown',
#   'linen dressing gown',
#   'printed dressing gown',
#   'limited edition dressing gown',
#   'long knit dressing gown'],
#  ['cotton jersey dress',
#   'printed dress trf',
#   'ribbed dress trf',
#   'plain cotton jersey dress',
#   'knit dress trf',
#   'printed dress',
#   'jersey dress',
#   'jersey dress trf',
#   'striped cotton jersey dress',
#   'pleated dress trf'],
#  ['cotton jersey shirt',
#   'striped cotton jersey shirt',
#   'plain cotton jersey shirt',
#   'basic cotton jersey shirt',
#   'cotton shirt with pocket',
#   'cotton shirt',
#   'v-neck shirt',
#   'printed shirt',
#   'plain cotton shirt',
#   'premium cotton jersey shirt'],
#  ['leggings',
#   'leggings with pockets',
#   'knit leggings',
#   'textured leggings',
#   'leggings trf',
#   'ribbed leggings',
#   'faux leather leggings',
#   'printed leggings',
#   'basic leggings',
#   'plain leggings'],
#  ['tartan flannel trousers',
#   'flannel trousers',
#   'flannel trousers with tartan',
#   'tartan print flannel trousers',
#   'tartan trousers',
#   'flannel trousers with print',
#   'trousers with tartan print',
#   'plaid flannel trousers',
#   'check flannel trousers',
#   'textured flannel trousers'],
#  ['tartan flannel eye mask',
#   'flannel eye mask',
#   'flannel tartan eye mask',
#   'tartan print flannel eye mask',
#   'flannel eye mask with tartan',
#   'flannel print eye mask',
#   'flannel and tartan eye mask',
#   'grey flannel eye mask',
#   'tartan flannel eyes mask',
#   'flannel tartan print eye mask'],
#  ['tartan flannel shirt',
#   'flannel shirt with tartan',
#   'flannel shirt',
#   'tartan shirt',
#   'flannel shirt with print',
#   'shirt with tartan print',
#   'plaid flannel shirt',
#   'striped flannel shirt',
#   'tartan print flannel shirt',
#   'printed flannel shirt'],
#  ['men’s flannel pyjamas',
#   'men’s tartan pyjamas',
#   'men’s pyjamas',
#   "men's flannel pyjamas",
#   "men's tartan pyjamas",
#   'flannel pyjamas with tartan print',
#   'tartan pyjamas',
#   'flannel pyjamas',
#   'men’s flannel set',
#   'men’s plaid pyjamas'],
#  ['washed linen fitted sheet',
#   'plain washed linen fitted sheet',
#   'wash linen fitted sheet',
#   'linen fitted sheet',
#   'basic washed linen fitted sheet',
#   'plain wash linen fitted sheet',
#   'fitted sheet (160 g)',
#   'striped washed linen fitted sheet',
#   'fitted sheet with elastic corners',
#   'washed linen fitted sheet.'],
#  ['lamp with resin base',
#   'resin lamp',
#   'lamp',
#   'lamp with base',
#   'lamp with fabric lampshade',
#   'resin lamp with lampshade',
#   'lampshade lamp',
#   'resin base lamp',
#   'resin lamp trf',
#   'lamp trf'],
#  ['striped towel',
#   'towel with striped border',
#   'striped cotton towel',
#   'stripe towel',
#   'multicoloured stripe towel',
#   'towel with stripe border',
#   'towel with stripes',
#   'towel with stripe',
#   'striped towel with border',
#   'cotton towel with stripe'],
#  ['cotton pouffe',
#   'pouffe',
#   'plain cotton pouffe',
#   'pouffe with pocket',
#   'printed pouffe',
#   'pouffe with strap',
#   'plain pouffe',
#   'limited edition pouffe',
#   'ribbed pouffe',
#   'striped cotton pouffe'],
#  ['lamp with wooden base',
#   'lamp',
#   'wooden lamp',
#   'wooden and glass lamp',
#   'lamp with glass lampshade',
#   'lamp with base',
#   'glass lamp',
#   'lamp with wood base',
#   'wooden lamp with lampshade',
#   'wood and glass lamp'],
#  ['methacrylate side table',
#   'methacrylate table',
#   'side table with methacrylate',
#   'u methacrylate side table',
#   'side table',
#   'metal methacrylate side table',
#   'methacrylate storage table',
#   'u-shaped side table',
#   'rectangular methacrylate side table',
#   'foldable methacrylate side table'],
#  ['faceted tray',
#   'faceted mirror tray',
#   'mirror tray',
#   'mirrored tray',
#   'square mirror tray',
#   'tray with faceted mirror',
#   'faceted tray with handles',
#   'square tray with mirror',
#   'rectangular mirror tray',
#   'square tray'],
#  ['night set',
#   'bubble-effect night set',
#   'bubble night set',
#   'bottle and tumbler night set',
#   'night set with bubbles',
#   'night set with bubble effect',
#   'glow bottle and tumbler set',
#   'glow night set',
#   'bubble bottle night set',
#   'glow bottle and tumbler'],
#  ['textured faux fur rug',
#   'textured rug',
#   'faux fur rug',
#   'textured fur rug',
#   'textured wool rug',
#   'textured rug trf',
#   'textured faux rug',
#   'rug with faux fur',
#   'faux-fur rug',
#   'texture rug'],
#  ['mirror with gold frame',
#   'gold mirror',
#   'gold frame mirror',
#   'gold wall mirror',
#   'mirror',
#   'symmetrical mirror',
#   'gold frame wall mirror',
#   'gold-framed mirror',
#   'gold framed mirror',
#   'mirrored wall mirror'],
#  ['scored rug',
#   'scored effect rug',
#   'rug',
#   'combined rug',
#   'score rug',
#   'knotted rug',
#   'striped rug',
#   'rug trf',
#   'limited edition rug',
#   'plain rug'],
#  ['faceted tumbler',
#   'faceted glass tumbler',
#   'faceted design tumbler',
#   'thick faceted glass tumbler',
#   'thick faceted tumbler',
#   'faceted design glass tumbler',
#   'faceted transparent glass tumbler',
#   'faceted transparent tumbler',
#   'thick glass tumbler',
#   'transparent tumbler'],
#  ['faceted soft drink tumbler',
#   'faceted glass soft drink tumbler',
#   'faceted design soft drink tumbler',
#   'soft drink tumbler with faceted design',
#   'thick faceted glass soft drink tumbler',
#   'thick faceted soft drink tumbler',
#   'faceted drink tumbler',
#   'faceted glass tumbler',
#   'faceted transparent soft drink tumbler',
#   'faceted translucent soft drink tumbler'],
#  ['wine glass',
#   'wine glass with base',
#   'circular wine glass',
#   'glass with circular base',
#   'circular base wine glass',
#   'round wine glass',
#   'limited edition wine glass',
#   'round base wine glass',
#   'wine glass and base',
#   'glass with base'],
#  ['round basket',
#   'round woven basket',
#   'round bread basket',
#   'woven basket',
#   'woven bread basket',
#   'basket with handle',
#   'round weave basket',
#   'basket',
#   'bread basket',
#   'basket with handles'],
#  ['geometric rug',
#   'multicoloured rug',
#   'cotton rug',
#   'geometric cotton rug',
#   'multicoloured cotton rug',
#   'geometric motif rug',
#   'geometric print rug',
#   'rug with geometric motifs',
#   'multicoloured geometric rug',
#   'geometric design rug'],
#  ['wool and jute rug',
#   'cream wool and jute rug',
#   'striped wool rug',
#   'striped wool and jute rug',
#   'wool and jute blend rug',
#   'wool and jute mix rug',
#   'striped rug',
#   'cream wool rug',
#   'beige wool and jute rug',
#   'jute and wool rug'],
#  ['patchwork rug',
#   'patchwork effect rug',
#   'patchwork rug.',
#   'striped patchwork rug',
#   'rug with patchwork',
#   'wool patchwork rug',
#   'combined patchwork rug',
#   'patchwork design rug',
#   'plain patchwork rug',
#   'rug'],
#  ['wireless lamp',
#   'wireless bamboo lamp',
#   'bamboo lamp',
#   'wireless plastic lamp',
#   'wireless light lamp',
#   'wireless light bulb',
#   'bamboo wireless lamp',
#   'wireless led lamp',
#   'wireless garden lamp',
#   'plastic lamp'],
#  ['triangle basket',
#   'basket with handles',
#   'basket',
#   'basket with handle',
#   'basket with triangles',
#   'triangular basket',
#   'triangle pattern basket',
#   'basket with triangle',
#   'triangles basket',
#   'striped basket'],
#  ['wooden side table',
#   'wood side table',
#   'side table',
#   'rectangular side table',
#   'rectangular wood side table',
#   'side table with cross',
#   'metal side table',
#   'wooden table',
#   'rectangular wooden side table',
#   'wooden table with cross'],
#  ['wooden jewellery box',
#   'circular wooden jewellery box',
#   'circular jewellery box',
#   'jewellery box',
#   'linen-lined jewellery box',
#   'linen jewellery box',
#   'rectangular wooden jewellery box',
#   'round wooden jewellery box',
#   'rustic jewellery box',
#   'limited edition wooden jewellery box'],
#  ['wooden jewellery box',
#   'rectangular wooden jewellery box',
#   'rectangular jewellery box',
#   'linen-lined jewellery box',
#   'linen jewellery box',
#   'rustic jewellery box',
#   'jewellery box',
#   'wooden and linen jewellery box',
#   'limited edition wooden jewellery box',
#   'wooden jewellery box with linen'],
#  ['table mirror',
#   'wooden table mirror',
#   'wooden mirror',
#   'mirror',
#   'mirrored table',
#   'wood table mirror',
#   'metal table mirror',
#   'rustic table mirror',
#   'glass table mirror',
#   'wooden frame mirror'],
#  ['stand-up mirror',
#   'mirror with iron base',
#   'mirror',
#   'black iron mirror',
#   'black mirror',
#   'stand up mirror',
#   'mirror with base',
#   'mirror with black base',
#   'stand mirror',
#   'mirror with metal base'],
#  ['lacquered lamp',
#   'lacquered metal lamp',
#   'black lacquered lamp',
#   'metal lamp',
#   'lacquered lamp trf',
#   'black lacquered metal lamp',
#   'black lamp',
#   'lamp with lacquered metal',
#   'lamp with lacquered finish',
#   'black metal lamp'],
#  ['fleece armchair',
#   'plush armchair',
#   'quilted armchair',
#   'armchair',
#   'faux shearling armchair',
#   'wool armchair',
#   'armchair with fleece',
#   'velvet armchair',
#   'soft fleece armchair',
#   'fleece upholstered armchair'],
#  ['striped towel',
#   'towel with striped design',
#   'towel with fringed edges',
#   'cotton towel',
#   'striped cotton towel',
#   'towel with stripes',
#   'towel with fringed design',
#   'striped towel with fringing',
#   'towel with fringing',
#   'cotton towel with fringing'],
#  ['double-sided towel',
#   'cotton towel',
#   'double towel',
#   'towel',
#   'double-side towel',
#   'double cotton towel',
#   'towel with double side',
#   'towel with double sides',
#   'double towel trf',
#   'single-sided towel'],
#  ['towel (pack of 2)',
#   'cotton towel (pack of 2)',
#   'double towel (pack of 2)',
#   'double-sided towel',
#   'double-sided towel (200 ml)',
#   'double-sided towel (200 g)',
#   '2-pack of double-sided towel',
#   'double-sided towel (250 ml)',
#   'double sided towel (pack of 2)',
#   'double cotton towel (pack of 2)'],
#  ['towel with tassels (pack of 3)',
#   'towel (pack of 3)',
#   'cotton towel (pack of 3)',
#   'towel with tassels',
#   'towel with tassels (3-pack)',
#   'tassel towel (pack of 3)',
#   'towel with tassel (pack of 3)',
#   'towel (pack of 3) with tassels',
#   'towels with tassels (pack of 3)',
#   'cotton towel with tassels'],
#  ['towel with tassels',
#   'cotton towel with tassels',
#   'cotton towel',
#   'tassel towel',
#   'towel with tassel',
#   'linen towel with tassels',
#   'tassels towel',
#   'cotton towel with tassel',
#   'towel',
#   'paper towel with tassels'],
#  ['towel with band',
#   'towel with lined band',
#   'cotton towel',
#   'cotton towel with band',
#   'towel with lining',
#   'towel',
#   'towel with a band',
#   'towel with polka dots',
#   'towel with bands',
#   'cotton towel with lining'],
#  ['nesting tables',
#   'marble nesting tables',
#   'golden nesting table',
#   'nesting table',
#   'two-piece nesting table',
#   'marble nesting table',
#   'nesting table with marble top',
#   'two-tier nesting table',
#   'golden marble nesting tables',
#   'golden nesting tables'],
#  ['towel with crochet border',
#   'crochet towel',
#   'cotton towel',
#   'towel with crochet detail',
#   'towel with crocheted border',
#   'cotton towel with crochet',
#   'towel with crochet',
#   'towels with crochet border',
#   'towel with crochet trim',
#   'towel with crochet design'],
#  ['basket',
#   'basket with metal structure',
#   'metal basket',
#   'metal and paper basket',
#   'paper basket',
#   'basket with resilient paper',
#   'basket with linen lining',
#   'basket with round base',
#   'linen basket',
#   'basket with fabric lining'],
#  ...]

# %%
save_submission(names, "submission_30")

# %%
save_submission(names, "submission_30", zip=False)

# %%
extended_names = generate_names(model, tokenizer, collator, test["description"], batchsize=4, num_sequences=30)

# %%
extended_names

# %%
save_submission(extended_names, "submission_23")

# %% [markdown]
# Check all lines have 10 names

# %%
from collections import Counter

Counter([len(n) for n in extended_names])

# %% [markdown]
# Check the names in the basic file are the first in the extended file

# %%
for n, xn in zip(names, extended_names):
    assert set(n).issubset(set(xn)), f"{set(n)} not in {set(xn)}"

# %%
for n, xn in zip(names, extended_names):
    assert xn[:len(n)] == n, f"{xn} != {n}"

# %% [markdown]
# Not the same elements, neither same ordering! So we might be able to produce better results with a different generation method?

# %% [markdown]
# Try now using top_k and top_p filters, and removing length penalties.

# %%
refined_names = generate_names(model, tokenizer, collator, test["description"], batchsize=4, num_sequences=30)

# %%
refined_names

# %%
save_submission(refined_names, "submission_22")

# %%
Counter([len(set(rn) ^ set(xn)) for xn, rn in zip(extended_names, refined_names)])

# %% [markdown]
# ## Generate predictions for training and validation data

# %% [markdown]
# This is useful for training ranker models

# %%
from model import generate_names
from postprocessing import save_submission

# %%
train_names = generate_names(model, tokenizer, collator, train["description"], batchsize=16, max_candidates=9999)
save_submission(train_names, "train_BART-base-submission-23")

# %%
val_names = generate_names(model, tokenizer, collator, val["description"], batchsize=16, max_candidates=9999)
save_submission(val_names, "val_BART-base-submission-23")
