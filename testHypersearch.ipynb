# %% [markdown]
# # Tests for model hyperparameter tuning

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load resources

# %%
from data import load_data

train, val, test = load_data()

# %% [markdown]
# ## Try doing a simple optimization

# %%
from model import optimize_model_parameters

res = optimize_model_parameters(
    'facebook/bart-base', 
    train, 
    val,
    train_batch_size=8,
    epochs=1,
    gradient_accumulation_steps=8
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# {'loss': 2.1071, 'learning_rate': 5e-05, 'epoch': 0.96}
# {'eval_loss': 1.2912861108779907, 'eval_runtime': 13.6698, 'eval_samples_per_second': 272.864, 'epoch': 1.0}
# DCG=16.076478785586865
# {'train_runtime': 1643.2276, 'train_samples_per_second': 0.318, 'epoch': 1.0}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-b2261e7145cd> in <module>
#       1 from model import optimize_model_parameters
#       2
# ----> 3 res = optimize_model_parameters(
#       4     'facebook/bart-base',
#       5     train,
#
# ~/spainAIhackathon/model.py in optimize_model_parameters(model_name, train, val, train_batch_size, epochs, gradient_accumulation_steps, n_calls)
#     250     scorer = lambda params: partial_scorer(**_unwrap_model_parameters(params))
#     251
# --> 252     results = gp_minimize(
# ...
