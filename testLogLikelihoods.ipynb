# %% [markdown]
# # Notebook to test measuring log likelihoods of predictions

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Config

# %%
model_path = "./good_models/BART-base-submission-23/"
model_class = 'facebook/bart-base'

# %% [markdown]
# ## Load resources

# %%
from transformers import BartForConditionalGeneration

model = BartForConditionalGeneration.from_pretrained(model_path)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(50265, 768, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768, padding_idx=1)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768, padding_idx=1)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=50265, bias=False)
# )

# %%
from transformers import BartTokenizer

tokenizer = BartTokenizer.from_pretrained(model_class)

# %%
from model import SpainAICollator

collator = SpainAICollator(tokenizer, model)

# %%
from data import load_data

train, val, test = load_data()

# %% [markdown]
# ## Generate log-probabilities for a name

# %%
sample_description = train["description"].iloc[0]
sample_description
# Out:
# 'tote bag in a combination of colours. braided exterior in a combination of materials. shoulder straps with a decorative stud. lined interior with pocket and zip purse. magnetic clasp closure.height x length x width 26.3 x 38.5 x 14.5 cm. / 10.3 x 15.1 x 5.7″'

# %%
sample_name = train["name"].iloc[0]
sample_name
# Out:
# 'fabric tote bag'

# %%
import torch

def model_logprob(model, collator, input_text, output_text, length_penalty=0):
    encoded_inputs = collator.encode_inputs([input_text])
    encoded_outputs = collator.encode_outputs([output_text])
    with torch.no_grad():
        output = model(**encoded_inputs, **encoded_outputs)
    total_logprob = sum([
        output["logits"][0, i].log_softmax(dim=0)[encoded_outputs["labels"][0][i]]
        for i in range(1, len(encoded_outputs["labels"][0]) - 1)
    ])
    # Normalize by length: https://www.aclweb.org/anthology/W18-6322.pdf
    num_output_tokens = len(encoded_outputs["labels"][0]) - 2  # Ignore tokens for text start/end
    total_logprob /= (5+num_output_tokens)**length_penalty / (5+1)**length_penalty
    return total_logprob

# %%
def resort_name_proposals(model, collator, descriptions, name_proposals, length_penalty=0):
    resorted_proposals = []
    for description, proposals in zip(descriptions, name_proposals):
        logprobs = [model_logprob(model, collator, description, name, length_penalty) for name in proposals]
        #resorted_proposals.append([z[0] for z in sorted(zip(proposals, logprobs), key=lambda x: x[1], reverse=True)])
        resorted_proposals.append([z for z in sorted(zip(proposals, logprobs), key=lambda x: x[1], reverse=True)])
    return resorted_proposals

# %%
from postprocessing import read_proposals_files, normalize_proposals_list

name_proposals = normalize_proposals_list(read_proposals_files(["val_BART-base-submission-23.csv"]))

# %%
resort_name_proposals(model, collator, train["description"][0:1], name_proposals[0:1], length_penalty=1)
# Out:
# [[('fabric tote bag', tensor(-0.4432, device='cuda:0')),
#   ('fabric tote bag with studs', tensor(-0.7342, device='cuda:0')),
#   ('fabric tote bag with stud', tensor(-0.7806, device='cuda:0')),
#   ('braided tote bag', tensor(-1.1178, device='cuda:0')),
#   ('braided tote bag with studs', tensor(-1.2826, device='cuda:0')),
#   ('plaited tote bag with stud', tensor(-1.3074, device='cuda:0')),
#   ('plaited tote bag', tensor(-1.3076, device='cuda:0')),
#   ('contrast braided tote bag', tensor(-1.3372, device='cuda:0')),
#   ('braided tote bag with stud', tensor(-1.3636, device='cuda:0')),
#   ('combined braided tote bag', tensor(-1.9073, device='cuda:0')),
#   ('fabric tote bag trf', tensor(-1.9641, device='cuda:0')),
#   ('woven tote bag with studs', tensor(-2.3306, device='cuda:0')),
#   ('braided tote bag with purse', tensor(-2.3714, device='cuda:0')),
#   ('multicoloured braided tote bag', tensor(-2.4489, device='cuda:0')),
#   ('braided maxi handbag trf', tensor(-2.5390, device='cuda:0')),
#   ('beaded tote bag', tensor(-2.5969, device='cuda:0')),
#   ('fabric tote bag - limited edition', tensor(-2.6029, device='cuda:0')),
#   ('seamless braided tote bag', tensor(-2.6136, device='cuda:0')),
#   ('beaded tote bag with purse', tensor(-2.6348, device='cuda:0')),
#   ('braided tote bag trf', tensor(-2.8029, device='cuda:0')),
#   ('natural braided tote bag', tensor(-2.8853, device='cuda:0')),
#   ('floral braided tote bag', tensor(-2.9616, device='cuda:0')),
#   ('plaited tote bag trf', tensor(-2.9693, device='cuda:0')),
#   ('textured braided tote bag', tensor(-3.0001, device='cuda:0')),
#   ('canvas tote bag with studs', tensor(-3.0357, device='cuda:0')),
#   ('bided tote bag with studs', tensor(-3.0574, device='cuda:0'))]]

# %%
from postprocessing import unroll_test_data

unrolled_proposals = unroll_test_data(val["description"], name_proposals)
unrolled_proposals
# Out:
#                                             name  \
# 0              textured t-shirt with ruffle trim
# 1                         ruffled poplin t-shirt
# 2                      t-shirt with frilled neck
# 3                     plush t-shirt with ruffles
# 4                   ruffled t-shirt with ruffles
# ...                                          ...
# 110965    sweatshirt with reversible sequin hood
# 110966  plush sweatshirt with reversible sequins
# 110967             sequinned doll sweatshirt trf
# 110968          sequinned long sleeve sweatshirt
# 110969             plush sweatshirt with sequins
#
#                                               description  original_row
# 0       round neck t-shirt featuring long sleeves with...             0
# 1       round neck t-shirt featuring long sleeves with...             0
# 2       round neck t-shirt featuring long sleeves with...             0
# 3       round neck t-shirt featuring long sleeves with...             0
# 4       round neck t-shirt featuring long sleeves with...             0
# ...                                                   ...           ...
# 110965  long sleeve sweatshirt with a round neckline, ...          3729
# 110966  long sleeve sweatshirt with a round neckline, ...          3729
# 110967  long sleeve sweatshirt with a round neckline, ...          3729
# 110968  long sleeve sweatshirt with a round neckline, ...          3729
# 110969  long sleeve sweatshirt with a round neckline, ...          3729
#
# [110970 rows x 3 columns]

# %%
len(unrolled_proposals)
# Out:
# 110970

# %%
# %%time
from postprocessing import model_logprobs
#logprobs = model_logprobs(model, collator, unrolled_proposals["description"], unrolled_proposals["name"])
logprobs_penalty = model_logprobs(model, collator, unrolled_proposals["description"], unrolled_proposals["name"], length_penalty=1)
# Out:
# CPU times: user 5min 20s, sys: 50.2 s, total: 6min 11s
# Wall time: 6min 2s

# %%
len(logprobs)
# Out:
# 110970

# %%
unrolled_proposals["score"] = logprobs_penalty

# %%
unrolled_proposals
# Out:
#                                             name  \
# 0              textured t-shirt with ruffle trim
# 1                         ruffled poplin t-shirt
# 2                      t-shirt with frilled neck
# 3                     plush t-shirt with ruffles
# 4                   ruffled t-shirt with ruffles
# ...                                          ...
# 110965    sweatshirt with reversible sequin hood
# 110966  plush sweatshirt with reversible sequins
# 110967             sequinned doll sweatshirt trf
# 110968          sequinned long sleeve sweatshirt
# 110969             plush sweatshirt with sequins
#
#                                               description  original_row  \
# 0       round neck t-shirt featuring long sleeves with...             0
# 1       round neck t-shirt featuring long sleeves with...             0
# 2       round neck t-shirt featuring long sleeves with...             0
# 3       round neck t-shirt featuring long sleeves with...             0
# 4       round neck t-shirt featuring long sleeves with...             0
# ...                                                   ...           ...
# 110965  long sleeve sweatshirt with a round neckline, ...          3729
# 110966  long sleeve sweatshirt with a round neckline, ...          3729
# 110967  long sleeve sweatshirt with a round neckline, ...          3729
# 110968  long sleeve sweatshirt with a round neckline, ...          3729
# 110969  long sleeve sweatshirt with a round neckline, ...          3729
#
#             score
# 0      -14.405650
# 1      -23.951827
# 2      -23.716456
# 3      -14.545201
# 4      -14.691045
# ...           ...
# 110965 -26.678821
# 110966 -26.217781
# 110967 -28.294693
# 110968 -28.489211
# 110969 -30.628558
#
# [110970 rows x 4 columns]

# %%
from postprocessing import reroll_score_test_data

sorted_proposals = reroll_score_test_data(unrolled_proposals, ascending=False)
sorted_proposals
# Out:
# 0       [ribbed t-shirt with ruffles, floral t-shirt w...
# 1       [flowing dress with belt, satin dress with bel...
# 2       [cloudbedspread with metallic thread, cloud be...
# 3       [ceramic door knob with drawings (pack of 2), ...
# 4       [puffer jacket with faux fur trim, reflective-...
#                               ...
# 3725    [water lily dress - limited edition, water lil...
# 3726    [buttoned knit hoodie, plain sweatshirt with b...
# 3727    [t-shirt with ruffled hem, plain t-shirt with ...
# 3728    [pine cone and tartan napkin holder (pack of 2...
# 3729    [sweatshirt with reversible sequin detail, lim...
# Name: proposals, Length: 3730, dtype: object

# %%
unrolled_proposals.iloc[0:31]
# Out:
#                                  name  \
# 0   textured t-shirt with ruffle trim
# 1              ruffled poplin t-shirt
# 2           t-shirt with frilled neck
# 3          plush t-shirt with ruffles
# 4        ruffled t-shirt with ruffles
# 5                t-shirt with ruffles
# 6                      floral t-shirt
# 7       t-shirt with frilled neck trf
# 8            t-shirt with ruffles trf
# 9                      frilly t-shirt
# 10      gathered t-shirt with ruffles
# 11       striped t-shirt with ruffles
# 12   long sleeve t-shirt with ruffles
# 13    ribbed t-shirt with ruffle trim
# 14         plain t-shirt with ruffles
# 15          t-shirt with ruffle trims
# 16                    ruffled t-shirt
# 17         satin t-shirt with ruffles
# 18       t-shirt with ruffled sleeves
# 19        floral t-shirt with ruffles
# 20                frilled t-shirt trf
# 21           t-shirt with ruffle trim
# 22       t-shirt with ruffle trim trf
# 23                    frilled t-shirt
# 24             frilled poplin t-shirt
# 25       printed t-shirt with ruffles
# 26                ruffled t-shirt trf
# 27              frilly sleeve t-shirt
# 28        ribbed t-shirt with ruffles
# 29      textured t-shirt with ruffles
# 30              satin dress with belt
#
#                                           description  original_row      score
# 0   round neck t-shirt featuring long sleeves with...             0 -14.405650
# 1   round neck t-shirt featuring long sleeves with...             0 -23.951827
# 2   round neck t-shirt featuring long sleeves with...             0 -23.716456
# 3   round neck t-shirt featuring long sleeves with...             0 -14.545201
# 4   round neck t-shirt featuring long sleeves with...             0 -14.691045
# 5   round neck t-shirt featuring long sleeves with...             0 -24.523283
# 6   round neck t-shirt featuring long sleeves with...             0 -33.848721
# 7   round neck t-shirt featuring long sleeves with...             0 -14.972052
# 8   round neck t-shirt featuring long sleeves with...             0 -15.221459
# 9   round neck t-shirt featuring long sleeves with...             0 -35.405031
# 10  round neck t-shirt featuring long sleeves with...             0 -14.543599
# 11  round neck t-shirt featuring long sleeves with...             0 -14.562168
# 12  round neck t-shirt featuring long sleeves with...             0 -14.079339
# 13  round neck t-shirt featuring long sleeves with...             0 -14.076516
# 14  round neck t-shirt featuring long sleeves with...             0 -19.406762
# 15  round neck t-shirt featuring long sleeves with...             0 -18.846408
# 16  round neck t-shirt featuring long sleeves with...             0 -33.727895
# 17  round neck t-shirt featuring long sleeves with...             0 -14.405304
# 18  round neck t-shirt featuring long sleeves with...             0 -18.380850
# 19  round neck t-shirt featuring long sleeves with...             0 -13.981826
# 20  round neck t-shirt featuring long sleeves with...             0 -25.280995
# 21  round neck t-shirt featuring long sleeves with...             0 -23.566891
# 22  round neck t-shirt featuring long sleeves with...             0 -14.920600
# 23  round neck t-shirt featuring long sleeves with...             0 -35.294516
# 24  round neck t-shirt featuring long sleeves with...             0 -24.575767
# 25  round neck t-shirt featuring long sleeves with...             0 -19.200400
# 26  round neck t-shirt featuring long sleeves with...             0 -24.963652
# 27  round neck t-shirt featuring long sleeves with...             0 -29.459868
# 28  round neck t-shirt featuring long sleeves with...             0 -13.703164
# 29  round neck t-shirt featuring long sleeves with...             0 -14.024349
# 30  short v-neck dress featuring double straps and...             1 -34.963771

# %%
sorted_proposals[0]
# Out:
# ['ribbed t-shirt with ruffles',
#  'floral t-shirt with ruffles',
#  'textured t-shirt with ruffles',
#  'ribbed t-shirt with ruffle trim',
#  'long sleeve t-shirt with ruffles',
#  'satin t-shirt with ruffles',
#  'textured t-shirt with ruffle trim',
#  'gathered t-shirt with ruffles',
#  'plush t-shirt with ruffles',
#  'striped t-shirt with ruffles']

# %%
from model import dcg
import numpy as np

print(f"Original DCG={dcg(name_proposals, val['name'])}")
print(f"Loglikelihood DCG={dcg(sorted_proposals, val['name'])}")
print(f"Random DCG={dcg([list(np.random.permutation(x)) for x in sorted_proposals], val['name'])}")
# Out:
# Original DCG=12.70006517501936
# Loglikelihood DCG=7.455891613002281
# Random DCG=5.073725060921905
