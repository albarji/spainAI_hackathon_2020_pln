# %% [markdown]
# # Notebook to test ranking model

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data

# %%
from data import load_data

train, val, test = load_data()

# %% [markdown]
# Load proposals

# %%
from postprocessing import read_proposals_files

# %%
files = [
    "BART-base-submission-23.csv", 
    "BART-large-submission-21.csv",
    "pegasus-large-submission-30.csv",
    "t5-base-submission-40.csv",
    "t5-small-submission-36.csv",
]

# %%
train["name_proposals"] = read_proposals_files([f"train_{file}" for file in files])

# %%
train
# Out:
#                                      name  \
# 25291                     fabric tote bag
# 5328      knit cardigan with ruffle trims
# 28974          mercurised glass soap dish
# 10697                             joggers
# 8656                 ribbed knit cardigan
# ...                                   ...
# 7820                  ripped skinny jeans
# 15507  flannel shirt with stand-up collar
# 17874                  basic denim jacket
# 28245          low rattan basket with lid
# 15855                      cropped blazer
#
#                                              description  \
# 25291  tote bag in a combination of colours. braided ...
# 5328   knit cardigan with a round neck. featuring lon...
# 28974                        mercurised glass soap dish.
# 10697  relaxed fit trousers made of a linen blend. fe...
# 8656   cardigan with round neckline, long sleeves and...
# ...                                                  ...
# 7820   five-pocket skinny jeans with an adjustable in...
# 15507  regular fit shirt with a flannel finish. stand...
# 17874  collared denim jacket featuring long buttoned ...
# 28245  seagrass basket in two tones with lid and hand...
# 15855  blazer featuring a lapel collar and long sleev...
#
#                                           name_proposals
# 25291  [braided tote bag with bag detail, plaited tot...
# 5328   [rib knit cardigan with ruffles, check knit ca...
# 28974  [, enameled glass soap dish, mercurized glass ...
# 10697  [loose fit trousers, limited edition linen tro...
# 8656   [rib knit cardigan, basic knit cardigan trf, c...
# ...                                                  ...
# 7820   [just soft bleach wash skinny jeans, skin carg...
# 15507  [flannel jersey shirt, striped striped shirt, ...
# 17874  [hooded denim jacket, denim jacket with stripe...
# 28245  [seagrass basket and lid, seagrass basket, sea...
# 15855  [blazer with flap pockets, textured blazer trf...
#
# [33480 rows x 3 columns]

# %%
val["name_proposals"] = read_proposals_files([f"val_{file}" for file in files])
val
# Out:
#                                                     name  \
# 1190                     t-shirt with polka dot flocking
# 2774                         double strap wrap dress trf
# 32709        cloud design bedspread with metallic thread
# 32403        ceramic door knob with transfer (pack of 2)
# 14237                                      puffer jacket
# ...                                                  ...
# 31096                             water lily voile dress
# 9682                                  striped sweatshirt
# 2355                                 ruffled t-shirt trf
# 31358  pine cone and sleigh bells napkin holders (pac...
# 9442                          sequinned heart sweatshirt
#
#                                              description  \
# 1190   round neck t-shirt featuring long sleeves with...
# 2774   short v-neck dress featuring double straps and...
# 32709  bedspread with a cloud design and metallic thr...
# 32403  round white ceramic door knob featuring a blue...
# 14237  long sleeve puffer jacket featuring a detachab...
# ...                                                  ...
# 31096  children's dress featuring a water lily print ...
# 9682   long sleeve hoodie. button fastening on the yo...
# 2355   round neck t-shirt with short sleeves and a ru...
# 31358  napkin holder with faux twigs, pine cone, slei...
# 9442   long sleeve sweatshirt with a round neckline, ...
#
#                                           name_proposals
# 1190   [t-shirt, poplin t-shirt, t-shirt with ruffled...
# 2774   [, belted dress, polka dot print dress, pleate...
# 32709  [metallic thread clouds bedspread, blanket wit...
# 32403  [round ceramic door knob, ceramic door knob wi...
# 14237  [jacket with faux fur trim, long puffer jacket...
# ...                                                  ...
# 31096  [water lily kids dress, water lily slip dress,...
# 9682   [buttoned knit hoodie, sweatshirt with contras...
# 2355   [poplin t-shirt, t-shirt with ruffle detail, t...
# 31358  [pine cone and sleigh bell napkin holders (pac...
# 9442   [sequinned bomber sweatshirt, sweatshirt with ...
#
# [3730 rows x 3 columns]

# %% [markdown]
# ## Input data statistics

# %% [markdown]
# Count number of characters in data

# %%
all_descriptions = train["description"].append(val["description"]).append(test["description"])

# %%
all_descriptions

# %%
all_names = train["name"].append(val["name"])

# %%
all_names

# %%
all_texts = all_descriptions.append(all_names)

# %%
max_len_descriptions = max([len(d) for d in all_descriptions])
max_len_names = max([len(d) for d in all_names])

# %%
max_len_descriptions

# %%
max_len_names

# %% [markdown]
# Size of the vocabulary

# %%
from itertools import chain

vocabulary = set(chain(*all_descriptions, *all_names))
vocabulary_len = len(vocabulary)

# %% [markdown]
# ## Siamese network model

# %%
from keras import Model
from keras.layers import Input, Embedding, GRU, Bidirectional, GlobalAveragePooling1D, Dense, Dot, Activation, Dropout
from keras import backend as K

embedding_size = 32
mixer_size = 128
hidden_size = 256
dropout = 0

shared_embedding = Embedding(vocabulary_len+1, embedding_size)

# Name tower
name_input = Input(shape=(max_len_names,))
name_embedding = shared_embedding(name_input)
name_mix = Bidirectional(GRU(mixer_size, return_sequences=True))(name_embedding)
name_pool = GlobalAveragePooling1D()(name_mix)
name_dense = Dense(hidden_size, activation="relu")(name_pool)
name_drop = Dropout(dropout)(name_dense)

# Description tower
description_input = Input(shape=(max_len_descriptions,))
description_embedding = shared_embedding(description_input)
description_mix = Bidirectional(GRU(mixer_size, return_sequences=True))(description_embedding)
description_pool = GlobalAveragePooling1D()(description_mix)
description_dense = Dense(hidden_size, activation="relu")(description_pool)
description_drop = Dropout(dropout)(description_dense)

# Comparison
dot_product = Dot(axes=1, normalize=True)([name_drop, description_drop])
output = Activation('relu')(dot_product)

# Final model
model = Model(inputs=[name_input, description_input], outputs=output)
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=['accuracy'])

# %%
model.summary()

# %% [markdown]
# ## Data generator

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(filters=None, char_level=True)
tokenizer.fit_on_texts(all_texts)

# %%
from keras.preprocessing.sequence import pad_sequences 

X_train_desc = tokenizer.texts_to_sequences(train["description"])
X_train_desc = pad_sequences(X_train_desc, maxlen=max_len_descriptions)
X_train_name = tokenizer.texts_to_sequences(train["name"])
X_train_name = pad_sequences(X_train_name, maxlen=max_len_names)

# %%
X_val_desc = tokenizer.texts_to_sequences(val["description"])
X_val_desc = pad_sequences(X_val_desc, maxlen=max_len_descriptions)
X_val_name = tokenizer.texts_to_sequences(val["name"])
X_val_name = pad_sequences(X_val_name, maxlen=max_len_names)

# %%
from itertools import islice
import numpy as np

def splitevery(iterable, n):
    """Returns blocks of elements from an iterator"""
    i = iter(iterable)
    piece = list(islice(i, n))
    while piece:
        yield piece
        piece = list(islice(i, n))

        
def data_generator(X_name, X_desc, batch_size):
    """Generator for batches of ranker training data"""
    while True:
        for idx in splitevery(range(len(X_desc)), batch_size//2):
            # Positive samples
            names = X_name[idx]
            positive_descriptions = X_desc[idx]
            # Negative samples: randomly take other descriptions for the same names
            negative_descriptions = X_desc[np.random.choice(range(len(X_desc)), len(idx), replace=False)]
            # Yield batch
            inputs = (
                np.vstack([names, names]),
                np.vstack([positive_descriptions, negative_descriptions])
            )
            outputs = np.expand_dims(np.array([1] * len(idx) + [0] * len(idx)), axis=1)
            yield inputs, outputs

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping

batch_size = 64
model.fit(
    data_generator(X_train_name, X_train_desc, batch_size),
    batch_size=batch_size, 
    steps_per_epoch=len(X_train_desc) // int(np.ceil(batch_size/2)),
    validation_data=data_generator(X_val_name, X_val_desc, batch_size),
    validation_steps=len(X_val_desc) // int(np.ceil(batch_size/2)),
    epochs=20,
    callbacks=[
        EarlyStopping(patience=10, restore_best_weights=True)
    ]
)

# %% [markdown]
# # Different approach: DistilBERT model

# %%
from postprocessing import unroll_data

unrolled_train = unroll_data(train["name"], train["description"], train["name_proposals"])

# %%
unrolled_train["description"][0]
# Out:
# 'tote bag in a combination of colours. braided exterior in a combination of materials. shoulder straps with a decorative stud. lined interior with pocket and zip purse. magnetic clasp closure.height x length x width 26.3 x 38.5 x 14.5 cm. / 10.3 x 15.1 x 5.7″'

# %%
for name in unrolled_train[unrolled_train["description"] == unrolled_train["description"][0]]["name"]:
    if "fabric" in name:
        print(name)
# Out:
# fabric tote bag
# fabric tote bag - limited edition
# fabric tote bag with stud
# fabric tote bag trf
# fabric tote bag with studs

# %%
from ranker import train_ranker
trainer, model, tokenizer, collator = train_ranker("distilbert-base-uncased", train, val, train_batch_size=32)
#trainer, model, tokenizer, collator = train_ranker("distilbert-base-uncased", train[:1024], val[:1024], train_batch_size=32)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='321' max='100000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   321/100000 04:58 < 25:56:15, 1.07 it/s, Epoch 0.23/73]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.111319</td>
#       <td>0.509260</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.115204</td>
#       <td>0.510436</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.113703</td>
#       <td>0.511998</td>
#     </tr>
#   </tbody>
# </table><p>
# AUC=0.5092601779696868
# AUC=0.5104362569276104
# AUC=0.5119978168695545
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0bb8a7516e72> in <module>
#       1 from ranker import train_ranker
#       2 #trainer, model, tokenizer, collator = train_ranker("distilbert-base-uncased", train, val, train_batch_size=32)
# ----> 3 trainer, model, tokenizer, collator = train_ranker("distilbert-base-uncased", train[:1024], val[:1024], train_batch_size=32)
#
# ~/spainAIhackathon/ranker.py in train_ranker(model_name, train, val, train_batch_size, gradient_accumulation_steps)
#     199     )
#     200
# --> 201     trainer.train()
#     202
#     203     return trainer, model, tokenizer, collator
#
# ~/.conda/envs/spainAI/lib/python3.8/site-packages/transformers/trainer.py in train(self, model_path, trial)
#     828                         self.scaler.update()
#     829                     else:
# --> 830                         self.optimizer.step()
#     831
#     832                     self.lr_scheduler.step()
#
# ~/.conda/envs/spainAI/lib/python3.8/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      64                 instance._step_count += 1
#      65                 wrapped = func.__get__(instance, cls)
# ---> 66                 return wrapped(*args, **kwargs)
#      67
#      68             # Note that the returned function here is no longer a bound method,
#
# ~/.conda/envs/spainAI/lib/python3.8/site-packages/transformers/optimization.py in step(self, closure)
#     302                     step_size = step_size * math.sqrt(bias_correction2) / bias_correction1
#     303
# --> 304                 p.data.addcdiv_(exp_avg, denom, value=-step_size)
#     305
#     306                 # Just adding the square of the weights to the loss function is *not*
#
# KeyboardInterrupt:

# %% [markdown]
# ### Try predicting for some texts

# %%
from data import normalize_text

sample_description = normalize_text("Knit midi dress with a V-neckline, straps and matching lace detail.<br/><br/>HEIGHT OF MODEL: 177 CM. / 69.6")
sample_description
# Out:
# 'knit midi dress with a v-neckline, straps and matching lace detail.'

# %%
name_candidates = "knit dress with lace trim,lace dress trf,knit dress with lace trf,knit dress with lace,knit camisole dress,lace dress,knit dress with lace detail,cable-knit dress,knit dress,contrast lace dress trf,pepino,beautiful dress,hand-knit dress,hand-knit dress with lace,floral print dress,pleated dress trf,printed dress trf,printed dress,pleated dress,flowing dress trf,jacquilted dress,floral print dress trf,jacquard dress,loose-fitting dress".split(",")
name_candidates
# Out:
# ['knit dress with lace trim',
#  'lace dress trf',
#  'knit dress with lace trf',
#  'knit dress with lace',
#  'knit camisole dress',
#  'lace dress',
#  'knit dress with lace detail',
#  'cable-knit dress',
#  'knit dress',
#  'contrast lace dress trf',
#  'pepino',
#  'beautiful dress',
#  'hand-knit dress',
#  'hand-knit dress with lace',
#  'floral print dress',
#  'pleated dress trf',
#  'printed dress trf',
#  'printed dress',
#  'pleated dress',
#  'flowing dress trf',
#  'jacquilted dress',
#  'floral print dress trf',
#  'jacquard dress',
#  'loose-fitting dress']

# %%
from ranker import rank_candidates
#rank_candidates(trainer, [sample_description], [name_candidates])
rank_candidates(ranker, [sample_description], [name_candidates])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='5088' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 07:33]
#     </div>
# [['lace dress trf',
#   'contrast lace dress trf',
#   'knit dress with lace detail',
#   'knit dress with lace',
#   'jacquard dress',
#   'knit dress with lace trim',
#   'knit dress with lace trf',
#   'pleated dress trf',
#   'jacquilted dress',
#   'floral print dress trf']]

# %% [markdown]
# ### Load a previously saved model and rank validation proposals

# %%
from ranker import load_ranker

ranker = load_ranker("./ranker/checkpoint-20000", "distilbert-base-uncased")

# %%
result_loaded = rank_candidates(ranker, val["description"].values, val["name_proposals"].values[:128])

# %%
result_loaded
# Out:
# [['ruffled t-shirt trf',
#   'ruff t-shirt trf',
#   'ruffled poplin t-shirt',
#   'floral t-shirt with ruffles',
#   'satin t-shirt with ruffles',
#   'ruffled top',
#   'frilled t-shirt trf',
#   'ruffled t-shirt with ruffles',
#   't-shirt with ruffle trim trf',
#   'textured t-shirt with ruffle trim'],
#  ['satin dress',
#   'floral print dress',
#   'printed dress',
#   'printed midi dress',
#   'printed mini dress',
#   'satin dress trf',
#   'flowing dress',
#   'pleated dress',
#   'pleated dress trf',
#   'jacquard dress'],
#  ['melange cloud bedspread',
#   'clouds bedspread',
#   'cloudbedspread',
#   'cloud melange bedspread',
#   'cloud bedspread',
#   'metallic thread cloud bedspread',
#   'cloudspread with metallic thread',
#   'cloudsatin bedspread',
#   'cloud embroidery bedspread',
#   'cloud motif bedspread'],
#  ['cerceramic door knob',
#   'ceramic door knob with sketch design',
#   'cer ceramic door knob',
#   'cerceramic door knob with sketch (pack of 2)',
#   'cerceramic door knob with transfer (pack of 2)',
#   'cerceramic door knob (pack of 2) trf',
#   'cerceramic door knob with sketch',
#   'cer door knob with sketches (pack of 2)',
#   'cer ceramic door knob with sketches (pack of 2)',
#   'ceramic door knob with sketches'],
#  ['lightweight puffer jacket with hood',
#   'shimmery puffer jacket',
#   'faux leather puffer jacket',
#   'puffer jacket with removable detail',
#   'puffer jacket with puffer',
#   'hooded puffer jacket with faux fur',
#   'detachable puffer jacket',
#   'faux fur puffer jacket',
#   'puffer jacket with faux fur',
#   'puffer jacket with contrast trim'],
#  ['mirrored table',
#   'mirrored side table',
#   'barbecue table',
#   'side table with mirror',
#   'side table set',
#   'marand glass side table',
#   'side table with marble',
#   'side table and glass',
#   'marcement and marble side table',
#   'side marble and glass table'],
#  ['tulle ballerinas sweatshirt',
#   'sporty tulle sweatshirt',
#   'tulle sweatshirt',
#   'printed tulle sweatshirt',
#   'tulle mouse sweatshirt',
#   'ball®repreve sweatshirt',
#   'sweatshirt with tulle tiger',
#   'minnie mouse © disney sweatshirt',
#   'ballerina t-shirt',
#   'ballerina sweatshirt'],
#  ['striped shirt',
#   'corduroy shirt',
#   'striped denim shirt',
#   'check shirt',
#   'linen shirt',
#   'prnt shrt 05',
#   'flannel shirt with pocket',
#   'satin shirt with pocket',
#   'animal print shirt',
#   'shirt with pocket'],
#  ['faux suede joggers',
#   'plsporty joggers',
#   'faux leather jogger trousers',
#   'plush jersey joggers',
#   'jogger waist cargo trousers',
#   'cargo trousers with zips',
#   'jogger waist plush trousers',
#   'plush trousers with zips',
#   'technical trousers with zips',
#   'jogging trousers with zips'],
#  ['check overshirt',
#   'overshirt with contrast label',
#   'satin overshirt with pockets',
#   'overshirt with contrast collar',
#   'check overshirt with label',
#   'textured overshirt',
#   'denim overshirt with label',
#   'long check overshirt',
#   'faux leather overshirt',
#   'overshirt with contrast check detail'],
#  ['pleated floral quilt',
#   'floral embroidered quilt',
#   'striped floral quilt',
#   'floral swimsuit',
#   'striped linen quilt',
#   'stripedt/pk 04',
#   'strip & floral print quilt',
#   'stripedt/jkt 04',
#   'floral floral quilt',
#   'strip and floral print quilt'],
#  ['knotted top',
#   'crochet t-shirt',
#   'knotted top trf',
#   'striped knotted t-shirt',
#   'kn\\t 04',
#   'plain t-shirt',
#   'knot t-shirt',
#   'crochet t-shirt trf',
#   'knotted t-shirt trf',
#   'kn\\strp 04'],
#  ['sequinned bodysuit trf',
#   'velvet bodysuit',
#   'b bodysuit trf',
#   'bodysuit with lace trf',
#   'tulle bodysuit trf',
#   'draped bodysuit trf',
#   'lace-up bodysuit trf',
#   'floral print bodysuit trf',
#   'bodysuit with lace trim',
#   'rib knit bodysuit trf'],
#  ['ruff blouse with floral embroidery',
#   'embroderie blouse',
#   'embroidered jacquard blouse',
#   'ruff blouse with matching embroidery',
#   'blouse with matching embroidery trf',
#   'embroidered longline blouse',
#   'embroidered taffeta blouse',
#   'ruffled blouse',
#   'embroidered plumetis blouse',
#   'embroidered loose-fitting blouse'],
#  ['gingham check dress',
#   'floral dress with gathered detail',
#   'printed midi dress',
#   'floral panelled dress',
#   'floral print midi dress',
#   'floral dress with gathering',
#   'floral dress',
#   'floral midi dress',
#   'printed satin dress',
#   'floral print dress'],
#  ['pleated camouflage trousers',
#   'pleated printed trousers',
#   'plush trousers with slogan',
#   'printed pleated trousers',
#   'plush trousers with bears',
#   'pleated slogan trousers',
#   'pleated plush trousers',
#   'plush trousers with print',
#   'pleated graffiti trousers',
#   'pleated print trousers'],
#  ['cropped check top trf',
#   'st/strp 04',
#   'st/05',
#   'st/bs 05',
#   'asymmetric top trf',
#   'text top trf',
#   'cropped tank top trf',
#   'cropped top trf',
#   'cropped contrast top trf',
#   'cropped crop top trf'],
#  ['jacquard trousers',
#   'jacquard suit trousers',
#   'darted trousers',
#   'slouchy darted trousers',
#   'flowing trousers',
#   'check trousers',
#   'culottes',
#   'darted trousers trf',
#   'check slouchy trousers',
#   'straight fit trousers trf'],
#  ['jacquard top',
#   'jacquard knit top',
#   'floral knit top trf',
#   'jacquilted top',
#   'jacquard top trf',
#   'puff top trf',
#   'knit top trf',
#   'textured weave top trf',
#   'knit crop top',
#   'balloon sleeve top trf'],
#  ['maxi crack-effect clutch trf',
#   'crpadded maxi clutch',
#   'cr cg srpls',
#   'cracked metallic maxi clutch trf',
#   'crpyjama bottoms trf',
#   'crpumpkin maxi clutch',
#   'cracked maxi clutch trf',
#   'crcargo maxi clutch',
#   'cr cndl clutch',
#   'maxi cracked-effect clutch trf'],
#  ['pack of hoop earrings',
#   'femme + twilight 100 ml',
#   'wonder rose + oriental 100 ml',
#   'bohemian bluebells 90ml / 3.04\xa0oz',
#   'tuberose 100ml',
#   'bohemian bluebells 40ml / 1.35\xa0oz',
#   'wonder rose + oriental 100 ml / 3.38\xa0oz',
#   'tuberose 100 ml',
#   'pack of link necklaces',
#   'vibrant leather 100 ml / 3.38\xa0oz'],
#  ['jacquard top',
#   'jacquard knit top',
#   'knit top trf',
#   'knit halterneck top',
#   'knitted top trf',
#   'ribbed knit top',
#   'knit crop top trf',
#   'textured knit top',
#   'kn\\strp 04',
#   'rib knit crop top'],
#  ['zwaffle-knit petit smoke black jeans',
#   'je slouchy petit acid wash jeans',
#   'zwaffle-knit petit jeans',
#   'zwaxed-effect petit acid jeans',
#   'zwaxed-effect petit jeans',
#   'zwaxed petit jeans',
#   'zwaffle petit jeans',
#   'zw premium petit smoke black skinny jeans',
#   'zw premium petit acid black skinny jeans',
#   'je slouchy petit smoke black jeans'],
#  ['le bt srpls',
#   'split suede belt',
#   'le pareo leather belt',
#   'le bg srpls',
#   'le knotted leather belt',
#   'le corduroy belt',
#   'split suede leather belt',
#   'leather belt trf',
#   'textured leather belt',
#   'leather belt'],
#  ['jacquard scarf',
#   'check scarf',
#   'check jacquard scarf',
#   'woven scarf',
#   'checked jacquard scarf',
#   'checked scarf',
#   'check knit scarf trf',
#   'check crochet scarf',
#   'check textured weave scarf',
#   'check check scarf trf'],
#  ['text shirt',
#   'basic shirt',
#   'striped shirt',
#   'striped denim overshirt',
#   'strip shirt',
#   'striped denim shirt',
#   'paisley print shirt',
#   'basic oxford shirt',
#   'contrast textured shirt',
#   'strip print shirt'],
#  ['textured jacquard romper',
#   'romperforated silk romper',
#   'sil silk textured romper',
#   'textured lace romper',
#   'striped textured silk romper',
#   'seersucker silk romper',
#   'textured silk romper with straps',
#   'sil-12% silk romper',
#   'linen romper with straps',
#   'textured melange romper'],
#  ['faux fur sweatshirt',
#   'colour block sweatshirt',
#   'animal print sweatshirt',
#   'basic sweatshirt trf',
#   'plain-coloured sweatshirt',
#   'basic plain sweatshirt',
#   'premium plain sweatshirt',
#   'plain sweatshirt',
#   'colour block plush sweatshirt',
#   'faux shearling sweatshirt'],
#  ['rattan candle',
#   ' rattan lantern',
#   'wooden lantern',
#   'ray lantern',
#   'resinlantern',
#   'golden lantern',
#   'rattan lantern',
#   'rattan candle lantern',
#   'resin lantern',
#   'b rattan lantern'],
#  ['felt coaster with die cut stars',
#   'felt coaster with stars',
#   'felt coaster (pack of 6)',
#   'star felt coaster (pack of 6)',
#   'cowboy felt coaster (pack of 6)',
#   'felt coaster',
#   'crystal felt coaster (pack of 6)',
#   'christmas felt coaster',
#   'christmas felt coaster (pack of 6)',
#   'heartfelt coaster'],
#  ['linen scarf',
#   'printed scarf',
#   'geometric print linen scarf',
#   'frayed linen scarf',
#   'animal print scarf trf',
#   'textured linen scarf',
#   'linen scarf trf',
#   'animal print linen scarf',
#   'strip print linen scarf',
#   'check textured scarf'],
#  ['technical traveler trousers with belt',
#   'technical havana trousers with belt',
#   'technical trousers with contrast belt trf',
#   'baggy technical trousers',
#   'technical cargo trousers with belt trf',
#   'contrast technical trousers',
#   'technical traveller trousers with belt',
#   'technical trousers with belt detail',
#   'limited edition contrast belt trousers',
#   'technical cargo trousers'],
#  ['asymmetric asymmetric top',
#   'asymmetric midi top',
#   'asymmetric faux leather top',
#   'asymmetric poplin top',
#   'asymmetric printed top',
#   'asymmetric top with straps',
#   'printed asymmetric top trf',
#   'faux leather top',
#   'limited edition asymmetric top',
#   'asymmetric wrap top'],
#  ['flowing satin bodysuit',
#   'rib knit bodysuit',
#   'plumetis bodysuit',
#   'satin bodysuit',
#   'textured weave bodysuit',
#   'ribbed bodysuit',
#   'rib knit bodysuit trf',
#   'button bodysuit trf',
#   'animal print bodysuit',
#   'printed satin bodysuit'],
#  ['crystalline gold-rimmed tumbler',
#   'crystalline tumbler with chain',
#   'gold medallion crystalline wine glass',
#   'crystalline gold-rimmed wine glass',
#   'gold gold crystalline wine glass',
#   'gold frame crystalline wine glass',
#   'gold ring crystalline wine glass',
#   'golden rim crystalline wine glass',
#   'golden ring crystalline wine glass',
#   'crystalline gold rim wine glass with chain'],
#  ['linen cushion',
#   'rustic linen cushion',
#   'knotted linen cushion',
#   'ottoman linen cushion',
#   'linen cushion with opening',
#   'textured linen cushion',
#   'printed linen cushion',
#   'linen cushion with gathering',
#   'quilted linen cushion',
#   'linen cushion with bow'],
#  ['jacquard top',
#   'jacquard top with pearl buttons',
#   'satin top with pearl button',
#   'satin top with pleats',
#   'crop top with pearl buttons trf',
#   'satin top with bow',
#   'top with pearl buttons trf',
#   'knit top with pearl buttons',
#   'printed top with pearl buttons trf',
#   'rib knit top with pearl buttons'],
#  ['printed t-shirt with slogan',
#   'embossed t-shirt',
#   'embossed t-shirt with slogan',
#   't-shirt with slogan',
#   'ballerina t-shirt',
#   'slogan t-shirt',
#   'slogan t-shirt with text',
#   'swan t-shirt',
#   'placement slogan t-shirt',
#   'slogan t-shirt with print'],
#  ['asymmetric slogan t-shirt',
#   'asymmetric t-shirt',
#   'embossed t-shirt',
#   '‘love’ t-shirt',
#   '’always’ t-shirt',
#   't/strp/ t 04',
#   'slogan t-shirt trf',
#   'premium t-shirt with slogan',
#   'contrasting fabric t-shirt',
#   'slogan t-shirt'],
#  ['sock-style boots',
#   'block heel sock boots',
#   'chunky yarn boots',
#   'chunky sock boots',
#   'ribbed sock boots',
#   'knit sock ankle boots',
#   'knit chunky boots',
#   'ch knit ankle boots',
#   'chunky knit boots',
#   'knit cotton sock boots'],
#  ['leather boots with contrast seams',
#   'leather boots with track soles',
#   'leather high-top sneakers',
#   'leather boots with contrast sole',
#   'leather boots with contrasting sole',
#   'black leather lace-up boots',
#   'white leather lace-up boots',
#   'beige leather lace-up boots',
#   'leather boots with square toe',
#   'leather boots with seam details'],
#  ['offcrshrt / 05',
#   'offcrshrt /05',
#   'offr/shrt 04',
#   'wool blend satin shirt',
#   'paisley print shirt',
#   'oversized shirt with bow trf',
#   'limited edition oversize striped shirt',
#   'limited edition wool blend striped shirt',
#   'limited edition wool blend shirt',
#   'limited edition oversize shirt'],
#  ['striped knit t-shirt trf',
#   'stripedt/strp 04',
#   'stripedt/stripe t 04',
#   'stripedp t 04',
#   'stripedt/t 04',
#   'stripedt t 04',
#   'striped knit t-shirt',
#   'stripedt t 05',
#   'stripedt/skrt 04',
#   'striped textured weave t-shirt'],
#  ['reindeer christmas decoration',
#   'white bearchristmas decoration',
#   'whale bear christmas decoration',
#   'white bears christmas decoration',
#   'black bearchristmas decoration',
#   'white bear decoration',
#   'christmas bear decoration',
#   'barbecue bear decoration',
#   'wonder bear christmas decoration',
#   'bear christmas decoration'],
#  ['neoprene-effect leggings',
#   'animal print leggings',
#   'faux suede leggings',
#   'gingham leggings trf',
#   'tapered leggings trf',
#   'faux shearling leggings',
#   'split suede leggings',
#   'houndstooth leggings trf',
#   'f leggings with zips trf',
#   'seamed leggings'],
#  ['kitchen scales with a tray',
#   'kitchen scales with cream structure',
#   'kitchen scales with contrasting needle',
#   'kitchen scales with blue design',
#   'kitchen scales with wooden tray',
#   'kitchen scales with a rectangular design',
#   'rectangular design kitchen scales',
#   'kitchen scales with a pointed design',
#   'kitchen scales with antique design',
#   'kitchen scales with contrast needle design'],
#  ['fdaisy shoulder tote bag',
#   'f arm tote bag',
#   'faux patent shoulder tote bag trf',
#   'f/05',
#   'f\\pkct 05',
#   'shoulder tote bag with interwoven detail',
#   'f /05',
#   'f fabric shoulder tote bag',
#   'faux patent maxi tote bag',
#   'faux patent shoulder bag with interwoven straps'],
#  ['oversized jacquard sweater',
#   'textured jacquard sweater',
#   'strip jacquard sweater',
#   'textured irregular sweater',
#   'textured sweater with irregular detail',
#   'jogger sweater',
#   'striped knit sweater',
#   'overs sweater with irregular fringing',
#   'jacquard sweater',
#   'textured weave sweater'],
#  ['mesh kitten-heel shoes trf',
#   'kitten-heel mesh shoes trf',
#   'k slippers with mesh trf',
#   'mesh kitten-heel shoes',
#   'kitten-heel slingbacks trf',
#   'slingback kitten heel shoes',
#   'mesh kitten heel slingbacks trf',
#   'mesh slingback shoes trf',
#   'm srpls @',
#   'm mesh kitten heel slingback shoes trf'],
#  ['lo trousers with drawstrings',
#   'textured trousers with drawstrings',
#   'textured trousers with drawstring',
#   'loose-fitting trousers trf',
#   'flannel jogger waist trousers',
#   'loose-fitting joggers',
#   'loose-fitting check trousers',
#   'loose-fitting plush trousers',
#   'loose-fitting linen trousers',
#   'lo trousers with pockets'],
#  ['knit cable-knit sweater',
#   'slogan cable-knit sweater',
#   'acquard cable-knit sweater',
#   'contrast cable-knit sweater',
#   'basic cable-knit sweater',
#   'cable-knit sweater',
#   'combined cable-knit sweater',
#   'cable-knit sweater with geometric design',
#   'contrast cable-knit sweater trf',
#   'textured cable-knit sweater'],
#  ['floral crochet t-shirt',
#   '© doraemon t-shirt',
#   'crochet top',
#   'waffle-knit t-shirt',
#   'cro crochet t-shirt',
#   'crocement t-shirt',
#   'crochet t-shirt trf',
#   'cmo\\strp t 04',
#   'fl crochet t-shirt',
#   'crochet t-shirt'],
#  ['t-shirt with contrast slogan trf',
#   't © tm dc comics t-shirt',
#   't/05',
#   'rib t-shirt with shoulder pads',
#   't-shirt with contrast slogan',
#   'knit t-shirt with shoulder pads',
#   'raglan sleeve t-shirt with shoulder pads',
#   'shiny slogan t-shirt trf',
#   'contrast slogan t-shirt',
#   't/t 04'],
#  ['corduroy joggers',
#   'plush trousers with contrast waist',
#   'plush jersey joggers',
#   'plush trousers with side stripe',
#   'plush trousers with side band',
#   'plush trousers with side stripes',
#   'contrast jogger waist trousers',
#   'twill jogging trousers',
#   'plush trousers with tie waist',
#   'corduroy trousers'],
#  ['t-shirt with embossed text',
#   'slogan t-shirt',
#   'ruff t-shirt with slogan trf',
#   'ruffled t-shirt with front slogan',
#   'faux leather t-shirt with slogan',
#   'ruff t-shirt with ruffle trims',
#   'frilly sleeve t-shirt',
#   'plumetis t-shirt',
#   'frilly slogan t-shirt',
#   'long sleeve t-shirt with text'],
#  ['ple pleated skirt trf',
#   'faux leather pleated skirt',
#   'pleated faux leather skirt',
#   'wrinkled-effect skirt',
#   'pleated mini skirt trf',
#   'velvet mini skirt',
#   'pleated mini skirt',
#   'printed skirt trf',
#   'ple knit mini skirt trf',
#   'pleated skirt trf'],
#  ['check coat',
#   'm 05',
#   'herringbone coat',
#   'wool blend knit coat',
#   'houndstooth wool blend coat',
#   'oversized wool blend coat',
#   'masculine wool blend coat',
#   'wool blend coat limited edition',
#   'wool blend cape coat',
#   'limited edition wool blend coat'],
#  ['bckpck srpls',
#   'draped double bucket bag trf',
#   'dotted mesh double bucket bag',
#   'shiny double bucket bag trf',
#   'gingham double bucket bag',
#   'nylon double bucket bag',
#   'dotted double bucket bag',
#   'pleated double bucket bag',
#   'golden double bucket bag',
#   'two-tone bucket bag'],
#  ['pack of hoop earrings',
#   'femme + twilight 100 ml',
#   'wonder rose + oriental 100 ml',
#   'bohemian bluebells 90ml / 3.04\xa0oz',
#   'tuberose 100ml',
#   'bohemian bluebells 40ml / 1.35\xa0oz',
#   'wonder rose + oriental 100 ml / 3.38\xa0oz',
#   'tuberose 100 ml',
#   'pack of link necklaces',
#   'vibrant leather 100 ml / 3.38\xa0oz'],
#  ['jacquard scarf',
#   'printed scarf',
#   'jacquilted scarf',
#   'crochet scarf',
#   'checked scarf',
#   'limited edition scarf with fringe',
#   'fringed scarf',
#   'cable-knit scarf',
#   'geometric print scarf',
#   'textured scarf with fringe'],
#  ['printed bermuda skort',
#   'box pleat skort',
#   'box pleated bermuda skort',
#   'bermuda skort with bow',
#   'skort with box pleats',
#   'skort with box pleat',
#   'flowing bermuda skort',
#   'box pleat bermuda skort',
#   'bermuda skort with buckle',
#   'flowing bermuda skort with buckle'],
#  ['jacquard knit vest',
#   'knit vest',
#   'cable-knit vest',
#   'pleated knit vest',
#   'frilled knit vest',
#   'faux fur vest',
#   'printed knit vest',
#   'ruffled knit vest',
#   'oversize knit vest',
#   'floral knit vest'],
#  ['embossed animal print bucket bag',
#   'animal bucket bag trf',
#   'animals bucket bag trf',
#   'animal print bucket bag - limited edition',
#   'bucket bag with knot trf',
#   'animal print bucket bag with knot trim',
#   'black bucket bag with knot trf',
#   'animal print bucket bag with knot',
#   'leopard print bucket bag trf',
#   'animal print buckled bucket bag'],
#  ['belted paperbag bermuda shorts',
#   'belted bermuda shorts with belt',
#   'belted bermuda shorts trf',
#   'paperbag bermuda shorts with belt',
#   'belted linen blend bermudas',
#   'belted rustic bermuda skort',
#   'bermuda shorts with belt',
#   'belted linen blend bermuda shorts',
#   'belted textured bermuda shorts',
#   'belted paperbag denim bermuda shorts'],
#  ['metallic thread knit cardigan',
#   'long knit cardigan',
#   'long faux shearling jacket',
#   'faux fur jacket',
#   'f/05',
#   'jacket',
#   'f /05',
#   'floral print jacket',
#   'jacket with pockets trf',
#   'linen jacket'],
#  ['linen scarf',
#   'printed scarf',
#   'linen scarf trf',
#   'floral print linen scarf',
#   'frayed linen scarf',
#   'strip print linen scarf',
#   'animal print scarf trf',
#   'check textured scarf',
#   'houndstooth linen scarf',
#   'printed scarf trf'],
#  ['hoodedt/jkt 04',
#   'jckt/05',
#   'colour block puffer jacket',
#   'long faux shearling jacket',
#   'hooded faux shearling jacket',
#   'neoprene-effect jacket',
#   'f/05',
#   'faux shearling jacket trf',
#   'faux leather jacket',
#   'lightweight puffer jacket'],
#  ['t/strp/ t 04',
#   'embossed t-shirt',
#   'raglan sleeve t-shirt',
#   'premium t-shirt',
#   't-shirt with text and slogan',
#   '’always’ t-shirt',
#   'premium t-shirt with text',
#   'placement t-shirt with text',
#   'slogo t-shirt',
#   'sporty slogan t-shirt'],
#  ['wreath with hanging up',
#   'wreath for hanging up',
#   'wreath with hanging leaves',
#   'wreath for hanging',
#   'long wreath',
#   'christmas hanging up wreath',
#   'christmas hanging upreath',
#   'wreath with handles',
#   'wreath with raised design',
#   'christmasculine wreath'],
#  ['jacquilted napkin (pack of 4) with lace trim',
#   'jacquilted napkin (pack of 4)',
#   'jacquard napkin (pack of 4) with lace trim',
#   'jacard linen napkins (pack of 4)',
#   'jacquard napkin (pack of 4)',
#   'jacquilted napkin (set of 4) with lace trim',
#   'jacquilted napkin with lace trim (set of 4)',
#   'jacard napkin (pack of 4)',
#   'jacquilted linen napkin (pack of 4)',
#   'jacard linen and cotton napkin (pack of 4)'],
#  ['knit cable-knit blanket',
#   'cable-knit blanket.',
#   'geometric cable-knit blanket',
#   'beige cable-knit blanket',
#   'textured cable-knit blanket',
#   'colourful cable-knit blanket',
#   'coloured cable-knit blanket',
#   'bsc cable-knit blanket',
#   'bige cable-knit blanket',
#   'cable knit blanket'],
#  ['dustpan and brush set with a wooden handle',
#   'dustpan and brush set with wooden handles',
#   'dustpan and brush set with wood handle',
#   'dustpan and brush set with a wood handle',
#   'dustpan and brush set with wooden handle',
#   'acrylic and wood brush set',
#   'sparkly dustpan and brush set',
#   'acrylic and wood dustpan and brush set',
#   'dustpan and brush set with an acrylic handle',
#   'acrylic and metal dustpan and brush set'],
#  ['rib knit top with ruffle',
#   'ruffled t-shirt',
#   'ruff top trf',
#   'creased-effect top',
#   'top',
#   'floral print top trf',
#   'ruffled poplin top trf',
#   'top with tulle frill',
#   'ruffled knit top',
#   'top with ruched detail trf'],
#  ['dark amber reed diffuser (100 ml)',
#   'black amber reed diffuser (100 ml)',
#   'jasmine and ylang wood reed diffuser (100 ml)',
#   'zasmine and ylang reed diffuser (100 ml)',
#   'dark reed diffuser (100 ml)',
#   'ylang ylang reed diffuser (100 ml)',
#   'floral reed diffuser (100 ml)',
#   '(100 ml) ylang ylang reed diffuser',
#   'lit up dreams reed diffuser (100 ml)',
#   'white reed diffuser (100 ml)'],
#  ['t/strp/ t 04',
#   'cmo\\strp t 04',
#   'neon slogan t-shirt',
#   'sporty contrast t-shirt',
#   't-shirt with pocket',
#   'sporty slogan t-shirt',
#   'embossed t-shirt',
#   'technical t-shirt with pocket',
#   'plain t-shirt with pocket',
#   'premium t-shirt with neon pocket'],
#  ['wide wide-leg trousers trf',
#   'wide trousers with pleats trf',
#   'high-rise wide-leg trousers',
#   'pleated wide-leg trousers',
#   'wide pleated trousers',
#   'wide-leg trousers',
#   'faux leather wide-leg trousers',
#   'wide leg trousers',
#   'wide-leg satin trousers',
#   'wide-leg trousers with pleats'],
#  ['faux shearling coat',
#   'double breasted buttoned coat',
#   'houndstooth coat trf',
#   'textured wool blend coat',
#   'f/05',
#   'double-breasted wool blend coat',
#   'checked double-breasted coat',
#   'double-breasted faux fur coat',
#   'houndstooth wool blend coat',
#   'houndstooth textured coat'],
#  ['geometric flat sheet',
#   'geometric text flat sheet',
#   'ge flat sheet',
#   'ge flat sheet with geometric design',
#   'graphic geometric flat sheet',
#   'gathered flat sheet',
#   'geometric geometric flat sheet',
#   'geometric structure flat sheet',
#   'geometric fabric flat sheet',
#   'gonometric print flat sheet'],
#  ['contrast pyjama blouse',
#   'ruff blouse with peter pan collar',
#   'contrast jacquard blouse',
#   'comb blouse with peter pan collar',
#   'contrast dotted mesh blouse trf',
#   'contrast pyjama style blouse',
#   'limited edition peter pan collar blouse',
#   'contrast guipure blouse',
#   'contrast poplin blouse trf',
#   'blouse with peter pan collar'],
#  ['den jacquard jacket with faux shearling',
#   'denim jacket - limited edition',
#   'jeans with faux shearling',
#   'faux shearling denim jacket',
#   'den jacket with contrast faux shearling',
#   'acid wash denim jacket',
#   'denim jacket with faux shearling lining',
#   'ripped denim jacket with faux shearling detail',
#   'den denim jacket and faux shearling',
#   'denim jacket with faux shearling trim'],
#  ['blt bg srpls',
#   'split suede crossbody bag',
#   'suede leather crossbody bag',
#   'xl split suede crossbody bag',
#   'leather crossbody bag trf',
#   ' pleated leather crossbody bag',
#   'burgundy leather crossbody bag',
#   'pleated leather crossbody bag',
#   'split suede crossbody bag with flap',
#   'le crossbody bag with pleats'],
#  ['cerware hook',
#   'cer pottery hook',
#   'ceratells',
#   'cerceramic hook',
#   'ceratelier hook',
#   'ceratells hook',
#   'cerousseline hook',
#   'cerceramic number 1 hook',
#   'cerousseline ceramic hook',
#   'cer ceramic hook'],
#  ['jacquilted trousers trf',
#   'ribbed trousers trf',
#   'jacquilted trousers',
#   'jacquard trousers',
#   'baggy trousers trf',
#   'faux leather trousers trf',
#   'pleated trousers trf',
#   'paperbag trousers trf',
#   'joggers trf',
#   'check trousers trf'],
#  ['mickey mouse ©disney faux leather puffer coat',
#   'mickey mouse ©disney reversible puffer coat',
#   'puffer coat with mickey mouse ©disney patch',
#   'mickey mouse ©disney sporty puffer coat',
#   'mickey mouse ©disney down puffer coat',
#   'mickey mouse ©disney colour block puffer coat',
#   'mickey mouse ©disney puffer coat limited edition',
#   'mickey mouse ©disney slogan puffer coat',
#   'mickey mouse ©disney puffer coat with patches',
#   'mickey mouse ©disney puffer coat with patch'],
#  ['asymmetric dress trf',
#   'jacquard dress trf',
#   'short poplin dress trf',
#   'poplin shirt dress trf',
#   'voluminous dress trf',
#   'darted shirt dress trf',
#   'striped shirt dress trf',
#   'printed shirt dress trf',
#   'flowing shirt dress trf',
#   'striped dress trf'],
#  ['card holder with bead details',
#   'beaded metallic card holder',
#   'metallic card holder with strap',
#   'silver card holder',
#   'metal card holder',
#   'metal card holder with bead bead',
#   'metal card holder with beaded strap',
#   'metallic card holder with bead',
#   'metal card holder with bead straps',
#   'silver card holder with bead'],
#  ['jacquard dress',
#   'flounce dress trf',
#   'voluminous printed dress',
#   'jacquilted dress trf',
#   'floral print dress',
#   'floral print dress trf',
#   'flounce dress',
#   'check dress trf',
#   'poplin dress trf',
#   'printed dress trf'],
#  ['limited edition padded snow jumpsuit',
#   'p ®repreve snow jumpsuit',
#   'p®repreve padded snow jumpsuit',
#   'textured padded snow jumpsuit',
#   'p ®repreve ® padded snow jumpsuit',
#   'p ®repreve padded snow jumpsuit',
#   'p ®repreve technical padded snow jumpsuit',
#   'p ®repreve lightweight padded snow jumpsuit',
#   'padded snow jumpsuit with buckle',
#   'padded snow jumpsuit limited edition'],
#  ['woven clutch bag with topstitching',
#   'lace clutch bag with topstitching',
#   'rocker clutch bag with topstitching',
#   'woven clutch',
#   'maxi clutch bag with topstitching',
#   'topstitched clutch bag',
#   'crossbody strap clutch bag',
#   'striped interwoven clutch',
#   'strappy clutch bag with topstitching',
#   'limited edition interwoven crossbody clutch'],
#  ['leather ankle boots with thick sole trf',
#   'soft leather ankle boots with thick heel detail',
#   'soft leather high heel ankle boots trf',
#   'soft leather ankle boots with thick soles',
#   'flat leather ankle boots with track soles',
#   'soft leather ankle boots with thick sole trf',
#   'soft leather ankle boots with track soles',
#   'soft leather ankle boots with thick heel',
#   'soft leather ankle boots with thick heels',
#   'leather ankle boots with thick soles'],
#  ['waffle knit towel',
#   'cotton waffle-knit towel',
#   'cotton towel with waffle-knit trf',
#   'waffle-knit towel (set of 2)',
#   'waffle-knit towel',
#   'cotton towel with waffle-knit',
#   'cotton waffle-knit towel (set of 2)',
#   'cotton towel with waffle knit',
#   'towel with cotton waffle-knit trf',
#   'waffle knit towel (pack of 2)'],
#  ['pineapple print jumpsuit',
#   'chambray jumpsuit',
#   'check jumpsuit',
#   'juit',
#   'rustic knit jumpsuit',
#   'rustic cotton jumpsuit',
#   'rustic striped jumpsuit',
#   'den jumpsuit',
#   'paisley print jumpsuit',
#   'rustic jumpsuit trf'],
#  ['flat leather shoes',
#   'flat leather boots with contrast sole',
#   'flat leather boots with seam detail',
#   'flat leather boots trf',
#   'flat leather ankle boots',
#   'split suede flat boots',
#   'lace-up flat leather boots',
#   'flat leather boots',
#   'flat split suede leather boots',
#   'flat split suede boots'],
#  ['embroderie set',
#   'embroidered baby bloomer set',
#   'embroidered bloomer set',
#   'embroidered baby bloomers set',
#   'embroidered poplin shirt set',
#   'embroidered flower set',
#   'baby bloomers set',
#   'embroidered lace shirt set',
#   'set of embroidered shirt and flowers',
#   'set of floral embroidery'],
#  ['den midi skirt',
#   'denim-effect midi skirt',
#   'denim midi skirt',
#   'den midi skirt trf',
#   'essence midi skirt trf',
#   'den denim midi skirt',
#   'acid wash denim midi skirt',
#   'faded-effect midi skirt',
#   'satin midi skirt trf',
#   'den denim-effect skirt trf'],
#  ['geometric shape mug',
#   'geometric-pattern mug',
#   'geometric-shaped mug',
#   'geometric-design mug',
#   'geometric shaped mug',
#   'cable-knit mug',
#   'geometric pattern mug',
#   'beaded mug',
#   'geometric coffee mug',
#   'textured mug'],
#  ['zipped ribbed t-shirt',
#   't-shirt with zip',
#   'ribbed snowboard t-shirt',
#   'cable-knit t-shirt',
#   'ribbed t-shirt with zip',
#   'textured ribbed t-shirt',
#   'ribbed with zip',
#   'ribbed t-shirt',
#   'colour block ribbed t-shirt',
#   'zip knit t-shirt'],
#  ['asymmetric poplin top',
#   'asymmetric top trf',
#   'camisole top',
#   'satin top',
#   'printed top',
#   'crossover top',
#   'fl top',
#   'pleated top',
#   'f top trf',
#   'satin wrap top'],
#  ['quilted maxi handbag',
#   'quilt bg srpls',
#   'quilted metallic crossbody bag trf',
#   'quilted crossbody bag with herringbone detail',
#   'quiltd srpls',
#   'quilted herringbone crossbody bag trf',
#   'quilted minaudière crossbody bag',
#   'quilted maxi handbag trf',
#   'quard and herringbone crossbody bag',
#   'quilted fabric crossbody bag limited edition'],
#  ['chunky sole sneakers',
#   'white chunky sneakers',
#   'black chunky sneakers',
#   'black sneakers with seam',
#   'lace-up sneakers',
#   'sneakers with contrast sole',
#   'black sneakers with contrast soles',
#   'black contrast sole sneakers',
#   'caramel sole sneakers',
#   'black sneakers'],
#  ['little actors canvas',
#   'Actor canvas',
#   ' actor canvas',
#   'actor canvas',
#   'theatre canvas',
#   'anorak canvas',
#   'canvas with actors',
#   'the actor canvas',
#   "children's actor canvas",
#   "children's theatre canvas"],
#  ['knit midi dress',
#   'knit midi dress trf',
#   'knit dress',
#   'wool blend knit dress',
#   'rib knit dress',
#   'ribbed knit dress trf',
#   'oversize knit dress trf',
#   'limited edition knit dress trf',
#   'limited edition knit dress',
#   'long knit dress'],
#  ['padded down parka with hood',
#   'water down parka with hood',
#   'down down parka with hood',
#   'long down parka with hood',
#   'down parka with pouch pocket',
#   'hooded down parka',
#   'lightweight down parka with hood',
#   'mxd pffr/05',
#   'down parka with faux fur hood',
#   'water repellent down parka'],
#  ['denim jumpsuit with pockets',
#   'cotton worker jumpsuit',
#   'faux suede jumpsuit',
#   'cotton jumpsuit trf',
#   'faux shearling jumpsuit',
#   'textured jumpsuit with pockets',
#   'den cargo jumpsuit',
#   'textured worker jumpsuit',
#   'technical jumpsuit with pockets',
#   'prk drss 05'],
#  ['jacquard blouse',
#   'gingham blouse',
#   'houndstooth blouse',
#   'voluminous blouse',
#   'satin blouse',
#   'printed blouse trf',
#   'linen blouse',
#   'gingham check blouse',
#   'jacquilted blouse',
#   'gingham blouse trf'],
#  ['le bt srpls',
#   'le bg srpls',
#   'split suede belt',
#   'wide belt',
#   'leather belt',
#   'le wide leather belt',
#   'leather belt - limited edition',
#   'wide split suede belt',
#   'le belt',
#   'leather belt limited edition'],
#  ['oversized poplin shirt',
#   'long poplin shirt',
#   'poplinen shirt',
#   'faux suede shirt',
#   'poplin shirt with elastic detail',
#   'textured weave shirt',
#   'poplin shirt with elastic',
#   'textured shirt with elastic',
#   'shirt with elastic waist',
#   'faux leather shirt'],
#  ['straw strawberry bejewelled earrings',
#   'straw strawberry pendant and gem earrings',
#   'bejewelled strawberry earrings',
#   'strawberry bejewelled earrings',
#   'straw strawberry earrings with gem detail',
#   'straw strawberry earrings and gem earrings',
#   'strawberry and strawberries earrings',
#   'strawberry multicoloured earrings',
#   'straw strawberries earrings',
#   'straw strawberry dangle earrings'],
#  ['cropped check blazer trf',
#   'check blazer',
#   'velvet blazer',
#   'text blazer',
#   'check tailored blazer',
#   'double-70s blazer',
#   'check blazer trf',
#   'houndstooth blazer trf',
#   'textured check blazer',
#   'double-breasted suit blazer'],
#  ['the child the mandalorian © &™ lucasfilm graphic t-shirt tr',
#   'the © &™ lucasfilm t-shirt trf',
#   'the child the mandalorian © &™ lucasfilm print t-shirt',
#   'the child in the mandalorian © &™ lucasfilm t-shirt tr',
#   'father the mandalorian © &™ lucasfilm t-shirt trf',
#   'the child the mandalorian© &™ lucasfilm t-shirt trf',
#   'the child the mandalorian © &™ lucasfilm’s t-',
#   'the Child the mandalorian © &™ lucasfilm t-shirt trf',
#   'the child in mandalorian © &™ lucasfilm t-shirt trf',
#   'the child the mandalorian © &™ lucasfilm. t-shirt tr'],
#  ['pack of colour block socks',
#   'pack of one more level socks',
#   'pack of stand-up socks',
#   'pack of plain socks trf',
#   'pack of socks with lettering',
#   'pack of sock-style socks',
#   'pack of contrast socks trf',
#   'pack of socks with stripes',
#   'pack of ribbed socks',
#   'pack of striped socks'],
#  ['asymmetric dress with bow',
#   'asymmetric dress with belt',
#   'dress with asymmetric hem',
#   'tie-dye dress',
#   'asymmetric dress trf',
#   'jacquard dress',
#   'limitless contour collection dress',
#   'satin dress with tied detail',
#   'pleated dress',
#   'dress with cut-out detail'],
#  ['jama cookbook',
#   'tapanese cookbook by phaidon',
#   'japanese cookbook by phaidon',
#   'japanese cookbook trf',
#   'japanese cookbook with photos',
#   'nordic cookbook by phaidon',
#   'japanese cookbookwritten in spanish',
#   'd srpls',
#   'zapanese cookbook by phaidon',
#   'discovery set cookbook'],
#  ['crossover bermuda skort',
#   'bermuda shorts with zip',
#   'paperbag bermuda shorts trf',
#   'satin bermuda shorts',
#   'long wrap bermuda shorts trf',
#   'crossover bermuda shorts trf',
#   'satin bermuda shorts trf',
#   'wrap-style bermuda shorts',
#   'long bermuda shorts trf',
#   'crossover bermuda shorts'],
#  ['jacquard trousers with mouse',
#   'marl knit trousers with mouse',
#   'knit trousers with mouse trims',
#   'embroderie knit trousers',
#   'knit culottes with mouse',
#   'knit plush trousers with mouse detail',
#   'knit trousers with mouse pattern',
#   'knit trousers with mouse details',
#   'knit trousers with embroidered mouse',
#   'knit trousers with mouse detail'],
#  ['striped knit sweater',
#   'purl knit sweater',
#   'plain knit sweater',
#   'knit sweater',
#   'basic knit sweater',
#   'rib knit sweater',
#   'striped knit sweater trf',
#   'pointelle knit sweater',
#   'knit sweater - limited edition',
#   'knit sweater trf'],
#  ['rib knit jumpsuit',
#   'knit playsuit trf',
#   'cable-knit playsuit',
#   'long ribbed jumpsuit',
#   'ribbed jumpsuit',
#   'knit playsuit',
#   'rib knit playsuit',
#   'striped jumpsuit trf',
#   'textured playsuit',
#   'ribbed jumpsuit trf'],
#  ['linen blouse trf',
#   'linen blend blouse',
#   'gingham blouse',
#   'printed blouse trf',
#   'linen/cotton blouse',
#   'printed blouse',
#   'striped rustic blouse',
#   'textured blouse',
#   'cotton/linen blouse',
#   'rustic blouse'],
#  ['den twill worker jacket',
#   'den twill jacket',
#   'denim twill jacket',
#   'acid wash denim jacket',
#   'den denim jacket',
#   'den denim jacket with pockets',
#   'denim worker jacket trf',
#   'corduroy denim jacket',
#   'den biker jacket trf',
#   'den biker jacket'],
#  ['rib knit leggings with lettuce edge trim',
#   'rib leggings with lettuce edge trim',
#   'leggings with lettuce-edge trim',
#   'leggings with lettuce-edge hems',
#   'rib leggings with lettuce edge hems',
#   'rib leggings with ribbed hems',
#   'rib leggings with lettuce-edge trim',
#   'rib leggings with topstitching',
#   'ribbed leggings with slits',
#   'rib knit leggings with ribbed detail'],
#  ['jacquard dress',
#   'pleated midi dress',
#   'sequinned dress',
#   'sequin mini dress',
#   'flounce dress',
#   'jacquilted dress',
#   'floral tulle dress',
#   'printed dress',
#   'pleated dress',
#   'printed midi dress'],
#  ['© doraemon t-shirt',
#   'mickey mouse © disney t-shirt',
#   'embossed t-shirt',
#   'doll t-shirt with appliqués',
#   'plush t-shirt with appliqués',
#   'ballet top with appliqués',
#   'surfboard t-shirt',
#   'bear t-shirt with appliqués',
#   'ele t-shirt with appliqués',
#   'beaver t-shirt with appliqués'],
#  ['kaftan with crochet detail trf',
#   'kaftan with crochet crochet trims',
#   'knit kaftan with crochet trims',
#   'kaftan with crochet ruffles',
#   'kaftan with crochet tassels',
#   'knitkaftan with crochet trims',
#   'kaftan with crochet ruffle trim',
#   'kaftan with crochet details',
#   'kaftan with crochet rims',
#   'kaftan with crochet flocking'],
#  ['knit top',
#   'jacquard top',
#   'jacquard knit top',
#   'cable-knit top',
#   'knit crop top',
#   'rib knit top',
#   'knit top trf',
#   'ribbed knit top',
#   'rib knit crop top',
#   'ribbed top'],
#  ['ribbed knit t-shirt',
#   'rib knit t-shirt',
#   'striped texture t-shirt',
#   'rib knit top',
#   'textured t-shirt',
#   'ribbed t-shirt',
#   'strip t-shirt',
#   'textured t-shirt trf',
#   'basic ribbed t-shirt',
#   'plain-coloured t-shirt'],
#  ['little house tumbler',
#   'little house transfer tumbler',
#   'little soft drink tumbler',
#   'glass soft drink tumbler',
#   'little house transfer tumbler trf',
#   'little house transfer slub knit tumbler',
#   'house transfer soft drink tumbler',
#   'little house detail soft drink tumbler',
#   'little house design soft drink tumbler',
#   't tumbler with little house transfer'],
#  ['wrap neck set',
#   'plush jersey set',
#   'faux leather set',
#   'plush jersey wrap set',
#   'plush set',
#   'kimono wrap set',
#   'kimono plush set',
#   'wrap set with tied detail',
#   'waffle texture plush set',
#   'waffle-knit set'],
#  ['linen blazer',
#   'jacquard blazer',
#   'jacquilted blazer',
#   'linen blazer trf',
#   'check blazer',
#   'f blazer',
#   'textured blazer trf',
#   'basic blazer',
#   'tailored blazer',
#   'quilted blazer']]

# %%
val["name"]
# Out:
# 1190                       t-shirt with polka dot flocking
# 2774                           double strap wrap dress trf
# 32709          cloud design bedspread with metallic thread
# 32403          ceramic door knob with transfer (pack of 2)
# 14237                                        puffer jacket
#                                ...
# 31096                               water lily voile dress
# 9682                                    striped sweatshirt
# 2355                                   ruffled t-shirt trf
# 31358    pine cone and sleigh bells napkin holders (pac...
# 9442                            sequinned heart sweatshirt
# Name: name, Length: 3730, dtype: object

# %% [markdown]
# ### Rank an ensemble of previous submissions

# %%
submissions = ["submission_21.csv", "submission_23.csv"]

proposals = read_proposals_files(submissions)

# %%
proposals
# Out:
# [['lace-trimmed dress',
#   'knit camisole dress',
#   'knit dress with lace detail',
#   'strappy camisole dress',
#   'camisole dress trf',
#   'knit dress with lace',
#   'contrast lace dress trf',
#   'camisole dress',
#   'knit dress',
#   'contrast camisole dress',
#   'lace dress',
#   'lace dress trf',
#   'knit dress with lace trf',
#   'knit dress with lace trim',
#   'combined camisole dress',
#   'camisole dress with lace',
#   'cable-knit dress'],
#  ['printed dress',
#   'printed midi dress trf',
#   'pleated dress trf',
#   'long printed dress trf',
#   'long pleated dress trf',
#   'pleated dress',
#   'flowing dress with pleats',
#   'jacquard dress',
#   'flowing dress trf',
#   'jacquilted dress',
#   'printed dress trf',
#   'loose-fitting dress',
#   'satin dress with pleats',
#   'floral print dress',
#   'floral print dress trf',
#   'faux leather dress trf'],
#  ['textured nautical cap',
#   'nautical cap',
#   'check nautical cap',
#   'long nautical cap',
#   'printed nautical cap',
#   'cap with peak',
#   'seersucker nautical cap',
#   'c nautical cap',
#   'neon nautical cap',
#   'cargo nautical cap',
#   'aquamarine nautical cap',
#   'foil nautical cap',
#   'accesories 05',
#   'n nautical cap',
#   'sporty nautical cap',
#   'navy cap',
#   'herringbone nautical cap',
#   'nautical cap with peak'],
#  ['textured nautical cap',
#   'combined nautical cap',
#   'nautical cap',
#   'check nautical cap',
#   'long nautical cap',
#   'printed nautical cap',
#   'metallic nautical cap',
#   'seersucker nautical cap',
#   'c nautical cap',
#   'linen nautical cap',
#   'cap with inner strap detail',
#   'nautical cap with inner strap',
#   'seamless nautical cap',
#   'cap with inner strap',
#   'faux leather nautical cap',
#   'n nautical cap',
#   'sporty nautical cap',
#   'herringbone nautical cap'],
#  ['textured nautical cap',
#   'nautical cap with button',
#   'nautical cap with buttons',
#   'nautical cap',
#   'check nautical cap',
#   'plain nautical cap',
#   'cabin nautical cap',
#   'long nautical cap',
#   'printed nautical cap',
#   'striped nautical cap',
#   'nautical cap with side buttons',
#   'nautical cap with flap',
#   'faux leather nautical cap',
#   'n nautical cap',
#   'navy cap'],
#  ['faded graffiti t-shirt',
#   'faded-effect sporty t-shirt',
#   'faded-effect photograph t-shirt',
#   'faded-effect t-shirt',
#   'faded-effect football t-shirt',
#   'faded-effect slogan t-shirt',
#   'faded-effect surf t-shirt',
#   'faded-effect t-shirt with slogan',
#   'faded-effect basketball t-shirt',
#   'faded-effect print t-shirt',
#   'faded-effect graffiti t-shirt',
#   'faded-effect t-shirt with photo',
#   'faded slogan t-shirt',
#   'faded-effect photo print t-shirt',
#   'faded-effect t-shirt with print',
#   'f t-shirt'],
#  ['coat with faux suede',
#   'double-breasted coat',
#   'f/05',
#   'coat with faux shearling',
#   'cable-knit coat',
#   'houndstooth coat',
#   'coat with faux fur trf',
#   'double-faced coat',
#   'double-faced faux fur coat',
#   'coat with faux suede interior',
#   'coat with faux fur',
#   'faux fur coat',
#   'faux suede coat',
#   'coat with wraparound collar',
#   'coat with faux fur interior'],
#  ['striped ribbed t-shirt',
#   'ribbed t-shirt',
#   'cropped t-shirt trf',
#   'rib t-shirt',
#   'ribbed cropped t-shirt',
#   'ripped t-shirt',
#   'short sleeve t-shirt trf',
#   'striped t-shirt trf',
#   'striped t-shirt',
#   'textured cropped t-shirt',
#   'ripped t-shirt trf',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'textured t-shirt',
#   'strip t-shirt'],
#  ['stt-shirt with wide straps',
#   'stretch crop top',
#   'stretch stretch top trf',
#   'stretch top trf',
#   'st/05',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'strappy stretch top trf',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top',
#   'stretch top with wide straps',
#   'stretch top with straps',
#   'stretch stretch top',
#   'stretch crop top trf',
#   'stretch top with stretch'],
#  ['stt-shirt with wide straps',
#   'stretch crop top',
#   'stretch stretch top trf',
#   'stretch top trf',
#   'st/05',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'strappy stretch top trf',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top',
#   'stretch top with wide straps',
#   'stretch top with straps',
#   'stretch stretch top',
#   'stretch crop top trf',
#   'stretch top with stretch'],
#  ['stt-shirt with wide straps',
#   'stretch crop top',
#   'stretch stretch top trf',
#   'stretch top trf',
#   'st/05',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'strappy stretch top trf',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top',
#   'stretch top with wide straps',
#   'stretch top with straps',
#   'stretch stretch top',
#   'stretch crop top trf',
#   'stretch top with stretch'],
#  ['stnylon crop top',
#   'stretch stretch top trf',
#   'cropped stretch top trf',
#   'stretch top trf',
#   'elasticated top trf',
#   'fitted stretch top trf',
#   'st/05',
#   'stretch top - limited edition',
#   'strappy stretch top trf',
#   'stretch wrap top trf',
#   'stretch top',
#   'st/strp 04',
#   'stretch top with straps',
#   'stretch stretch top',
#   'stretch crop top trf',
#   'stnylon top trf',
#   'stnylon crop top trf',
#   'stretch top with stretch'],
#  ['stt-shirt',
#   'stretch vest top trf',
#   'st t-shirt',
#   'cropped stretch top trf',
#   'stnylon vest top trf',
#   'stretch top trf',
#   'ribbed vest top',
#   'elasticated top trf',
#   'st/05',
#   'strappy stretch top trf',
#   'ribbed stretch top trf',
#   'stretch vest top',
#   'ribbed vest top trf',
#   'fitted vest top trf',
#   'stretch top',
#   'cropped vest top trf',
#   'braided stretch top trf'],
#  ['stnylon crop top',
#   'stretch stretch top trf',
#   'cropped stretch top trf',
#   'stretch top trf',
#   'elasticated top trf',
#   'fitted stretch top trf',
#   'st/05',
#   'stretch top - limited edition',
#   'strappy stretch top trf',
#   'stretch wrap top trf',
#   'stretch top',
#   'st/strp 04',
#   'stretch top with straps',
#   'stretch stretch top',
#   'stretch crop top trf',
#   'stnylon top trf',
#   'stnylon crop top trf',
#   'stretch top with stretch'],
#  ['stt-shirt with wide straps',
#   'stretch crop top',
#   'stretch top with chest reinforcement',
#   'stretch top trf',
#   'elasticated top trf',
#   'st/05',
#   'strappy stretch top trf',
#   'hipster top with wide straps',
#   'stnylon stretch top trf',
#   'cropped stretch top',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top',
#   'stretch top with wide straps',
#   'stretch top with straps',
#   'elasticated stretch top',
#   'stretch top with stretch'],
#  ['printed dress',
#   'asymmetric poplin dress',
#   'dress with asymmetric ruffles',
#   'ruffled dress trf',
#   'frilled poplin dress',
#   'ruffled poplin dress trf',
#   'ruffled poplin dress',
#   'textured dress with ruffles',
#   'printed dress with frills',
#   'denim dress with frayed detail',
#   'ruffled printed dress',
#   'poplin dress with ruffles',
#   'rustic dress with ruffles',
#   'floral print dress',
#   'poplin dress with frayed detail',
#   'ruffled dress',
#   'ruffled printed dress trf',
#   'frilled printed dress',
#   'denim dress with ruffles'],
#  ['striped sweater with side stripes',
#   'sweater with contrast stripes',
#   'striped knit sweater',
#   'contrast striped sweater',
#   'swe™ repreve textured sweater',
#   'textured sweater with stripes',
#   'sweater with contrasting stripes',
#   'knit sweater with stripes',
#   'striped sweater with contrast stripes',
#   'knit sweater with side stripes',
#   'striped sweater',
#   'stripedt/swtr 04',
#   'knit sweater with contrast stripes',
#   'sweater with side stripes'],
#  ['rain hat with band',
#   'bucket hat with face',
#   'bucketernal flame bucket hat',
#   'bucket hat with band',
#   'bucket hat trf',
#   'bucket hat',
#   'bucket hat with bands',
#   'bucketernal muslin hat',
#   'bucketernal rain hat',
#   'bucket hat with print',
#   'bucket hat with photo',
#   'bucket hat with logo',
#   'bucketernal bucket hat',
#   'bucket hat with slogan',
#   'bucketernal garden bucket hat',
#   'bucket hat with gathering',
#   'bucketernal band bucket hat',
#   'bucketernal music bucket hat'],
#  ['fine knit sweater',
#   'textured sweater with buttons',
#   'text sweater',
#   'oversized sweater',
#   'colour block sweater',
#   'sweater with lettering',
#   'oversized knit sweater',
#   'textured sweater with stripes',
#   'sweater with irregular stripes',
#   'striped sweater',
#   'premium textured sweater',
#   'textured sweater',
#   'jacquard sweater',
#   'oversized textured sweater',
#   'cable-knit sweater'],
#  ['oversize knit sweater',
#   'oversize jacquard sweater',
#   'oversized knit sweater trf',
#   'textured jacquard sweater',
#   'textured cable-knit sweater',
#   'swe™ repreve textured sweater',
#   'oversized jacquard sweater',
#   'oversized knit sweater',
#   'textured sweater with stripes',
#   'textured sweater',
#   'geometric jacquard sweater',
#   'jacquard sweater',
#   'v-neck sweater',
#   'cable-knit sweater'],
#  ['oversize knit sweater',
#   'premium high neck sweater',
#   'high neck turtleneck sweater',
#   'oversized turtleneck sweater',
#   'textured colour block sweater',
#   'oversized knit sweater trf',
#   'textured cable-knit sweater',
#   'oversized knit turtleneck sweater',
#   'oversized knit sweater',
#   'textured sweater with stripes',
#   'oversized jacquard sweater',
#   'oversize knit turtleneck sweater',
#   'turtleneck sweater',
#   'tie-dye print sweater',
#   'oversize turtleneck sweater',
#   'textured turtleneck sweater'],
#  ['textured high neck sweater',
#   'oversize knit sweater',
#   'oversize jacquard sweater',
#   'textured sweater with high neck',
#   'oversized sweater',
#   'oversize textured sweater',
#   'colour block sweater',
#   'oversized knit sweater trf',
#   'oversized jacquard sweater',
#   'oversized knit sweater',
#   'textured sweater with stripes',
#   'oversize knit sweater trf',
#   'high neck sweater trf',
#   'high neck sweater',
#   'textured sweater',
#   'geometric jacquard sweater',
#   'jacquard sweater',
#   'cable-knit sweater'],
#  ['combined puffer jacket',
#   'combined jacket with faux fur',
#   'water-repellent padded jacket',
#   'combined bomber jacket',
#   'combined jacket with contrast detail',
#   'contrast puffer jacket',
#   'contrast padded jacket',
#   'contrast faux fur jacket',
#   'jacket with contrast padded interior',
#   'combined faux fur jacket',
#   'combined faux shearling jacket',
#   'contrast padded jacket trf',
#   'combined jacket',
#   'padded jacket with contrast detail',
#   'combined padded jacket',
#   'combined quilted jacket'],
#  ['limited edition coat',
#   'check textured coat',
#   'combined coat',
#   'faux shearling coat',
#   'puffer coat',
#   'textured puffer coat',
#   'tailored coat',
#   'textured wool blend coat',
#   'textured check coat',
#   'houndstooth coat',
#   'oversized coat',
#   'textured coat with pockets',
#   'double-faced coat',
#   'faux fur coat',
#   'faux suede coat',
#   'textured coat',
#   'check puffer coat'],
#  ['coat with removable collar',
#   'combined coat',
#   'combined coat with removable detail',
#   'coat with water and wind protection',
#   'coat with contrast collar',
#   'coat with removable sleeves',
#   'coat with removable detail trf',
#   'coat with removable detail',
#   'coat with removable hood',
#   'contrast puffer coat',
#   'water-repellent coat',
#   'coat with removable interior',
#   'combined puffer coat',
#   'coat with removable interior trf',
#   'coat with wraparound collar',
#   'coat with removable coat'],
#  ['limited edition coat',
#   'check textured coat',
#   'combined coat',
#   'puffer coat',
#   'limited edition cut-out coat',
#   'textured herringbone coat',
#   'textured puffer coat',
#   'textured coat with vent',
#   'textured wool blend coat',
#   'textured check coat',
#   'textured coat with vents',
#   'houndstooth coat',
#   'textured coat with pockets',
#   'double-faced coat',
#   'houndstooth textured coat',
#   'faux fur coat',
#   'textured coat'],
#  ['check textured coat',
#   'textured comfort knit coat',
#   'textured comfort fit coat',
#   'textured herringbone coat',
#   'textured puffer coat',
#   'textured wool blend coat',
#   'combined textured coat',
#   'textured check coat',
#   'houndstooth coat',
#   'double-faced coat',
#   'double-faced faux fur coat',
#   'coat with raised lapel collar',
#   'houndstooth textured coat',
#   'textured coat with raised collar',
#   'faux fur coat',
#   'textured double-faced coat',
#   'textured coat'],
#  ['t-shirt with contrast piping',
#   'rib knit t-shirt with piping',
#   'basic t-shirt with piping',
#   'ribbed t-shirt with piping',
#   'slogan print t-shirt',
#   'plain t-shirt with piping',
#   'textured t-shirt with piping',
#   'premium t-shirt with piping',
#   'floral print t-shirt',
#   't-shirt with piping',
#   'striped t-shirt with piping',
#   'combined textured t-shirt',
#   'basic piping t-shirt',
#   'technical t-shirt with piping',
#   'striped textured t-shirt',
#   'ribbed top with piping',
#   'textured long sleeve t-shirt'],
#  ['textured short sleeve t-shirt',
#   'basic long sleeve t-shirt',
#   'plain t-shirt',
#   'ribbed t-shirt',
#   'textured colour block t-shirt',
#   'basic straight fit t-shirt',
#   'basic short sleeve t-shirt',
#   'basic basic t-shirt',
#   'basic v-neck t-shirt',
#   'v-neck t-shirt',
#   'basic plain t-shirt',
#   'basic t-shirt',
#   'ribbed t-shirt trf',
#   'textured long sleeve t-shirt',
#   'premium plain t-shirt',
#   'textured t-shirt',
#   'basic plain t-shirt trf'],
#  ['faded-effect top trf',
#   'faded-effect sporty t-shirt',
#   'cropped tie-dye t-shirt',
#   'faded-effect t-shirt trf',
#   'faded t-shirt trf',
#   'f t-shirt trf',
#   'faded-effect t-shirt',
#   'f print t-shirt trf',
#   'faded-effect slogan t-shirt',
#   'faded-effect basketball t-shirt trf',
#   'f lyocell t-shirt',
#   'faded t-shirt',
#   'f long sleeve t-shirt trf',
#   'faded-effect slogan t-shirt trf',
#   'faded-effect surf t-shirt trf',
#   'f t-shirt',
#   'f dyed t-shirt trf',
#   'faded-effect printed t-shirt trf'],
#  ['basic long sleeve t-shirt',
#   'plain t-shirt',
#   'ribbed t-shirt',
#   'faded-effect t-shirt',
#   'long sleeve t-shirt',
#   'plain-coloured t-shirt',
#   'long sleeve printed t-shirt',
#   'long sleeve compact t-shirt',
#   'long t-shirt',
#   'slogan t-shirt',
#   'rib knit t-shirt',
#   'long sleeve plain t-shirt',
#   'striped t-shirt',
#   'long sleeve t-shirt trf',
#   'basic plain t-shirt',
#   'basic t-shirt',
#   'strip t-shirt'],
#  ['ribbed beanie with label',
#   'rib knit beanie with slogan',
#   'plain ribbed beanie',
#   'ribbed hat with label detail',
#   'ribbed beanie',
#   'ribbed beanie with slogan',
#   'basic ribbed beanie',
#   'herringbone beanie',
#   'textured ribbed beanie',
#   'ribbed hat with label',
#   'rib knit beanie',
#   'ribbed slogan beanie',
#   'rib beanie with label',
#   'rib knit beanie with label',
#   'ribbed cap with label'],
#  ['cropped knit sweater',
#   'textured colour block sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'colour block sweater',
#   'knit sweater with vents',
#   'textured weave knit sweater',
#   'textured sweater with vents',
#   'textured sweater with stripes',
#   'sweater with vents',
#   'mixed knit sweater',
#   'textured sweater',
#   'cropped sweater trf',
#   'purl knit sweater',
#   'cropped sweater',
#   'colour block sweater trf',
#   'cable-knit sweater',
#   'ribbed sweater'],
#  ['cropped knit sweater',
#   'textured colour block sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'colour block sweater',
#   'knit sweater with vents',
#   'textured weave knit sweater',
#   'textured sweater with vents',
#   'textured sweater with stripes',
#   'sweater with vents',
#   'mixed knit sweater',
#   'textured sweater',
#   'cropped sweater trf',
#   'purl knit sweater',
#   'cropped sweater',
#   'colour block sweater trf',
#   'cable-knit sweater',
#   'ribbed sweater'],
#  ['buckleather belt',
#   'striped stretch belt',
#   'slim belt with golden buckle',
#   'stretch belt with golden buckle',
#   'strip®repreve leather belt',
#   'elastic belt with gold buckle',
#   'limited edition belt with golden buckle',
#   'velvet belt with golden buckle',
#   'stretch belt',
#   'stpckt 05',
#   'belt',
#   'elastic belt - limited edition',
#   'belt with golden buckle',
#   'stpckt/05',
#   'elastic belt with golden buckle',
#   'tretch belt with golden buckle',
#   'belt with gold buckle',
#   'elastic belt',
#   'thretch belt with golden buckle'],
#  ['belt with chain buckle',
#   'belt with chain',
#   'wide buckled belt',
#   'double buckle belt with chain',
#   'wide belt with chains',
#   'wide belt with double buckle',
#   'double buckle belt',
#   'wide belt with chain detail',
#   'belt with double buckle',
#   'wide belt with chain buckle',
#   'wide belt with chain',
#   'belt with double buckle and chain',
#   'belt with buckle and chain',
#   'double buckle belt trf',
#   'buckled belt with chain'],
#  ['plush trousers with side slogan',
#   'plush jersey trousers with slogan',
#   'trousers with slogan print',
#   'plush trousers with slogan print',
#   'plslogan trousers',
#   'plush trousers with slogan',
#   'slogan trousers',
#   'plush jersey slogan trousers',
#   'plsporty trousers with slogan',
#   'plush jersey jogging trousers',
#   'plush jogging trousers',
#   'plush piqué trousers',
#   'jogging trousers with slogan print',
#   'jogging trousers with slogan',
#   'sporty trousers with slogan'],
#  ['plush trousers with side slogan',
#   'plush jersey trousers with slogan',
#   'trousers with slogan print',
#   'plush trousers with slogan print',
#   'plslogan trousers',
#   'plush trousers with slogan',
#   'slogan trousers',
#   'plush jogging trousers',
#   'plsporty trousers with slogan',
#   'plush jersey slogan trousers',
#   'plush jersey jogging trousers',
#   'plush piqué trousers',
#   'jogging trousers with slogan print',
#   'jogging trousers with slogan',
#   'sporty trousers with slogan'],
#  ['short sleeve t-shirt',
#   'plain t-shirt',
#   'ribbed t-shirt',
#   'rib t-shirt',
#   'basic short sleeve t-shirt',
#   'cropped ribbed t-shirt',
#   'plain-coloured t-shirt',
#   'long sleeve t-shirt',
#   'tie-dye t-shirt',
#   'short sleeve t-shirt trf',
#   'striped t-shirt trf',
#   'striped texture t-shirt',
#   'striped t-shirt',
#   'long sleeve t-shirt trf',
#   'basic plain t-shirt',
#   'ribbed t-shirt trf',
#   'textured t-shirt'],
#  ['cropped trousers',
#   'darted trousers trf',
#   'jacquard trousers',
#   'wide-leg trousers',
#   'cropped trousers trf',
#   'flowing trousers trf',
#   'loose-fitting trousers',
#   'high waist trousers',
#   'high-rise modern trousers',
#   'check trousers',
#   'slouchy trousers',
#   'faux leather trousers',
#   'faux suede trousers',
#   'straight fit trousers',
#   'check trousers trf'],
#  ['flounce dress trf',
#   'voluminous printed dress trf',
#   'pleated dress trf',
#   'floral print dress trf',
#   'flowing dress trf',
#   'loose-fitting dress trf',
#   'puff sleeve dress trf',
#   'printed dress trf',
#   'voluminous dress trf',
#   'voliskirt dress trf',
#   'voluminous mini dress trf',
#   'floral print dress',
#   'printed mini dress trf',
#   'faux leather dress trf',
#   'animal print dress trf'],
#  ['flowing jumpsuit with belt',
#   'belted jumpsuit with belt',
#   'belted flannel jumpsuit',
#   'belted duffle bag jumpsuit',
#   'textured jumpsuit with belt',
#   'printed jumpsuit with belt',
#   'rustic jumpsuit with belt',
#   'belted jumpsuit',
#   'jumpsuit with contrast belt',
#   'faux leather belted jumpsuit',
#   'belted jumpsuit trf',
#   'jumpsuit with belt',
#   'jumpsuit with contrasting belt',
#   'jumpsuit with belt trf',
#   'belted jumpsuit with draped detail',
#   'faux leather jumpsuit with belt'],
#  [' fujiji instax mini 9 camera pack',
#   'fujifilm instax mini 9 camera pack',
#   ' fujiji instax mini 9 camera set',
#   'srpls x fuji cmr 1',
#   'pack of fujifilm instax mini 9 camera',
#   'fujifilm mini 9 camera',
#   'pack of fujifilm instax mini 9 cameras',
#   'fujifilm instax mini 9 camera',
#   'pack of fuji instax mini 9 camera and film',
#   'srpls x fuji cmr',
#   'pack of fujifilm instax mini 9 camera and film',
#   'fujifilm instax mini 9 camera and film packs',
#   'srpls x fuji',
#   'srpls x fuji cmr i',
#   ' fujiji instax mini 9 camera',
#   ' fujiji instax mini 9 camera bag',
#   ' fujiji cmr srpls',
#   'pack of fuji camera film and camera film',
#   ' fuji cmr srpls',
#   'pack of fuji camera film and camera film accessories'],
#  ['asymmetric poplin dress',
#   'asymmetric dress with belt',
#   'poplin dress with belt',
#   'printed midi dress',
#   'printed dress with belt trf',
#   'printed dress with belt',
#   'asymmetric midi dress',
#   'asymmetric belted dress',
#   'asymmetric satin dress',
#   'asymmetric pleated dress',
#   'printed mini dress',
#   'pleated dress with belt',
#   'ruffled dress with belt',
#   'floral print dress',
#   'asymmetric printed dress'],
#  ['jacket with faux fur lining',
#   'faux fur jacket',
#   'faux fur biker jacket',
#   'faux leather puffer jacket',
#   'faux shearling jacket trf',
#   'faux fur jacket with belt',
#   'faux shearling biker jacket',
#   'faux leather jacket',
#   'faux shearling jacket with belt',
#   'faux suede jacket trf',
#   'faux leather jacket trf',
#   'faux suede biker jacket',
#   'faux leather jacket with belt',
#   'faux leather biker jacket',
#   'faux suede jacket',
#   'faux fur jacket trf'],
#  ['fjacket with shoulder pads',
#   'faux leather jacket with shoulder pads',
#   'faux suede bomber jacket',
#   'faux fur jacket with shoulder pads',
#   'quilted jacket with shoulder pads',
#   'neoprene-effect jacket',
#   'knit jacket with shoulder pads',
#   'jacket with shoulder pads trf',
#   'faux leather jacket',
#   'bomber jacket with shoulder pads',
#   'faux suede jacket trf',
#   'faux leather jacket trf',
#   'denim jacket with shoulder pads',
#   'velvet jacket with shoulder pads',
#   'jacket with shoulder pads',
#   'faux suede jacket'],
#  ['sweater with contrast pocket',
#   'henley sweater',
#   'henley sweater with pocket',
#   'plain knit henley sweater',
#   'colour block henley sweater',
#   'cropped henley sweater',
#   'knit henley sweater',
#   'plain henley sweater',
#   'striped henley sweater',
#   'textured henley sweater',
#   'mixed knit henley sweater',
#   'purl knit henley sweater',
#   'basic henley sweater',
#   'strip knit henley sweater'],
#  ['jacket with bejewelled fringing',
#   'fringed jacket trf',
#   'fringed faux suede jacket',
#   'fringed denim jacket trf',
#   'jacket with gem appliqué',
#   'fringed jacket',
#   'denim jacket with bejewelled fringe',
#   'fringed velvet jacket',
#   'fringed faux shearling jacket',
#   'jacket with bejewelled fringe',
#   'fringed faux leather jacket',
#   'jacket with fringed fringe',
#   'fringed denim jacket',
#   'limited edition bejewelled fringe jacket'],
#  ['printed dress',
#   'printed shirt dress',
#   'denim dress with belt',
#   'satin dress with belt',
#   'printed midi dress',
#   'midi dress with belt',
#   'belted shirt dress',
#   'printed dress with belt',
#   'flowing dress with belt',
#   'belted midi dress',
#   'belteddy twill dress',
#   'rustic dress with belt',
#   'belted dress',
#   'belted dress trf'],
#  ['ribbed leggings',
#   'leggings with natural pearl bead',
#   'rib knit leggings',
#   'ribbed leggings with print',
#   'bib leggings',
#   'leggings with natural pearl beads',
#   'ribbed leggings with biodiversity',
#   'beaded leggings',
#   'leggings with thin waistband',
#   'basic leggings',
#   'rib leggings with textured weave',
#   'ribbed cotton leggings',
#   'basic leggings with elastic waistband',
#   'ribbed leggings with gathering',
#   'ribbed leggings with slogan',
#   'leggings with natural fibres',
#   'leggings with round waistband',
#   'leggings with elastic waistband',
#   'leggings with edge edge'],
#  ['cropped knit sweater',
#   'textured colour block sweater',
#   'open-knit sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'colour block sweater',
#   'plain knit sweater',
#   'textured weave knit sweater',
#   'mixed knit sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'textured sweater',
#   'basic knit sweater',
#   'purl knit sweater',
#   'colour block sweater trf',
#   'cable-knit sweater',
#   'ribbed sweater'],
#  ['textured wool blend sweater',
#   'textured colour block sweater',
#   'striped textured sweater',
#   'wool blend knit sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'knt/swtr 05',
#   'textured wool sweater',
#   'textured cable-knit sweater',
#   'textured weave knit sweater',
#   'cable-knit sweater',
#   'cropped wool blend sweater',
#   'textured sweater - limited edition',
#   'textured sweater with stripes',
#   'striped wool blend sweater',
#   'textured knit sweater',
#   'purl knit sweater',
#   'ribbed wool blend sweater',
#   'wool blend sweater'],
#  ['text suit blazer',
#   'pinstriped suit blazer',
#   'textured double-layer blazer',
#   'textured check suit blazer',
#   'textured suit blazer',
#   'double-breasted suit blazer',
#   'double-layer suit blazer',
#   'double-breasted check blazer',
#   'text check suit blazer',
#   'comfort fit check suit blazer',
#   'textured blazer',
#   'textured check blazer',
#   'comfort fit suit blazer',
#   'check textured suit blazer',
#   'check suit blazer',
#   'relaxed fit suit blazer',
#   'basic blazer'],
#  ["zw premium '80s skinny bering blue jeans",
#   'jeans zw premium ‘80s skinny bering blue',
#   'z ‘80s skinny bering blue jeans',
#   'zwonder rose ‘80s skinny bering blue jeans',
#   'zw premium the ’80s skinny bering blue jeans',
#   'zwz premium ‘80s skinny bering blue jeans',
#   'zw premium the ‘80s skinny bering blue jeans',
#   "zw premium the '80s skinny bering blue jeans",
#   'zw ‘80s skinny bering blue jeans',
#   'zw premium ’80s skinny bering blue jeans',
#   'zw premium 80s skinny bering blue jeans',
#   'zwaffle-knit ‘80s skinny bering blue jeans',
#   'zw premium‘80s skinny bering blue jeans',
#   "zwz premium '80s skinny bering blue jeans",
#   'zw premium ‘80s skinny bering blue jeans',
#   "jeans zw premium '80s skinny bering blue"],
#  ['basic asymmetric t-shirt',
#   'basic asymmetric t-shirt trf',
#   'striped asymmetric t-shirt',
#   'long sleeve t-shirt',
#   't-shirt with contrast neckline',
#   'oversized t-shirt trf',
#   'striped t-shirt trf',
#   'long sleeve asymmetric t-shirt',
#   'striped texture t-shirt',
#   'striped t-shirt',
#   'asymmetric t-shirt trf',
#   'long sleeve t-shirt trf',
#   'asymmetric hem t-shirt',
#   'textured long sleeve t-shirt',
#   'textured t-shirt',
#   't-shirt with asymmetric hem'],
#  ['basic asymmetric t-shirt',
#   'asymmetric t-shirt',
#   'long sleeve t-shirt',
#   't-shirt with contrast neckline',
#   'contrast t-shirt trf',
#   'oversized t-shirt trf',
#   'striped t-shirt trf',
#   'long sleeve asymmetric t-shirt',
#   'asymmetric textured t-shirt',
#   'striped texture t-shirt',
#   'striped t-shirt',
#   'asymmetric t-shirt trf',
#   'long sleeve t-shirt trf',
#   't-shirt with asymmetrical hem',
#   'oversized t-shirt',
#   'asymmetric hem t-shirt',
#   't-shirt with asymmetric hem',
#   'asymmetric length t-shirt'],
#  ['asymmetric t-shirt',
#   'basic asymmetrical t-shirt',
#   't-shirt with contrast neckline',
#   'long sleeve asymmetrical t-shirt',
#   'tie-dye t-shirt',
#   'oversized t-shirt trf',
#   'striped t-shirt trf',
#   'long sleeve asymmetric t-shirt',
#   'striped t-shirt',
#   'basic asymmetrical t-shirt trf',
#   'asymmetric t-shirt trf',
#   'long sleeve t-shirt trf',
#   't-shirt with asymmetrical hem',
#   'asymmetric hem t-shirt',
#   't-shirt with asymmetric hem',
#   'asymmetric length t-shirt'],
#  ['embroidered t-shirt',
#   'contrast texture t-shirt',
#   'basic asymmetrical t-shirt',
#   't-shirt with contrast hem',
#   't-shirt with contrast neckline',
#   'ecologically grown cotton t-shirt',
#   'contrast textured t-shirt',
#   'cotton t-shirt',
#   'contrasting fabric t-shirt',
#   't-shirt with irregular hem',
#   'striped t-shirt',
#   't-shirt with asymmetrical hem',
#   't-shirt with square hem',
#   'asymmetric hem t-shirt',
#   't-shirt with asymmetric hem',
#   't-shirt with square neckline',
#   'fibre t-shirt',
#   't-shirt with contrast trim'],
#  ['plain t-shirt',
#   'ribbed t-shirt',
#   'basic t-shirt trf',
#   'rib t-shirt',
#   'plain-coloured t-shirt',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'striped t-shirt trf',
#   'slogan t-shirt',
#   'striped t-shirt',
#   'basic plain t-shirt',
#   'rib t-shirt trf',
#   'basic t-shirt',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'premium plain t-shirt',
#   'basic plain t-shirt trf',
#   'strip t-shirt'],
#  ['large hoop earrings with letters',
#   'large hoop earrings with lace',
#   'hoop earrings',
#   'bejewelled hoop earrings',
#   'limited edition large hoop earrings',
#   'large hoop earrings with detail',
#   'contrasting hoop earrings',
#   'textured hoop earrings',
#   'beaded hoop earrings',
#   'large hoop earrings trf',
#   'limited edition hoop earrings',
#   'large hoop earrings with flower',
#   'large hoop earrings with ribbon',
#   'large hoop earrings',
#   'large hoop hoop earrings',
#   'large hoop earrings with hoop',
#   'contrast hoop earrings',
#   'contrast design hoop earrings'],
#  ['2-pack of contrast hoop earrings',
#   'two-pack of hoop earrings',
#   'two 2-pack of hoop earrings',
#   'pack of multicoloured hoop earrings',
#   '2-pack of small hoop earrings',
#   'pack of 2 pairs of earrings',
#   '2-pack of assorted hoop earrings',
#   '2-pack of large hoop earrings',
#   'pack of 2 pairs of assorted earrings',
#   'pack of 20 pairs of hoop earrings',
#   'pack of earrings',
#   '2-pack of hoop earrings',
#   'pack of 2 pairs of hoop earrings',
#   'pack of assorted hoop earrings',
#   '2-pack of assorted earrings',
#   'pack of hoop earrings',
#   'pack of contrast hoop earrings',
#   'pack of assorted earrings'],
#  ['textured scarf with fringe',
#   'jacquilted scarf',
#   'fringed scarf',
#   'textured check scarf',
#   'jacquard scarf',
#   'check textured scarf',
#   'premium textured scarf',
#   'basic textured scarf',
#   'limited edition textured scarf',
#   'animal print scarf',
#   'scarf with fringing',
#   'striped textured scarf',
#   'textured scarf'],
#  ['faux leather pleated skirt',
#   'textured pleated skirt',
#   'pleated faux leather skirt',
#   'pleated skirt',
#   'ple pleated skirt',
#   'pleated midi skirt',
#   'pleated skirt trf',
#   'ottoman pleated skirt',
#   'pleated check skirt',
#   'ple pleated skirt trf',
#   'rubberised pleated skirt',
#   'polka dot pleated skirt',
#   'pleated pleated skirt',
#   'pleated knit skirt',
#   'houndstooth pleated skirt'],
#  ['ribbed t-shirt',
#   'cropped t-shirt trf',
#   'basic t-shirt trf',
#   'rib t-shirt',
#   'rib knit t-shirt trf',
#   'basic v-neck t-shirt',
#   'v-neck t-shirt',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'rib knit t-shirt',
#   'striped t-shirt',
#   'long sleeve t-shirt trf',
#   'cable-knit t-shirt',
#   'rib t-shirt trf',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'textured t-shirt'],
#  ['ribbed t-shirt',
#   'cropped t-shirt trf',
#   'basic t-shirt trf',
#   'rib t-shirt',
#   'rib knit t-shirt trf',
#   'basic v-neck t-shirt',
#   'v-neck t-shirt',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'rib knit t-shirt',
#   'striped t-shirt',
#   'long sleeve t-shirt trf',
#   'cable-knit t-shirt',
#   'rib t-shirt trf',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'textured t-shirt'],
#  ['ribbed t-shirt',
#   'textured v-neck t-shirt',
#   'rib t-shirt',
#   'basic t-shirt trf',
#   'striped v-neck t-shirt',
#   'rib knit t-shirt trf',
#   'long sleeve t-shirt',
#   'basic v-neck t-shirt',
#   'v-neck t-shirt',
#   'v-neck t-shirt trf',
#   'rib knit t-shirt',
#   'striped t-shirt',
#   'cable-knit t-shirt',
#   'cropped t-shirt',
#   'rib t-shirt trf',
#   'ribbed t-shirt trf',
#   'strip t-shirt',
#   'ribbed v-neck t-shirt'],
#  ['frilled top trf',
#   'ruffled top trf',
#   'contrast poplin top',
#   'ruffled printed top',
#   'contrast textured top',
#   'floral print top',
#   'ruffled top',
#   'frilly poplin top',
#   'ruff top',
#   'top with contrast ruffles',
#   'ruff top trf',
#   'ruffled printed top trf',
#   'frilled poplin top',
#   'top with contrasting ruffles',
#   'ruffled poplin top',
#   'combined poplin top',
#   'ruffled floral print top'],
#  ['textured fabric earrings',
#   'earrings with fabric',
#   'minimalist earrings',
#   'plumetis earrings',
#   'textured earrings',
#   'fabricotta earrings',
#   'fabrico earrings',
#   'pack of earrings',
#   'round fabric earrings',
#   'round earrings',
#   'fabric hoop earrings',
#   'contrasting earrings',
#   'contrast earrings',
#   'pack of sparkly earrings',
#   'fabric earrings',
#   'pack of earrings with fabric',
#   'contrasting fabric earrings',
#   'contrast fabric earrings',
#   'floral earrings'],
#  ['faux leather jumpsuit',
#   'belteddy twill jumpsuit',
#   'belteddy dyd jumpsuit',
#   'belted jumpsuit with pockets',
#   'belted jumpsuit with belt',
#   'den jumpsuit with belt trf',
#   'long belted jumpsuit',
#   'belteddy jumpsuit',
#   'long jumpsuit with belt',
#   'jumpsuit with pockets',
#   'belted jumpsuit',
#   'denim jumpsuit with belt',
#   'faux suede jumpsuit',
#   'jmp 04',
#   'belted jumpsuit trf',
#   'jumpsuit with belt'],
#  ['cropped knit sweater',
#   'textured colour block sweater',
#   'striped textured sweater',
#   'striped knit sweater',
#   'textured short sleeve sweater',
#   'plain knit sweater',
#   'textured weave knit sweater',
#   'textured sweater with stripes',
#   'textured cotton sweater',
#   'textured knit sweater',
#   'ribbed knit sweater',
#   'textured sweater',
#   'basic knit sweater',
#   'cable-knit sweater',
#   'textured striped sweater'],
#  ['plain t-shirt',
#   'ribbed t-shirt',
#   'basic t-shirt trf',
#   'rib t-shirt',
#   'plain-coloured t-shirt',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'striped t-shirt trf',
#   'slogan t-shirt',
#   'striped t-shirt',
#   'basic plain t-shirt',
#   'rib t-shirt trf',
#   'basic t-shirt',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'premium plain t-shirt',
#   'basic plain t-shirt trf',
#   'strip t-shirt'],
#  ['halterneck bodysuit',
#   'ribbed bodysuit trf',
#   'hal knit bodysuit',
#   'halter bodysuit trf',
#   'halvelvet bodysuit trf',
#   'halute bodysuit trf',
#   'halter neck bodysuit trf',
#   'bodysuit with halter neck',
#   'halter-neck bodysuit',
#   'halter bodysuit',
#   'lace bodysuit trf',
#   'hal knit bodysuit trf',
#   'halterneck bodysuit trf',
#   'halter top bodysuit trf',
#   'halter neck bodysuit',
#   'halvelvet bodysuit'],
#  ['t-shirt with front print',
#   'slogan print t-shirt',
#   'contrasting print t-shirt',
#   'contrast textured t-shirt',
#   'photo print t-shirt',
#   'skull print t-shirt',
#   'contrast print t-shirt',
#   'front print t-shirt trf',
#   'floral print t-shirt',
#   'photographic print t-shirt',
#   'daisy print t-shirt',
#   't/strp/ t 04',
#   'front print t-shirt',
#   'photo print t-shirt trf'],
#  ['faux suede bomber jacket',
#   'neoprene-effect jacket',
#   'faux leather puffer jacket',
#   'faux shearling jacket trf',
#   'jacket with contrast faux shearling',
#   'contrast puffer jacket',
#   'jacket with pockets',
#   'faux fur puffer jacket',
#   'faux leather jacket',
#   'faux suede jacket trf',
#   'faux suede puffer jacket',
#   'faux leather jacket trf',
#   'faux leather biker jacket',
#   'faux shearling jacket',
#   'faux suede jacket',
#   'rubberised puffer jacket'],
#  ['faux suede trench coat',
#   'belted trench coat',
#   'double breasted trench coat trf',
#   'houndstooth trench coat',
#   'faux leather trench coat',
#   'trench coat with buckles',
#   'limited edition leather trench coat',
#   'double-breasted trench coat',
#   'trench coat with belt',
#   'rustic trench coat',
#   'double breasted trench coat',
#   'limited edition trench coat with belt',
#   'limited edition trench coat',
#   'rustic trench coat with belt'],
#  ['puffer jacket with hood',
#   'tailored puffer jacket',
#   'hooded jacket',
#   'hooded jacket trf',
#   'hooded puffer jacket',
#   'quilted jacket with hood',
#   'hooded quilted jacket',
#   'faux leather puffer jacket',
#   'faux suede hooded jacket',
#   'hooded technical jacket',
#   'hooded puffer jacket trf',
#   'lightweight puffer jacket',
#   'faux suede puffer jacket',
#   'reflective print puffer jacket',
#   'faux suede jacket'],
#  ['cropped knit sweater',
#   'cropped knit sweater trf',
#   'v-neck knit sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'long knit sweater',
#   'striped knit sweater trf',
#   'knit sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'v-neck sweater',
#   'ribbed knit sweater trf',
#   'v-neck sweater trf',
#   'jacquard knit sweater',
#   'cable-knit sweater'],
#  ['cropped knit sweater',
#   'cropped knit sweater trf',
#   'v-neck knit sweater',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'long knit sweater',
#   'striped knit sweater trf',
#   'knit sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'v-neck sweater',
#   'ribbed knit sweater trf',
#   'v-neck sweater trf',
#   'jacquard knit sweater',
#   'cable-knit sweater'],
#  ['snoopy ®peanuts jogging trousers',
#   'snoopy ® peanuts plush jersey jogging trousers',
#   'jogging trousers with snoopy ® peanuts print',
#   's ® peanuts plush jersey jogging trousers',
#   'snoopy ® peanuts joggers',
#   's snoopy ® peanuts jogging trousers',
#   'snoopy ®peanuts plush trousers',
#   'snoopy ® peanuts plush jogging trousers',
#   'snoopy ® peanuts plush jersey trousers',
#   'snoopy ® peanuts trousers',
#   'snoopy ® peanuts plush jersey joggers',
#   'plush snoopy ® peanuts jogging trousers',
#   'snoopy ® peanuts plush trousers',
#   'snoopy ®peanuts plush jogging trousers',
#   'snoopy ® peanuts print jogging trousers',
#   'snoopy ® peanuts jogging trousers'],
#  ['skinny jeans',
#   'slim fit 70s jeans',
#   'faded slim fit jeans',
#   'easy care slim fit jeans',
#   'jeans z1975 slim',
#   'z1975 slim fit jeans',
#   'skinny fit jeans',
#   'slim fit 80s jeans',
#   'slimber fit jeans',
#   'slim fit faded jeans',
#   'slim fit faded fit jeans',
#   'slim fit z1975 jeans',
#   'slim fit faded blue jeans',
#   'basic slim fit jeans',
#   'slim fit jeans',
#   'slim fit tapered fit jeans'],
#  ['contrast poplin top',
#   'contrast pleated top',
#   'ple top with bow trf',
#   'contrast textured top',
#   'poplinen top with bow',
#   'contrast top trf',
#   'contrasting pleated top',
#   'pleated top with bow',
#   'ple top with bow',
#   'top with contrast pleated sleeves',
#   'crop top with pleated sleeves',
#   'poplin top with bows',
#   'contrast top with bow',
#   'contrast top',
#   'combined poplin top',
#   'poplin top with bow',
#   'flowing top with bow'],
#  ['super slim fit poplin shirt',
#   'super slim fit striped poplin shirt',
#   'stretch poplin shirt with model',
#   'premium super slim fit shirt',
#   'slim fit poplin shirt',
#   'stretch shirt with textured weave',
#   'stretch poplin shirt with detail',
#   'stretch poplin shirt',
#   'basic super slim fit shirt trf',
#   'stretch poplin shirt with slogan',
#   'super slim fit shirt',
#   'stretch shirt with animal print',
#   'super slim fit poplin shirt trf',
#   'stretch shirt with contrast collar',
#   'stretch shirt with classic collar',
#   'basic super slim fit shirt',
#   'striped stretch shirt',
#   'stretch poplin shirt with print'],
#  ['premium super slim fit shirt',
#   'super slim fit shirt trf',
#   'super slim fit stretch shirt',
#   'super slim fit oxford shirt',
#   'super slim fit printed shirt',
#   'super slim fit textured shirt',
#   'super slim fit chino shirt',
#   'super slim fit floral print shirt',
#   'super slim fit shirt',
#   'super slim fit check shirt',
#   'super slim fit striped shirt',
#   'super slim fit t-shirt',
#   'super slim fit traveler shirt',
#   'basic super slim fit shirt',
#   'striped stretch shirt'],
#  ['embroidered midi dress',
#   'embroidered poplin dress',
#   'em embroidered dress',
#   'embroidered dress',
#   'dress dress with embroidery trf',
#   'embroidered voluminous dress',
#   'dress with contrast tassels',
#   'dress with contrast embroidery',
#   'limited edition embroidered dress',
#   'embroidered mini dress',
#   'embroidered dress trf',
#   'dress with contrasting embroidery',
#   'dress with embroidered sleeves',
#   'embroidered velvet dress',
#   'embroidered tulle dress'],
#  ['down puffer jacket with slogan',
#   'long down puffer jacket with slogan',
#   'diamond down puffer jacket',
#   'water repellent down puffer jacket',
#   'striped down puffer jacket',
#   's ®repreve down puffer jacket',
#   'down ®repreve down puffer jacket',
#   'hooded down puffer jacket',
#   'rubberised down puffer jacket',
#   'embossed down puffer jacket',
#   'sporty down puffer jacket',
#   'lightweight down puffer jacket',
#   'down puffer jacket with rubberised detail',
#   'long down puffer jacket',
#   'hooded down puffer jacket with slogan',
#   'basic down puffer jacket',
#   'colour block down puffer jacket'],
#  ['high neck sweater with buttons',
#   'textured sweater with buttons',
#   'knit sweater with buttons',
#   'ribbed high neck sweater',
#   'basic high neck sweater',
#   'rib knit sweater with buttons',
#   'cable-knit sweater',
#   'sweater with metal buttons',
#   'textured weave knit sweater',
#   'high neck sweater trf',
#   'sweater with buttons',
#   'high neck sweater'],
#  ['textured check suit blazer',
#   'textured suit blazer',
#   'linen/cotton blazer',
#   'cotton/linen suit blazer',
#   'linen - cotton suit blazer',
#   'rustic check suit blazer',
#   'linen blend suit blazer',
#   'cotton/linen blazer',
#   'linen/cotton suit blazer',
#   'textured linen - cotton blazer',
#   'textured linen/cotton blazer',
#   'linen blend blazer',
#   'linen blend check suit blazer',
#   'linen/viscose blazer',
#   'rustic blazer',
#   'rustic suit blazer'],
#  ['linen - cotton suit trousers',
#   'textured linen/cotton suit trousers',
#   'linen/cotton textured trousers',
#   'textured linen - cotton trousers',
#   'slim fit linen blend trousers',
#   'slim fit rustic trousers',
#   'slim fit linen/cotton trousers',
#   'rustic trousers',
#   'textured linen/cotton trousers',
#   'textured linen - cotton suit trousers',
#   'slim fit linen - cotton trousers',
#   'cotton/linen textured trousers',
#   'textured suit trousers',
#   'linen blend suit trousers',
#   'textured cotton/linen trousers',
#   'cotton/linen suit trousers',
#   'linen/cotton suit trousers',
#   'textured check suit trousers'],
#  ['wool blend knit sweater',
#   'w/swtr 05',
#   'knt/swtr 05',
#   'oversized knit sweater trf',
#   'limited edition wool blend sweater',
#   'cropped wool blend sweater',
#   'oversized knit sweater',
#   'striped wool blend sweater',
#   'high neck sweater trf',
#   'w/swtr 04',
#   'high neck sweater',
#   'cropped sweater trf',
#   'wool blend sweater trf',
#   'ribbed wool blend sweater',
#   'wool blend sweater',
#   'wool blend sweater with vents'],
#  ['star chunky knit carrycot baby wrap',
#   'stars carrycot baby wrap',
#   'faux fur carrycot baby wrap',
#   'stars carrycot baby wrap with faux fur lining',
#   'lined star print carrycot baby wrap',
#   'star printcarrycot baby wrap',
#   'star print carrycot baby wrap with hood',
#   'star carrycot baby wrap with faux fur lining',
#   'star carrycot baby wrap',
#   'star-print carrycot baby wrap',
#   'carrycot baby wrap with stars',
#   'star print carrycot baby wrap trf',
#   'star print carrycot baby wrap with lining',
#   'star print carrycot baby wrap',
#   'knit carrycot baby wrap with stars'],
#  ['coat with removable collar',
#   'coat with contrast collar trf',
#   'coat with wraparound collar',
#   'coat with removable collar trf',
#   'coat with water and wind protection',
#   'coat with faux shearling',
#   'coat with contrast collar',
#   'coat with removable detail',
#   'coat with contrast faux shearling',
#   'coat with faux fur collar',
#   'combined faux shearling coat',
#   'water-repellent coat',
#   'contrast puffer coat',
#   'coat with faux fur',
#   'combined faux fur coat',
#   'faux leather puffer coat'],
#  ['textured chino trousers',
#   'cropped trousers',
#   'textured trousers',
#   'cropped chino trousers',
#   'cropped trousers trf',
#   'slim fit chino trousers',
#   'chintz comfort suit trousers',
#   'striped textured suit trousers',
#   'textured suit trousers',
#   'cropped chinos',
#   'cropped slouchy trousers',
#   'cropped corduroy trousers',
#   'slim fit trousers',
#   'cropped suit trousers',
#   'slim fit suit trousers',
#   'cropped check suit trousers',
#   'cropped slim fit trousers',
#   'slouchy trousers',
#   'textured check suit trousers'],
#  ['jeans zw premium 70s revolve black',
#   'jeans zw premium 90s revolve black',
#   'zw premium revolve black jeans',
#   'zwaffle-knit high waist revolve black jeans',
#   'jeans zw premium slim revolve black',
#   'z premium high waist revolve black jeans',
#   'zw premium the hw waist revolve black jeans',
#   'zwaxed-effect revolve black jeans',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zw premium slim revolve black jeans',
#   'jeans zw premium the high waist revolve black',
#   'jeans zw premium high waist revolve black',
#   'zw premium high waist revolve black jeans',
#   'z premium revolve black jeans',
#   'zw premium 90s revolve black jeans'],
#  ['jeans zw premium 70s revolve black',
#   'zw premium skinny revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium zw premium revolve black jeans',
#   'zw premium high waist revolve black skinny jeans',
#   'z premium high waist revolve black jeans',
#   'zw premium 90s revolve black jeans',
#   'zwaxed-effect revolve black jeans',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zwaxed-effect revolve black skinny jeans',
#   'jeans zw premium revolve black',
#   'jeans zw premium high waist revolve black',
#   'zw premium high waist revolve black jeans',
#   'jeans zw premium 90s revolve black'],
#  ['jeans zw premium 70s revolve black',
#   'jeans zw premium 90s revolve black',
#   'zw premium revolve black jeans',
#   'zwaffle-knit high waist revolve black jeans',
#   'jeans zw premium slim revolve black',
#   'z premium high waist revolve black jeans',
#   'zw premium the hw waist revolve black jeans',
#   'zwaxed-effect revolve black jeans',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zw premium slim revolve black jeans',
#   'jeans zw premium the high waist revolve black',
#   'jeans zw premium high waist revolve black',
#   'zw premium high waist revolve black jeans',
#   'z premium revolve black jeans',
#   'zw premium 90s revolve black jeans'],
#  ['ballerina t-shirt with slogan',
#   'slogan print t-shirt',
#   'sporty slogan t-shirt',
#   'embossed t-shirt',
#   'sporty t-shirt with slogan',
#   'tiger t-shirt',
#   'embossed t-shirt with slogan',
#   'striped t-shirt with slogan',
#   'placement slogan t-shirt',
#   'contrast slogan t-shirt',
#   'paint splatter t-shirt',
#   'ballerina t-shirt',
#   'skull print t-shirt',
#   'slogan t-shirt with print',
#   't-shirt with front slogan',
#   'slogan t-shirt',
#   't-shirt with back slogan',
#   'raglan sleeve t-shirt'],
#  ['limited edition sequinned dress',
#   'limited edition dress with sequins',
#   'contrast sequinned dress',
#   'sequinverted hem dress',
#   'sequinverted lapel collar dress',
#   'velvet dress with sequins',
#   'sequinned dress',
#   'sequinned dress trf',
#   'dress with contrast sequins',
#   'sequinverted hem dress trf',
#   'sequinverted pleated dress',
#   'sequinverted dress trf',
#   'sequinverted lapel dress',
#   'combined sequinned dress',
#   'sequinned midi dress',
#   'satin dress with sequins'],
#  ['textured nautical cap',
#   'nautical cap',
#   'check nautical cap',
#   'long nautical cap',
#   'printed nautical cap',
#   'cap with peak',
#   'seersucker nautical cap',
#   'c nautical cap',
#   'neon nautical cap',
#   'cargo nautical cap',
#   'aquamarine nautical cap',
#   'foil nautical cap',
#   'accesories 05',
#   'n nautical cap',
#   'sporty nautical cap',
#   'navy cap',
#   'herringbone nautical cap',
#   'nautical cap with peak'],
#  ['asymmetric midi skirt trf',
#   'asymmetric skirt',
#   'asymmetric skirt with zip',
#   'faux leather midi skirt trf',
#   'asymmetric pencil skirt trf',
#   'denim skirt with buttons trf',
#   'asymmetric midi skirt',
#   'asymmetric pencil skirt',
#   'asymmetric skirt with button',
#   'denim skirt trf',
#   'faux leather midi skirt',
#   'denim skirt with belt loops',
#   'asymmetric skirt with pockets trf',
#   'asymmetric skirt with buttons',
#   'asymmetric skirt trf',
#   'denim midi skirt trf',
#   'asymmetric buttoned skirt trf',
#   'asymmetric skirt with belt loops',
#   'accordion pleat skirt'],
#  ['coat with contrast collar trf',
#   'combined coat',
#   'coat with contrast collar',
#   'contrast collar coat',
#   'textured coat with contrast collar',
#   'combined coat with contrast collar',
#   'double-faced faux fur coat',
#   'combined faux shearling coat',
#   'contrast puffer coat',
#   'water-repellent coat',
#   'combined puffer coat',
#   'puffer coat with contrast collar',
#   'combined faux fur coat',
#   'coat with contrasting collar'],
#  ['cropped knit sweater',
#   'textured colour block sweater',
#   'open-knit sweater',
#   'striped knit sweater',
#   'soft-touch knit sweater',
#   'textured weave knit sweater',
#   'mixed knit sweater',
#   'knit sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'textured sweater',
#   'basic knit sweater',
#   'purl knit sweater',
#   'cable-knit sweater'],
#  ['textured textured bermuda shorts',
#   'textured bermudas',
#   'textured check bermuda shorts',
#   'textured bermuda shorts with buttons',
# ...
#   'pouffe with a strap',
#   'p pouffe',
#   'faux leather pouffe',
#   'textured pouffe',
#   'textured cotton pouffe'],
#  ['crystal lamp',
#   'wood lamp with wooden base',
#   'wooden lamp',
#   'glass lamp with wooden base',
#   'lamp with wooden base',
#   'lamp with glass base',
#   'crystal base lamp',
#   'kids lamp with wooden base',
#   'glass base lamp',
#   'wooden base lamp',
#   'wood and glass lamp',
#   'light bulb with wooden base',
#   'glass lamp with base',
#   ' glass base lamp',
#   'wooden and glass lamp',
#   'wood lamp'],
#  ['methacrylate storage side table',
#   'wooden methacrylate side table',
#   'methacrylate side rack',
#   'agate and methacrylate side table',
#   'm methacrylate storage space',
#   'methacrylate storage area',
#   'acrylate side table',
#   'storage side rack with methacrylate',
#   'methacrylate storage structure',
#   'methacrylate storage space',
#   'sethacrylate side table',
#   'large methacrylate side table',
#   'methacrylate side storage space',
#   'methacrylate side drawer',
#   'methacrylate side table',
#   'agate sethacrylate side table',
#   'cethacrylate side table',
#   'methacrylate storage unit',
#   'methacrylate side storage',
#   'shaped methacrylate side table'],
#  ['mirrored tray',
#   'faceted mirror tray',
#   'mirrored tray with handles',
#   'rectangular mirror tray',
#   'mirrored tray with two sides',
#   'facetate tray',
#   'mirrored tray with holes',
#   'square mirror tray',
#   'mirror tray',
#   'mirrored square tray with holes',
#   'aceted mirror tray',
#   'multi faceted mirror tray',
#   'mirrored tray with two handles',
#   'faceted tray',
#   'hexagonal mirror tray',
#   'mirrored square tray'],
#  ['bubbles night set',
#   'bubble bath night set',
#   'bubble night set',
#   'bubbleach-effect night set',
#   'bubbly night set',
#   'bubble bathnight set',
#   'bubble design night set',
#   'bubble-effect night set',
#   'zara night set',
#   'bubbleobed night set',
#   'gathered night set',
#   'bubbly-effect night set',
#   ' bubble-effect night set',
#   'bubble glass night set',
#   'bubbled night set',
#   'balloon-effect night set',
#   'bubble effect night set'],
#  ['faux fur cushion cover',
#   'feather rug',
#   'textured faux fur rug',
#   'faux shearling rug',
#   'textured fur rug',
#   'faux fur rug',
#   'textured rug',
#   'crossover faux fur rug',
#   'basic faux fur rug',
#   'corduroy rug',
#   'houndstooth rug',
#   'cable-knit rug',
#   'fuzzy rug',
#   'fur rug',
#   'f rug'],
#  ['symmetrical wall mirror',
#   'large gold frame mirror',
#   'gold frame mirror trf',
#   'gold frame mirror.',
#   'symmetrical square mirror',
#   'symmetrical gold mirror',
#   'gold frame mirror',
#   'gold framed mirror',
#   'symmetrical mirror',
#   'gold frame mirror with mirror',
#   'symmetrical double mirror',
#   'gold mirror',
#   'golden frame mirror',
#   'symmetrical glass mirror',
#   'mirror with gold frame',
#   'symmetric mirror'],
#  ['scored rug',
#   'cored rug',
#   'diamond pattern rug',
#   'scordained rug',
#   'scordinarily scored rug',
#   'striped rug',
#   'textured rug',
#   'kids scored rug',
#   'scorduroy rug',
#   'rattan rug',
#   'scored effect rug',
#   'schedgehog rug',
#   'geometric print rug',
#   'wooden rug',
#   'mirrored rug',
#   'romantic rug',
#   'scored-effect rug'],
#  ['faceted water tumbler',
#   'thick glass water glass tumbler',
#   'faceted glass tumbler',
#   'faceted water glass tumbler',
#   'thick transparent glass tumbler',
#   'faceted transparent glass tumbler',
#   'faceted-effect tumbler',
#   'faceted transparent tumbler',
#   'f glass tumbler (pack of 3)',
#   'transparent glass tumbler',
#   'transaceted glass tumbler',
#   'thick glass faceted tumbler',
#   'thick faceted glass tumbler',
#   'f tumbler (pack of 3)',
#   'faceted thin tumbler',
#   'thick faceted tumbler',
#   'faceted tumbler'],
#  ['f glass soft drink tumbler (pack of 3)',
#   'f glass soft drink tumbler',
#   'thick faceted glass soft drink tumbler',
#   'faceted-effect soft drink tumbler',
#   'faceted water glass soft drink tumbler',
#   'faceted-glass soft drink tumbler',
#   'faceted water soft drink tumbler',
#   'f transparent glass soft drink tumbler',
#   'transparent glass soft drink tumbler',
#   'faceted transparent glass soft drink tumbler',
#   'faceted soft drink tumbler trf',
#   'faceted glass soft drink tumbler',
#   'faceted soft drink tumbler',
#   'transaceted glass soft drink tumbler',
#   'aceted soft drink tumbler',
#   'faceted transparent soft drink tumbler',
#   'thick faceted soft drink tumbler'],
#  ['round design wine glass',
#   'wine glass with round base',
#   'round wine glass',
#   'wine glass with a circular base',
#   'irregular wine glass',
#   'textured wine glass',
#   'large red wine glass with circular base',
#   'large wine glass with circular base',
#   'circular wine glass',
#   'glass with circular base',
#   'round-shaped wine glass',
#   'wine glass with circular base',
#   'large round wine glass',
#   'bottle with circular base',
#   'round textured wine glass',
#   'glass wine glass with circular base',
#   'large circular wine glass'],
#  ['round bread basket with handle',
#   'round woven basket with handles',
#   'round basket',
#   'round basket with handles',
#   'round woven bread basket',
#   'basket with side handle',
#   'round basket with side handle',
#   'woven basket with handle',
#   'round baskets with side handle',
#   'round woven basket with handle',
#   'basket with handle',
#   'w loaves of bread basket',
#   'round basket with handle',
#   'woven bread basket',
#   'round woven basket'],
#  ['geometric pattern rug',
#   'geometric rug',
#   'geometric print cotton rug',
#   'ge rug',
#   'geometric cotton rug',
#   'geometric design cotton rug',
#   'multicoloured geometric rug',
#   'multicoloured rug',
#   'multidle geometric rug',
#   'geometric print rug',
#   'multicoloured cotton rug',
#   'cotton rug',
#   'multicoloured striped rug'],
#  ['two-tone striped rug',
#   'sweatshirt and jute mix rug',
#   'w/strp/05',
#   'w and jute mix rug',
#   'wool and jute mix rug',
#   'sweater with beige and cream stripes',
#   'w jute/wool rug',
#   'stripedt/swtr 04',
#   'striped wool and jute mix rug',
#   'striped jute rug',
#   'cream wool and jute mix rug',
#   'wool jute rug',
#   'striped wool and jute rug',
#   'wool and jute rug',
#   'sweats and jute mix rug',
#   'multicoloured striped rug',
#   'stripedt/swtr 05',
#   'stripedt/jkt 04'],
#  ['patchwork knit rug',
#   'cro patchwork rug',
#   'limited edition patchwork rug',
#   'c patchwork rug',
#   'stripedpatchwork rug',
#   'patchwork-effect rug',
#   'patch-effect rug',
#   'striped patchwork rug',
#   'patchwork rug',
#   'patchwork rug trf',
#   'limited patchwork rug',
#   'patchwork effect rug',
#   'patch rug',
#   'strip patchwork rug',
#   'colourful patchwork rug',
#   'patch rug trf',
#   'check patchwork rug',
#   'cable-knit rug',
#   'patch rug.'],
#  ['wireless lamp with bamboo handle',
#   'wireless bulb with bamboo handle',
#   'light with bamboo handle',
#   'lamp with a bamboo handle',
#   'l bg srpls',
#   'lamp with bamboo handle',
#   'usb lamp with bamboo handle',
#   'bamboo led light lamp',
#   'bamboo lamp with bamboo handle',
#   'b lamp with bamboo handle',
#   'bamboo led light bulb',
#   'wireless bamboo lamp',
#   'wireless led lamp',
#   'ward lamp with bamboo handle',
#   'bamboo led lamp',
#   'lamp thermo-sealed'],
#  ['tri basket with handles',
#   ' triangle basket with handles',
#   'triangles basket',
#   'triangle-pattern basket',
#   'asymmetric triangle basket',
#   'triangular basket',
#   'basket with triangles',
#   'triangles basket with handles',
#   ' triangle basket',
#   'triangle pattern basket',
#   'triangle basket with handles',
#   'basket with handles',
#   'triangle basket',
#   'basket with triangle pattern',
#   'triangular pattern basket',
#   'triangular basket with handles'],
#  ['two-tone wood table',
#   'wood side table',
#   'wooden and metal side table',
#   'side table with metal legs',
#   'side table with cross over legs',
#   'rectangular wooden side table',
#   'round wooden side table',
#   'round wooden table',
#   'rectangular wood side table',
#   'wood wood side table',
#   'rectangular wood table',
#   'crossed wood side table',
#   'metal and wood side table',
#   'wooden side table',
#   'wood side table with metal legs',
#   'wood and metal side table',
#   'wood side table with cross over legs',
#   'rectangular wooden table'],
#  ['wood and linen jewellery box',
#   'circular wooden jewellery box',
#   'wood wooden and linen jewellery box',
#   'wood wooden jewellery box',
#   'two-tone wooden jewellery box',
#   'wood wooden jewellery box with linen interior',
#   'glass jewellery box with two trays',
#   'circular christmas jewellery box',
#   'wooden and linen jewellery box',
#   'small wooden jewellery box',
#   'wood wood and linen jewellery box',
#   'round wooden jewellery box',
#   'wooden jewellery box',
#   'circular jewellery box',
#   'circular jewellery box with two designs',
#   ' wooden jewellery box with two trays'],
#  ['rectangular wooden jewellery box',
#   'wood and linen jewellery box',
#   'wood wooden and linen jewellery box',
#   'two-toned wooden jewellery box',
#   'wood wooden jewellery box',
#   'two-tone wooden jewellery box',
#   'wood wooden jewellery box with linen interior',
#   'decorative wooden jewellery box',
#   'monochrome wooden jewellery box',
#   'wooden jewellery box with trays',
#   'wooden and linen jewellery box',
#   'wood wood and linen jewellery box',
#   'round wooden jewellery box',
#   'wooden jewellery box',
#   'wood & linen jewellery box',
#   ' wooden jewellery box with two trays',
#   'wood jewellery box with two trays'],
#  ['large mirror with wooden frame',
#   'wooden mirror',
#   'wooden and mirror',
#   'mirror with wooden frame',
#   'wooden frame mirror',
#   'wood mirror',
#   'wooden mirror with frame',
#   'wooden table mirror',
#   'mirror in wooden frame',
#   'round mirror with wooden frame',
#   'wood table mirror',
#   'table mirror with wood frame',
#   'table mirror',
#   'table mirror with wooden frame',
#   'large wooden mirror',
#   'mirror',
#   'mirror with wood frame'],
#  ['iron mirror with a black base',
#   'mirror with black iron base',
#   'mirium stand-up mirror',
#   'metal stand-up mirror',
#   'iron and metal mirror',
#   'iron and wood mirror',
#   'metal and wood mirror',
#   'black iron mirror',
#   'stand-up iron mirror',
#   'stand mirror',
#   'iron stand-up mirror',
#   'iron mirror with tilt',
#   'mirror',
#   'standmirror with black iron base',
#   'stand-up mirror',
#   'black iron stand-up mirror',
#   'mirror with iron base'],
#  ['lquartz metal lamp',
#   'lamp with metal piece',
#   'black lacquered lamp',
#   'lamquered metal lamp',
#   'lamp with metal frame',
#   'black lacquered metal lamp',
#   'lamp with metal base',
#   'lacquered lamp',
#   'lacquered metal lamp',
#   'lquartz-effect lamp',
#   'lamp with metal lamp',
#   'lquilted metal lamp',
#   'lamp with metal trim',
#   'lquered metal lamp',
#   'lamp with metal handle',
#   'lamp with metal grill',
#   'lamp with metal edge',
#   'lamp with metal ring',
#   'lquilted lamp'],
#  ['fugly fleece armchair',
#   'upholstered armchair',
#   'cable-knit armchair',
#   'fleeveless armchair',
#   'long fleece armchair',
#   'feather armchair',
#   'fleece armchair',
#   'faux suede armchair',
#   'textured fleece armchair',
#   'multi-use armchair',
#   'paisley print armchair',
#   'fleece armchair.',
#   'textured armchair',
#   'corduroy armchair',
#   'multiuse armchair',
#   'faux fur armchair',
#   'velvet armchair',
#   'raffia armchair',
#   'quilted armchair'],
#  ['textured striped towel',
#   'towel with fringe',
#   'cotton towel with fringing',
#   'cotton towel with stripes',
#   'washed cotton towel',
#   'towel with fringing',
#   'cotton striped towel',
#   'stripedt towel with fringing',
#   'fringed cotton towel',
#   'fringed towel',
#   'striped towel with fringing',
#   'striped towel with fringe',
#   'stripedt/t 04',
#   'striped towel',
#   'striped cotton towel',
#   'stripedt towel'],
#  ['double-sided towel',
#   'double-sized cotton towel',
#   'cotton towel with double border',
#   'two double-sided cotton towel',
#   'double-sided textured towel',
#   'double cotton towel',
#   'double-size cotton towel',
#   'two-sided cotton towel',
#   'double-sized towel',
#   'double-double-sided towel',
#   'cotton towel',
#   'plain double-sided towel',
#   'cotton towel with double edge',
#   'striped double-sided towel',
#   'double-sided cotton towel',
#   'double-toned cotton towel',
#   'double-sided towel trf'],
#  ['double-sized cotton towel (pack of 2)',
#   'double-sided cotton towel (pack of 2)',
#   'c towel (pack of 2)',
#   'cotton towel (pack of 2)',
#   'striped double-sided towel (pack of 2)',
#   'two-sided cotton towel (pack of 2)',
#   'double-sided towel (pack of 2)',
#   'double-size cotton towel (pack of 2)',
#   'double-sized towel (pack of 2)',
#   'cotton double-sided towel (pack of 2)',
#   'double-sided textured towel (pack of 2)',
#   'plain double-sided towel (pack of 2)',
#   'double-sided printed towel (pack of 2)',
#   'double double-sided towel (pack of 2)',
#   'doublesided cotton towel (pack of 2)',
#   'double cotton towel (pack of 2)',
#   'double towel (pack of 2)'],
#  ['towel with tassel edges (pack of 3)',
#   't and towel with tassels (pack of 3)',
#   't & tassel towel (pack of 3)',
#   't houndstooth towel (pack of 3)',
#   'towel with tassel (pack of 3)',
#   'plain towel with tassels (pack of 3)',
#   'towel with tassels (pack of 3)',
#   'c towel with tassels (pack of 3)',
#   'towel with tassel trim (pack of 3)',
#   'towel with tassel stripes (pack of 3)',
#   'textured towel with tassels (pack of 3)',
#   'towel with contrast tassels (pack of 3)',
#   't towel with tassels (pack of 3)',
#   'towler with tassels (pack of 3)',
#   'ribbed towel with tassels (pack of 3)',
#   't & towel with tassels (pack of 3)',
#   'cotton towel with tassels (pack of 3)',
#   'towel with tassels (set of 3)'],
#  ['c towel with tassels',
#   'towel with tassel edges',
#   'cotton towel with tassels',
#   'towler with tassels',
#   'towel with tassel stripes',
#   'towel with tassel',
#   'towel with tassel detail',
#   't towel with tassels',
#   'towel with contrast tassels',
#   'towlin towel with tassels',
#   'towel with tassels',
#   'ribbed towel with tassels',
#   'towel with tassel border',
#   'towel with tassel trim'],
#  ['ribbed towel with band',
#   'towel with band',
#   'towel with printed band',
#   'towel with square band',
#   'towel with thin band',
#   'towel with metallic band',
#   'towel with metallic thread',
#   'cotton towel with bands',
#   'c towel with band',
#   'towlin towel with band',
#   'towel with lined band',
#   'towel with contrast band',
#   'cotton towel with band',
#   'cotton towel with lined band',
#   'towel with bands'],
#  ['mar marble nesting tables (set of 2)',
#   'golden and marble nesting tables',
#   'golden marble nesting table',
#   'marble nesting tables (set of 2)',
#   'golden structure nesting tables',
#   'white marble nesting tables (set of 2)',
#   'golden and marble nest',
#   'marble nesting tables (pack of 2)',
#   'two marble nesting tables (set of 2)',
#   'golden marble nesting tables',
#   'large marble table (set of 2)',
#   'nesting tables (set of 2)',
#   'golden marble nest',
#   'golden marble nest sheet',
#   'two-tone marble nesting tables',
#   'golden marble nest of tables',
#   'marble nesting tables',
#   'golden structure nest of tables',
#   'set of marble nesting tables',
#   'golden marble nest tables'],
#  ['cotton crochet towel',
#   'crochet cotton towel',
#   'crochet crochet towel',
#   'c towel with crochet border',
#   'towel with crochet border',
#   'crochet towel',
#   't towel with crochet border',
#   'crochet-effect towel',
#   'cotton crochet border towel',
#   'crochet border towel',
#   'crochet towel trf',
#   'knit towel with crochet border',
#   'cotton towel',
#   'floral crochet towel',
#   'cropped cotton towel',
#   'cropped towel with crochet border'],
#  ['textured basket with fabric lining',
#   'round basket',
#   'paper basket with fabric lining',
#   'basket with resilient paper',
#   'oval basket with fabric lining',
#   'horizontal basket with fabric lining',
#   'round basket with paper lining',
#   'metal basket with fabric lining',
#   'vibrant basket',
#   'thick basket with fabric lining',
#   'basket with paper lining',
#   'large basket with fabric lining',
#   'rectangular basket with fabric lining',
#   'rect basket with fabric lining',
#   'round basket with fabric lining',
#   'basket with fabric lining',
#   'varsity basket with fabric lining',
#   'paper basket'],
#  ...]

# %%
with open("submission_21.csv") as f:
    name_candidates = [line[:-1].split(",") for line in f.readlines()][1:]

# %%
with open("submission_23.csv") as f:
    name_candidates_2 = [line[:-1].split(",") for line in f.readlines()][1:]

# %%
len(name_candidates)

# %%
len(name_candidates_2)

# %%
name_candidates = [list(set(n1 + n2)) for n1, n2 in zip(name_candidates, name_candidates_2)]

# %%
test["description"]
# Out:
# 0       knit midi dress with a v-neckline, straps and ...
# 1       loose-fitting dress with a round neckline, lon...
# 2       nautical cap with peak.this item must be retur...
# 3       nautical cap with peak. adjustable inner strap...
# 4       nautical cap with side button detail.this item...
#                               ...
# 1436    striped print cotton cushion cover. cushion fi...
# 1437         rectangular cushion featuring a gnome print.
# 1438    cotton jersey eye mask featuring an elastic ba...
# 1439    padded chipboard hanger featuring an iron hook...
# 1440    iron hanger suitable for hanging all kinds of ...
# Name: description, Length: 1441, dtype: object

# %%
from ranker import rank_candidates

result = rank_candidates(ranker, test["description"].values, proposals)
result
# Out:
# [['lace dress trf',
#   'contrast lace dress trf',
#   'knit dress with lace detail',
#   'knit dress with lace',
#   'knit dress with lace trf',
#   'knit dress with lace trim',
#   'lace-trimmed dress',
#   'contrast camisole dress',
#   'camisole dress',
#   'camisole dress with lace'],
#  ['jacquard dress',
#   'pleated dress trf',
#   'flowing dress trf',
#   'floral print dress trf',
#   'printed dress',
#   'printed midi dress trf',
#   'long printed dress trf',
#   'long pleated dress trf',
#   'flowing dress with pleats',
#   'jacquilted dress'],
#  ['herringbone nautical cap',
#   'accesories 05',
#   'textured nautical cap',
#   'nautical cap',
#   'neon nautical cap',
#   'aquamarine nautical cap',
#   'navy cap',
#   'cap with peak',
#   'n nautical cap',
#   'sporty nautical cap'],
#  ['herringbone nautical cap',
#   'seersucker nautical cap',
#   'linen nautical cap',
#   'cap with inner strap detail',
#   'textured nautical cap',
#   'nautical cap with inner strap',
#   'metallic nautical cap',
#   'seamless nautical cap',
#   'sporty nautical cap',
#   'printed nautical cap'],
#  ['navy cap',
#   'nautical cap',
#   'plain nautical cap',
#   'cabin nautical cap',
#   'printed nautical cap',
#   'striped nautical cap',
#   'check nautical cap',
#   'textured nautical cap',
#   'nautical cap with buttons',
#   'long nautical cap'],
#  ['faded-effect football t-shirt',
#   'faded-effect slogan t-shirt',
#   'faded-effect t-shirt with slogan',
#   'faded-effect basketball t-shirt',
#   'faded-effect t-shirt with photo',
#   'faded-effect t-shirt with print',
#   'faded-effect photograph t-shirt',
#   'faded-effect surf t-shirt',
#   'faded-effect graffiti t-shirt',
#   'faded-effect photo print t-shirt'],
#  ['coat with faux fur trf',
#   'coat with faux suede',
#   'f/05',
#   'houndstooth coat',
#   'double-faced faux fur coat',
#   'faux fur coat',
#   'faux suede coat',
#   'coat with wraparound collar',
#   'double-breasted coat',
#   'coat with faux shearling'],
#  ['rib t-shirt',
#   'ribbed t-shirt',
#   'striped t-shirt trf',
#   'striped t-shirt',
#   'ripped t-shirt trf',
#   'ribbed t-shirt trf',
#   'textured t-shirt trf',
#   'textured t-shirt',
#   'strip t-shirt',
#   'striped ribbed t-shirt'],
#  ['st/05',
#   'stretch crop top',
#   'stretch top trf',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top trf',
#   'stretch top with wide straps',
#   'stretch top with straps'],
#  ['st/05',
#   'stretch crop top',
#   'stretch top trf',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top trf',
#   'stretch top with wide straps',
#   'stretch top with straps'],
#  ['st/05',
#   'stretch crop top',
#   'stretch top trf',
#   'stretch top - limited edition',
#   'stretch top limited edition',
#   'stretch top',
#   'st/strp 04',
#   'strappy stretch top trf',
#   'stretch top with wide straps',
#   'stretch top with straps'],
#  ['fitted stretch top trf',
#   'st/strp 04',
#   'stretch top trf',
#   'stnylon crop top',
#   'st/05',
#   'stretch top - limited edition',
#   'stretch wrap top trf',
#   'stretch top',
#   'stretch stretch top',
#   'stretch crop top trf'],
#  ['st/05',
#   'stretch vest top trf',
#   'stnylon vest top trf',
#   'stretch vest top',
#   'fitted vest top trf',
#   'stretch top',
#   'stt-shirt',
#   'st t-shirt',
#   'stretch top trf',
#   'ribbed vest top'],
#  ['fitted stretch top trf',
#   'st/strp 04',
#   'stretch top trf',
#   'stnylon crop top',
#   'st/05',
#   'stretch top - limited edition',
#   'stretch wrap top trf',
#   'stretch top',
#   'stretch stretch top',
#   'stretch crop top trf'],
#  ['st/strp 04',
#   'st/05',
#   'stretch top',
#   'stnylon stretch top trf',
#   'stretch top with straps',
#   'stt-shirt with wide straps',
#   'stretch crop top',
#   'stretch top trf',
#   'stretch top with wide straps',
#   'stretch top with stretch'],
#  ['dress with asymmetric ruffles',
#   'ruffled printed dress trf',
#   'printed dress',
#   'asymmetric poplin dress',
#   'ruffled dress trf',
#   'ruffled poplin dress trf',
#   'ruffled printed dress',
#   'rustic dress with ruffles',
#   'floral print dress',
#   'ruffled dress'],
#  ['striped sweater with side stripes',
#   'striped knit sweater',
#   'contrast striped sweater',
#   'striped sweater with contrast stripes',
#   'knit sweater with side stripes',
#   'stripedt/swtr 04',
#   'sweater with contrast stripes',
#   'swe™ repreve textured sweater',
#   'textured sweater with stripes',
#   'sweater with contrasting stripes'],
#  ['bucket hat with slogan',
#   'bucket hat with photo',
#   'bucket hat with gathering',
#   'bucket hat trf',
#   'bucket hat with bands',
#   'bucket hat with band',
#   'rain hat with band',
#   'bucket hat',
#   'bucket hat with face',
#   'bucket hat with logo'],
#  ['jacquard sweater',
#   'text sweater',
#   'colour block sweater',
#   'oversized knit sweater',
#   'textured sweater with stripes',
#   'sweater with irregular stripes',
#   'premium textured sweater',
#   'oversized textured sweater',
#   'cable-knit sweater',
#   'fine knit sweater'],
#  ['geometric jacquard sweater',
#   'oversize jacquard sweater',
#   'oversized knit sweater trf',
#   'oversized jacquard sweater',
#   'jacquard sweater',
#   'oversize knit sweater',
#   'textured jacquard sweater',
#   'cable-knit sweater',
#   'textured cable-knit sweater',
#   'oversized knit sweater'],
#  ['oversized jacquard sweater',
#   'oversized knit sweater trf',
#   'textured cable-knit sweater',
#   'oversized knit sweater',
#   'oversize knit sweater',
#   'textured colour block sweater',
#   'oversized knit turtleneck sweater',
#   'oversized turtleneck sweater',
#   'textured sweater with stripes',
#   'oversize knit turtleneck sweater'],
#  ['geometric jacquard sweater',
#   'jacquard sweater',
#   'oversize jacquard sweater',
#   'oversized jacquard sweater',
#   'colour block sweater',
#   'oversized knit sweater',
#   'cable-knit sweater',
#   'oversize knit sweater',
#   'oversized sweater',
#   'oversize textured sweater'],
#  ['combined bomber jacket',
#   'combined faux fur jacket',
#   'combined padded jacket',
#   'combined jacket with contrast detail',
#   'contrast puffer jacket',
#   'contrast faux fur jacket',
#   'combined faux shearling jacket',
#   'contrast padded jacket trf',
#   'combined quilted jacket',
#   'combined puffer jacket'],
#  ['faux suede coat',
#   'check textured coat',
#   'combined coat',
#   'faux shearling coat',
#   'faux fur coat',
#   'limited edition coat',
#   'puffer coat',
#   'textured puffer coat',
#   'tailored coat',
#   'textured wool blend coat'],
#  ['coat with removable collar',
#   'coat with removable detail trf',
#   'coat with removable hood',
#   'water-repellent coat',
#   'coat with removable interior',
#   'combined puffer coat',
#   'coat with removable interior trf',
#   'coat with wraparound collar',
#   'combined coat',
#   'combined coat with removable detail'],
#  ['textured herringbone coat',
#   'textured check coat',
#   'textured coat with vents',
#   'houndstooth coat',
#   'limited edition coat',
#   'check textured coat',
#   'combined coat',
#   'textured coat with vent',
#   'textured wool blend coat',
#   'puffer coat'],
#  ['houndstooth coat',
#   'double-faced coat',
#   'check textured coat',
#   'textured comfort fit coat',
#   'textured herringbone coat',
#   'textured wool blend coat',
#   'combined textured coat',
#   'textured check coat',
#   'double-faced faux fur coat',
#   'coat with raised lapel collar'],
#  ['rib knit t-shirt with piping',
#   'floral print t-shirt',
#   'basic t-shirt with piping',
#   't-shirt with piping',
#   'striped t-shirt with piping',
#   'technical t-shirt with piping',
#   't-shirt with contrast piping',
#   'slogan print t-shirt',
#   'plain t-shirt with piping',
#   'premium t-shirt with piping'],
#  ['textured colour block t-shirt',
#   'ribbed t-shirt trf',
#   'plain t-shirt',
#   'ribbed t-shirt',
#   'basic straight fit t-shirt',
#   'basic basic t-shirt',
#   'basic v-neck t-shirt',
#   'basic plain t-shirt',
#   'basic t-shirt',
#   'premium plain t-shirt'],
#  ['faded-effect surf t-shirt trf',
#   'faded-effect printed t-shirt trf',
#   'faded-effect top trf',
#   'cropped tie-dye t-shirt',
#   'f t-shirt trf',
#   'faded-effect t-shirt',
#   'f print t-shirt trf',
#   'faded-effect basketball t-shirt trf',
#   'f lyocell t-shirt',
#   'faded t-shirt'],
#  ['basic plain t-shirt',
#   'ribbed t-shirt',
#   'faded-effect t-shirt',
#   'striped t-shirt',
#   'basic t-shirt',
#   'strip t-shirt',
#   'basic long sleeve t-shirt',
#   'plain t-shirt',
#   'long sleeve t-shirt',
#   'plain-coloured t-shirt'],
#  ['rib knit beanie with slogan',
#   'herringbone beanie',
#   'rib knit beanie',
#   'ribbed beanie with label',
#   'ribbed beanie',
#   'ribbed beanie with slogan',
#   'textured ribbed beanie',
#   'ribbed slogan beanie',
#   'rib knit beanie with label',
#   'plain ribbed beanie'],
#  ['colour block sweater trf',
#   'purl-knit sweater',
#   'textured colour block sweater',
#   'striped knit sweater',
#   'colour block sweater',
#   'knit sweater with vents',
#   'textured weave knit sweater',
#   'textured sweater with vents',
#   'textured sweater with stripes',
#   'sweater with vents'],
#  ['colour block sweater trf',
#   'purl-knit sweater',
#   'textured colour block sweater',
#   'striped knit sweater',
#   'colour block sweater',
#   'knit sweater with vents',
#   'textured weave knit sweater',
#   'textured sweater with vents',
#   'textured sweater with stripes',
#   'sweater with vents'],
#  ['stpckt 05',
#   'stpckt/05',
#   'striped stretch belt',
#   'strip®repreve leather belt',
#   'belt',
#   'stretch belt with golden buckle',
#   'limited edition belt with golden buckle',
#   'velvet belt with golden buckle',
#   'stretch belt',
#   'tretch belt with golden buckle'],
#  ['double buckle belt with chain',
#   'double buckle belt',
#   'belt with buckle and chain',
#   'double buckle belt trf',
#   'belt with chain buckle',
#   'belt with double buckle and chain',
#   'belt with chain',
#   'wide buckled belt',
#   'wide belt with chains',
#   'wide belt with chain detail'],
#  ['plsporty trousers with slogan',
#   'plush jersey trousers with slogan',
#   'plush trousers with side slogan',
#   'plush trousers with slogan print',
#   'sporty trousers with slogan',
#   'jogging trousers with slogan print',
#   'plush jersey jogging trousers',
#   'plush piqué trousers',
#   'plush trousers with slogan',
#   'plush jersey slogan trousers'],
#  ['plush trousers with side slogan',
#   'sporty trousers with slogan',
#   'plsporty trousers with slogan',
#   'plush jersey trousers with slogan',
#   'plush trousers with slogan print',
#   'jogging trousers with slogan print',
#   'plush piqué trousers',
#   'plush trousers with slogan',
#   'plush jersey jogging trousers',
#   'jogging trousers with slogan'],
#  ['striped t-shirt trf',
#   'striped t-shirt',
#   'textured t-shirt',
#   'plain t-shirt',
#   'ribbed t-shirt',
#   'rib t-shirt',
#   'cropped ribbed t-shirt',
#   'plain-coloured t-shirt',
#   'striped texture t-shirt',
#   'basic plain t-shirt'],
#  ['jacquard trousers',
#   'flowing trousers trf',
#   'slouchy trousers',
#   'faux suede trousers',
#   'darted trousers trf',
#   'cropped trousers',
#   'wide-leg trousers',
#   'cropped trousers trf',
#   'loose-fitting trousers',
#   'high waist trousers'],
#  ['flounce dress trf',
#   'pleated dress trf',
#   'flowing dress trf',
#   'puff sleeve dress trf',
#   'printed dress trf',
#   'voliskirt dress trf',
#   'voluminous mini dress trf',
#   'floral print dress',
#   'printed mini dress trf',
#   'faux leather dress trf'],
#  ['faux leather belted jumpsuit',
#   'belted jumpsuit with belt',
#   'belted jumpsuit trf',
#   'jumpsuit with belt trf',
#   'belted jumpsuit with draped detail',
#   'belted flannel jumpsuit',
#   'belted duffle bag jumpsuit',
#   'rustic jumpsuit with belt',
#   'faux leather jumpsuit with belt',
#   'textured jumpsuit with belt'],
#  ['fujifilm instax mini 9 camera pack',
#   'srpls x fuji cmr i',
#   ' fujiji cmr srpls',
#   ' fuji cmr srpls',
#   'pack of fujifilm instax mini 9 camera',
#   'fujifilm instax mini 9 camera',
#   'srpls x fuji cmr',
#   ' fujiji instax mini 9 camera',
#   ' fujiji instax mini 9 camera pack',
#   ' fujiji instax mini 9 camera set'],
#  ['asymmetric midi dress',
#   'asymmetric poplin dress',
#   'asymmetric dress with belt',
#   'asymmetric belted dress',
#   'asymmetric satin dress',
#   'printed midi dress',
#   'printed dress with belt trf',
#   'asymmetric pleated dress',
#   'pleated dress with belt',
#   'asymmetric printed dress'],
#  ['faux fur jacket trf',
#   'faux leather jacket trf',
#   'jacket with faux fur lining',
#   'faux fur jacket',
#   'faux shearling biker jacket',
#   'faux leather jacket',
#   'faux shearling jacket with belt',
#   'faux suede jacket trf',
#   'faux leather biker jacket',
#   'faux suede jacket'],
#  ['neoprene-effect jacket',
#   'faux suede jacket trf',
#   'faux leather jacket trf',
#   'fjacket with shoulder pads',
#   'faux suede bomber jacket',
#   'faux fur jacket with shoulder pads',
#   'knit jacket with shoulder pads',
#   'faux leather jacket',
#   'denim jacket with shoulder pads',
#   'velvet jacket with shoulder pads'],
#  ['purl knit henley sweater',
#   'knit henley sweater',
#   'strip knit henley sweater',
#   'henley sweater',
#   'plain knit henley sweater',
#   'colour block henley sweater',
#   'striped henley sweater',
#   'textured henley sweater',
#   'mixed knit henley sweater',
#   'basic henley sweater'],
#  ['limited edition bejewelled fringe jacket',
#   'jacket with bejewelled fringing',
#   'jacket with gem appliqué',
#   'fringed jacket',
#   'fringed jacket trf',
#   'fringed faux suede jacket',
#   'fringed denim jacket trf',
#   'denim jacket with bejewelled fringe',
#   'fringed velvet jacket',
#   'fringed faux shearling jacket'],
#  ['printed shirt dress',
#   'printed midi dress',
#   'belteddy twill dress',
#   'printed dress',
#   'midi dress with belt',
#   'printed dress with belt',
#   'belted midi dress',
#   'rustic dress with belt',
#   'belted dress trf',
#   'denim dress with belt'],
#  ['ribbed leggings with slogan',
#   'leggings with natural fibres',
#   'leggings with natural pearl beads',
#   'ribbed leggings with print',
#   'ribbed leggings with biodiversity',
#   'ribbed leggings with gathering',
#   'leggings with natural pearl bead',
#   'ribbed leggings',
#   'bib leggings',
#   'beaded leggings'],
#  ['purl knit sweater',
#   'purl-knit sweater',
#   'textured knit sweater',
#   'cable-knit sweater',
#   'textured colour block sweater',
#   'open-knit sweater',
#   'textured weave knit sweater',
#   'colour block sweater trf',
#   'cropped knit sweater',
#   'striped knit sweater'],
#  ['striped knit sweater',
#   'textured wool blend sweater',
#   'wool blend knit sweater',
#   'textured weave knit sweater',
#   'striped wool blend sweater',
#   'textured colour block sweater',
#   'striped textured sweater',
#   'purl-knit sweater',
#   'knt/swtr 05',
#   'textured wool sweater'],
#  ['text suit blazer',
#   'pinstriped suit blazer',
#   'textured double-layer blazer',
#   'textured check suit blazer',
#   'textured suit blazer',
#   'double-layer suit blazer',
#   'textured check blazer',
#   'check textured suit blazer',
#   'relaxed fit suit blazer',
#   'double-breasted suit blazer'],
#  ['zwonder rose ‘80s skinny bering blue jeans',
#   "zw premium '80s skinny bering blue jeans",
#   'z ‘80s skinny bering blue jeans',
#   'zwz premium ‘80s skinny bering blue jeans',
#   "zw premium the '80s skinny bering blue jeans",
#   'zwaffle-knit ‘80s skinny bering blue jeans',
#   'zw ‘80s skinny bering blue jeans',
#   'jeans zw premium ‘80s skinny bering blue',
#   'zw premium the ’80s skinny bering blue jeans',
#   'zw premium the ‘80s skinny bering blue jeans'],
#  ['asymmetric t-shirt trf',
#   'asymmetric hem t-shirt',
#   'basic asymmetric t-shirt',
#   'striped asymmetric t-shirt',
#   'basic asymmetric t-shirt trf',
#   'oversized t-shirt trf',
#   'striped t-shirt',
#   'striped t-shirt trf',
#   'long sleeve asymmetric t-shirt',
#   'textured t-shirt'],
#  ['basic asymmetric t-shirt',
#   'asymmetric t-shirt',
#   'asymmetric hem t-shirt',
#   'asymmetric length t-shirt',
#   'striped t-shirt trf',
#   'long sleeve asymmetric t-shirt',
#   'asymmetric textured t-shirt',
#   'striped texture t-shirt',
#   'asymmetric t-shirt trf',
#   't-shirt with asymmetrical hem'],
#  ['asymmetric t-shirt',
#   'basic asymmetrical t-shirt',
#   'asymmetric hem t-shirt',
#   'basic asymmetrical t-shirt trf',
#   'asymmetric t-shirt trf',
#   't-shirt with asymmetrical hem',
#   'asymmetric length t-shirt',
#   'long sleeve asymmetrical t-shirt',
#   'oversized t-shirt trf',
#   'striped t-shirt trf'],
#  ['t-shirt with asymmetrical hem',
#   't-shirt with asymmetric hem',
#   'contrast texture t-shirt',
#   'basic asymmetrical t-shirt',
#   'ecologically grown cotton t-shirt',
#   'cotton t-shirt',
#   'contrasting fabric t-shirt',
#   't-shirt with irregular hem',
#   'asymmetric hem t-shirt',
#   't-shirt with square neckline'],
#  ['basic t-shirt trf',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'striped t-shirt trf',
#   'slogan t-shirt',
#   'rib t-shirt trf',
#   'premium plain t-shirt',
#   'strip t-shirt',
#   'ribbed t-shirt',
#   'striped t-shirt'],
#  ['hoop earrings',
#   'contrasting hoop earrings',
#   'beaded hoop earrings',
#   'contrast hoop earrings',
#   'limited edition hoop earrings',
#   'contrast design hoop earrings',
#   'textured hoop earrings',
#   'large hoop hoop earrings',
#   'large hoop earrings',
#   'limited edition large hoop earrings'],
#  ['pack of 2 pairs of hoop earrings',
#   '2-pack of contrast hoop earrings',
#   'two 2-pack of hoop earrings',
#   'pack of multicoloured hoop earrings',
#   'pack of 2 pairs of earrings',
#   'pack of 20 pairs of hoop earrings',
#   'pack of earrings',
#   '2-pack of hoop earrings',
#   'pack of assorted hoop earrings',
#   'pack of hoop earrings'],
#  ['jacquard scarf',
#   'fringed scarf',
#   'animal print scarf',
#   'striped textured scarf',
#   'textured scarf',
#   'textured scarf with fringe',
#   'jacquilted scarf',
#   'textured check scarf',
#   'check textured scarf',
#   'premium textured scarf'],
#  ['ple pleated skirt trf',
#   'rubberised pleated skirt',
#   'ple pleated skirt',
#   'ottoman pleated skirt',
#   'pleated skirt trf',
#   'houndstooth pleated skirt',
#   'pleated knit skirt',
#   'textured pleated skirt',
#   'faux leather pleated skirt',
#   'pleated pleated skirt'],
#  ['ribbed t-shirt',
#   'rib t-shirt',
#   'paint splatter t-shirt',
#   'striped t-shirt',
#   'textured t-shirt trf',
#   'rib knit t-shirt trf',
#   'plain t-shirt trf',
#   'rib knit t-shirt',
#   'long sleeve t-shirt trf',
#   'ribbed t-shirt trf'],
#  ['ribbed t-shirt',
#   'rib t-shirt',
#   'paint splatter t-shirt',
#   'striped t-shirt',
#   'textured t-shirt trf',
#   'rib knit t-shirt trf',
#   'plain t-shirt trf',
#   'rib knit t-shirt',
#   'long sleeve t-shirt trf',
#   'ribbed t-shirt trf'],
#  ['rib t-shirt',
#   'rib knit t-shirt trf',
#   'rib knit t-shirt',
#   'striped t-shirt',
#   'rib t-shirt trf',
#   'basic t-shirt trf',
#   'cable-knit t-shirt',
#   'ribbed t-shirt trf',
#   'strip t-shirt',
#   'ribbed t-shirt'],
#  ['ruff top',
#   'ruffled printed top trf',
#   'ruffled floral print top',
#   'ruffled top trf',
#   'contrast poplin top',
#   'ruffled printed top',
#   'ruffled top',
#   'ruff top trf',
#   'frilled poplin top',
#   'top with contrasting ruffles'],
#  ['textured fabric earrings',
#   'fabricotta earrings',
#   'fabric hoop earrings',
#   'contrasting earrings',
#   'earrings with fabric',
#   'minimalist earrings',
#   'plumetis earrings',
#   'textured earrings',
#   'fabrico earrings',
#   'pack of earrings'],
#  ['den jumpsuit with belt trf',
#   'belteddy dyd jumpsuit',
#   'belteddy jumpsuit',
#   'belted jumpsuit with belt',
#   'long belted jumpsuit',
#   'belted jumpsuit with pockets',
#   'faux leather jumpsuit',
#   'belteddy twill jumpsuit',
#   'long jumpsuit with belt',
#   'jumpsuit with pockets'],
#  ['plain knit sweater',
#   'cable-knit sweater',
#   'textured striped sweater',
#   'textured colour block sweater',
#   'striped textured sweater',
#   'striped knit sweater',
#   'textured weave knit sweater',
#   'textured cotton sweater',
#   'textured knit sweater',
#   'textured sweater'],
#  ['basic t-shirt trf',
#   'plain t-shirt trf',
#   'paint splatter t-shirt',
#   'striped t-shirt trf',
#   'slogan t-shirt',
#   'rib t-shirt trf',
#   'premium plain t-shirt',
#   'strip t-shirt',
#   'ribbed t-shirt',
#   'striped t-shirt'],
#  ['halvelvet bodysuit trf',
#   'hal knit bodysuit trf',
#   'halterneck bodysuit trf',
#   'halterneck bodysuit',
#   'ribbed bodysuit trf',
#   'halute bodysuit trf',
#   'lace bodysuit trf',
#   'halvelvet bodysuit',
#   'hal knit bodysuit',
#   'halter bodysuit trf'],
#  ['contrasting print t-shirt',
#   'photo print t-shirt',
#   'floral print t-shirt',
#   't/strp/ t 04',
#   'photo print t-shirt trf',
#   't-shirt with front print',
#   'contrast textured t-shirt',
#   'skull print t-shirt',
#   'front print t-shirt trf',
#   'daisy print t-shirt'],
#  ['neoprene-effect jacket',
#   'jacket with contrast faux shearling',
#   'faux suede jacket trf',
#   'faux shearling jacket trf',
#   'faux suede puffer jacket',
#   'faux leather puffer jacket',
#   'contrast puffer jacket',
#   'faux fur puffer jacket',
#   'faux leather jacket trf',
#   'rubberised puffer jacket'],
#  ['faux suede trench coat',
#   'double breasted trench coat trf',
#   'double-breasted trench coat',
#   'trench coat with buckles',
#   'limited edition leather trench coat',
#   'limited edition trench coat with belt',
#   'belted trench coat',
#   'houndstooth trench coat',
#   'faux leather trench coat',
#   'rustic trench coat'],
#  ['faux suede puffer jacket',
#   'puffer jacket with hood',
#   'faux suede hooded jacket',
#   'hooded puffer jacket trf',
#   'reflective print puffer jacket',
#   'faux suede jacket',
#   'hooded jacket trf',
#   'hooded puffer jacket',
#   'tailored puffer jacket',
#   'quilted jacket with hood'],
#  ['jacquard knit sweater',
#   'striped knit sweater trf',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'ribbed knit sweater trf',
#   'textured knit sweater',
#   'cropped knit sweater trf',
#   'ribbed knit sweater',
#   'cable-knit sweater',
#   'cropped knit sweater'],
#  ['jacquard knit sweater',
#   'striped knit sweater trf',
#   'striped knit sweater',
#   'purl-knit sweater',
#   'ribbed knit sweater trf',
#   'textured knit sweater',
#   'cropped knit sweater trf',
#   'ribbed knit sweater',
#   'cable-knit sweater',
#   'cropped knit sweater'],
#  ['snoopy ®peanuts plush jogging trousers',
#   'snoopy ® peanuts plush jersey joggers',
#   'snoopy ® peanuts plush jersey jogging trousers',
#   'snoopy ®peanuts jogging trousers',
#   'snoopy ®peanuts plush trousers',
#   'plush snoopy ® peanuts jogging trousers',
#   's ® peanuts plush jersey jogging trousers',
#   's snoopy ® peanuts jogging trousers',
#   'snoopy ® peanuts plush jogging trousers',
#   'snoopy ® peanuts plush jersey trousers'],
#  ['skinny fit jeans',
#   'slim fit z1975 jeans',
#   'skinny jeans',
#   'slim fit 70s jeans',
#   'slimber fit jeans',
#   'slim fit faded fit jeans',
#   'faded slim fit jeans',
#   'easy care slim fit jeans',
#   'jeans z1975 slim',
#   'z1975 slim fit jeans'],
#  ['contrast top trf',
#   'contrast textured top',
#   'combined poplin top',
#   'contrast poplin top',
#   'ple top with bow trf',
#   'contrast top',
#   'contrasting pleated top',
#   'contrast pleated top',
#   'poplin top with bows',
#   'poplin top with bow'],
#  ['premium super slim fit shirt',
#   'stretch poplin shirt',
#   'super slim fit shirt',
#   'basic super slim fit shirt',
#   'striped stretch shirt',
#   'super slim fit striped poplin shirt',
#   'stretch poplin shirt with slogan',
#   'super slim fit poplin shirt',
#   'stretch poplin shirt with model',
#   'slim fit poplin shirt'],
#  ['premium super slim fit shirt',
#   'super slim fit shirt trf',
#   'super slim fit oxford shirt',
#   'super slim fit printed shirt',
#   'super slim fit textured shirt',
#   'super slim fit chino shirt',
#   'super slim fit floral print shirt',
#   'super slim fit shirt',
#   'super slim fit striped shirt',
#   'super slim fit traveler shirt'],
#  ['embroidered voluminous dress',
#   'embroidered midi dress',
#   'embroidered poplin dress',
#   'dress dress with embroidery trf',
#   'dress with contrast tassels',
#   'dress with contrast embroidery',
#   'limited edition embroidered dress',
#   'embroidered dress trf',
#   'dress with contrasting embroidery',
#   'embroidered tulle dress'],
#  ['down puffer jacket with slogan',
#   'diamond down puffer jacket',
#   'striped down puffer jacket',
#   'hooded down puffer jacket',
#   'rubberised down puffer jacket',
#   'embossed down puffer jacket',
#   'sporty down puffer jacket',
#   'lightweight down puffer jacket',
#   'down puffer jacket with rubberised detail',
#   'basic down puffer jacket'],
#  ['knit sweater with buttons',
#   'cable-knit sweater',
#   'rib knit sweater with buttons',
#   'sweater with metal buttons',
#   'textured weave knit sweater',
#   'sweater with buttons',
#   'textured sweater with buttons',
#   'high neck sweater',
#   'basic high neck sweater',
#   'high neck sweater trf'],
#  ['linen/viscose blazer',
#   'linen blend blazer',
#   'textured check suit blazer',
#   'textured suit blazer',
#   'linen/cotton blazer',
#   'cotton/linen suit blazer',
#   'linen - cotton suit blazer',
#   'rustic check suit blazer',
#   'linen blend suit blazer',
#   'cotton/linen blazer'],
#  ['textured linen - cotton trousers',
#   'slim fit linen blend trousers',
#   'textured linen/cotton trousers',
#   'cotton/linen textured trousers',
#   'textured suit trousers',
#   'textured check suit trousers',
#   'linen - cotton suit trousers',
#   'linen/cotton textured trousers',
#   'slim fit linen/cotton trousers',
#   'textured linen - cotton suit trousers'],
#  ['wool blend knit sweater',
#   'w/swtr 05',
#   'oversized knit sweater',
#   'striped wool blend sweater',
#   'w/swtr 04',
#   'wool blend sweater',
#   'knt/swtr 05',
#   'oversized knit sweater trf',
#   'limited edition wool blend sweater',
#   'high neck sweater'],
#  ['star carrycot baby wrap with faux fur lining',
#   'star chunky knit carrycot baby wrap',
#   'faux fur carrycot baby wrap',
#   'stars carrycot baby wrap with faux fur lining',
#   'star print carrycot baby wrap trf',
#   'stars carrycot baby wrap',
#   'star printcarrycot baby wrap',
#   'star carrycot baby wrap',
#   'star-print carrycot baby wrap',
#   'carrycot baby wrap with stars'],
#  ['coat with faux fur collar',
#   'coat with faux fur',
#   'coat with wraparound collar',
#   'coat with removable collar trf',
#   'combined faux fur coat',
#   'coat with removable collar',
#   'coat with contrast collar trf',
#   'coat with faux shearling',
#   'coat with contrast collar',
#   'coat with removable detail'],
#  ['cropped trousers trf',
#   'cropped slouchy trousers',
#   'slim fit trousers',
#   'slouchy trousers',
#   'textured chino trousers',
#   'cropped chino trousers',
#   'slim fit chino trousers',
#   'cropped chinos',
#   'textured check suit trousers',
#   'cropped trousers'],
#  ['zwaffle-knit high waist revolve black jeans',
#   'zwaxed-effect revolve black jeans',
#   'zw premium high waist revolve black jeans',
#   'jeans zw premium 70s revolve black',
#   'jeans zw premium 90s revolve black',
#   'zw premium revolve black jeans',
#   'jeans zw premium slim revolve black',
#   'z premium high waist revolve black jeans',
#   'zw premium the hw waist revolve black jeans',
#   'zw premium the high waist revolve black jeans'],
#  ['jeans zw premium 70s revolve black',
#   'zwaxed-effect revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zwaxed-effect revolve black skinny jeans',
#   'jeans zw premium 90s revolve black',
#   'zw premium skinny revolve black jeans',
#   'zw premium zw premium revolve black jeans',
#   'zw premium 90s revolve black jeans',
#   'zw premium the high waist revolve black jeans',
#   'zw premium high waist revolve black jeans'],
#  ['zwaffle-knit high waist revolve black jeans',
#   'zwaxed-effect revolve black jeans',
#   'zw premium high waist revolve black jeans',
#   'jeans zw premium 70s revolve black',
#   'jeans zw premium 90s revolve black',
#   'zw premium revolve black jeans',
#   'jeans zw premium slim revolve black',
#   'z premium high waist revolve black jeans',
#   'zw premium the hw waist revolve black jeans',
#   'zw premium the high waist revolve black jeans'],
#  ['contrast slogan t-shirt',
#   'embossed t-shirt',
#   'tiger t-shirt',
#   'raglan sleeve t-shirt',
#   'ballerina t-shirt with slogan',
#   'slogan print t-shirt',
#   'sporty t-shirt with slogan',
#   'embossed t-shirt with slogan',
#   'placement slogan t-shirt',
#   'paint splatter t-shirt'],
#  ['velvet dress with sequins',
#   'satin dress with sequins',
#   'dress with contrast sequins',
#   'combined sequinned dress',
#   'limited edition dress with sequins',
#   'sequinverted hem dress trf',
#   'sequinverted hem dress',
#   'sequinned dress trf',
#   'limited edition sequinned dress',
#   'sequinverted pleated dress'],
#  ['herringbone nautical cap',
#   'accesories 05',
#   'textured nautical cap',
#   'nautical cap',
#   'neon nautical cap',
#   'aquamarine nautical cap',
#   'navy cap',
#   'cap with peak',
#   'n nautical cap',
#   'sporty nautical cap'],
#  ['asymmetric midi skirt trf',
#   'asymmetric midi skirt',
#   'asymmetric skirt',
#   'asymmetric skirt with zip',
#   'asymmetric pencil skirt trf',
#   'asymmetric pencil skirt',
#   'asymmetric skirt trf',
#   'faux leather midi skirt',
#   'asymmetric skirt with buttons',
#   'faux leather midi skirt trf'],
#  ['textured coat with contrast collar',
#   'coat with contrast collar trf',
#   'combined coat',
#   'coat with contrast collar',
#   'contrast collar coat',
#   'combined coat with contrast collar',
#   'double-faced faux fur coat',
#   'combined faux shearling coat',
#   'contrast puffer coat',
#   'water-repellent coat'],
#  ['striped knit sweater',
#   'purl knit sweater',
#   'textured weave knit sweater',
#   'basic knit sweater',
#   'textured colour block sweater',
#   'textured knit sweater',
#   'textured sweater',
#   'mixed knit sweater',
#   'knit sweater',
#   'ribbed knit sweater'],
#  ['textured jogger bermuda shorts',
#   'textured bermuda shorts',
#   'textured bermudas',
#   'textured melange bermuda shorts',
#   'textured bermuda shorts trf',
#   'textured textured bermuda shorts',
#   'textured weave bermuda shorts',
#   'textured bermuda shorts with buttons',
#   'premium textured bermuda shorts',
#   'basic textured bermuda shorts'],
#  ['satin shirt dress trf',
#   'satin dress trf',
#   'full sleeve dress trf',
#   'midi dress with buttons',
#   'printed shirt dress trf',
#   'flowing dress trf',
#   'printed midi dress trf',
#   'satin dress',
#   'animal print dress trf',
#   'printed dress trf'],
#  ['parka with contrast faux shearling detail',
#   'padded parka with contrast faux shearling',
#   'water-repellent contrast parka',
#   'parka with contrast faux shearling lining',
#   'parka with contrast faux shearling',
#   'parka with contrast faux shearling trims',
#   'contrast faux shearling parka',
#   'quilted parka with faux shearling',
#   'water-repellent parka',
#   'parka with contrast shearling'],
#  ['shirt with pocket',
#   'premium oxford shirt',
#   'striped denim shirt',
#   'textured check shirt',
#   'contrast textured shirt',
#   'textured oxford shirt',
#   'premium textured shirt',
#   'paisley print shirt',
#   'plain shirt with pocket',
#   'striped shirt'],
#  ['loose-fitting trousers with pockets',
#   'slouchy trousers with pockets',
#   'loose-fitting cargo trousers',
#   'loose-fitting jogging trousers',
#   'plush trousers with pockets',
#   'loose-fitting knit trousers',
#   'joggers with pockets',
#   'jogging trousers with pockets',
#   'loose-fitting trousers',
#   'cargo trousers with pockets'],
#  ['faux suede leggings',
#   'quilted cargo leggings',
#   'pinstriped leggings',
#   'houndstooth cargo leggings',
#   'faux leather cargo leggings',
#   'plush leggings with pockets',
#   'cargo leggings with pockets',
#   'f leggings with pockets trf',
#   'knit cargo leggings',
#   'knit leggings with pockets'],
#  ['contrasting blouse',
#   'contrasting pleated blouse',
#   'blouse with contrasting sleeves',
#   'contrasting print blouse',
#   'blouse with contrasting polka dots',
#   'limited edition contrast blouse',
#   'contrast blouse',
#   'limited edition contrasting blouse',
#   'contrasting satin blouse',
#   'contrast print blouse'],
#  ['textured striped skinny tie',
#   'basic wide-leg skinny tie',
#   'triangular textured skinny tie',
#   'diagonal textured skinny tie',
#   'striped skinny tie',
#   'ribbed skinny tie',
#   'basic skinny tie',
#   'diagonal textured tie',
#   'textured skinny tie',
#   'jacquilted skinny tie'],
#  ['zw premium sunrise blue skinny jeans',
#   'zw premium skinny sunrise blue jeans',
#   'zwool blend sunrise blue jeans',
#   'zw premium the sunrise blue skinny jeans',
#   'zwaxed-effect sunrise blue skinny jeans',
#   'zw premium  sunrise blue skinny jeans',
#   'zw premium the high waist sunrise blue skinny jeans',
#   'zwool blend sunrise blue skinny jeans',
#   'zwaffle-knit sunrise blue skinny jeans',
#   'zwaxed-effect sunrise blue jeans'],
#  ['jogger waist revolve black trousers',
#   'zwaxed-effect revolve black jeans',
#   'zwaxed-effect revolve black trousers',
#   'zw premium high waist revolve black skinny trousers',
#   'zw premium revolve black skinny trousers',
#   'zw premium the high waist revolve black trousers',
#   'zw premium slim fit revolve black trousers',
#   'zw premium high waist revolve black suit trousers',
#   'zw premium revolve black trousers',
#   'zw premium revolve black jeans'],
#  ['houndstooth coat',
#   'oversized coat trf',
#   'oversize wool blend coat',
#   'cropped wool blend coat',
#   'wool blend coat with pockets',
#   'limited edition wool blend coat',
#   'double-breasted coat',
#   'textured wool blend coat',
#   'wool blend check coat',
#   'long wool blend coat'],
#  ['linen/cotton textured shirt',
#   'striped linen/cotton shirt',
#   'linen blend stand-up collar shirt',
#   'linen/cotton shirt',
#   'rustic shirt with stand-up collar',
#   'striped cotton/linen shirt',
#   'cotton/linen textured shirt',
#   'textured linen/cotton shirt',
#   'textured linen - cotton shirt',
#   'stand-up collar textured shirt'],
#  ['contrasting striped shirt trf',
#   'contrast shirt trf',
#   'shirt with contrast trims trf',
#   'contrasting fabric shirt trf',
#   'contrast poplin shirt trf',
#   'contrast textured shirt trf',
#   'contrast shirt',
#   'contrast poplin shirt',
#   'combined poplin shirt trf',
#   'contrast striped shirt trf'],
#  ['loose-fitting trousers with bow',
#   'pleated trousers with shiny bow',
#   'pleated trousers with bow detail',
#   'trousers with shiny thread bow',
#   'flowing trousers with shiny bow',
#   'pleated trousers with bow',
#   'flowing trousers with pleats',
#   'jogging trousers with pleats',
#   'flowing trousers with shiny thread',
#   'shiny thread bow trousers'],
#  ['pleated trousers with metallic thread',
#   'jogging trousers with pleats',
#   'pleated trousers with bow detail',
#   'flowing trousers with metallic thread',
#   'pleated trousers with bow',
#   'check trousers with metallic thread bow',
#   'trousers with pleats',
#   'metallic thread bow trousers',
#   'plush trousers with bow',
#   'textured trousers with bows'],
#  ['frayed shawl collar jacket',
#   'double breasted jacket with shawl collar',
#   'check shawl collar jacket',
#   'double-breasted jacket trf',
#   'frayed double-breasted jacket',
#   'double-breasted quilted jacket',
#   'double-breasted faux leather jacket',
#   'double-breasted shawl collar jacket',
#   'tailored double-breasted jacket',
#   'double-breasted faux suede jacket'],
#  ['sequinned flared trousers',
#   'sequinverted trousers trf',
#   'sequinverted hem trousers trf',
#   'sequinverted trousers',
#   'sequinned trousers',
#   'flared sequin trousers',
#   'sequinverted hem trousers',
#   'trousers with sequins',
#   'velvet trousers with sequins',
#   'sequinverted lapel trousers'],
#  ['jacquard trousers',
#   'slouchy trousers trf',
#   'high-rise skinny trousers',
#   'high waist trousers',
#   'high-rise flowing trousers',
#   'high-rise trousers',
#   'high-rise printed trousers',
#   'high waist trousers trf',
#   'high-rise sculpting trousers',
#   'high-rise modern trousers'],
#  ['belteddy twill jumpsuit',
#   'jmp 04',
#   'flowing jumpsuit with belt',
#   'denim jumpsuit with pockets',
#   'belted dungarees',
#   'long jumpsuit with belt',
#   'dyd/jmp 04',
#   'faux suede jumpsuit',
#   'denim jumpsuit with belt',
#   'belted jumpsuit with belt'],
#  ['contrast jacquard dress',
#   'contrast dress',
#   'contrast dress trf',
#   'contrast tulle dress',
#   'combined textured dress',
#   'ruffled knit dress',
#   'contrast textured dress',
#   'contrast knit dress trf',
#   'knit dress with ruffle trim',
#   'dress with contrast ruffles'],
#  ['puffer jacket with water and wind protection',
#   'water-repellent puffer jacket',
#   'comfortemp® thermal insulation puffer jacket',
#   'puffer jacket with zips',
#   'puffer jacket with contrast zips',
#   'faux suede puffer jacket',
#   'puffer jacket with hood',
#   'faux leather puffer jacket',
#   'corduroy puffer jacket',
#   'reflective-effect puffer jacket'],
#  ['f ®repreve faux leather jacket',
#   'faux leather biker jacket',
#   'faux leather bomber jacket',
#   'faux leather jacket with zip',
#   'faux leather jacket with zips',
#   'faux leather puffer jacket',
#   'double-faced faux leather jacket',
#   'faux leather jacket trf',
#   'faux leather coach jacket',
#   'contrast faux leather jacket'],
#  ['faux leather overshirt',
#   'faux suede overshirt',
#   'wool blend check overshirt',
#   'overshirt with pockets trf',
#   'textured check overshirt',
#   'textured overshirt',
#   'overshirt with rolled-up sleeves',
#   'frayed overshirt trf',
#   'frayed overshirt',
#   'cropped check overshirt'],
#  ['belted chinos',
#   'slouchy trousers with belt',
#   'faux leather trousers trf',
#   'belted palazzo trousers',
#   'belted paperbag trousers',
#   'belted trousers trf',
#   'belted slouchy trousers',
#   'paperbag trousers with belt',
#   'cropped trousers with belt',
#   'wide-leg trousers with belt'],
#  ['faux suede trousers trf',
#   'jacquard trousers with belt',
#   'faux leather trousers with belt',
#   'faux suede trousers',
#   'belted palazzo trousers',
#   'high waist trousers with belt',
#   'paperbag trousers with belt',
#   'slouchy trousers with belt',
#   'wide-leg trousers with belt',
#   'trousers with buckled belt'],
#  ['water-repellent ® thermal insulation parka',
#   'padded water-repellent parka',
#   'padded parka thermore ® thermal insulation',
#   'padded parka thermore® thermal insulation',
#   'water-repellent anorak parka',
#   'water-repellent ®repreve parka',
#   'water-repellent traveller parka',
#   'padded parka thermore ® mobility',
#   'water-repellent padded parka',
#   'water-repellent puffer parka'],
#  ['pack of three pairs of assorted panda briefs',
#   'threepack of three pairs of panda briefs',
#   'three packs of 3 pairs of panda briefs',
#   'three packs of three pairs of panda briefs',
#   'three pack of three pairs of panda briefs',
#   'pack of three pairs of panda briefs.',
#   'pack of 3 pairs of panda briefs',
#   'pack of three pairs of panda print briefs',
#   '3-pack of three panda briefs',
#   'three-pack of panda print briefs'],
#  ['oversized puffer coat',
#   'houndstooth coat',
#   'oversized coat',
#   'oversized faux fur coat',
#   'oversize coat',
#   'oversize coat trf',
#   'oversize faux fur coat',
#   'oversized coat with collar',
#   'oversize coat with wool',
#   'oversized coat with wool'],
#  ['lace dress with velvet trim',
#   'pleated dress with velvet trim',
#   'pleated dress with velvet tape',
#   'pleated dress with velvet detail',
#   'limited edition dress with velvet trim',
#   'contrast dress with lace trim',
#   'contrast camisole dress',
#   'contrasting velvet tape dress',
#   'contrast pleated dress',
#   'contrast velvet tape dress'],
#  ['striped oversized shirt',
#   'oversized shirt trf',
#   'oversized denim shirt trf',
#   'oversized check shirt trf',
#   'oversized striped shirt trf',
#   'oversized printed shirt trf',
#   'oversized check shirt',
#   'striped oversized shirt trf',
#   'oversized poplin shirt',
#   'oversized printed shirt'],
#  ['embossed feather t-shirt',
#   'fe t-shirt with feather appliques',
#   'feather tiger t-shirt',
#   'feather bunny t-shirt',
#   'fe t-shirt',
#   'feather appliqué t-shirt',
#   'feather sporty t-shirt',
#   'feather tiger print t-shirt',
#   't-shirt with feather appliqué',
#   'feather t-shirt'],
#  ['embossed feather t-shirt',
#   'fe t-shirt with feather appliques',
#   'feather tiger t-shirt',
#   'feather bunny t-shirt',
#   'fe t-shirt',
#   'feather appliqué t-shirt',
#   'feather sporty t-shirt',
#   'feather tiger print t-shirt',
#   't-shirt with feather appliqué',
#   'feather t-shirt'],
#  ['contrast print t-shirt',
#   't/strp/ t 04',
#   'slogan print t-shirt',
#   'photo print t-shirt',
#   'photographic print t-shirt',
#   'front print t-shirt',
#   't-shirt with front print',
#   'contrasting print t-shirt',
#   'contrast textured t-shirt',
#   'skull print t-shirt'],
#  ['je ‘80s high waist old blue jeans',
#   'zw premium ‘80s vintage blue jeans',
#   'zw premium ‘80s high waist old blue skinny jeans',
#   'zw premium ‘80s high waist skinny old blue jeans',
#   'zw premium ‘80s old blue skinny jeans',
#   'zw premium ‘80s high waistold blue jeans',
#   'zw premium ‘80s high waist vintage blue jeans',
#   'zw premium ’80s high waist old blue jeans',
#   'zw premium ‘80s high waist old blue jeans',
#   'zwz premium ‘80s high waist old blue jeans'],
#  ['ruff knit dress with frills',
#   'floral jacquard dress',
#   'flounce dress trf',
#   'knit dress with ruffle trim',
#   'knit dress with ruffles',
#   'ruff knit dress with frill',
#   'knit dress with frills',
#   'mini dress with ruffles',
#   'printed dress with ruffles',
#   'ruffled dress trf'],
#  ['chinos with multicoloured cord detail',
#   'chinos with multicolored lobster clasp',
#   'panelled chino trousers with lobster clasp',
#   'chinos with lobster clasp and cord detail',
#   'panelled chinos with lobster clasp',
#   'chinos with multicoloured lobster clasp',
#   'chino trousers with contrast lobster clasp',
#   'multicoloured cord chino trousers',
#   'chino trousers with multicoloured cord',
#   'chinos with multicoloured cord'],
#  ['metallic leather high heel boots',
#   'leather heeled boots with animal print',
#   'animal print leather heeled boots trf',
#   'animal print leather high-heel boots',
#   'animal print heeled leather boots',
#   'leather heeled boots with metallic detail',
#   'animal print leather heeled boots',
#   'animal print leather high heel boots',
#   'leather high heel boots with metallic detail',
#   'animal print leather heeled ankle boots'],
#  ['girregular mini giraffe crossbody bag',
#   'g giraffe crossbody bag',
#   'giraffe mini crossbody bag',
#   'mini giraffe crossbody bag trf',
#   'mini giraffe crossbody bag',
#   'giraffe crossbody bag with accessories',
#   'giraffe crossbody bag with flap',
#   'giraffe crossbody bag with accessory',
#   'giraffe crossbody bag with decorative accessory',
#   'giraffe crossbody bag with detail'],
#  ['animal print high heel ankle boots',
#   'animal print ankle boots trf',
#   'animal print stiletto-heel ankle boots',
#   'animal print high-heel ankle boots trf',
#   'animal print heeled ankle boots',
#   'animal print mid-heel ankle boots',
#   'animal print mid-heel ankle boots trf',
#   'animal print high heel ankle boots trf',
#   'animal print heeled ankle boots with pointed toe',
#   'animal print heeled ankle boots with zip trf'],
#  ['shinyvelvet high-heel ankle boots',
#   'mesh high heel ankle boots with pointed toe',
#   'shiny mesh heeled ankle boots trf',
#   'm mesh high-heel ankle boots trf',
#   'mesh heeled ankle boots with pointed toe',
#   'heeled mesh ankle boots with shiny details',
#   'shiny mesh high-heel ankle boots',
#   'mesh high-heel ankle boots trf',
#   'high heel mesh ankle boots trf',
#   'shiny mesh high heel ankle boots'],
#  ['animal print asymmetrical high-heel shoes',
#   'animal print high-heel shoes with snakeskin',
#   'animal print asymmetric high-heel shoes',
#   'animal print stiletto-heel shoes',
#   'animal print high-heeled shoes trf',
#   'animal print high heel shoes',
#   'animal print high-heel shoes with animal print',
#   'animal print high heel shoes trf',
#   'animal print mid-heel shoes trf',
#   'animal print high-heel shoes'],
#  ['vin vinyl high heel shoes trf',
#   'contrast vinyl high-heel shoes trf',
#   'transparent vinyl high-heel shoes',
#   'transparent vinyl vinyl high-heel shoes',
#   'vin hi-heel shoes trf',
#   'contrast vinyl high-heel shoes',
#   'vinyl high heel shoes trf',
#   'metallic vinyl high-heel shoes',
#   'silver vinyl high-heel shoes',
#   'vin high-heel shoes trf'],
#  ['suede metallic high heel shoes trf',
#   'suede metallic stiletto heel shoes',
#   'suede metallic heeled shoes',
#   'suede metallic heeled shoes trf',
#   'suede high heel shoes trf',
#   'suede metallic heel shoes trf',
#   'suede metallic stiletto heels',
#   'suede heeled shoes',
#   'metallic suede heeled shoes trf',
#   'suede heeled shoes with metallic detail'],
#  ['vinyl heeled mules with patent finish trf',
#   'vinyl heeled mules with pointed toe trf',
#   'vinyl heeled mules with patent finish',
#   'vinyl high-heel mules trf',
#   'vinyl mid-heel mules trf',
#   'vinyl heeled mules with pointed toe',
#   'vin vinyl heeled mules trf',
#   'vin mid-heel mules trf',
#   'vinyl high heel mules trf',
#   'vinyl heeled mules trf'],
#  ['suede high-heel mules trf',
#   'suede high heel mules with pointed toes',
#   's suede high-heel mules trf',
#   'suede heeled mules with pointed toes',
#   'suede high-heel mules',
#   'leather high heel mules trf',
#   'high heel suede mules with pointed toes',
#   'leather heeled mules',
#   'suede high heel mules trf',
#   'leather high-heel shoes'],
#  ['asymmetric high-heel sandals trf',
#   'asymmetric rhinestone heel sandals trf',
#   'asymmetric rhinestone heeled sandals trf',
#   'asymmetric high heel sandals trf',
#   'asymmetric rhinestone high heel sandals trf',
#   'asymmetric rhinestone high-heel sandals',
#   'heheeled sandals with rhinestone strap trf',
#   'rhinestone strap high-heel sandals',
#   'heeled sandals with rhinestone strap',
#   'rhinestone strap high-heel sandals trf'],
#  ['vel high heel platform sandals with knot trf',
#   'velvet platform sandals trf',
#   'velvet platform sandals with tied detail',
#   'velvet platform sandals with knotted detail',
#   'velvet high heel platform sandals',
#   'knknot high heel platform sandals trf',
#   'velvet platform sandals with raised knot',
#   'velvet platform sandals',
#   'vel high heel platform sandals with knot',
#   'velvet heeled platform sandals with knot'],
#  ['leather mini wedges with buckles trf',
#   'leather mini jute wedges trf',
#   'le leather mini wedges with track soles',
#   'leather mini wedges trf',
#   'leather mini jute wedges with ankle strap',
#   'leather mini wedges with jute heel',
#   'leather mini wedges with track sole trf',
#   'leather mini crossover wedges trf',
#   'leather and jute mini wedges',
#   'leather mini wedges with ankle strap trf'],
#  ['leather high-heel sandals with diamanté strap',
#   'blue collection high-heel sandals',
#   'leather high-heel sandals with diamanté',
#   'leather diamanté high-heel sandals',
#   'minimalist leather high-heel sandals trf',
#   'leather heeled sandals with diamanté strap',
#   'leather high-heel sandals with diamanté detail',
#   'leather high-heel sandals with diamanté buckle',
#   'blue collection diamanté leather high-heel sandals',
#   'leather high-heel sandals with diamanté details'],
#  ['high heel jute mules trf',
#   'raffia high heel mules trf',
#   'natural high heel jute mules trf',
#   'jute high heel mules with knot',
#   'raffia jute high heel mules',
#   'knot high heel mules trf',
#   'jute high heel mules with fringing',
#   'knotted jute high heel mules',
#   'jute high heel mules with knot detail',
#   'natural high heel jute mules'],
#  ['mid heel asymmetric strappy mules trf',
#   'asymmetric mid heel mules trf',
#   'high heel asymmetric strappy mules trf',
#   'asymmetric high heel mules trf',
#   'satin high heel mules trf',
#   'high heel asymmetric strappy sandals trf',
#   'high heel asymmetric strappy sandals',
#   'heeled mules with thin asymmetric straps',
#   'mid-heel asymmetric strappy sandals',
#   'heheeled mules with thin straps trf'],
#  ['combined heeled plaited sandals trf',
#   'blt sndls srpls',
#   'combined high heel plaited sandals trf',
#   'blt bt srpls',
#   'combined high heel plaited sandals',
#   'plaited high heel sandals trf',
#   'braided combined strappy sandals trf',
#   'strappy sandals with bead trf',
#   'beaded heeled sandals trf',
#   'strappy sandals with wooden bead trf'],
#  ['piggy bad.',
#   'piggy-shaped bad design',
#   'piggy',
#   'piggy piggy bad',
#   'piggy-shaped bad.',
#   'piggy-shaped badger',
#   'piggy-shaped bad with sheep',
#   'piggy-shaped bad book',
#   'piggy christmas bad.',
#   'piggy-shaped bad shoe'],
#  ['chunky jogging sneakers trf',
#   'chunky sole sneakers trf',
#   'chunky sneakers trf',
#   'double-chunky sneakers trf',
#   'multicoloured sneakers trf',
#   'contrast sneakers trf',
#   'multi-piece sneakers trf',
#   'white sneakers trf',
#   'combined sneakers trf',
#   'track sole sneakers trf'],
#  ['lngpck srpls',
#   'limited edition cotton lunch bag',
#   'mini lunch bag trf',
#   'lngr srpls',
#   'cotton lunch bag',
#   'mini lunch bag',
# ...
#  ['t houndstooth cotton towel',
#   'hooded towel with metallic thread',
#   'cotton towel with metallic thread',
#   't houndstooth towel',
#   'cotton towel with geometric border',
#   'towel with geometric border',
#   't towel with geometric border',
#   'metal thread jacquard towel',
#   'metallic thread towel',
#   'two-tone jacquard towel'],
#  ['wooden hanger (set of 2)',
#   'trousers hanger (set of 2)',
#   'lacquered hanger (set of 2)',
#   'lacquered wood hanger (set of 2)',
#   'lacquered wooden hanger (set of 2)',
#   'lacquered wood hanger (set of 3)',
#   'lacquered wooden hanger (set of 4)',
#   'lacquered furniture hanger (set of 2)',
#   'lacquered wooden hanger (set of 20)',
#   'lacquered wooden peg hanger (set of 2)'],
#  ['lacquered wooden skirt hanger',
#   'lacquered hanger (set of 2)',
#   'lacquered hanger (set of 3)',
#   'wooden hanger (set of 2)',
#   'lacquered wooden hanger (set of 2)',
#   'wood wood hanger (set of 2)',
#   'wooden skirt hanger (set of 2)',
#   'lacquered wood hanger (set of 2)',
#   'lacquired wooden hanger (set of 2)',
#   'lacquered wooden hanger (set of 3)'],
#  ['aluminium hanger (set of 2)',
#   'aluminum hanger (set of 2)',
#   'wood wooden and metal hanger (set of 2)',
#   'wooden hanger (set of 2)',
#   'wood metal and wood hanger (set of 2)',
#   'iron and wood hanger (set of 2)',
#   'steel and wood hanger (set of 2)',
#   'aluminium and wood hanger (set of 2)',
#   'wooden and metal hanger (set of 2)',
#   'wood and metal peg hanger (set of 2)'],
#  ['wooden hanger (set of 2)',
#   'wood metal and wood hanger (set of 2)',
#   'wooden laundry hanger (set of 2)',
#   'wood wood and metal hanger (set of 2)',
#   'wood hanger (set of 2)',
#   'wooden hanging hanger (set of 2)',
#   'wood wooden and metal hanger (set of 2)',
#   'wooden clothes hanger (set of 2)',
#   'wooden and metal clothes hanger (set of 2)',
#   'wooden and metal hanging hanger (set of 2)'],
#  ['blanketernal muslin blanket',
#   'feather blanket',
#   'houndstooth blanket',
#   'blanket with faux fur',
#   'fleece blanket',
#   'fur blanket',
#   'furry blanket',
#   'fuzzy blanket',
#   'f blanket',
#   'sheep blanket'],
#  ['metal skirt hangers',
#   'set of skirt hangers',
#   'metal mini skirt hanger (set of 2)',
#   'metal skirt hanger (set of 3)',
#   'metal miniskirt hanger (set of 2)',
#   'metal skirt hangers (set of 20)',
#   'metal skirt hanger (set of 6)',
#   'skirt hanger (set of 2)',
#   'metal skirt hanger (set of 2)',
#   'metal skirt hangers (set of 6)'],
#  ['iron hanger with tassels (pack of 4)',
#   'iron and linen hanger with tassel',
#   'p hanger with tassels (pack of 4)',
#   'p hanger with tassel (pack of 4)',
#   'padded iron hanger with tassels (pack of 4)',
#   'iron and cotton hanger with tassels (pack of 4)',
#   'iron hanger with tassel (pack of 4)',
#   'iron and linen hanger (pack of 4)',
#   'padded iron and tassel hanger (pack of 4)',
#   'iron and linen tassel hanger (pack of 4)'],
#  ['cropped hanger (set of 2)',
#   'metal hanger (set of 4)',
#   'metal vest hanger (set of 20)',
#   'metal hanger (set of 3)',
#   'metal hanger',
#   'textured hanger (set of 2)',
#   'metal lined hanger (set of 2)',
#   'metal vest hanger (set of 2)',
#   'basic hanger (set of 2)',
#   'metal hanger (set of 20)'],
#  ['cotton jersey t-shirt',
#   'striped oversized t-shirt trf',
#   'textured cotton jersey t-shirt',
#   'essentials cotton jersey t-shirt',
#   'essentials cotton t-shirt',
#   'oversized striped t-shirt',
#   'striped oversized t-shirt',
#   'oversized cotton t-shirt trf',
#   'oversized cotton t-shirt',
#   'oversized t-shirt'],
#  ['jacquard trousers',
#   'joggers',
#   'cotton joggers',
#   'cotton jogger trousers',
#   'knit joggers',
#   'cotton jogging trousers',
#   'cotton trousers',
#   'cotton jersey joggers',
#   'cotton jersey trousers',
#   'knit jogger waist trousers'],
#  ['cotton dressing gown',
#   'cotton jersey dressing gown',
#   'c dressing gown',
#   'striped dressing gown',
#   'long dressing gown',
#   'long cotton dressing gown',
#   'striped cotton dressing gown',
#   'striped cotton jersey dressing gown',
#   'long jersey dressing gown',
#   'long cotton jersey dressing gown'],
#  ['jacquard dress',
#   'cotton dress',
#   'jacquilted dress',
#   'knit dress trf',
#   'knit dress',
#   'cotton dress trf',
#   'cotton jersey dress',
#   'textured dress trf',
#   'ribbed dress',
#   'textured cotton dress'],
#  ['striped jacquard shirt',
#   'cotton jacquard shirt',
#   'cotton pyjama shirt',
#   'striped cotton jersey shirt',
#   'jogger shirt',
#   'cotton jersey shirt',
#   'striped cotton shirt',
#   'cotton shirt',
#   'textured cotton shirt',
#   'basic cotton shirt'],
#  ['rib knit leggings',
#   'houndstooth leggings',
#   'basic leggings',
#   'knit leggings with pockets',
#   'basic plain leggings',
#   'textured leggings',
#   'plain leggings',
#   'ribbed leggings',
#   'leggings',
#   'long knit leggings'],
#  ['flannel trousers',
#   'flannel tartan trousers',
#   'printed flannel trousers',
#   'basic flannel trousers',
#   'tartan flannel trousers',
#   'textured check flannel trousers',
#   'flannel cargo trousers',
#   'check-texture flannel trousers',
#   'textured flannel trousers',
#   'check flannel trousers'],
#  ['textured tartan eye mask',
#   'striped flannel eye mask',
#   'printed flannel eye mask',
#   'tartan flannel eye mask',
#   'tartan check eye mask',
#   'tartan print eye mask',
#   'flannel eye mask',
#   'flannel tartan eye mask',
#   'flannel print eye mask',
#   'flannel check eye mask'],
#  ['flannel shirt with pocket',
#   'tartan print shirt',
#   'flannel shirt',
#   'check print flannel shirt',
#   'checked flannel shirt',
#   'textured check shirt',
#   'tartan check shirt',
#   'printed flannel shirt',
#   'flannel shirt with a pocket',
#   'flannel check shirt'],
#  ['men’s tartan pyjamas',
#   'men pyjamas with tartan print',
#   "men's flannel pyjamas",
#   'tartan print flannel pyjamas',
#   'check flannel pyjama set',
#   'check flannel pyjamas',
#   "men's tartan pyjamas",
#   'men’s check flannel pyjamas',
#   "men's check flannel pyjamas",
#   "men's check flannel set"],
#  ['taupe washed linen fitted sheet',
#   'plain washed linen fitted sheet',
#   'striped washed linen fitted sheet',
#   'textured washed linen fitted sheet',
#   'wash linen fitted sheet',
#   'white washed linen fitted sheet',
#   'navy washed linen fitted sheet',
#   'washed linen fitted sheet',
#   'wool washed linen fitted sheet',
#   ' washed linen fitted sheet'],
#  ['crystal lamp',
#   'recycled resin lamp',
#   'kids lamp with resin base',
#   'transparent resin lamp',
#   'rattan lamp',
#   'transparent fabric lamp',
#   'resin lamp',
#   'reflective-effect lamp',
#   'crystal resin lamp',
#   'textured resin lamp'],
#  ['multi-striped towel',
#   'multicoloured stripe towel',
#   'multicoloured striped towel',
#   'striped towel with border',
#   'multicolored striped towel',
#   'panelled towel with stripe design',
#   'striped towel',
#   'multicoloured border towel',
#   'striped cotton towel',
#   'towel with striped border'],
#  ['cotton pouffe',
#   'p pouffe',
#   'pouffe with strap',
#   'c pouffe',
#   'pouffe with a strap',
#   'pouffe with pocket',
#   'faux leather pouffe',
#   'pouch pocket pouffe',
#   'c pouffe with strap',
#   'textured pouffe'],
#  ['wood lamp with wooden base',
#   'kids lamp with wooden base',
#   'crystal lamp',
#   'wooden lamp',
#   'wood and glass lamp',
#   'wooden and glass lamp',
#   'glass lamp with wooden base',
#   'lamp with wooden base',
#   'lamp with glass base',
#   'crystal base lamp'],
#  ['methacrylate storage unit',
#   'methacrylate storage area',
#   'acrylate side table',
#   'methacrylate storage structure',
#   'sethacrylate side table',
#   'methacrylate side drawer',
#   'methacrylate side table',
#   'cethacrylate side table',
#   'methacrylate side storage',
#   'methacrylate storage side table'],
#  ['mirrored tray',
#   'hexagonal mirror tray',
#   'mirror tray',
#   'mirrored tray with handles',
#   'rectangular mirror tray',
#   'square mirror tray',
#   'mirrored square tray',
#   'facetate tray',
#   'faceted tray',
#   'faceted mirror tray'],
#  ['zara night set',
#   'bubbles night set',
#   'bubble bath night set',
#   'bubble night set',
#   'bubbleach-effect night set',
#   'bubbly night set',
#   'bubble bathnight set',
#   'bubble design night set',
#   'bubble-effect night set',
#   'bubbleobed night set'],
#  ['fuzzy rug',
#   'houndstooth rug',
#   'feather rug',
#   'fur rug',
#   'textured rug',
#   'corduroy rug',
#   'faux shearling rug',
#   'textured fur rug',
#   'faux fur cushion cover',
#   'f rug'],
#  ['symmetrical mirror',
#   'symmetric mirror',
#   'symmetrical gold mirror',
#   'gold mirror',
#   'gold framed mirror',
#   'symmetrical double mirror',
#   'symmetrical wall mirror',
#   'gold frame mirror.',
#   'gold frame mirror',
#   'golden frame mirror'],
#  ['mirrored rug',
#   'striped rug',
#   'scored effect rug',
#   'wooden rug',
#   'scordained rug',
#   'schedgehog rug',
#   'scordinarily scored rug',
#   'scorduroy rug',
#   'textured rug',
#   'scored-effect rug'],
#  ['transparent glass tumbler',
#   'faceted tumbler',
#   'transaceted glass tumbler',
#   'f tumbler (pack of 3)',
#   'faceted water tumbler',
#   'faceted glass tumbler',
#   'thick transparent glass tumbler',
#   'faceted-effect tumbler',
#   'faceted transparent tumbler',
#   'thick faceted glass tumbler'],
#  ['f glass soft drink tumbler',
#   'faceted-effect soft drink tumbler',
#   'f transparent glass soft drink tumbler',
#   'transparent glass soft drink tumbler',
#   'faceted soft drink tumbler',
#   'transaceted glass soft drink tumbler',
#   'aceted soft drink tumbler',
#   'faceted transparent soft drink tumbler',
#   'faceted water soft drink tumbler',
#   'faceted transparent glass soft drink tumbler'],
#  ['irregular wine glass',
#   'textured wine glass',
#   'circular wine glass',
#   'glass with circular base',
#   'bottle with circular base',
#   'round textured wine glass',
#   'round design wine glass',
#   'wine glass with round base',
#   'round wine glass',
#   'wine glass with a circular base'],
#  ['w loaves of bread basket',
#   'woven bread basket',
#   'round bread basket with handle',
#   'round basket',
#   'basket with side handle',
#   'woven basket with handle',
#   'basket with handle',
#   'round woven basket',
#   'round woven basket with handles',
#   'round woven basket with handle'],
#  ['multicoloured cotton rug',
#   'multicoloured striped rug',
#   'multicoloured rug',
#   'cotton rug',
#   'multidle geometric rug',
#   'ge rug',
#   'geometric print cotton rug',
#   'geometric pattern rug',
#   'multicoloured geometric rug',
#   'geometric rug'],
#  ['sweater with beige and cream stripes',
#   'w/strp/05',
#   'stripedt/swtr 04',
#   'stripedt/swtr 05',
#   'stripedt/jkt 04',
#   'w jute/wool rug',
#   'striped wool and jute rug',
#   'sweatshirt and jute mix rug',
#   'w and jute mix rug',
#   'wool and jute mix rug'],
#  ['stripedpatchwork rug',
#   'cable-knit rug',
#   'colourful patchwork rug',
#   'cro patchwork rug',
#   'patchwork knit rug',
#   'striped patchwork rug',
#   'patch rug trf',
#   'limited patchwork rug',
#   'strip patchwork rug',
#   'patchwork rug trf'],
#  ['bamboo led lamp',
#   'wireless bamboo lamp',
#   'wireless led lamp',
#   'wireless lamp with bamboo handle',
#   'wireless bulb with bamboo handle',
#   'ward lamp with bamboo handle',
#   'b lamp with bamboo handle',
#   'light with bamboo handle',
#   'lamp with a bamboo handle',
#   'l bg srpls'],
#  ['asymmetric triangle basket',
#   'triangular basket',
#   'triangles basket',
#   'triangles basket with handles',
#   ' triangle basket',
#   'triangle basket',
#   'triangular pattern basket',
#   'triangular basket with handles',
#   'tri basket with handles',
#   ' triangle basket with handles'],
#  ['wood side table',
#   'rectangular wood table',
#   'wooden side table',
#   'rectangular wooden table',
#   'round wooden table',
#   'rectangular wood side table',
#   'wooden and metal side table',
#   'rectangular wooden side table',
#   'round wooden side table',
#   'wood wood side table'],
#  ['circular wooden jewellery box',
#   'circular christmas jewellery box',
#   'wooden and linen jewellery box',
#   'circular jewellery box',
#   'wood wooden and linen jewellery box',
#   'wood wooden jewellery box',
#   'small wooden jewellery box',
#   'wood wood and linen jewellery box',
#   'round wooden jewellery box',
#   'wooden jewellery box'],
#  ['wood & linen jewellery box',
#   'rectangular wooden jewellery box',
#   'wood and linen jewellery box',
#   'wood wooden and linen jewellery box',
#   'wood wooden jewellery box',
#   'decorative wooden jewellery box',
#   'monochrome wooden jewellery box',
#   'wooden and linen jewellery box',
#   'wood wood and linen jewellery box',
#   'round wooden jewellery box'],
#  ['wooden mirror',
#   'wooden frame mirror',
#   'wood mirror',
#   'mirror',
#   'wooden and mirror',
#   'mirror in wooden frame',
#   'wooden table mirror',
#   'wood table mirror',
#   'table mirror',
#   'mirror with wooden frame'],
#  ['mirror',
#   'iron and metal mirror',
#   'iron and wood mirror',
#   'stand mirror',
#   'iron stand-up mirror',
#   'iron mirror with tilt',
#   'stand-up mirror',
#   'mirium stand-up mirror',
#   'metal stand-up mirror',
#   'stand-up iron mirror'],
#  ['lquartz-effect lamp',
#   'lamquered metal lamp',
#   'lacquered metal lamp',
#   'lquartz metal lamp',
#   'lamp with metal piece',
#   'black lacquered lamp',
#   'black lacquered metal lamp',
#   'lacquered lamp',
#   'lquered metal lamp',
#   'lamp with metal grill'],
#  ['faux fur armchair',
#   'faux suede armchair',
#   'fleeveless armchair',
#   'fleece armchair',
#   'cable-knit armchair',
#   'fleece armchair.',
#   'paisley print armchair',
#   'fugly fleece armchair',
#   'textured fleece armchair',
#   'velvet armchair'],
#  ['fringed towel',
#   'striped towel',
#   'stripedt towel',
#   'towel with fringe',
#   'textured striped towel',
#   'washed cotton towel',
#   'towel with fringing',
#   'cotton striped towel',
#   'fringed cotton towel',
#   'striped towel with fringe'],
#  ['cotton towel',
#   'double-sided towel',
#   'double cotton towel',
#   'double-double-sided towel',
#   'double-sided towel trf',
#   'double-sized cotton towel',
#   'double-sized towel',
#   'double-sided cotton towel',
#   'cotton towel with double border',
#   'two double-sided cotton towel'],
#  ['doublesided cotton towel (pack of 2)',
#   'double-sized cotton towel (pack of 2)',
#   'double-sided cotton towel (pack of 2)',
#   'cotton towel (pack of 2)',
#   'two-sided cotton towel (pack of 2)',
#   'cotton double-sided towel (pack of 2)',
#   'double cotton towel (pack of 2)',
#   'striped double-sided towel (pack of 2)',
#   'double-sided towel (pack of 2)',
#   'double-size cotton towel (pack of 2)'],
#  ['t & tassel towel (pack of 3)',
#   'plain towel with tassels (pack of 3)',
#   'c towel with tassels (pack of 3)',
#   'towel with tassel stripes (pack of 3)',
#   'towel with tassel edges (pack of 3)',
#   'towel with tassel (pack of 3)',
#   't & towel with tassels (pack of 3)',
#   'towel with tassels (set of 3)',
#   't and towel with tassels (pack of 3)',
#   'towel with tassels (pack of 3)'],
#  ['towel with tassel stripes',
#   'towel with tassel',
#   'towel with tassel detail',
#   'towel with tassels',
#   'cotton towel with tassels',
#   'towel with tassel border',
#   'towel with tassel edges',
#   'towel with contrast tassels',
#   'towlin towel with tassels',
#   'towel with tassel trim'],
#  ['ribbed towel with band',
#   'towel with band',
#   'towel with printed band',
#   'towel with thin band',
#   'towel with metallic band',
#   'towlin towel with band',
#   'towel with bands',
#   'cotton towel with band',
#   'towel with square band',
#   'towel with metallic thread'],
#  ['marble nesting tables (set of 2)',
#   'golden structure nesting tables',
#   'golden marble nest',
#   'golden marble nest sheet',
#   'two-tone marble nesting tables',
#   'marble nesting tables',
#   'set of marble nesting tables',
#   'golden and marble nesting tables',
#   'golden marble nesting table',
#   'golden and marble nest'],
#  ['cotton towel',
#   'cotton crochet towel',
#   'crochet cotton towel',
#   'crochet towel',
#   'crochet-effect towel',
#   'crochet towel trf',
#   'floral crochet towel',
#   'crochet crochet towel',
#   'cotton crochet border towel',
#   'crochet border towel'],
#  ['basket with resilient paper',
#   'round basket with fabric lining',
#   'round basket',
#   'metal basket with fabric lining',
#   'vibrant basket',
#   'thick basket with fabric lining',
#   'basket with paper lining',
#   'rectangular basket with fabric lining',
#   'rect basket with fabric lining',
#   'paper basket'],
#  ...]

# %%
from postprocessing import save_submission

save_submission(result, "submission_27")

# %% [markdown]
# ## Silly idea: just do majority voting

# %%
from postprocessing import read_proposals_files

submissions = [
#    "submission_56.csv",  # 30.29  BART-large x22
#    "submission_71.csv",  # 30.10  BART-large x14 crawl v3
#    "submission_77.csv",  # 29.76  BART-large x5 crawl v4
#    "submission_58.csv",  # 29.79  Pegasus-large x11
#    "submission_48.csv",  # 29.38  BART-base x21
#    "submission_55.csv",  # 29.08  t5-base x12
#    "submission_60.csv"   # 26.68  t5-small x12
]

# Hyper ensemble: join the best ensembles so far
submissions = [
    "submission_82.csv",  # 37.00
    "submission_79.csv",  # 36.97
    "submission_74.csv",  # 35.37
    "submission_66.csv",  # 34.83
    "submission_59.csv",  # 34.29
    "submission_57.csv",  # 34.21
    "submission_61.csv",  # 34.04
    #"submission_53.csv",  # 33.71
    "submission_49.csv",  # 32.72
    "submission_45.csv",  # 32.16
    "submission_41.csv",  # 32.91
    "submission_37.csv",  # 32.00
    "submission_32.csv",  # 30.94
    #"submission_29.csv",  # 29.03
]

    #"submission_50.csv",  # 29.07  t5-base x5
    #"submission_40.csv",  # 27.71  t5-base
    #"submission_21.csv",  # 27.37  BART-large
    #"submission_31.csv",  # 26.04  Pegasus-large
    #"submission_36.csv"   # 25.1   t5-small

proposals = read_proposals_files(submissions, remove_duplicates=None)

# %%
#from postprocessing import normalize_proposals_list
#
#proposals = normalize_proposals_list(proposals)
# TODO: seems to worsen results

# %%
from collections import Counter

def majority_ranking(proposals):
    return [[elem[0] for elem in Counter(names).most_common(10)] for names in proposals]

# %%
result = majority_ranking(proposals)

# %%
result
# Out:
# [['knit dress with lace trim',
#   'lace dress trf',
#   'knit dress with lace trf',
#   'knit dress with lace detail',
#   'knit dress with lace',
#   'lace-trimmed dress',
#   'combined lace dress',
#   'contrast lace dress trf',
#   'knit dress with matching lace',
#   'camisole dress'],
#  ['pleated dress trf',
#   'printed dress trf',
#   'flowing dress trf',
#   'floral print dress trf',
#   'floral print dress',
#   'pleated dress',
#   'pleated midi dress',
#   'oversized dress trf',
#   'textured dress with pleats',
#   'printed dress'],
#  ['nautical cap',
#   'textured nautical cap',
#   'nautical cap with peak',
#   'striped nautical cap',
#   'check nautical cap',
#   'n nautical cap',
#   'limited edition nautical cap',
#   'seashell nautical cap',
#   'sporty nautical cap',
#   'faux leather nautical cap'],
#  ['textured nautical cap',
#   'nautical cap',
#   'striped nautical cap',
#   'limited edition nautical cap',
#   'faux leather nautical cap',
#   'nautical cap with strap',
#   'sporty nautical cap',
#   'technical nautical cap',
#   'check nautical cap',
#   'combined nautical cap'],
#  ['nautical cap',
#   'striped nautical cap',
#   'nautical cap with buttons',
#   'printed nautical cap',
#   'nautical cap with button',
#   'nautical cap with side buttons',
#   'buttoned nautical cap',
#   'textured nautical cap',
#   'check nautical cap',
#   'sporty nautical cap'],
#  ['faded-effect t-shirt',
#   'faded-effect slogan t-shirt',
#   'faded-effect t-shirt with slogan',
#   'faded-effect print t-shirt',
#   'faded-effect graffiti t-shirt',
#   'faded-effect printed t-shirt',
#   'faded photo print t-shirt',
#   'faded-effect t-shirt with photo',
#   'faded-effect t-shirt with print',
#   'f t-shirt'],
#  ['faux suede coat',
#   'coat with faux suede',
#   'double-faced coat',
#   'coat with faux fur',
#   'faux fur coat',
#   'houndstooth coat',
#   'coat with faux suede interior',
#   'coat with faux suede detail',
#   'double-breasted coat',
#   'textured coat'],
#  ['ribbed t-shirt',
#   'ripped t-shirt',
#   'striped t-shirt',
#   'ribbed t-shirt trf',
#   'striped t-shirt trf',
#   'ripped t-shirt trf',
#   'textured t-shirt',
#   'striped ribbed t-shirt',
#   'ripped ribbed t-shirt',
#   'ripped denim t-shirt'],
#  ['stretch top with wide straps',
#   'stretch top trf',
#   'stretch top',
#   'stretch top with straps',
#   'stretch crop top',
#   'stretch top - limited edition',
#   'strappy stretch top',
#   'st/05',
#   'stretch top limited edition',
#   'textured top with straps'],
#  ['stretch top with wide straps',
#   'stretch top trf',
#   'stretch top',
#   'stretch top with straps',
#   'stretch crop top',
#   'stretch top - limited edition',
#   'strappy stretch top',
#   'st/05',
#   'stretch top limited edition',
#   'textured top with straps'],
#  ['stretch top with wide straps',
#   'stretch top trf',
#   'stretch top',
#   'stretch top with straps',
#   'stretch crop top',
#   'stretch top - limited edition',
#   'strappy stretch top',
#   'st/05',
#   'stretch top limited edition',
#   'textured top with straps'],
#  ['stretch top trf',
#   'stretch top',
#   'stretch crop top trf',
#   'stretch top with straps',
#   'strappy stretch top',
#   'stretch crop top',
#   'stretch wrap top trf',
#   'strappy stretch top trf',
#   'elasticated top trf',
#   'st/05'],
#  ['stretch top trf',
#   'stretch vest top trf',
#   'stretch top',
#   'stretch vest top',
#   'elasticated top trf',
#   'vest top with straps',
#   'knit vest top',
#   'strappy stretch top trf',
#   'stnylon vest top trf',
#   'ribbed vest top'],
#  ['stretch top trf',
#   'stretch top',
#   'stretch crop top trf',
#   'stretch top with straps',
#   'strappy stretch top',
#   'stretch crop top',
#   'stretch wrap top trf',
#   'strappy stretch top trf',
#   'elasticated top trf',
#   'st/05'],
#  ['stretch top trf',
#   'stretch top with wide straps',
#   'stretch top',
#   'stretch top with straps',
#   'stretch crop top',
#   'top with wide straps',
#   'strappy stretch top',
#   'stretch top with chest reinforcement',
#   'st/05',
#   'knit top with wide straps'],
#  ['ruffled poplin dress',
#   'ruffled dress',
#   'asymmetric poplin dress',
#   'ruffled printed dress',
#   'frilled poplin dress',
#   'printed dress',
#   'frilled midi dress',
#   'ruffled denim dress',
#   'mini dress with frayed detail',
#   'poplin midi dress'],
#  ['sweater with side stripes',
#   'contrast striped sweater',
#   'sweater with contrast stripes',
#   'striped knit sweater',
#   'textured sweater with stripes',
#   'knit sweater with side stripes',
#   'striped sweater',
#   'striped sweater with side stripes',
#   'stripedt/swtr 04',
#   'knit sweater with stripes'],
#  ['bucket hat with band',
#   'bucket hat with bands',
#   'bucket hat',
#   'textured bucket hat',
#   'rain hat with band',
#   'rain hat',
#   'striped bucket hat',
#   'hat with band',
#   'faux leather bucket hat',
#   'bucketernal rain hat'],
#  ['textured sweater',
#   'fine knit sweater',
#   'textured sweater with stripes',
#   'cable-knit sweater',
#   'colour block sweater',
#   'textured colour block sweater',
#   'oversized fine knit sweater',
#   'colour block jacquard sweater',
#   'premium textured sweater',
#   'textured knit sweater'],
#  ['v-neck sweater',
#   'textured sweater',
#   'textured sweater with stripes',
#   'oversized knit sweater',
#   'oversized jacquard sweater',
#   'cable-knit sweater',
#   'striped jacquard sweater',
#   'geometric jacquard sweater',
#   'textured cable-knit sweater',
#   'v-neck knit sweater'],
#  ['turtleneck sweater',
#   'textured turtleneck sweater',
#   'oversized turtleneck sweater',
#   'oversized knit sweater',
#   'striped turtleneck sweater',
#   'textured sweater with stripes',
#   'basic turtleneck sweater',
#   'oversized knit turtleneck sweater',
#   'soft-touch turtleneck sweater',
#   'tie-dye print sweater'],
#  ['high neck sweater',
#   'cable-knit sweater',
#   'textured high neck sweater',
#   'textured sweater with high neck',
#   'oversized knit sweater',
#   'high neck sweater trf',
#   'high neck textured sweater',
#   'oversized high neck sweater',
#   'high neck jacquard sweater',
#   'premium high neck sweater'],
#  ['contrast padded jacket',
#   'contrast puffer jacket',
#   'padded jacket with contrast detail',
#   'combined padded jacket',
#   'contrast faux shearling jacket',
#   'combined faux shearling jacket',
#   'combined faux fur jacket',
#   'contrast faux leather jacket',
#   'double-faced jacket',
#   'contrast faux fur jacket'],
#  ['textured coat',
#   'check textured coat',
#   'houndstooth coat',
#   'faux fur coat',
#   'textured coat with pockets',
#   'combined coat',
#   'double-faced coat',
#   'textured coat with buttons',
#   'textured wool blend coat',
#   'faux shearling coat'],
#  ['coat with removable detail',
#   'coat with removable collar',
#   'combined coat',
#   'coat with contrast collar',
#   'double-faced coat',
#   'coat with matching collar',
#   'coat with removable interior',
#   'water-repellent coat',
#   'double-breasted coat',
#   'houndstooth coat'],
#  ['textured coat',
#   'check textured coat',
#   'faux fur coat',
#   'houndstooth coat',
#   'double-faced coat',
#   'textured wool blend coat',
#   'limited edition textured coat',
#   'faux shearling coat',
#   'textured coat with buttons',
#   'masculine coat'],
#  ['textured coat',
#   'check textured coat',
#   'textured wool blend coat',
#   'textured check coat',
#   'textured coat with raised collar',
#   'coat with raised collar',
#   'houndstooth textured coat',
#   'textured herringbone coat',
#   'textured coat with buttons',
#   'double-faced coat'],
#  ['textured t-shirt with piping',
#   't-shirt with piping',
#   'basic t-shirt with piping',
#   'ribbed t-shirt with piping',
#   't-shirt with contrast piping',
#   'plain t-shirt with piping',
#   'striped t-shirt with piping',
#   'ribbed t-shirt',
#   'striped textured t-shirt',
#   'textured colour block t-shirt'],
#  ['ribbed t-shirt',
#   'v-neck t-shirt',
#   'textured t-shirt',
#   'basic v-neck t-shirt',
#   'basic t-shirt',
#   'basic plain t-shirt',
#   'textured ribbed t-shirt',
#   'v-neck basic t-shirt',
#   'basic ribbed t-shirt',
#   'basic straight fit t-shirt'],
#  ['faded-effect t-shirt',
#   'faded t-shirt trf',
#   'f t-shirt',
#   'faded-effect rib t-shirt',
#   'faded-effect striped t-shirt',
#   'f t-shirt trf',
#   'faded t-shirt',
#   'faded-effect textured t-shirt',
#   'faded-effect ribbed t-shirt',
#   'faded-effect t-shirt trf'],
#  ['striped t-shirt',
#   'textured t-shirt',
#   'plain t-shirt',
#   'basic plain t-shirt',
#   'long sleeve t-shirt',
#   'ribbed t-shirt',
#   'basic t-shirt',
#   'plain-coloured t-shirt',
#   't-shirt',
#   'premium plain t-shirt'],
#  ['ribbed beanie with label',
#   'ribbed beanie',
#   'ribbed hat with label',
#   'ribbed beanie with slogan',
#   'ribbed hat with label detail',
#   'ribbed hat with slogan',
#   'rib knit beanie with label',
#   'basic ribbed beanie',
#   'ribbed hat',
#   'ribbed beanie with text'],
#  ['textured sweater',
#   'striped knit sweater',
#   'cable-knit sweater',
#   'knit sweater with vents',
#   'purl-knit sweater',
#   'textured sweater with stripes',
#   'jacquard knit sweater',
#   'textured sweater with vents',
#   'basic knit sweater',
#   'textured knit sweater'],
#  ['textured sweater',
#   'striped knit sweater',
#   'cable-knit sweater',
#   'knit sweater with vents',
#   'purl-knit sweater',
#   'textured sweater with stripes',
#   'jacquard knit sweater',
#   'textured sweater with vents',
#   'basic knit sweater',
#   'textured knit sweater'],
#  ['belt with golden buckle',
#   'stretch belt',
#   'belt with gold buckle',
#   'stretch belt with buckle',
#   'striped stretch belt',
#   'buckled belt',
#   'golden buckle belt',
#   'gold buckle belt',
#   'elastic belt',
#   'belt with buckle'],
#  ['double buckle belt with chain',
#   'wide belt with chain',
#   'belt with double buckle',
#   'wide belt with double buckle',
#   'belt with chain',
#   'wide belt with chain detail',
#   'double buckle belt',
#   'wide belt with chains',
#   'belt with double buckle and chain',
#   'belt with chain buckle'],
#  ['plush trousers with slogan',
#   'trousers with slogan print',
#   'plush jersey trousers with slogan',
#   'slogan trousers',
#   'jogging trousers with slogan print',
#   'sporty trousers with slogan',
#   'plush jersey jogging trousers',
#   'jogger waist trousers',
#   'plush jersey slogan trousers',
#   'jogging trousers'],
#  ['plush trousers with slogan',
#   'sporty trousers with slogan',
#   'slogan trousers',
#   'plush jersey trousers with slogan',
#   'trousers with slogan print',
#   'jogging trousers with slogan',
#   'plush jersey slogan trousers',
#   'trousers with slogan',
#   'plush jersey jogging trousers',
#   'jogger waist trousers'],
#  ['ribbed t-shirt',
#   'striped t-shirt',
#   'plain t-shirt',
#   'basic plain t-shirt',
#   'short sleeve t-shirt',
#   'textured t-shirt',
#   'plain-coloured t-shirt',
#   'basic t-shirt',
#   'ribbed t-shirt trf',
#   'printed t-shirt trf'],
#  ['faux leather trousers',
#   'straight fit trousers',
#   'wide-leg trousers',
#   'loose-fitting trousers',
#   'slouchy trousers',
#   'check trousers trf',
#   'printed trousers trf',
#   'check trousers',
#   'high-waist trousers',
#   'cropped trousers trf'],
#  ['floral print dress trf',
#   'printed dress trf',
#   'faux leather dress trf',
#   'flounce dress trf',
#   'puff sleeve dress trf',
#   'animal print dress trf',
#   'voluminous printed dress trf',
#   'gingham check dress trf',
#   'poplin dress trf',
#   'printed mini dress trf'],
#  ['belted jumpsuit',
#   'printed jumpsuit with belt',
#   'jumpsuit with contrast belt',
#   'belted jumpsuit trf',
#   'flowing jumpsuit with belt',
#   'oversized jumpsuit with belt',
#   'long belted jumpsuit',
#   'textured jumpsuit with belt',
#   'gathered jumpsuit with belt',
#   'jumpsuit with belt'],
#  ['fujifilm instax mini 9 camera pack',
#   'fujifilm instax mini 9 camera',
#   'instax mini 9 camera pack',
#   'fujifilm mini 9 camera pack',
#   'instax mini 9 camera (pack of 3)',
#   'srpls x fuji cmr 1',
#   'pack with fujifilm instax mini 9 camera',
#   'fuji instax mini 9 camera pack',
#   'pack of fujifilm instax mini 9 camera',
#   'fujifilm mini 9 camera'],
#  ['asymmetric dress with belt',
#   'printed dress with belt',
#   'pleated dress with belt',
#   'asymmetric poplin dress',
#   'asymmetric printed dress',
#   'asymmetric midi dress',
#   'asymmetric mini dress',
#   'asymmetric pleated dress',
#   'asymmetric satin dress',
#   'asymm drss 05'],
#  ['faux leather biker jacket',
#   'faux fur jacket with belt',
#   'faux fur jacket trf',
#   'faux fur jacket',
#   'faux leather jacket with belt',
#   'jacket with faux fur lining',
#   'faux leather jacket',
#   'faux fur biker jacket',
#   'double-faced jacket',
#   'double-faced jacket trf'],
#  ['faux leather jacket with shoulder pads',
#   'quilted jacket with shoulder pads',
#   'jacket with shoulder pads',
#   'faux fur jacket with shoulder pads',
#   'faux suede jacket',
#   'faux suede jacket with shoulder pads',
#   'leather jacket with shoulder pads',
#   'faux leather jacket',
#   'denim jacket with shoulder pads',
#   'faux shearling jacket with shoulder pads'],
#  ['knit henley sweater',
#   'textured henley sweater',
#   'basic henley sweater',
#   'henley sweater',
#   'henley sweater with pocket',
#   'plain henley sweater',
#   'plain knit henley sweater',
#   'basic knit henley sweater',
#   'striped knit henley sweater',
#   'ribbed henley sweater'],
#  ['jacket with bejewelled fringe',
#   'fringed denim jacket',
#   'fringed denim jacket trf',
#   'fringed jacket',
#   'fringed jacket trf',
#   'bejewelled fringe jacket',
#   'denim jacket with bejewelled fringe',
#   'bejewelled fringed jacket',
#   'check jacket with bejewelled fringe',
#   'denim jacket with fringe'],
#  ['midi dress with belt',
#   'printed dress with belt',
#   'belted shirt dress',
#   'printed midi dress',
#   'belted dress',
#   'denim dress with belt',
#   'faux leather belted dress',
#   'printed dress',
#   'mini dress with belt',
#   'satin dress with belt'],
#  ['ribbed leggings',
#   'basic leggings',
#   'ecologically grown cotton leggings',
#   'ribbed cotton leggings',
#   'ecologically grown leggings',
#   'rib knit leggings',
#   'cotton leggings',
#   'leggings with ecologically grown cotton',
#   'eco-friendly leggings',
#   'leggings with elastic waistband'],
#  ['textured sweater',
#   'cable-knit sweater',
#   'striped knit sweater',
#   'basic knit sweater',
#   'plain knit sweater',
#   'jacquard knit sweater',
#   'purl-knit sweater',
#   'textured weave knit sweater',
#   'textured knit sweater',
#   'ribbed knit sweater'],
#  ['textured wool blend sweater',
#   'striped wool blend sweater',
#   'wool blend sweater',
#   'cable-knit sweater',
#   'textured sweater',
#   'textured knit sweater',
#   'ribbed wool blend sweater',
#   'textured weave knit sweater',
#   'textured colour block sweater',
#   'wool blend knit sweater'],
#  ['textured suit blazer',
#   'textured check suit blazer',
#   'check suit blazer',
#   'check textured suit blazer',
#   'basic blazer',
#   'comfort textured suit blazer',
#   'comfort knit textured suit blazer',
#   'double-breasted suit blazer',
#   'check blazer',
#   'textured blazer'],
#  ['zw premium ‘80s skinny bering blue jeans',
#   "zw premium '80s skinny bering blue jeans",
#   'jeans zw premium ‘80s skinny bering blue',
#   'zw premium the ‘80s skinny bering blue jeans',
#   'zw premium ‘80s skinny jeans',
#   'zw premium ‘80s bering blue jeans',
#   'zw premium ’80s skinny bering blue jeans',
#   'zw premium ‘80s bering blue skinny jeans',
#   "jeans zw premium '80s skinny bering blue",
#   'zwz premium ‘80s skinny bering blue jeans'],
#  ['striped t-shirt',
#   'textured t-shirt',
#   'asymmetric hem t-shirt',
#   't-shirt with asymmetric hem',
#   'asymmetric t-shirt',
#   'basic asymmetric t-shirt',
#   't-shirt with contrast neckline',
#   'long sleeve t-shirt',
#   'basic asymmetrical t-shirt',
#   'contrasting fabric t-shirt'],
#  ['striped t-shirt',
#   'asymmetric t-shirt',
#   't-shirt with asymmetric hem',
#   'striped t-shirt trf',
#   'asymmetric hem t-shirt',
#   'basic asymmetric t-shirt',
#   'textured t-shirt',
#   'oversized t-shirt trf',
#   'basic asymmetrical t-shirt',
#   'faded-effect t-shirt'],
#  ['basic asymmetrical t-shirt',
#   'asymmetric hem t-shirt',
#   't-shirt with asymmetric hem',
#   'asymmetric t-shirt',
#   'striped t-shirt trf',
#   'striped t-shirt',
#   'oversized t-shirt trf',
#   't-shirt with asymmetrical hem',
#   'textured t-shirt',
#   't-shirt with contrast neckline'],
#  ['ecologically grown cotton t-shirt',
#   't-shirt with contrast neckline',
#   'cotton t-shirt',
#   'ecologically grown t-shirt',
#   't-shirt with asymmetric hem',
#   'contrasting fabric t-shirt',
#   't-shirt with asymmetrical hem',
#   'striped t-shirt',
#   't-shirt with contrast hem',
#   'asymmetric hem t-shirt'],
#  ['basic t-shirt trf',
#   'ribbed t-shirt',
#   'basic t-shirt',
#   'textured t-shirt',
#   'striped t-shirt',
#   'basic plain t-shirt',
#   'plain t-shirt',
#   'printed t-shirt trf',
#   'plain t-shirt trf',
#   'basic modal t-shirt'],
#  ['large hoop earrings',
#   'limited edition hoop earrings',
#   'hoop earrings',
#   'textured hoop earrings',
#   'small hoop earrings',
#   'beaded hoop earrings',
#   'contrast hoop earrings',
#   'medium hoop earrings',
#   'large textured hoop earrings',
#   'contrasting hoop earrings'],
#  ['2-pack of hoop earrings',
#   'pack of 2 pairs of hoop earrings',
#   'pack of hoop earrings',
#   'two-pack of hoop earrings',
#   'pack of 2 hoop earrings',
#   '2-pack of assorted earrings',
#   'pack of contrast hoop earrings',
#   'pack of assorted earrings',
#   '2-pack of plain hoop earrings',
#   '2-pack of coloured hoop earrings'],
#  ['textured scarf',
#   'fringed scarf',
#   'check textured scarf',
#   'animal print scarf',
#   'textured scarf with fringe',
#   'striped textured scarf',
#   'textured check scarf',
#   'check scarf',
#   'striped scarf',
#   'limited edition textured scarf'],
#  ['pleated skirt',
#   'pleated midi skirt',
#   'pleated faux leather skirt',
#   'pleated skirt trf',
#   'pleated pleated skirt',
#   'pleated check skirt',
#   'pleated satin finish skirt',
#   'textured pleated skirt',
#   'pleated knit skirt',
#   'velessentials pleated skirt'],
#  ['v-neck t-shirt',
#   'ribbed t-shirt',
#   'basic t-shirt trf',
#   'textured t-shirt',
#   'ribbed t-shirt trf',
#   'basic v-neck t-shirt',
#   'printed t-shirt trf',
#   'cropped t-shirt trf',
#   'striped t-shirt',
#   'short sleeve t-shirt'],
#  ['v-neck t-shirt',
#   'ribbed t-shirt',
#   'basic t-shirt trf',
#   'textured t-shirt',
#   'ribbed t-shirt trf',
#   'basic v-neck t-shirt',
#   'printed t-shirt trf',
#   'cropped t-shirt trf',
#   'striped t-shirt',
#   'short sleeve t-shirt'],
#  ['v-neck t-shirt',
#   'ribbed t-shirt',
#   'striped t-shirt',
#   'textured t-shirt',
#   'basic v-neck t-shirt',
#   'ribbed t-shirt trf',
#   'printed t-shirt trf',
#   'printed t-shirt',
#   'short sleeve t-shirt',
#   't-shirt'],
#  ['ruffled poplin top',
#   'ruffled top',
#   'ruffled top trf',
#   'ruffled printed top',
#   'frilled poplin top',
#   'contrast ruffled top',
#   'ruffled crop top',
#   'ruffled denim top',
#   'contrast top',
#   'top with contrast ruffle'],
#  ['textured earrings',
#   'fabric earrings',
#   'round fabric earrings',
#   'round earrings',
#   'floral earrings',
#   'contrasting earrings',
#   'ribbed earrings',
#   'pack of ear cuffs',
#   'fabric hoop earrings',
#   'earrings with fabric'],
#  ['belted jumpsuit',
#   'denim jumpsuit with belt',
#   'jumpsuit with belt',
#   'faux leather jumpsuit',
#   'belted jumpsuit trf',
#   'belted denim jumpsuit',
#   'long belted jumpsuit',
#   'belted jumpsuit with pockets',
#   'faux leather jumpsuit with belt',
#   'faux leather belted jumpsuit'],
#  ['textured sweater',
#   'textured weave knit sweater',
#   'textured knit sweater',
#   'striped knit sweater',
#   'textured sweater with stripes',
#   'cable-knit sweater',
#   'textured colour block sweater',
#   'striped textured sweater',
#   'jacquard knit sweater',
#   'ribbed knit sweater'],
#  ['basic t-shirt trf',
#   'ribbed t-shirt',
#   'basic t-shirt',
#   'textured t-shirt',
#   'striped t-shirt',
#   'basic plain t-shirt',
#   'plain t-shirt',
#   'printed t-shirt trf',
#   'plain t-shirt trf',
#   'basic modal t-shirt'],
#  ['halterneck bodysuit',
#   'halter neck bodysuit',
#   'ribbed bodysuit trf',
#   'halter bodysuit trf',
#   'bodysuit with halter neck',
#   'hal knit bodysuit trf',
#   'halter neck bodysuit trf',
#   'hal bodysuit trf',
#   'halterneck bodysuit trf',
#   'bodysuit trf'],
#  ['t-shirt with front print',
#   'floral print t-shirt',
#   'photo print t-shirt',
#   'slogan print t-shirt',
#   'contrast print t-shirt',
#   'front print t-shirt',
#   'printed t-shirt',
#   'animal print t-shirt',
#   't-shirt with contrast print',
#   'skull print t-shirt'],
#  ['faux shearling jacket',
#   'faux leather puffer jacket',
#   'faux suede bomber jacket',
#   'faux leather jacket',
#   'faux suede jacket',
#   'colour block puffer jacket',
#   'faux fur jacket',
#   'neoprene-effect jacket',
#   'faux leather jacket trf',
#   'faux fur jacket trf'],
#  ['faux leather trench coat',
#   'trench coat with belt',
#   'double-breasted trench coat',
#   'belted trench coat',
#   'limited edition trench coat',
#   'double breasted trench coat',
#   'limited edition leather trench coat',
#   'trench coat with matching belt',
#   'faux suede trench coat',
#   'limited edition trench coat with belt'],
#  ['lightweight puffer jacket',
#   'hooded puffer jacket',
#   'puffer jacket with hood',
#   'faux leather puffer jacket',
#   'hooded jacket trf',
#   'hooded jacket',
#   'hooded puffer jacket trf',
#   'faux leather jacket with hood',
#   'quilted jacket with hood',
#   'faux suede puffer jacket'],
#  ['cable-knit sweater',
#   'striped knit sweater',
#   'v-neck sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'knit sweater',
#   'v-neck knit sweater',
#   'cropped knit sweater',
#   'jacquard knit sweater',
#   'knit sweater trf'],
#  ['cable-knit sweater',
#   'striped knit sweater',
#   'v-neck sweater',
#   'ribbed knit sweater',
#   'textured knit sweater',
#   'knit sweater',
#   'v-neck knit sweater',
#   'cropped knit sweater',
#   'jacquard knit sweater',
#   'knit sweater trf'],
#  ['snoopy ® peanuts jogging trousers',
#   'snoopy ® peanuts plush trousers',
#   'snoopy ® peanuts joggers',
#   'snoopy ® peanuts trousers',
#   'snoopy ® peanuts plush jersey trousers',
#   'snoopy ® peanuts plush jogging trousers',
#   'plush snoopy ® peanuts trousers',
#   'snoopy ®peanuts jogging trousers',
#   's ® peanuts plush jersey jogging trousers',
#   'snoopy ®peanuts plush trousers'],
#  ['basic slim fit jeans',
#   'slim fit jeans',
#   'z1975 slim fit jeans',
#   'slim fit z1975 jeans',
#   'slim fit faded jeans',
#   'faded slim fit jeans',
#   'slim fit chino jeans',
#   'slim fit indigo jeans',
#   'z1975 skinny jeans',
#   'premium slim fit jeans'],
#  ['pleated top with bow',
#   'contrast top with bow',
#   'contrast top',
#   'contrast pleated top',
#   'contrasting pleated top',
#   'top with contrast pleated sleeves',
#   'top with pleated sleeves',
#   'contrast top with pleated sleeves',
#   'contrast poplin top',
#   'contrast top with pleats'],
#  ['super slim fit poplin shirt',
#   'stretch poplin shirt',
#   'striped stretch shirt',
#   'super slim fit striped shirt',
#   'super slim fit shirt',
#   'basic super slim fit shirt',
#   'super slim poplin shirt',
#   'striped poplin shirt',
#   'stretch shirt with collar detail',
#   'stretch shirt'],
#  ['super slim fit shirt',
#   'super slim fit striped shirt',
#   'striped stretch shirt',
#   'super slim fit check shirt',
#   'super slim fit printed shirt',
#   'super slim fit textured shirt',
#   'basic super slim fit shirt',
#   'super slim fit floral print shirt',
#   'super slim fit oxford shirt',
#   'stretch shirt'],
#  ['embroidered poplin dress',
#   'embroidered tulle dress',
#   'dress with contrast embroidery',
#   'embroidered dress',
#   'embroidered mini dress',
#   'embroidered velvet dress',
#   'embroidered tassel dress',
#   'embroidered dress trf',
#   'embroidered voluminous dress',
#   'embroderie anglaise dress'],
#  ['sporty down puffer jacket',
#   'hooded down puffer jacket',
#   'rubberised down puffer jacket',
#   'down puffer jacket with slogan',
#   'down puffer jacket with rubberised detail',
#   'long down puffer jacket',
#   'hooded down puffer jacket with slogan',
#   'colour block down puffer jacket',
#   'slogan down puffer jacket',
#   'down puffer jacket'],
#  ['textured sweater with buttons',
#   'high neck sweater',
#   'cable-knit sweater',
#   'high neck sweater with buttons',
#   'knit sweater with buttons',
#   'ribbed high neck sweater',
#   'high neck knit sweater',
#   'textured high neck sweater',
#   'basic high neck sweater',
#   'sweater with buttons'],
#  ['linen/cotton blazer',
#   'linen blend suit blazer',
#   'rustic check suit blazer',
#   'linen blend blazer',
#   'rustic blazer',
#   'linen blend check suit blazer',
#   'linen/cotton suit blazer',
#   'textured check suit blazer',
#   'textured linen/cotton blazer',
#   'linen blend check blazer'],
#  ['linen/cotton suit trousers',
#   'textured linen/cotton trousers',
#   'textured check suit trousers',
#   'linen blend suit trousers',
#   'linen - cotton suit trousers',
#   'slim fit linen blend trousers',
#   'linen/cotton textured trousers',
#   'linen blend check suit trousers',
#   'rustic check suit trousers',
#   'rustic trousers'],
#  ['wool blend sweater',
#   'wool blend knit sweater',
#   'wool blend sweater trf',
#   'limited edition wool blend sweater',
#   'high neck sweater trf',
#   'high neck sweater',
#   'wool blend sweater with vents',
#   'ribbed wool blend sweater',
#   'high neck wool blend sweater',
#   'wool blend high neck sweater'],
#  ['star print carrycot baby wrap',
#   'stars carrycot baby wrap',
#   'star carrycot baby wrap',
#   'carrycot baby wrap with stars',
#   'carrycot baby wrap with star print',
#   'star print carryingcot baby wrap',
#   'star carrycot baby wrap with faux fur lining',
#   'star print carrycot baby wrap trf',
#   'star print carrycot baby wrap with lining',
#   'carrycot baby wrap'],
#  ['coat with contrast collar',
#   'coat with removable collar',
#   'coat with contrast faux shearling',
#   'water-repellent coat',
#   'textured coat with contrast collar',
#   'contrast puffer coat',
#   'faux shearling coat',
#   'double-faced coat',
#   'coat with removable detail',
#   'faux fur coat'],
#  ['cropped chino trousers',
#   'slim fit trousers',
#   'textured suit trousers',
#   'textured check suit trousers',
#   'textured trousers',
#   'textured chino trousers',
#   'striped textured suit trousers',
#   'cropped trousers',
#   'slim fit chino trousers',
#   'textured cropped trousers'],
#  ['zw premium high waist revolve black jeans',
#   'jeans zw premium high waist revolve black',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zw premium hw revolve black jeans',
#   'zw premium revolve black high waist jeans',
#   'jeans zw premium the high waist revolve black',
#   'zwaxed-effect revolve black jeans',
#   'jeans zw premium revolve black'],
#  ['zw premium high waist revolve black jeans',
#   'jeans zw premium high waist revolve black',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium high waist revolve black skinny jeans',
#   'jeans zw premium revolve black',
#   'zw premium revolve black skinny jeans',
#   'zwaxed-effect revolve black jeans',
#   'jeans zw premium the high waist revolve black',
#   'zw premium revolve black high waist skinny jeans'],
#  ['zw premium high waist revolve black jeans',
#   'jeans zw premium high waist revolve black',
#   'zw premium the high waist revolve black jeans',
#   'zw premium revolve black jeans',
#   'zw premium revolve black skinny jeans',
#   'zw premium hw revolve black jeans',
#   'zw premium revolve black high waist jeans',
#   'jeans zw premium the high waist revolve black',
#   'zwaxed-effect revolve black jeans',
#   'jeans zw premium revolve black'],
#  ['slogan t-shirt',
#   'sporty slogan t-shirt',
#   't-shirt with front slogan',
#   'printed t-shirt',
#   'embossed t-shirt',
#   'animal print t-shirt',
#   'slogan print t-shirt',
#   'skater print t-shirt',
#   'skate print t-shirt',
#   'printed t-shirt with slogan'],
#  ['sequinned dress',
#   'limited edition sequinned dress',
#   'sequinned dress trf',
#   'sequinned midi dress',
#   'limited edition dress with sequins',
#   'contrast sequinned dress',
#   'sequinned mini dress',
#   'combined sequinned dress',
#   'sequinverted lapel dress',
#   'textured dress with sequins'],
#  ['nautical cap',
#   'textured nautical cap',
#   'nautical cap with peak',
#   'striped nautical cap',
#   'check nautical cap',
#   'n nautical cap',
#   'limited edition nautical cap',
#   'seashell nautical cap',
#   'sporty nautical cap',
#   'faux leather nautical cap'],
#  ['asymmetric skirt',
#   'asymmetric midi skirt',
#   'asymmetric skirt trf',
#   'faux leather midi skirt',
#   'asymmetric mini skirt',
#   'denim midi skirt',
#   'denim midi skirt trf',
#   'denim skirt trf',
#   'asymmetric denim skirt',
#   'faux leather skirt'],
#  ['coat with contrast collar',
#   'contrast puffer coat',
#   'combined coat',
#   'contrast collar coat',
#   'coat with contrasting collar',
#   'textured coat with contrast collar',
#   'double-faced coat',
#   'water-repellent coat',
#   'coat with contrast faux shearling',
#   'contrast faux shearling coat'],
#  ['ribbed knit sweater',
#   'striped knit sweater',
#   'cable-knit sweater',
#   'textured weave knit sweater',
#   'textured knit sweater',
#   'cropped knit sweater',
#   'open-knit sweater',
#   'soft-touch knit sweater',
#   'knit sweater',
#   'jacquard knit sweater'],
#  ['textured bermuda shorts',
#   'textured check bermuda shorts',
#   'textured bermuda shorts with pockets',
#   'textured bermuda shorts with buttons',
#   'textured jogger bermuda shorts',
#   'textured bermudas',
#   'textured denim bermuda shorts',
#   'textured textured bermuda shorts',
#   'textured melange bermuda shorts',
#   'striped textured bermuda shorts'],
#  ['printed midi dress',
#   'printed dress trf',
#   'floral print dress',
#   'printed dress',
#   'printed mini dress',
#   'floral print dress trf',
#   'flowing dress trf',
#   'midi dress with buttons',
#   'midi dress with elastic waist',
#   'floral print midi dress'],
#  ['parka with contrast faux shearling',
#   'parka with contrast faux shearling lining',
#   'contrast faux shearling parka',
#   'contrast parka with faux shearling',
#   'parka with faux shearling lining',
#   'contrast pouch pocket parka',
#   'contrasting faux shearling parka',
#   'water-repellent contrast parka',
#   'water-repellent parka',
#   'textured parka with faux shearling'],
#  ['textured check shirt',
#   'striped textured shirt',
#   'textured oxford shirt',
#   'premium textured shirt',
#   'striped denim shirt',
#   'textured shirt with pocket',
#   'premium oxford shirt',
#   'striped denim overshirt',
#   'geometric print shirt',
#   'textured shirt'],
#  ['textured trousers with pockets',
#   'trousers with pockets',
#   'jogging trousers with pockets',
#   'loose-fitting trousers with pockets',
#   'textured trousers',
#   'textured trousers with ribbons',
#   'plush trousers with ribbons',
#   'loose-fitting knit trousers',
#   'jogger waist trousers',
#   'loose-fitting trousers'],
#  ['faux leather leggings',
#   'leggings with pockets',
#   'faux suede leggings',
#   'knit leggings with pockets',
#   'leggings with pockets trf',
#   'plush leggings with pockets',
#   'cargo leggings with pockets',
#   'ribbed leggings with pockets',
#   'faux leather leggings trf',
#   'textured leggings'],
#  ['contrast blouse',
#   'contrasting blouse',
#   'floral print blouse',
#   'dotted mesh blouse',
#   'contrasting satin blouse',
#   'contrast dotted mesh blouse',
#   'contrast satin blouse',
#   'combined blouse',
#   'contrasting pleated blouse',
#   'blouse with contrast lining'],
#  ['ottoman skinny tie',
#   'textured skinny tie',
#   'jacquard skinny tie',
#   'diagonal textured tie',
#   'diagonal textured skinny tie',
#   'silk jacquard skinny tie',
#   'ott skinny tie',
#   'diagonal texture skinny tie',
#   'basic skinny tie',
#   'striped skinny tie'],
#  ['zw premium sunrise blue skinny jeans',
#   'zw premium high waist sunrise blue skinny jeans',
#   'zw premium skinny sunrise blue jeans',
#   'zw premium high waist skinny sunrise blue jeans',
#   'zw premium high waist sunrise blue jeans',
#   'zw premium the high waist skinny sunrise blue jeans',
#   'zwaxed-effect sunrise blue jeans',
#   'zw premium the high waist sunrise blue jeans',
#   'jeans zw premium high waist sunrise blue',
#   'zw premium sunset blue skinny jeans'],
#  ['zw premium high waist revolve black trousers',
#   'the high waist revolve black trousers',
#   'zw premium revolve black trousers',
#   'zw premium high waist revolve black jeans',
#   'high waist revolve black trousers',
#   'zw premium revolve black skinny trousers',
#   'jeans zw premium high waist revolve black',
#   'zw premium revolve black high waist trousers',
#   'zwaxed-effect revolve black trousers',
#   'zw premium revolve black jeans'],
#  ['wool blend coat',
#   'double-breasted coat',
#   'wool blend coat with pockets',
#   'limited edition wool blend coat',
#   'long wool blend coat',
#   'textured wool blend coat',
#   'houndstooth coat',
#   'wool blend check coat',
#   'wool blend coat trf',
#   'coat with patch pockets'],
#  ['stand-up collar textured shirt',
#   'textured linen/cotton shirt',
#   'linen/cotton textured shirt',
#   'stand-up collar shirt',
#   'striped linen/cotton shirt',
#   'striped cotton/linen shirt',
#   'textured cotton/linen shirt',
#   'rustic shirt with stand-up collar',
#   'shirt with stand-up collar',
#   'stand-up collar rustic shirt'],
#  ['shirt with contrast trims',
#   'contrast shirt trf',
#   'satin shirt with trims',
#   'striped shirt with trims',
#   'textured shirt with trims',
#   'poplin shirt with trims',
#   'printed shirt with trims',
#   'shirt with contrasting trims',
#   'contrasting shirt trf',
#   'contrast shirt'],
#  ['pleated trousers with bow',
#   'trousers with shiny thread bow',
#   'trousers with shiny bow',
#   'shiny thread bow trousers',
#   'shiny thread trousers',
#   'flowing trousers with bow',
#   'pleated trousers with shiny bow',
#   'loose-fitting trousers with bow',
#   'trousers with bow',
#   'shiny pleated trousers'],
#  ['pleated trousers with bow',
#   'pleated trousers with bow detail',
#   'flowing trousers with bow',
#   'trousers with bow',
#   'trousers with metallic thread bow',
#   'trousers with metallic thread bows',
#   'textured trousers with bow',
#   'pleated trousers',
#   'flowing trousers with bow detail',
#   'loose-fitting trousers with bow'],
#  ['double-breasted jacket',
#   'jacket with shawl collar',
#   'shawl collar jacket',
#   'double-breasted jacket with buttons',
#   'double-breasted jacket trf',
#   'double-breasted check jacket',
#   'double-breasted denim jacket',
#   'jacket with contrast buttons',
#   'double-breasted puffer jacket',
#   'double-breasted wool blend jacket'],
#  ['sequinned flared trousers',
#   'flared trousers with sequins',
#   'limited edition sequinned trousers',
#   'sequinned trousers',
#   'flared sequinned trousers',
#   'sequin flared trousers',
#   'flared sequin trousers',
#   'sequinned flare trousers',
#   'sequinverted lapel trousers',
#   'flared trousers'],
#  ['high-rise trousers',
#   'faux leather trousers',
#   'high-rise sculpting trousers',
#   'high-rise faux leather trousers',
#   'high-rise trousers trf',
#   'high-rise cigarette trousers',
#   'high-rise modern trousers',
#   'high-rise flowing trousers',
#   'high-rise printed trousers',
#   'slouchy trousers trf'],
#  ['belted jumpsuit',
#   'belted jumpsuit trf',
#   'denim jumpsuit with belt',
#   'faux leather jumpsuit',
#   'textured jumpsuit with belt',
#   'belted jumpsuit with pockets',
#   'long belted jumpsuit',
#   'flowing jumpsuit with belt',
#   'rustic jumpsuit with belt',
#   'faux leather belted jumpsuit'],
#  ['contrast dress trf',
#   'contrast knit dress',
#   'contrasting knit dress',
#   'contrast dress',
#   'contrast tulle dress',
#   'contrast ruffled dress',
#   'contrast textured dress',
#   'combined dress trf',
#   'contrast jacquard dress',
#   'combined poplin dress'],
#  ['hooded puffer jacket',
#   'colour block puffer jacket',
#   'water-repellent puffer jacket',
#   'puffer jacket with zips',
#   'puffer jacket with hood',
#   'contrast puffer jacket',
#   'hooded quilted jacket',
#   'faux leather puffer jacket',
#   'lightweight puffer jacket',
#   'hooded puffer jacket trf'],
#  ['faux leather bomber jacket',
#   'faux leather jacket',
#   'faux leather biker jacket',
#   'contrast faux leather jacket',
#   'faux leather puffer jacket',
#   'leather biker jacket',
#   'double-faced jacket',
#   'faux leather coach jacket',
#   'double-faced faux leather jacket',
#   'textured faux leather jacket'],
#  ['check overshirt',
#   'corduroy overshirt',
#   'overshirt with pockets',
#   'textured overshirt',
#   'frayed overshirt',
#   'textured check overshirt',
#   'overshirt with front pockets',
#   'oversized check overshirt',
#   'denim overshirt with pockets',
#   'cropped check overshirt'],
#  ['belted trousers',
#   'trousers with belt',
#   'faux leather trousers with belt',
#   'wide-leg trousers with belt',
#   'belted trousers trf',
#   'high waist trousers with belt',
#   'slouchy trousers with belt',
#   'check trousers with belt',
#   'faux leather trousers',
#   'paperbag trousers with belt'],
#  ['faux leather trousers with belt',
#   'wide-leg trousers with belt',
#   'trousers with belt',
#   'paperbag trousers with belt',
#   'darted trousers with belt',
#   'high waist trousers with belt',
#   'belted trousers',
#   'pleated trousers with belt',
#   'trousers with buckled belt',
#   'slouchy trousers with belt'],
#  ['water-repellent padded parka',
#   'water-repellent puffer parka',
#   'water-repellent parka',
#   'water-repellent quilted parka',
#   'padded parka with thermore® thermal insulation',
#   'water-repellent technical parka',
#   'water-repellent traveller parka',
#   'padded parka with pockets',
#   'water-repellent parka with pockets',
#   'water-repellent thermore® parka'],
#  ['3-pack of panda briefs',
#   'three-pack of panda briefs',
#   'pack of three pairs of panda briefs',
#   '3-pack of panda print briefs',
#   'pack of three panda briefs',
#   'three-pack of panda print briefs',
#   'pack of 3 panda briefs',
#   'pack of 3 pairs of panda briefs',
#   '3-pack of panda shorts',
#   '3-pack of pandas briefs'],
#  ['oversized coat',
#   'oversized coat trf',
#   'oversized coat with wool',
#   'houndstooth coat',
#   'oversized faux fur coat',
#   'oversize coat with wool',
#   'oversize coat trf',
#   'faux fur coat',
#   'loose-fitting coat',
#   'oversized check coat'],
#  ['contrasting pleated dress',
#   'pleated dress with velvet tape',
#   'contrast lace dress',
#   'lace dress with velvet tape',
#   'combined voluminous dress',
#   'contrasting velvet dress',
#   'contrasting velvet tape dress',
#   'contrasting lace dress',
#   'limited edition matching dress',
#   'lace dress'],
#  ['oversized poplin shirt',
#   'oversized shirt with pocket',
#   'oversized check shirt',
#   'oversized shirt',
#   'oversized shirt trf',
#   'oversized denim shirt trf',
#   'oversized denim shirt',
#   'oversized corduroy shirt',
#   'striped oversized shirt',
#   'oversized striped shirt'],
#  ['feather print t-shirt',
#   'feather t-shirt',
#   't-shirt with feather appliqué',
#   'feather tiger t-shirt',
#   'feather appliqué t-shirt',
#   't-shirt with feathers',
#   't-shirt with feather appliqués',
#   'fe t-shirt',
#   'fe t-shirt with appliqués',
#   't-shirt with feather print'],
#  ['feather print t-shirt',
#   'feather t-shirt',
#   't-shirt with feather appliqué',
#   'feather tiger t-shirt',
#   'feather appliqué t-shirt',
#   't-shirt with feathers',
#   't-shirt with feather appliqués',
#   'fe t-shirt',
#   'fe t-shirt with appliqués',
#   't-shirt with feather print'],
#  ['contrast print t-shirt',
#   't-shirt with front print',
#   'slogan print t-shirt',
#   'photo print t-shirt',
#   'floral print t-shirt',
#   'front print t-shirt',
#   'printed t-shirt',
#   'animal print t-shirt',
#   't-shirt with contrast print',
#   'skull print t-shirt'],
#  ['zw premium ‘80s high waist old blue jeans',
#   "zw premium '80s high waist old blue jeans",
#   'jeans zw premium ‘80s high waist old blue',
#   'zw premium the ‘80s high waist old blue jeans',
#   'zw premium ‘80s old blue skinny jeans',
#   'zw premium ‘80s old blue jeans',
#   'zw premium ’80s high waist old blue jeans',
#   'zw premium ‘80s high waist old blue skinny jeans',
#   "zw premium '80s old blue jeans",
#   'zwaxed-effect ‘80s old blue jeans'],
#  ['ruffled knit dress',
#   'knit dress with ruffles',
#   'ruffled dress trf',
#   'floral print dress',
#   'mini dress with ruffles',
#   'ruffled printed dress',
#   'floral jacquard dress',
#   'ruffled poplin dress',
#   'floral print dress trf',
#   'ruffled dress'],
#  ['chinos with lobster clasp',
#   'chinos with cord detail',
#   'chino trousers with cord detail',
#   'corduroy chino trousers',
#   'chino trousers with lobster clasp',
#   'chinos with multicoloured cord',
#   'multicoloured chino trousers',
#   'chinos with lobster clasp detail',
#   'chino trousers with multicoloured cord',
#   'chino trousers with cord'],
#  ['animal print leather high heel boots',
#   'animal print leather high-heel boots',
#   'animal print leather high heel boots trf',
#   'animal print leather heeled boots',
#   'animal print heeled leather boots',
#   'metallic leather high-heel boots',
#   'animal print high heel leather boots',
#   'metallic leather high heel boots',
#   'slouchy leather high heel boots',
#   'animal print leather heeled boots trf'],
#  ['giraffe crossbody bag',
#   'mini giraffe crossbody bag',
#   'giraffe mini crossbody bag',
#   'giraffe-shaped crossbody bag',
#   'mini giraffe crossbody bag trf',
#   'little giraffe crossbody bag',
#   'girregular giraffe crossbody bag',
#   'small giraffe crossbody bag',
#   'girregular mini giraffe crossbody bag',
#   'crossbody bag with mini giraffe'],
#  ['animal print high heel ankle boots trf',
#   'animal print heeled ankle boots trf',
#   'animal print heeled ankle boots',
#   'animal print high-heel ankle boots',
#   'animal print mid-heel ankle boots',
#   'animal print mid-heel ankle boots trf',
#   'animal print mid heel ankle boots trf',
#   'animal print high-heel ankle boots trf',
#   'animal print stiletto-heel ankle boots',
#   'animal print high heel ankle boots'],
#  ['shiny mesh high-heel ankle boots',
#   'mesh high-heel ankle boots',
#   'mesh high heel ankle boots trf',
#   'shiny mesh high heel ankle boots trf',
#   'high heel mesh ankle boots trf',
#   'mesh high-heel ankle boots trf',
#   'high-heel mesh ankle boots trf',
#   'high heel mesh ankle boots',
#   'shiny mesh high heel ankle boots',
#   'heeled mesh ankle boots with shiny details'],
#  ['animal print high-heel shoes',
#   'animal print high heel shoes trf',
#   'animal print high-heel shoes trf',
#   'animal print heeled shoes trf',
#   'animal print high heel shoes',
#   'animal print high-heeled shoes trf',
#   'animal print asymmetrical high-heel shoes',
#   'animal print asymmetric high-heel shoes',
#   'animal print stiletto-heel shoes',
#   'animal print high-heel slingback shoes'],
#  ['contrast vinyl high-heel shoes',
#   'vinyl high-heel shoes',
#   'vinyl high-heel shoes trf',
#   'high-heel shoes with vinyl detail',
#   'silver vinyl high-heel shoes',
#   'vinyl high heel shoes trf',
#   'transparent vinyl high-heel shoes',
#   'vinyl and metal high-heel shoes',
#   'combined vinyl high-heel shoes',
#   'metallic vinyl high-heel shoes'],
#  ['suede metallic heeled shoes',
#   'suede heeled shoes with metallic heels',
#   'suede heeled shoes with pointed toes',
#   'metallic suede heeled shoes',
#   'suede metallic heeled shoes trf',
#   'suede high-heel shoes',
#   'suede mid-heel shoes',
#   'suede high heel shoes trf',
#   's suede heeled shoes',
#   'leather heeled shoes with metallic heels'],
#  ['vinyl mid-heel mules trf',
#   'vinyl mid-heel mules',
#   'vin mid-heel mules trf',
#   'vinyl mid-heel mules with faux patent finish',
#   'vin mid heel mules trf',
#   'vinyl mules with faux patent finish heels trf',
#   'vinyl high heel mules trf',
#   'vinyl heeled mules with faux patent finish',
#   'vinyl heeled mules with faux patent finish heels',
#   'vinyl high-heel mules with faux patent finish'],
#  ['suede high-heel mules',
#   'suede high heel mules trf',
#   'suede heeled mules with pointed toes',
#   'suede heeled mules with metal section',
#   'suede mid-heel mules',
#   'suede high-heel mules with metal detail',
#   'suede high-heel mules trf',
#   'suede high heel mules',
#   'faux suede high-heel mules',
#   'suede heeled mules with pointed toe'],
#  ['asymmetric high-heel sandals trf',
#   'heeled sandals with rhinestone strap',
#   'asymmetric high-heel sandals',
#   'rhinestone high-heel sandals',
#   'asymmetric high heel sandals trf',
#   'asymmetric rhinestone high-heel sandals',
#   'asymmetric strappy high-heel sandals',
#   'rhinestone high-heel sandals trf',
#   'high-heel sandals with rhinestone strap',
#   'asymmetric strappy high-heel sandals trf'],
#  ['velvet high heel platform sandals',
#   'velvet high-heel platform sandals',
#   'knotted high heel platform sandals trf',
#   'velvet heeled platform sandals',
#   'velvet high heel platform sandals with knot',
#   'knotted high-heel platform sandals',
#   'knotted velvet high heel platform sandals',
#   'velvet high heel platform sandals trf',
#   'knotted velvet high-heel sandals',
#   'velvet heeled platform sandals with knot'],
#  ['leather mini wedges with track soles',
#   'leather mini wedges with track sole',
#   'leather mini wedges trf',
#   'leather mini wedges with jute heel',
#   'leather mini wedges',
#   'leather mini wedges with ankle strap',
#   'mini leather wedges with ankle strap',
#   'leather mini wedges with jute',
#   'le mini wedges with ankle strap',
#   'leather wedges with track soles'],
#  ['diamanté leather high-heel sandals',
#   'blue collection leather high-heel sandals',
#   'leather high-heel sandals with diamanté detail',
#   'diamanté leather high-heel sandals trf',
#   'blue collection high-heel sandals with diamanté detail',
#   'leather high-heel sandals with diamanté',
#   'blue collection diamanté leather high-heel sandals',
#   'blue collection leather high-heel sandals with diamanté detail',
#   'blue collection leather high-heel sandals trf',
#   'bejewelled leather high-heel sandals'],
#  ['jute high heel mules with knot',
#   'knotted high heel mules trf',
#   'jute high heel mules trf',
#   'jute high heel mules with knot detail',
#   'jute high heel mules',
#   'knotted jute high-heel mules',
#   'jute high-heel mules with knot',
#   'knotted high-heel mules',
#   'knotted jute high heel mules',
#   'jute high heel mules with frayed knot'],
#  ['heeled mules with thin straps',
#   'mid-heel mules with thin straps',
#   'asymmetric high heel mules trf',
#   'heeled mules with asymmetric straps',
#   'heeled sandals with asymmetric straps',
#   'strappy mid-heel mules trf',
#   'asymmetric heeled mules trf',
#   'mid-heel mules with asymmetric straps',
#   'asymmetric strappy heeled mules',
#   'strappy mid-heel mules'],
#  ['plaited high heel sandals trf',
#   'plaited high-heel sandals',
#   'plaited high-heel sandals trf',
#   'combined high-heel sandals trf',
#   'braided strappy high-heel sandals',
#   'braided high-heel sandals trf',
#   'braided high-heel sandals',
#   'plaited strappy high-heel sandals',
#   'combined strappy high-heel sandals',
#   'plaited high heel sandals'],
#  ['piggy-shaped bad',
#   'piggy bad',
#   'piggy with sheep',
#   'piggy soft toy',
#   'sheep piggy',
#   'piggy christmas bad',
#   'piggy print bad',
#   'sheep piggy bad',
#   'piggy shaped bad',
#   'piggy piggy bad'],
#  ['chunky sole sneakers trf',
#   'chunky sneakers trf',
#   'contrast sneakers trf',
#   'white sneakers trf',
#   'multi-piece sneakers trf',
#   'contrasting sneakers trf',
#   'white sneakers with chunky soles',
#   'monochrome sneakers trf',
#   'white chunky sneakers trf',
#   'chunky sole sneakers'],
#  ['cotton lunch bag',
#   'cotton lunch bag trf',
#   'cotton lunch bag with zip',
#   'lunch bag',
#   'lunch bag with zip',
#   '100% cotton lunch bag',
#   'limited edition cotton lunch bag',
#   'c lunch bag',
#   'mini cotton lunch bag',
#   'picnic lunch bag'],
#  ['leather loafers with gathering',
#   'leather loafers with gathered detail',
#   'leather loafers with gathered seam',
#   'leather loafers',
#   'leather loafers with gathered seams',
#   'leather loafers with gathered toe',
#   'leather loafers with gathered seam detail',
#   'leather loafers with seam detail',
#   'le loafers with gathered toe',
#   'leather loafers trf'],
#  ['cotton backpack with ears',
#   'backpack with ears',
#   'mini faux shearling backpack',
#   'faux shearling backpack',
#   'backpack with faux shearling',
#   'shearling backpack with ears',
#   'mini backpack with ears',
#   'cotton backpack with faux shearling',
#   'backpack with faux shearling ears',
#   'back with ears'],
#  ['flat die-cut shoes trf',
#   'flat die-cut shoes',
#   'die-cut flat shoes',
#   'flat shoes with die-cut upper trf',
#   'flat shoes with die-cut heels trf',
#   'cut-out flat shoes trf',
#   'die-cut flat shoes trf',
#   'flat shoes with die-cut detail trf',
#   'flat shoes trf',
#   'flat shoes with die-cut sole'],
#  ['flat slingback shoes with cage straps',
#   'flat slingback shoes trf',
#   'flat slingback shoes',
#   'flat slingback shoes with cage',
#   'flat slingbacks with cage straps trf',
#   'slingback shoes with cage straps',
#   'flat slingback shoes with cage detail',
# ...
#   'cotton towel with geometric design'],
#  ['lacquered wooden hanger (set of 3)',
#   'lacquered wood hanger (set of 3)',
#   'lacquered wooden hanger (set of 2)',
#   'lacquered wood hanger (set of 2)',
#   'lacquered wooden hanger',
#   'lacquered wood hanger',
#   'lacquered wooden hanger (set of 4)',
#   'lacquered wooden hanger (set of 6)',
#   'lacquered wood trousers hanger',
#   'lacquered wooden trousers hanger'],
#  ['lacquered wood hanger',
#   'lacquered wooden skirt hanger (set of 2)',
#   'lacquered wooden skirt hanger',
#   'lacquered wood skirt hanger (set of 2)',
#   'lacquered wooden skirt hanger (set of 3)',
#   'lacquered wood skirt hanger (set of 3)',
#   'lacquered wooden skirt hanger (set of 4)',
#   'lacquered wooden skirt hanger (set of 6)',
#   'lacquered wooden hanger',
#   'lacquered wood skirt hanger'],
#  ['aluminum and wood hanger (set of 2)',
#   'wooden and metal hanger (set of 2)',
#   'wood and metal hanger (set of 2)',
#   'aluminum hanger (set of 2)',
#   'hanger with wooden bar (set of 2)',
#   'metal and wood hanger (set of 2)',
#   'wooden hanger (set of 2)',
#   'wood and metal peg hanger (set of 2)',
#   'aluminium and wood hanger (set of 2)',
#   'metal hanger (set of 2)'],
#  ['wooden and metal hanger (set of 2)',
#   'wood and metal hanger (set of 2)',
#   'aluminum and wood hanger (set of 2)',
#   'aluminum and wood clothes hanger (set of 2)',
#   'wood hanger (set of 2)',
#   'metal and wood hanger (set of 2)',
#   'hanger with wooden bar (set of 2)',
#   'wooden and metal laundry hanger (set of 2)',
#   'wooden hanger (set of 2)',
#   'wooden and metal clothes hanger (set of 2)'],
#  ['fleece blanket',
#   'faux fur blanket',
#   'super soft blanket',
#   'fur blanket',
#   'blanket with faux fur',
#   'fuzzy blanket',
#   'soft faux fur blanket',
#   'furry blanket',
#   'super soft faux fur blanket',
#   'textured faux fur blanket'],
#  ['metal skirt hanger (set of 2)',
#   'metal skirt hanger (set of 3)',
#   'metal skirt hangers (set of 2)',
#   'metal skirt hangers',
#   'set of metal skirt hangers',
#   'metal skirt hangers (set of 3)',
#   'set of skirt hangers',
#   'metal skirt hanger (set of 6)',
#   'metal skirt hangers (pack of 2)',
#   'metal skirt hanger (pack of 2)'],
#  ['padded iron hanger (pack of 4)',
#   'padded linen and cotton hanger (pack of 4)',
#   'iron and linen hanger (pack of 4)',
#   'iron hanger with tassels (pack of 4)',
#   'padded iron hanger (set of 4)',
#   'padded cotton and linen hanger (pack of 4)',
#   'padded iron and linen hanger (pack of 4)',
#   'iron hanger with tassel (pack of 4)',
#   'linen and cotton hanger (pack of 4)',
#   'padded linen and cotton hanger (set of 4)'],
#  ['metal hanger (set of 2)',
#   'metal hanger (set of 3)',
#   'metal hanger',
#   'metal hanger (set of 4)',
#   'metal hanger (set of 6)',
#   'metal garment hanger (set of 2)',
#   'metal hanger (set of 20)',
#   'metal hanger (set of 8)',
#   'metal hanger with notches',
#   'metal hanger (set of 5)'],
#  ['oversized cotton jersey t-shirt',
#   'oversized t-shirt',
#   'cotton jersey t-shirt',
#   'oversized cotton t-shirt',
#   'striped oversized t-shirt',
#   'textured cotton jersey t-shirt',
#   'oversized striped t-shirt',
#   'oversize cotton jersey t-shirt',
#   'textured cotton t-shirt',
#   'oversized t-shirt trf'],
#  ['cotton jersey trousers',
#   'knit joggers',
#   'cotton jogging trousers',
#   'cotton jersey joggers',
#   'knit jogging trousers',
#   'cotton joggers',
#   'knit trousers',
#   'c jogging trousers',
#   'knit palazzo trousers',
#   'striped cotton jersey trousers'],
#  ['cotton jersey dressing gown',
#   'long cotton jersey dressing gown',
#   'long dressing gown',
#   'long dressing gown with belt',
#   'long cotton dressing gown',
#   'striped cotton dressing gown',
#   'cotton dressing gown',
#   'striped cotton jersey dressing gown',
#   'long dressing gown with pockets',
#   'long jersey dressing gown'],
#  ['cotton jersey dress',
#   'ribbed dress trf',
#   'jacquard dress',
#   'textured dress',
#   'striped cotton jersey dress',
#   'ribbed dress',
#   'ribbed cotton jersey dress',
#   'textured cotton jersey dress',
#   'basic cotton jersey dress',
#   'printed dress trf'],
#  ['cotton jersey shirt',
#   'v-neck shirt',
#   'striped cotton jersey shirt',
#   'cotton shirt with pocket',
#   'slogan print shirt',
#   'cotton shirt',
#   'basic cotton jersey shirt',
#   'textured cotton shirt',
#   'cotton jersey shirt with pocket',
#   'basic cotton shirt'],
#  ['leggings with pockets',
#   'basic leggings',
#   'ribbed leggings',
#   'check leggings',
#   'plain leggings',
#   'textured leggings',
#   'basic leggings with pockets',
#   'faux leather leggings',
#   'knit leggings with pockets',
#   'basic plain leggings'],
#  ['check flannel trousers',
#   'checked flannel trousers',
#   'flannel trousers',
#   'check print flannel trousers',
#   'tartan flannel trousers',
#   'printed flannel trousers',
#   'flannel trousers with tartan',
#   'flannel check trousers',
#   'flannel tartan trousers',
#   'flannel culottes'],
#  ['flannel eye mask',
#   'check flannel eye mask',
#   'checked flannel eye mask',
#   'tartan flannel eye mask',
#   'flannel tartan eye mask',
#   'flannel print eye mask',
#   'printed flannel eye mask',
#   'tartan print eye mask',
#   'check print flannel eye mask',
#   'tartan eye mask'],
#  ['printed flannel shirt',
#   'flannel shirt',
#   'check flannel shirt',
#   'flannel shirt with tartan',
#   'check print flannel shirt',
#   'flannel shirt with pocket',
#   'flannel check shirt',
#   'tartan flannel shirt',
#   'checked flannel shirt',
#   'striped flannel shirt'],
#  ["men's flannel pyjamas",
#   "men's tartan pyjamas",
#   "men's flannel set of pyjamas",
#   'men’s tartan pyjamas',
#   "men's check pyjamas",
#   'check flannel pyjamas',
#   "men's check flannel pyjamas",
#   'men’s flannel pyjamas',
#   'men pyjamas with tartan print',
#   'men’s check flannel pyjamas'],
#  ['washed linen fitted sheet',
#   'plain washed linen fitted sheet',
#   ' washed linen fitted sheet',
#   'striped washed linen fitted sheet',
#   'wash linen fitted sheet',
#   'white washed linen fitted sheet',
#   'linen fitted sheet',
#   'washed linen fitted sheet.',
#   'striped linen fitted sheet',
#   'navy washed linen fitted sheet'],
#  ['lamp with resin base',
#   'resin lamp',
#   'lamp with a resin base',
#   'light bulb with resin base',
#   'rattan lamp',
#   'textured resin lamp',
#   'kids lamp with resin base',
#   'light lamp with resin base',
#   'resin and fabric lamp',
#   'transparent resin lamp'],
#  ['multicoloured stripe towel',
#   'multicoloured striped towel',
#   'striped towel with border',
#   'towel with striped border',
#   'striped towel',
#   'cotton towel with border',
#   'towel with multicoloured border',
#   'multicoloured border towel',
#   'towel with multicoloured stripes',
#   'stripedt towel with border'],
#  ['cotton pouffe',
#   'pouffe with pocket',
#   'pouffe with strap',
#   'striped cotton pouffe',
#   'textured cotton pouffe',
#   'basic cotton pouffe',
#   'cotton pouffe with strap',
#   'textured pouffe',
#   'cotton pouffe with pocket',
#   'c pouffe'],
#  ['lamp with wooden base',
#   'glass base lamp',
#   'wood and glass lamp',
#   'glass lamp with wooden base',
#   'wooden and glass lamp',
#   'glass lamp',
#   'lamp with glass base',
#   'glass and wood lamp',
#   'wooden base lamp',
#   'wooden lamp'],
#  ['methacrylate side table',
#   'methacrylate table',
#   'methacrylate side table with storage',
#   'large methacrylate side table',
#   'methacrylate storage table',
#   'round methacrylate table',
#   'methacrylate table with storage',
#   'u methacrylate side table',
#   'sethacrylate side table',
#   'm methacrylate side table'],
#  ['faceted mirror tray',
#   'mirrored tray',
#   'square mirror tray',
#   'mirrored tray with handles',
#   'mirrored square tray',
#   'mirror tray',
#   'faceted tray',
#   'transparent mirror tray',
#   'square faceted mirror tray',
#   'faceted tray with handles'],
#  ['bubble-effect night set',
#   'bubbles night set',
#   'bubble effect night set',
#   'night set',
#   'night set with bubbles',
#   'bubbleach-effect night set',
#   'bottle and tumbler night set',
#   'balloon-effect night set',
#   'bubbled glass night set',
#   'glow in the dark night set'],
#  ['faux fur rug',
#   'textured rug',
#   'textured faux fur rug',
#   'textured fur rug',
#   'rug with faux fur',
#   'fuzzy rug',
#   'furry rug',
#   'fleece rug',
#   'contrast faux fur rug',
#   'f rug'],
#  ['gold frame mirror',
#   'mirror with gold frame',
#   'gold framed mirror',
#   'symmetrical mirror',
#   'gold mirror',
#   'symmetrical gold mirror',
#   'symmetrical wall mirror',
#   'large gold frame mirror',
#   'wall mirror with gold frame',
#   'symmetric mirror'],
#  ['scored rug',
#   'scored-effect rug',
#   'scored effect rug',
#   'striped rug',
#   'textured rug',
#   'rug with scored effect',
#   'score-effect rug',
#   'schedgehog rug',
#   'kids scored rug',
#   'scordained rug'],
#  ['faceted glass tumbler',
#   'faceted-effect tumbler',
#   'thick faceted glass tumbler',
#   'faceted tumbler',
#   'thick faceted tumbler',
#   'faceted transparent tumbler',
#   'thick transparent glass tumbler',
#   'faceted design glass tumbler',
#   'faceted transparent glass tumbler',
#   'transparent glass tumbler'],
#  ['faceted glass soft drink tumbler',
#   'faceted soft drink tumbler',
#   'faceted-effect soft drink tumbler',
#   'thick faceted soft drink tumbler',
#   'transparent glass soft drink tumbler',
#   'soft drink tumbler with faceted design',
#   'thick transparent glass soft drink tumbler',
#   'thick faceted glass soft drink tumbler',
#   'transparent soft drink tumbler',
#   'faceted transparent soft drink tumbler'],
#  ['circular wine glass',
#   'wine glass with circular base',
#   'glass with circular base',
#   'wine glass with round base',
#   'round wine glass',
#   'circular base wine glass',
#   'wine glass with a circular base',
#   'circular-shaped wine glass',
#   'circular textured wine glass',
#   'transparent wine glass'],
#  ['round basket with handles',
#   'round basket with handle',
#   'round woven basket',
#   'round woven basket with handle',
#   'round bread basket with handle',
#   'round woven bread basket',
#   'round basket with side handle',
#   'round bread basket',
#   'round basket',
#   'woven basket with handle'],
#  ['multicoloured geometric rug',
#   'multicoloured rug',
#   'multicoloured cotton rug',
#   'geometric print rug',
#   'cotton rug',
#   'geometric cotton rug',
#   'multicolored geometric rug',
#   'geometric rug',
#   'multicoloured striped rug',
#   'cotton rug with geometric design'],
#  ['wool and jute rug',
#   'wool and jute mix rug',
#   'striped wool and jute rug',
#   'striped wool rug',
#   'beige wool and jute rug',
#   'cream wool and jute rug',
#   'w and jute rug',
#   'striped jute rug',
#   'striped jute and wool rug',
#   'w jute and wool rug'],
#  ['patchwork rug',
#   'striped patchwork rug',
#   'patchwork effect rug',
#   'patchwork rug trf',
#   'patchwork-effect rug',
#   'textured patchwork rug',
#   'limited edition patchwork rug',
#   'patchwork rug.',
#   'patchwork print rug',
#   'patchwork textured rug'],
#  ['lamp with bamboo handle',
#   'wireless lamp with bamboo handle',
#   'wireless bamboo lamp',
#   'bamboo led lamp',
#   'plastic lamp with bamboo handle',
#   'bamboo lamp',
#   'usb lamp with bamboo handle',
#   'usb rechargeable lamp',
#   'usb connection lamp with bamboo handle',
#   'wireless plastic lamp'],
#  ['basket with handles',
#   'triangle basket with handles',
#   'triangle basket',
#   'triangle pattern basket',
#   'triangular basket',
#   'triangular basket with handles',
#   'basket with triangles',
#   'triangles basket',
#   'basket with triangle pattern',
#   'triangles basket with handles'],
#  ['wooden side table',
#   'wood side table',
#   'side table with metal legs',
#   'rectangular wooden side table',
#   'rectangular wood side table',
#   'wood and metal side table',
#   'metal and wood side table',
#   'wooden and metal side table',
#   'side table with wooden legs',
#   'side table'],
#  ['wooden jewellery box',
#   'circular wooden jewellery box',
#   'wooden and linen jewellery box',
#   'two-tone wooden jewellery box',
#   'round wooden jewellery box',
#   'wood and linen jewellery box',
#   'circular jewellery box',
#   'linen-lined jewellery box',
#   'wood jewellery box',
#   'wooden jewellery box with trays'],
#  ['rectangular wooden jewellery box',
#   'wooden jewellery box',
#   'wooden and linen jewellery box',
#   'two-tone wooden jewellery box',
#   'wooden jewellery box with trays',
#   'linen-lined jewellery box',
#   'wood and linen jewellery box',
#   'wood jewellery box',
#   'linen jewellery box',
#   'rectangular jewellery box'],
#  ['mirror with wooden frame',
#   'wooden frame mirror',
#   'wooden mirror',
#   'table mirror',
#   'wooden table mirror',
#   'large wooden frame mirror',
#   'large wooden mirror',
#   'table mirror with wooden frame',
#   'metal and wood mirror',
#   'wood frame mirror'],
#  ['stand-up mirror',
#   'black iron mirror',
#   'black iron stand-up mirror',
#   'mirror with iron base',
#   'mirror with black iron base',
#   'iron stand-up mirror',
#   'metal stand-up mirror',
#   'iron and metal mirror',
#   'iron and wood mirror',
#   'stand mirror'],
#  ['lacquered metal lamp',
#   'lacquered lamp',
#   'black lacquered lamp',
#   'metal lamp',
#   'lamp with lacquered metal',
#   'lamp with metal frame',
#   'black lacquered metal lamp',
#   'lquilted metal lamp',
#   'lamp with metal grill',
#   'lquilted lamp'],
#  ['fleece armchair',
#   'upholstered armchair',
#   'fleece upholstered armchair',
#   'upholstered fleece armchair',
#   'fleece-upholstered armchair',
#   'padded fleece armchair',
#   'fleece armchair.',
#   'faux fur armchair',
#   'fleeveless armchair',
#   'faux shearling armchair'],
#  ['striped cotton towel',
#   'striped towel',
#   'cotton towel with fringing',
#   'striped towel with fringing',
#   'towel with fringed edges',
#   'fringed cotton towel',
#   'striped towel with fringe',
#   'towel with fringing',
#   'cotton towel with fringe',
#   'fringed towel'],
#  ['double-sided towel',
#   'double-sided cotton towel',
#   'cotton towel',
#   'striped cotton towel',
#   'two-sided cotton towel',
#   'double-sized cotton towel',
#   'two-sided towel',
#   'doublesided cotton towel',
#   'double cotton towel',
#   'double-double-sided towel'],
#  ['double-sided towel (pack of 2)',
#   'cotton towel (pack of 2)',
#   'double-sided cotton towel (pack of 2)',
#   'two-sided towel (pack of 2)',
#   'striped cotton towel (pack of 2)',
#   'towel (pack of 2)',
#   'doublesided cotton towel (pack of 2)',
#   'two-sided cotton towel (pack of 2)',
#   'doublesided towel (pack of 2)',
#   'double cotton towel (pack of 2)'],
#  ['towel with tassels (pack of 3)',
#   'cotton towel with tassels (pack of 3)',
#   'towel with tassel (pack of 3)',
#   'towel with tassels (set of 3)',
#   'tassel towel (pack of 3)',
#   'c towel with tassels (pack of 3)',
#   'towels with tassels (pack of 3)',
#   'towel with contrast tassels (pack of 3)',
#   't (pack of 3)',
#   't towel with tassels (pack of 3)'],
#  ['towel with tassels',
#   'cotton towel with tassels',
#   'towel with tassel',
#   'towel with contrast tassels',
#   'towel with tassel detail',
#   'towel with tassel edges',
#   'linen towel with tassels',
#   'tassel towel',
#   'paper towel with tassels',
#   'c towel with tassels'],
#  ['cotton towel with band',
#   'towel with band',
#   'towel with lined band',
#   'towel with printed band',
#   'towel with contrast band',
#   'cotton towel',
#   'towel with elastic band',
#   'striped cotton towel',
#   'cotton towel with bands',
#   'towel with a band'],
#  ['golden marble nesting tables',
#   'marble nesting tables',
#   'nesting tables',
#   'golden marble nesting table',
#   'two-tone marble nesting tables',
#   'golden nesting tables',
#   'nesting tables with marble top',
#   'two-piece marble nesting table',
#   'nesting tables (set of 2)',
#   'golden marble nest of tables'],
#  ['towel with crochet border',
#   'cotton crochet towel',
#   'crochet cotton towel',
#   'crochet towel',
#   'crochet border towel',
#   'towels with crochet border',
#   'cotton towel with crochet border',
#   'c towel with crochet border',
#   'cotton towel with border',
#   'towel with crochet borders'],
#  ['basket with fabric lining',
#   'round basket with fabric lining',
#   'rectangular basket with fabric lining',
#   'large basket with fabric lining',
#   'round fabric-lined basket',
#   'metal basket with fabric lining',
#   'round basket',
#   'oval basket with fabric lining',
#   'basket with metal structure',
#   'basket with resilient paper'],
#  ...]

# %%
from postprocessing import save_submission

submission_name = "submission_84"
save_submission(result, submission_name)
save_submission(result, submission_name, zip=False)
