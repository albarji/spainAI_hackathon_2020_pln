# %% [markdown]
# # Notebook to test ranking proposals by sentence transformers

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load resources

# %%
from data import load_data

train, val, test = load_data()

# %%
from postprocessing import read_proposals_files

models = [
    "BART-large-submission-21", 
    "BART-base-submission-23",
    "pegasus-large-submission-30",
    "t5-base-submission-40",
    "t5-small-submission-36",
    "t5-small-submission-38"
]
    
val["name_proposals"] = read_proposals_files([f"val_{model}.csv" for model in models], remove_duplicates='global')
test["name_proposals"] = read_proposals_files([f"submission_{model.split('-')[-1]}.csv" for model in models], remove_duplicates='global')

# %%
train
# Out:
#                                      name  \
# 25291                     fabric tote bag
# 5328      knit cardigan with ruffle trims
# 28974          mercurised glass soap dish
# 10697                             joggers
# 8656                 ribbed knit cardigan
# ...                                   ...
# 7820                  ripped skinny jeans
# 15507  flannel shirt with stand-up collar
# 17874                  basic denim jacket
# 28245          low rattan basket with lid
# 15855                      cropped blazer
#
#                                              description
# 25291  tote bag in a combination of colours. braided ...
# 5328   knit cardigan with a round neck. featuring lon...
# 28974                        mercurised glass soap dish.
# 10697  relaxed fit trousers made of a linen blend. fe...
# 8656   cardigan with round neckline, long sleeves and...
# ...                                                  ...
# 7820   five-pocket skinny jeans with an adjustable in...
# 15507  regular fit shirt with a flannel finish. stand...
# 17874  collared denim jacket featuring long buttoned ...
# 28245  seagrass basket in two tones with lid and hand...
# 15855  blazer featuring a lapel collar and long sleev...
#
# [33480 rows x 2 columns]

# %%
val
# Out:
#                                                     name  \
# 1190                     t-shirt with polka dot flocking
# 2774                         double strap wrap dress trf
# 32709        cloud design bedspread with metallic thread
# 32403        ceramic door knob with transfer (pack of 2)
# 14237                                      puffer jacket
# ...                                                  ...
# 31096                             water lily voile dress
# 9682                                  striped sweatshirt
# 2355                                 ruffled t-shirt trf
# 31358  pine cone and sleigh bells napkin holders (pac...
# 9442                          sequinned heart sweatshirt
#
#                                              description  \
# 1190   round neck t-shirt featuring long sleeves with...
# 2774   short v-neck dress featuring double straps and...
# 32709  bedspread with a cloud design and metallic thr...
# 32403  round white ceramic door knob featuring a blue...
# 14237  long sleeve puffer jacket featuring a detachab...
# ...                                                  ...
# 31096  children's dress featuring a water lily print ...
# 9682   long sleeve hoodie. button fastening on the yo...
# 2355   round neck t-shirt with short sleeves and a ru...
# 31358  napkin holder with faux twigs, pine cone, slei...
# 9442   long sleeve sweatshirt with a round neckline, ...
#
#                                           name_proposals
# 1190   [ruff t-shirt, t-shirt with ruffles, plain t-s...
# 2774   [satin dress, printed dress, printed dress trf...
# 32709  [cloud bedspread, cloudbedspread, cloud bedspr...
# 32403  [ceramic door knob with sketches (pack of 2).,...
# 14237  [water repellent puffer jacket, quilted jacket...
# ...                                                  ...
# 31096  [water lily-print dress, water lily print mini...
# 9682   [cropped sweatshirt, textured hoodie, ribbed s...
# 2355   [ruff t-shirt, frilled hem t-shirt, plain t-sh...
# 31358  [pine pine cone napkin holder (pack of 2), pin...
# 9442   [sequinverted stripes sweatshirt, swehirt with...
#
# [3730 rows x 3 columns]

# %%
test
# Out:
#                                             description  \
# 0     knit midi dress with a v-neckline, straps and ...
# 1     loose-fitting dress with a round neckline, lon...
# 2     nautical cap with peak.this item must be retur...
# 3     nautical cap with peak. adjustable inner strap...
# 4     nautical cap with side button detail.this item...
# ...                                                 ...
# 1436  striped print cotton cushion cover. cushion fi...
# 1437       rectangular cushion featuring a gnome print.
# 1438  cotton jersey eye mask featuring an elastic ba...
# 1439  padded chipboard hanger featuring an iron hook...
# 1440  iron hanger suitable for hanging all kinds of ...
#
#                                          name_proposals
# 0     [knit dress with lace trim, lace dress trf, kn...
# 1     [floral print dress trf, flowing dress trf, lo...
# 2     [foil nautical cap, check nautical cap, nautic...
# 3     [nautical cap with inner strap, check nautical...
# 4     [check nautical cap, nautical cap, nautical ca...
# ...                                                 ...
# 1436  [stripedt/crg 05, stripedt print cushion cover...
# 1437  [nogome cushion, nogger cushion, noggin cushio...
# 1438  [cotton jersey eye mask, c cotton jersey eye m...
# 1439  [paisley jacquard padded hanger (pack of 3), p...
# 1440  [iron hanger (set of 5), metal hanger (pack of...
#
# [1441 rows x 2 columns]

# %% [markdown]
# ## Compute similarities with sentence transformers

# %%
#from sentence_transformers import SentenceTransformer
#model = SentenceTransformer('paraphrase-distilroberta-base-v1')

# %%
def combine_proposals(dataset):
    models = list(set(val.columns) - set(["name", "description"]))
    proposals = [[] for _ in range(len(dataset))]
    for model in models:
        proposals = [p + added for p, added in zip(proposals, dataset[model])]
    return proposals

# %%
import numpy as np
from sentence_transformers import util

def rank_sentence_embeddings(model, dataset):
    return [
        rank_proposals(model, description, proposals)
        #for description, proposals in zip(dataset["description"], combine_proposals(dataset))
        for description, proposals in zip(dataset["description"], dataset["name_proposals"])
    ]
    
    
def rank_proposals(model, description, proposals, limit=10):
    #Compute embedding for both lists
    embedding_description = model.encode([description], convert_to_tensor=True)
    embeddings_proposals = model.encode(proposals, convert_to_tensor=True)

    #Compute cosine-similarities
    cosine_scores = util.pytorch_cos_sim(embedding_name, embeddings_proposals)[0]
    
    # Sort by similarity
    sorted_proposals = [proposals[z[0]] for z in sorted(enumerate(cosine_scores), key=lambda x: x[1], reverse=True)][:limit]
    return sorted_proposals

# %%
sample = 100

# %%
# %%time
ranked_proposals = rank_sentence_embeddings(model, val.iloc[:sample])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-21-99849ee634b0> in rank_sentence_embeddings(model, dataset)
#       3
#       4 def rank_sentence_embeddings(model, dataset):
# ----> 5     return [
#       6         rank_proposals(model, description, proposals)
#       7         #for description, proposals in zip(dataset["description"], combine_proposals(dataset))
#
# <ipython-input-21-99849ee634b0> in <listcomp>(.0)
#       4 def rank_sentence_embeddings(model, dataset):
#       5     return [
# ----> 6         rank_proposals(model, description, proposals)
#       7         #for description, proposals in zip(dataset["description"], combine_proposals(dataset))
#       8         for description, proposals in zip(dataset["description"], dataset["name_proposals"])
#
# <ipython-input-21-99849ee634b0> in rank_proposals(model, description, proposals, limit)
#      16
#      17     #Compute cosine-similarities
# ---> 18     cosine_scores = util.pytorch_cos_sim(embedding_name, embeddings_proposals)[0]
#      19
#      20     # Sort by similarity
#
# NameError: name 'embedding_name' is not defined

# %%
from ranker import majority_ranking

majority_ranked_proposals = majority_ranking(combine_proposals(val.iloc[:sample]))

# %%
from model import dcg

print(f"DCG majority ranked = {dcg(majority_ranked_proposals, val['name'][:sample])}")
print(f"DCG s-transformers  = {dcg(ranked_proposals, val['name'][:sample])}")
# Out:
# DCG majority ranked = 21.259635900581586
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8f007a2c63aa> in <module>
#       2
#       3 print(f"DCG majority ranked = {dcg(majority_ranked_proposals, val['name'][:sample])}")
# ----> 4 print(f"DCG s-transformers  = {dcg(ranked_proposals, val['name'][:sample])}")
#
# NameError: name 'ranked_proposals' is not defined

# %% [markdown]
# ## Train similarity model with sentence tranformers

# %%
from postprocessing import unroll_data

unrolled_val = unroll_data(val["name"], val["description"], val["name_proposals"])

# %%
unrolled_val
# Out:
#                                         name  \
# 0            t-shirt with polka dot flocking
# 1                            striped t-shirt
# 2                    ribbed top with ruffles
# 3                             poplin t-shirt
# 4              gathered t-shirt with ruffles
# ...                                      ...
# 379310           sequinned oxford sweatshirt
# 379311  sequinverted lapel collar sweatshirt
# 379312       asymmetric sequinned sweatshirt
# 379313     sweatshirt with sequinned sleeves
# 379314       sequinned sweatshirt with tulle
#
#                                               description  label
# 0       round neck t-shirt featuring long sleeves with...      1
# 1       round neck t-shirt featuring long sleeves with...      0
# 2       round neck t-shirt featuring long sleeves with...      0
# 3       round neck t-shirt featuring long sleeves with...      0
# 4       round neck t-shirt featuring long sleeves with...      0
# ...                                                   ...    ...
# 379310  long sleeve sweatshirt with a round neckline, ...      0
# 379311  long sleeve sweatshirt with a round neckline, ...      0
# 379312  long sleeve sweatshirt with a round neckline, ...      0
# 379313  long sleeve sweatshirt with a round neckline, ...      0
# 379314  long sleeve sweatshirt with a round neckline, ...      0
#
# [379315 rows x 3 columns]

# %%
from sentence_transformers import SentenceTransformer

#Define the model. Either from scratch of by loading a pre-trained model
model = SentenceTransformer('distilbert-base-nli-mean-tokens')

# %%
from sentence_transformers import InputExample, losses, evaluation
from torch.utils.data import DataLoader

#Define your train examples.
train_examples = [
    InputExample(texts=[name, description], label=float(label))
    for name, description, label in zip(unrolled_val["name"], unrolled_val["description"], unrolled_val["label"])
]

#Define your train dataset, the dataloader and the train loss
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=128)
train_loss = losses.CosineSimilarityLoss(model)

#Tune the model
#evaluator = evaluation.EmbeddingSimilarityEvaluator(unrolled_val["name"].iloc[:128], unrolled_val["description"].iloc[:128], unrolled_val["label"].iloc[:128])
#model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=10, warmup_steps=100, evaluator=evaluator, evaluation_steps=1)
model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=1, warmup_steps=100)
# Out:
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/2964 [00:00<?, ?it/s]

# %%
model.evaluate(evaluator)
# Out:
# 0.056261097289757186

# %% [markdown]
# * 1-epoch train:  0.0460318068734377
# * 2-epochs train: 0.056261097289757186

# %% [markdown]
# ## Test model

# %%
import numpy as np
from sentence_transformers import util

def rank_sentence_embeddings(model, dataset):
    return [
        rank_proposals(model, description, proposals)
        for description, proposals in zip(dataset["description"], dataset["name_proposals"])
    ]
    
    
def rank_proposals(model, description, proposals, limit=10):
    #Compute embedding for both lists
    embedding_description = model.encode([description], convert_to_tensor=True)
    embeddings_proposals = model.encode(proposals, convert_to_tensor=True)

    #Compute cosine-similarities
    cosine_scores = util.pytorch_cos_sim(embedding_description, embeddings_proposals)[0]
    
    # Sort by similarity
    sorted_proposals = [proposals[z[0]] for z in sorted(enumerate(cosine_scores), key=lambda x: x[1], reverse=True)][:limit]
    return sorted_proposals

# %%
sample = 100

# %%
# %%time
ranked_proposals = rank_sentence_embeddings(model, val.iloc[:sample])
# Out:
# CPU times: user 2min 49s, sys: 30.8 s, total: 3min 20s
# Wall time: 26.5 s

# %%
ranked_proposals
# Out:
# [['printed t-shirt',
#   'printed t-shirt',
#   'printed t-shirt with ruffles',
#   'printed t-shirt with ruffles',
#   'floral print t-shirt',
#   'long sleeve t-shirt with ruffles',
#   'animal print t-shirt',
#   'contrast sleeve t-shirt',
#   'ruffled print t-shirt',
#   'ruffle-trimmed t-shirt'],
#  ['printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'check dress',
#   'printed mini dress',
#   'printed mini dress',
#   'printed mini dress',
#   'printed mini dress'],
#  ['cloud bedpread',
#   'cloud bedpread',
#   'Cloud bedpread',
#   'cloud bedpread',
#   'cloud print cotton bedspread',
#   'cloud mesh bedspread',
#   'metallic thread cloud bedspread',
#   'metallic thread cloud bedspread',
#   'metallic thread cloud bedspread',
#   'cloud bed sheet'],
#  ['round ceramic door knob',
#   'round ceramic door knob',
#   'cerceramic door knob',
#   'round ceramic door knob with sketch design transfer',
#   'ceramic door knob (pack of 2).',
#   'ceramic door knob (pack of 2).',
#   'blue and black ceramic door knob',
#   'ceramic door knob',
#   'ceramic door knob',
#   'ceramic door knob'],
#  ['double-faced puffer jacket',
#   'double-faced puffer jacket',
#   'double-faced puffer jacket',
#   'double-faced puffer jacket',
#   'faux fur jacket',
#   'faux fur hooded puffer jacket',
#   'faux fur bomber jacket',
#   'faux leather puffer jacket',
#   'faux leather puffer jacket',
#   'faux leather puffer jacket'],
#  ['a marble side table',
#   'marble and glass side tables',
#   'marble and glass side table',
#   ' marble and glass side table',
#   'marble and glass side table',
#   'marble and glass side table',
#   'glass marble and glass side table',
#   'glass side table',
#   'glass side table',
#   'glass side table'],
#  ['printed sweatshirt',
#   'print sweatshirt',
#   'waffle-knit sweatshirt',
#   'velvet ballerina sweatshirt',
#   'floral sweatshirt',
#   'animal print sweatshirt',
#   'sweats 04',
#   'ballerina print sweatshirt',
#   'piqué sweatshirt',
#   'tuxedo sweatshirt'],
#  ['printed shirt',
#   'printed shirt',
#   'printed shirt',
#   'check shirt',
#   'check shirt',
#   'check shirt',
#   'check shirt',
#   'check shirt',
#   'check shirt',
#   'flowing printed shirt'],
#  ['check trousers',
#   'check trousers',
#   'rustic trousers',
#   'faux leather jogging trousers',
#   'faux leather jogging trousers',
#   'faux leather cargo trousers',
#   'faux leather cargo trousers',
#   'faux leather cargo trousers',
#   'plush jersey cargo trousers',
#   'plush jersey cargo trousers'],
#  ['wool blend check overshirt',
#   'wool blend check overshirt',
#   'contrast check overshirt',
#   'contrast check overshirt',
#   'contrast check overshirt',
#   'contrast check overshirt',
#   'faux leather overshirt',
#   'faux leather overshirt',
#   'faux leather overshirt',
#   'faux leather overshirt'],
#  ['printed quilt',
#   'floral printed quilt',
#   'tropical print quilt',
#   'floral print quilt',
#   'floral print quilt',
#   'floral print quilt',
#   'floral print quilt',
#   'floral print quilt',
#   'floral print quilt',
#   'floral quilt'],
#  ['',
#   'round neck t-shirt',
#   'knotted long sleeve t-shirt',
#   'printed t-shirt',
#   'printed t-shirt',
#   'floral print t-shirt',
#   'loose-fitting t-shirt with knot',
#   'animal print t-shirt',
#   'knitted hem t-shirt',
#   'plain knotted t-shirt'],
#  ['tuxedo bodysuit',
#   'tuxedo bodysuit',
#   'printed bodysuit',
#   'printed bodysuit',
#   'sleeveless bodysuit',
#   'sleeveless bodysuit',
#   'velvet bodysuit',
#   'velvet bodysuit',
#   'text bodysuit',
#   'bodysuit'],
#  ['printed blouse',
#   'printed blouse',
#   'printed blouse',
#   'embroidered check blouse',
#   'embroidered check blouse',
#   'embroidered check blouse',
#   'embroidered lace blouse',
#   'embroidered lace blouse',
#   'floral print blouse',
#   'floral print blouse'],
#  ['printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'printed draped dress',
#   'gathered floral print dress',
#   'gathered floral print dress',
#   'printed mini dress',
#   'printed mini dress'],
#  ['printed trousers',
#   'printed trousers',
#   'printed trousers',
#   'printed trousers',
#   'printed trousers',
#   'printed cargo trousers',
#   'printed cargo trousers',
#   'abstract print trousers',
#   'printed flowing trousers',
#   'print trousers'],
#  ['printed crop top',
#   'contrast crop top',
#   'square neckline top',
#   'elasticated crop top',
#   'printed top',
#   'crop top',
#   'crop top',
#   'crop top',
#   'crop top',
#   'crop top'],
#  ['check chino trousers',
#   'faux leather chino trousers',
#   'chinos',
#   'chinos',
#   'check trousers',
#   'check trousers',
#   'check trousers',
#   'check trousers',
#   'check trousers',
#   'check trousers'],
#  ['printed top',
#   'asymmetric knit top',
#   'asymmetric knit top',
#   'contrast knit top',
#   'contrast knit top',
#   'check knit top',
#   'puff sleeve knit top',
#   'puff sleeve knit top',
#   'faux leather top',
#   'lace top'],
#  ['cracked metallic maxi clutch',
#   'metallic maxi clutch',
#   'metallic maxi clutch',
#   'metallic maxi clutch',
#   'cracked multi-piece maxi clutch',
#   'broken maxi clutch',
#   'cracked maxi clutch - limited edition',
#   'thermo-sealed maxi clutch',
#   'cracked maxi clutch',
#   'cracked maxi clutch'],
#  ['textured weave bikini bottoms trf',
#   'pack of link necklaces with medallion pendant',
#   'vetiver pamplemousse & ebony wood aromatic candle 200 g',
#   'amalfi sunray aromatic candle 470 g',
#   'vetiver pamplemousse aromatic candle 200 g',
#   'vetiver pamplemousse & ebony wood aromatic candle 470 g',
#   'ribbed bikini bottoms trf',
#   "fleur d'oranger aromatic candle 200 g",
#   "fleur d' oranger aromatic candle 200 g",
#   "fleur d'oranger aromatic candle 200 g"],
#  ['asymmetric knit top',
#   'asymmetric knit top',
#   'check knit top',
#   'contrast knit top',
#   'cable-knit top',
#   'cable-knit top',
#   'cable-knit top',
#   'crop top',
#   'strap top',
#   'knit top with straight neckline'],
#  ['zw premium small smoke black jeans',
#   'zw premium petit blue smoke black jeans',
#   'zw premium petit chic smoke black jeans',
#   'zw premium petit leather smoke black jeans',
#   'limited edition petit smoke slouchy jeans',
#   'hi-rise smoke black petit jeans',
#   'zw premium petit acid black skinny jeans',
#   'zw premium mini smoke black jeans',
#   'zw premium petit smoker black jeans',
#   'zw premium petit smoker black jeans'],
#  ['buckle belt',
#   'check belt',
#   'metal belt',
#   'leather belt',
#   'leather belt',
#   'leather belt',
#   'leather belt',
#   'leather belt',
#   'Leather belt',
#   'leather belt'],
#  ['check textured scarf.',
#   'check border scarf',
#   'check handbag',
#   'check scarf',
#   'check scarf',
#   'check scarf',
#   'check scarf',
#   'check scarf',
#   'check scarf',
#   'checked scarf'],
#  ['printed shirt',
#   'circular print shirt',
#   'abstract print shirt',
#   'abstract print shirt',
#   'abstract print shirt',
#   'slogan print shirt',
#   'floral print shirt',
#   'floral print shirt',
#   'floral print shirt',
#   'floral print shirt'],
#  ['seamless silk romper',
#   'silk blend check romper',
#   'asymmetric silk romper',
#   'striped silk blend romper',
#   'silk blend romper',
#   'silk blend romper',
#   'limited edition silk romper',
#   'printed romper',
#   'printed romper',
#   'printed romper'],
#  ['printed sweatshirt',
#   'plain-coloured sweatshirt',
#   'faux leather sweatshirt',
#   'hooded sweatshirt',
#   'hooded sweatshirt',
#   'faux fur sweatshirt',
#   'contrast sweatshirt',
#   'contrast sweatshirt',
#   'contrast sweatshirt',
#   'oxford sweatshirt'],
#  ['glass lantern',
#   'glass lantern',
#   ' glass lantern',
#   'rattan glass lantern',
#   'rattan glass lantern',
#   'rattan glass lantern',
#   'glass rattan lantern',
#   'glass candle lantern',
#   'thick glass lantern',
#   'candle lantern'],
#  ['felt coaster with the stars (pack of 6)',
#   'felt coaster with a star (pack of 6)',
#   'felt coaster with die cut stars (pack of 6)',
#   'felt coaster with die-cut stars (pack of 2)',
#   'star felt coaster (set of 6)',
#   'felt coaster with a die-cut star',
#   'felt coaster with die-cut stars (pack of6)',
#   'heartfelt coaster with die-cut stars',
#   'star-shaped felt coaster (pack of 6)',
#   'star felt coaster (pack of six)'],
#  ['paper scarf',
#   'printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'check linen scarf',
#   'check linen scarf',
#   'check linen scarf',
#   'rustic scarf'],
#  ['combined technical trousers',
#   'lightweight technical trousers',
#   'lightweight technical trousers',
#   'contrast technical trousers',
#   'contrast technical trousers',
#   'contrast technical trousers',
#   'contrast technical trousers',
#   'contrast cargo trousers',
#   'lightweight cargo trousers',
#   'technical suit trousers'],
#  ['asymmetric crop top',
#   'asymmetric crop top',
#   'asymmetric crop top',
#   'asymmetric crop top',
#   'asymmetric neckline top',
#   'asymmetric neckline top',
#   'printed asymmetric top',
#   'printed asymmetric top',
#   'printed asymmetric top',
#   'printed asymmetric top'],
#  ['faux leather bodysuit',
#   'faux leather bodysuit',
#   'faux leather bodysuit',
#   'faux leather bodysuit',
#   'check bodysuit',
#   'check bodysuit',
#   'check bodysuit',
#   'abstract print bodysuit',
#   'printed bodysuit',
#   'printed bodysuit'],
#  ['sterling rim crystalline wine glass',
#   'sterling silver rim crystalline wine glass',
#   'sterling silver rim crystalline wine glass',
#   'crystalline crystalline wine glass',
#   'crystalline chain crystalline wine glass',
#   'crystalline chain wine glass',
#   'crystalline chain wine glass',
#   'crystalline chain wine glass',
#   'crystalline wine glass',
#   'crystalline wine glass'],
#  ['check cushion',
#   'cushion',
#   'leather cushion',
#   'faux leather cushion',
#   'check linen cushion',
#   'check linen cushion',
#   'rustic cushion',
#   'overlock cushion',
#   'linen pillow',
#   'cotton cushion'],
#  ['printed crop top',
#   'printed top',
#   'faux leather top',
#   'printed cropped top',
#   'pleated check top',
#   'lace top',
#   'lace top',
#   'faux leather top with pearl buttons',
#   'contrasting top',
#   'printed top with bow'],
#  ['printed t-shirt',
#   'london t-shirt',
#   'printed sporty t-shirt',
#   'leaf print t-shirt',
#   'slogan print t-shirt',
#   'slogan print t-shirt',
#   'slogan print t-shirt',
#   'technical camera t-shirt',
#   'voluminous t-shirt',
#   'animal print t-shirt'],
#  ['asymmetric slogan t-shirt',
#   'asymmetric slogan t-shirt',
#   'asymmetric slogan t-shirt',
#   'asymmetric slogan t-shirt',
#   'asymmetric slogan t-shirt',
#   'printed t-shirt',
#   'asymmetric hem t-shirt',
#   'asymmetric t-shirt',
#   'asymmetric t-shirt',
#   'asymmetric t-shirt'],
#  ['cotton sock boot',
#   'sock knit boots',
#   'sock knit boots',
#   'cotton sock boots',
#   'cotton sock boots',
#   'cotton sock boots',
#   'cotton sock boots',
#   'cotton sock boots',
#   'cotton socks',
#   'cotton chunky knit boots'],
#  ['split suede lace-up boots',
#   'monochrome leather boots',
#   'white leather lace-up boots',
#   'white leather lace-up boots',
#   'leather boot',
#   'double-faced leather boots',
#   'beige leather lace-up boots',
#   'neutral leather boots',
#   'leather lightweight track sole boots',
#   'leather chunky sole boots'],
#  ['printed shirt',
#   'wool blend check shirt',
#   'check shirt',
#   'limited edition wool blend check shirt',
#   'voluminous wool blend shirt',
#   'voluminous wool blend shirt',
#   'oversize check shirt',
#   'paisley print shirt',
#   'limited edition wool blend striped shirt',
#   'wool blend shirt'],
#  ['',
#   'striped high neck t-shirt',
#   'striped seamless t-shirt',
#   'woven ribbed t-shirt',
#   'woven stripe t-shirt',
#   'woven stripe t-shirt',
#   'woven stripe t-shirt',
#   'woven stripe t-shirt',
#   'woven striped t-shirt',
#   'woven striped t-shirt'],
#  ['bear christmas decoration.',
#   'sparkly bear christmas christmas decoration',
#   'snowflake christmas tree decoration',
#   'wonder bear christmas decoration',
#   'sparkly snowflake christmas decoration',
#   'sparkling bear christmas decoration',
#   'wild bear christmas decoration',
#   'wild bear christmas decoration',
#   'apple bear christmas decoration',
#   'bear christmas christmas decoration'],
#  ['double-faced leggings',
#   'double-faced leggings',
#   'double-faced leggings trf',
#   'faux leather leggings',
#   'faux leather leggings',
#   'faux leather leggings',
#   'faux leather leggings',
#   'faux leather leggings',
#   'faux leather leggings',
#   'faux leather zipped leggings'],
#  ['kitchen scales with a rectangular design',
#   'kitchen scales with a blue design',
#   'kitchen scales with a black design',
#   'kitchen scales with a pointed design',
#   'kitchen scales with a raised design',
#   'kitchen scales with a green design',
#   'modern kitchen scales',
#   'modern kitchen scales',
#   'stainless steel kitchen scales',
#   'stainless steel kitchen scales'],
#  ['faux patent interior shoulder tote bag',
#   'faux patent crossbody shoulder tote bag',
#   'faux patent crossbody shoulder tote bag',
#   'faux patent fabric shoulder tote bag',
#   'faux patent split suede shoulder tote bag',
#   'faux patent interwoven shoulder tote bag',
#   'faux patent bodysuit shoulder tote bag',
#   'faux patent leather shoulder tote bag',
#   'faux patent leather shoulder tote bag',
#   'faux patent leather shoulder tote bag'],
#  ['frayed effect knit sweater',
#   'cable-knit sweater',
#   'loose-fitting knit sweater',
#   'oversized frayed effect sweater',
#   'frayed effect sweater',
#   'contrast knit sweater',
#   'frayed wool blend sweater',
#   'frayed-effect knit sweater',
#   'tie-dye print sweater',
#   'tie-dye print sweater'],
#  ['white mesh kitten-heel slingback shoes',
#   'metallic kitten-heel slingback shoes',
#   'white kitten-heel slingback shoes',
#   'white kitten-heel slingback shoes',
#   'white kitten-heel slingback shoes',
#   'mesh kitten-heel slingbacks',
#   'mesh kitten-heel slingbacks',
#   'mesh kitten-heel slingbacks',
#   'mesh kitten-heel slingbacks',
#   'mesh kitten-heel slingbacks'],
#  ['printed trousers',
#   'check trousers',
#   'check trousers',
#   'check trousers',
#   'loose-fitting culottes',
#   'rustic trousers',
#   'rustic trousers',
#   'loose-fitting drawstring trousers',
#   'loose-fitting check trousers',
#   'loose-fitting check trousers'],
#  ['cable-knit sweater with geometric design',
#   'combined cable-knit sweater',
#   'combined cable-knit sweater',
#   'combined cable-knit sweater',
#   'combined cable-knit sweater',
#   'voluminous cable-knit sweater',
#   'asymmetric cable-knit sweater',
#   'asymmetric cable-knit sweater',
#   'cable-knit jacquard sweater',
#   'cable-knit jacquard sweater'],
#  ['double-faced crochet t-shirt',
#   'floral crochet t-shirt',
#   'floral crochet t-shirt',
#   'oversize t-shirt with crochet pocket',
#   'patchwork t-shirt with crochet pocket',
#   'printed t-shirt with crochet pocket',
#   'animal print t-shirt with crochet pocket',
#   'printed t-shirt',
#   'cable-knit t-shirt',
#   'contrast crochet t-shirt'],
#  ['asymmetric slogan t-shirt',
#   'asymmetric t-shirt with shoulder pads',
#   'asymmetric t-shirt with shoulder pads',
#   't © sony interactive entertainment t-shirt',
#   'contrast shoulder pads t-shirt',
#   'contrast shoulder pad t-shirt',
#   'printed t-shirt with shoulder pads',
#   't © tm dc comics t-shirt',
#   'technical t-shirt with shoulder pads',
#   'shoulder pads t-shirt'],
#  ['check trousers',
#   'check trousers',
#   'check trousers',
#   'printed trousers',
#   'printed trousers',
#   'faux leather jogging trousers',
#   'faux leather trousers',
#   'faux leather trousers',
#   'faux leather trousers',
#   'faux leather trousers'],
#  ['printed t-shirt',
#   'slogan print t-shirt',
#   'long printed t-shirt',
#   'printed t-shirt with ruffles',
#   'printed t-shirt with ruffles',
#   'frilly sleeve t-shirt',
#   'frilly slogan t-shirt',
#   'colour block t-shirt',
#   'raglan sleeve t-shirt',
#   'text t-shirt with ruffle trims'],
#  ['printed skirt',
#   'printed skirt',
#   'printed skirt',
#   'printed mini skirt',
#   'printed mini skirt',
#   'printed mini skirt',
#   'velvet mini skirt',
#   'faux leather mini skirt',
#   'faux leather mini skirt',
#   'faux leather mini skirt'],
#  ['checked wool blend coat',
#   'check coat',
#   'check coat',
#   'check coat',
#   'check wool blend coat',
#   'check wool blend coat',
#   'check wool blend coat',
#   'wool blend check coat',
#   'wool blend check coat',
#   'wool blend check coat'],
#  ['faux leather double bucket bag',
#   'faux leather double bucket bag',
#   'faux leather double bucket bag',
#   'gathered leather double bucket bag',
#   'printed double bucket bag',
#   'gathered gathered double bucket bag',
#   '',
#   'rustic double bucket bag',
#   'metal double bucket bag',
#   'velvet double bucket bag'],
#  ['textured weave bikini bottoms trf',
#   'pack of link necklaces with medallion pendant',
#   'vetiver pamplemousse & ebony wood aromatic candle 200 g',
#   'amalfi sunray aromatic candle 470 g',
#   'vetiver pamplemousse aromatic candle 200 g',
#   'vetiver pamplemousse & ebony wood aromatic candle 470 g',
#   'ribbed bikini bottoms trf',
#   "fleur d'oranger aromatic candle 200 g",
#   "fleur d' oranger aromatic candle 200 g",
#   "fleur d'oranger aromatic candle 200 g"],
#  ['check scarf',
#   'check scarf',
#   'check scarf',
#   'checked scarf',
#   'checked scarf',
#   'contrast scarf',
#   'contrast scarf',
#   'velvet scarf',
#   'printed scarf',
#   'printed scarf'],
#  ['faux leather bermuda skort',
#   'faux leather bermuda skort',
#   'faux leather bermuda skort',
#   'bermuda box pleats',
#   'bermuda box pleats',
#   'check bermuda skort',
#   'check bermuda skort',
#   'check bermuda skort',
#   'checked bermuda skort',
#   'checked bermuda skort'],
#  ['printed vest',
#   'high neck vest',
#   'high neck vest',
#   'tuxedo vest',
#   'tuxedo vest',
#   'cable-knit vest',
#   'faux leather vest',
#   'faux leather vest',
#   'printed knit vest',
#   'faux fur vest'],
#  ['jungle print bucket bag',
#   'animal print bag',
#   'floral animal print bucket bag',
#   'fluorescent print bucket bag',
#   'fluorescent print bucket bag',
#   'wild print bucket bag',
#   'fluorescent animal print bucket bag',
#   'fluorescent animal print bucket bag',
#   'printed bucket bag',
#   'animal print basket bag'],
#  ['check linen blend bermuda shorts',
#   'check linen blend bermuda shorts',
#   'linen blend paperbag bermuda shorts',
#   'paperbag linen blend bermuda shorts',
#   'paperbag rustic bermuda shorts',
#   'high waist linen blend bermuda shorts',
#   'high waist linen blend bermuda shorts',
#   'linen paperbag bermuda shorts',
#   'linen/viscose bermuda shorts',
#   'paperbag denim bermuda shorts'],
#  ['printed jacket',
#   'printed jacket',
#   'leather jacket',
#   'combined jacket',
#   'check jacket',
#   'printed bomber jacket',
#   'text jacket',
#   'flowing printed jacket',
#   'contrast jacket',
#   'faux leather jacket'],
#  ['printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'printed scarf',
#   'check linen scarf',
#   'check linen scarf',
#   'check linen scarf',
#   'rustic scarf',
#   'printed rustic scarf'],
#  ['printed jacket',
#   'check jacket',
#   'contrast jacket',
#   'faux leather jacket',
#   'faux leather jacket',
#   'faux leather jacket',
#   'faux leather jacket',
#   'faux leather jacket',
#   'animal print jacket',
#   'velvet jacket'],
#  ['printed t-shirt',
#   'slogan print t-shirt',
#   'long sleeve slogan t-shirt',
#   'long sleeve slogan t-shirt',
#   'long sleeve printed t-shirt',
#   'soft-touch slogan t-shirt',
#   'long printed t-shirt',
#   'surfboard t-shirt',
#   'new york slogan t-shirt',
#   'long sleeve t-shirt'],
#  ['draped wreath',
#   'draped christmas wreath',
#   'draped christmas bell',
#   'hanging up wreath',
#   'hanging up wreath',
#   'draped christmas treereath',
#   'tree wreath',
#   'christmas tree wreath',
#   'christmas tree wreath',
#   'christmas wreath'],
#  ['jacquilted napkin (set of 4) with lace trim',
#   'jacquard napkin with lace trim (set of 4)',
#   'jacquard napkin with lace trim (set of 4)',
#   'jacquard napkin with lace trim (set of 4)',
#   'jacquard napkin (pack of 4) with lace trim',
#   'jacquard napkin (pack of 4) with lace trim',
#   'jacquard napkin and lace trim (pack of 4)',
#   'blue jacquard napkin (pack of 4)',
#   'jacquard lace-trimmed napkin (pack of 4)',
#   'jacquilted napkins (pack of 4) with lace trim'],
#  ['cable-knit blanket in beige colour',
#   'blanket with a beige pattern',
#   'blanket with a beige finish',
#   'blanket with a beige color',
#   'blanket with a beige colour',
#   'blanket with a beige weave',
#   'blanket with a beige edge',
#   'plain cable-knit blanket',
#   'check cable-knit blanket',
#   'blue cable-knit blanket'],
#  ['dustpan and brush set with a wooden handle',
#   'dustpan and brush set with a bamboo handle',
#   'dustpan and brush set with an acrylic handle',
#   'natural acrylic bristle dustpan set',
#   'natural acrylic bristles dustpan set',
#   'dustpan and brush set with a wood handle',
#   'metal and acrylic dustpan set',
#   'beech wood brush set',
#   'beech wood dustpan set',
#   'beech wood dustpan set'],
#  ['printed top',
#   'printed top',
#   'sleeveless top',
#   'sleeveless top',
#   'crop top',
#   'crop top',
#   'printed cropped top',
#   'chino top',
#   'asymmetric top trf',
#   'top'],
#  ['vanilla reed diffuser',
#   'vanilla reed diffuser (100 ml) ylang',
#   'vanilla floral reed diffuser (100 ml)',
#   'vanilla floral reed diffuser (100 ml)',
#   'vanilla puree reed diffuser (100 ml)',
#   'vanilla blossom reed diffuser (100 ml)',
#   'vanilla blossom reed diffuser (100 ml)',
#   'vanilla jasmine reed diffuser (100 ml)',
#   '(100 ml) jasmine reed diffusers',
#   'jasmine reed diffuser'],
#  ['printed t-shirt',
#   '',
#   'slogan print t-shirt',
#   'contrast pocket t-shirt',
#   'colour block t-shirt',
#   'sporty contrast t-shirt',
#   'patch pocket t-shirt',
#   '100 ml',
#   'faded-effect t-shirt',
#   'limited edition slogan t-shirt'],
#  ['checked wide-leg trousers',
#   'check wide-leg trousers',
#   'faux leather wide-leg trousers',
#   'paperbag wide-leg trousers',
#   'wide waist trousers',
#   'high-rise wide-leg trousers',
#   'faux leather trousers',
#   'faux leather trousers',
#   'faux leather trousers',
#   'wide-leg chino trousers'],
#  ['double-breasted wool blend coat',
#   'double-breasted check coat',
#   'double-breasted check coat',
#   'double-breasted knit coat',
#   'double-breasted knit coat',
#   'checked double-breasted coat',
#   'double breasted wool blend coat',
#   'double-breasted linen coat',
#   'check double-breasted coat',
#   'double-breasted faux fur coat'],
#  ['a geometric print flat sheet',
#   'a geometric print flat sheet',
#   'printed flat sheet',
#   'flat sheet',
#   'geometric printed flat sheet',
#   'geometric printed flat sheet',
#   'geometric printed flat sheet',
#   'geometric printed flat sheet',
#   'geometric printed flat sheet',
#   'print flat sheet'],
#  ['double-faced printed blouse',
#   'contrast printed blouse',
#   'contrast printed blouse',
#   'contrast printed blouse',
#   'printed blouse',
#   'printed blouse',
#   'combined printed blouse',
#   'contrast check blouse',
#   'contrast check blouse',
#   'contrast check blouse'],
#  ['combined denim jacket',
#   'printed denim jacket',
#   'check denim jacket',
#   'check denim jacket',
#   'contrast faux shearling denim jacket',
#   'ripped denim bomber jacket',
#   'straight-fit denim jacket',
#   'checked denim jacket',
#   'acid wash denim jacket',
#   'straight fit denim jacket'],
#  ['double-faced leather crossbody bag',
#   'double-faced leather crossbody bag',
#   'tuxedo style leather crossbody bag',
#   'faux leather crossbody bag',
#   'faux leather crossbody bag',
#   'faux leather crossbody bag',
#   'thick leather crossbody bag',
#   'burgundy faux leather crossbody bag',
#   'leather crossbody bag',
#   'leather crossbody bag'],
#  ['crochet hook with number 2.',
#   'crochet hook with number 2.',
#   'ceramic hook with no 2.',
#   'black ceramic hook',
#   'black ceramic hook',
#   'black ceramic hook',
#   'monochrome ceramic hook',
#   'crochet number 2.',
#   'crochet number 2.',
#   'black hook'],
#  ['check trousers',
#   'check trousers',
#   'check trousers',
#   'check trousers',
#   'printed trousers',
#   'printed trousers',
#   'printed trousers',
#   'printed trousers',
#   'rustic trousers',
#   'rustic trousers'],
#  ['mickey mouse ©disney reversible puffer coat',
#   'hooded mickey mouse ©disney puffer coat',
#   'mickey mouse ©disney pouch pocket puffer coat',
#   'mickey mouse ©disney patch puffer coat',
#   'mickey mouse ©disney snow puffer coat',
#   'mickey mouse ©disney puffer coat limited edition',
#   'mickey mouse ©disney colour block puffer coat',
#   'mickey mouse ©disney faux leather puffer coat',
#   'mickey mouse ©disney tracksuit puffer coat',
#   'mickey mouse ©disney lightweight puffer coat'],
#  ['printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'printed dress',
#   'paisley print dress',
#   'printed shirt dress',
#   'printed shirt dress',
#   'printed shirt dress',
#   'printed shirt dress'],
#  ['monochrome card holder',
#   'monochrome card holder',
#   'monochrome card holder',
#   'double-faced card holder',
#   'monochrome silver card holder',
#   'double-faced silver card holder',
#   'metallic card holder',
#   'metallic card holder',
#   'metallic card holder',
#   'metallic card holder'],
#  ['printed dress',
#   'printed dress',
#   'printed dress',
#   'balloon sleeve dress',
#   'full sleeve dress',
#   'voluminous printed dress',
#   'voluminous printed dress',
#   'voluminous printed dress',
#   'sleeveless dress',
#   'sleeveless dress'],
#  ['water-reversible padded snow jumpsuit',
#   'padded snow jumpsuit - limited edition',
#   'faux leather padded snow jumpsuit',
#   'faux snow jumpsuit',
#   'lightweight padded snow jumpsuit',
#   'lightweight padded snow jumpsuit',
#   'pineapple print snow jumpsuit',
#   'printed snow jumpsuit',
#   'printed snow jumpsuit',
#   'waterproof padded snow jumpsuit'],
#  ['limited edition interwoven crossbody clutch',
#   'faux leather clutch bag',
#   'multicoloured crossbody clutch bag',
#   'geometric print clutch bag',
#   'geometric print clutch bag',
#   'interwoven crossbody clutch bag',
#   'interwoven crossbody clutch bag',
#   'interwoven crossbody clutch bag',
#   'printed clutch bag',
#   'triangular crossbody clutch bag'],
#  ['soft leather ankle boots.',
#   'soft leather lace-up ankle boots',
#   'soft leather lace-up ankle boots',
#   'leather lace-up ankle boots',
#   'soft leather high-heel ankle boots',
#   'soft leather high-heel ankle boots',
#   'soft leather high-heel ankle boots',
#   'soft leather double-heel ankle boots',
#   'soft leather mountain-style ankle boots',
#   'soft™ suede heeled ankle boots'],
#  ['waffle-knit towel (pack of 2).',
#   'waffle-knit towel (pack of 2).',
#   'towel with 100% cotton waffle-knit',
#   'cotton waffle-knit towel (pack of 2).',
#   'cotton waffle-knit towel (pack of 2).',
#   'waffle knit towel (pack of 2).',
#   'cotton waffle knit towel (pack of 2).',
#   'c cotton waffle-knit towel (pack of 2).',
#   'waffle-knit towel (2.300)',
#   'cotton waffle-knit towel (set of 2)'],
#  ['rustic striped jumpsuit',
#   'rustic cotton jumpsuit',
#   'faux leather jumpsuit',
#   'faux leather jumpsuit',
#   'rustic snow jumpsuit',
#   'rustic button-up jumpsuit',
#   'printed jumpsuit',
#   'rustic denim jumpsuit',
#   'rustic denim jumpsuit',
#   'rustic buttoned jumpsuit'],
#  ['flat leather lace-up boots',
#   'rounded leather boots',
#   'rounded leather boots',
#   'flat leather boot',
#   'leather rounded-toe flat boots',
#   'rounded flat leather boots',
#   'lace-up flat leather boots',
#   'lace-up flat leather boots',
#   'flat leather chelsea boots',
#   'flat leather rounded-toe boots'],
#  ['printed shirt set',
#   'printed shirt set',
#   'printed shirt and baby bloomers',
#   'floral print set',
#   'embroidered floral print set',
#   'embroidered floral print set',
#   'embroidered floral print shirt set',
#   'embroidered check shirt set',
#   'floral print shirt set',
#   'floral print shirt set'],
#  ['printed skirt',
#   'check skirt',
#   'printed midi skirt',
#   'faux leather midi skirt',
#   'faux leather midi skirt',
#   'faux leather skirt',
#   'faux leather skirt',
#   'faded-effect mini skirt',
#   'acid wash denim midi skirt',
#   'floral print skirt'],
#  ['mug with geometric design',
#   'mug with geometric design',
#   'mug with geometric design',
#   'mug with geometric design',
#   'mug with geometric design',
#   'mug with geometric design',
#   'mug with geometric designs',
#   'mug with geometric designs',
#   'mug with geometric shape',
#   'mug with geometric shape'],
#  ['printed ribbed t-shirt',
#   'printed ribbed t-shirt',
#   'ribbed high neck t-shirt',
#   'ribbed high neck t-shirt',
#   'printed t-shirt',
#   'faux leather ribbed t-shirt',
#   'cable-knit t-shirt',
#   'double-faced t-shirt',
#   'check ribbed t-shirt',
#   'ribbed snowboard t-shirt'],
#  ['asymmetric crop top',
#   'asymmetric crop top',
#   'asymmetric crop top',
#   'asymmetric neckline top',
#   'asymmetric neckline top',
#   'asymmetric top with fringing',
#   'asymmetric top',
#   'asymmetric top',
#   'asymmetric top',
#   'asymmetric contrast top'],
#  ['quilted border crossbody bag',
#   'combined quilted crossbody bag',
#   'quilted mesh crossbody bag',
#   'quilted fabric - limited edition crossbody bag',
#   'quilted fabric crossbody bag - limited edition',
#   'quilted mini crossbody bag',
#   'quilted mini crossbody bag',
#   'quilted metallic crossbody bag',
#   'black quilted crossbody bag',
#   'quilted - herringbone crossbody bag'],
#  ['contrast sneakers',
#   'contrast sneakers',
#   'contrast sneakers',
#   'contrast sneakers',
#   'white chunky sole sneakers',
#   'monochrome sneakers',
#   'black chunky sole sneakers',
#   'black technical sneakers',
#   'white lace-up sneakers',
#   'black faux leather sneakers']]

# %%
from ranker import majority_ranking

majority_ranked_proposals = majority_ranking(combine_proposals(val.iloc[:sample]))

# %%
from model import dcg

print(f"DCG majority ranked = {dcg(majority_ranked_proposals, val['name'][:sample])}")
print(f"DCG s-transformers  = {dcg(ranked_proposals, val['name'][:sample])}")
# Out:
# DCG majority ranked = 21.259635900581586
# DCG s-transformers  = 4.003598325126213
